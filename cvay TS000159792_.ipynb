# %%
import pandas as pd
import numpy as np

# %%
#vf1=pd.read_csv('/home/jlhb1984/py-projects/data/COMERCIALIZADORA VICTOR ALVAREZ Y CIA S A S TS000159792/TRM255.csv',sep=';',encoding='latin1')
#vf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  205 non-null    object
#  1   Message  205 non-null    object
#  2   Status   205 non-null    object
# dtypes: object(3)
# memory usage: 4.9+ KB

# %%
vf1=pd.read_csv('/home/jlhb1984/py-projects/data/COMERCIALIZADORA VICTOR ALVAREZ Y CIA S A S TS000159792/TRM255 - copia.csv',sep=';',encoding='latin1')
vf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  182 non-null    object
#  1   Message  182 non-null    object
#  2   Status   182 non-null    object
# dtypes: object(3)
# memory usage: 4.4+ KB

# %%
vf1m=pd.read_csv('/home/jlhb1984/py-projects/data/COMERCIALIZADORA VICTOR ALVAREZ Y CIA S A S TS000159792/TRM255m - copia.csv',sep=';',encoding='latin1')
vf1m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 68 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      182 non-null    object
#  1   Unnamed: 1   182 non-null    object
#  2   Unnamed: 2   182 non-null    object
#  3   Unnamed: 3   182 non-null    object
#  4   Unnamed: 4   182 non-null    object
#  5   Unnamed: 5   182 non-null    object
#  6   Unnamed: 6   182 non-null    object
#  7   Unnamed: 7   182 non-null    object
#  8   Unnamed: 8   182 non-null    object
#  9   Unnamed: 9   182 non-null    object
#  10  Unnamed: 10  182 non-null    object
#  11  Unnamed: 11  182 non-null    object
#  12  Unnamed: 12  182 non-null    object
#  13  Unnamed: 13  182 non-null    object
#  14  Unnamed: 14  182 non-null    object
#  15  Unnamed: 15  182 non-null    object
#  16  Unnamed: 16  182 non-null    object
#  17  Unnamed: 17  182 non-null    object
# ...

# %%
vf1m['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              89
# {"notificationType":"CameraRunningInfo"     41
# {"notificationType":"AutoSnapshot"          27
# {"notificationType":"IgnitionStatus"        14
# {"notificationType":"CameraEvent"            7
# {"notificationType":"MaintenanceWarning"     3
# {"notificationType":"DataUsage"              1
# Name: count, dtype: int64

# %%
vf_camera_events=vf1m[vf1m['Message'].str.contains('CameraEvent')]
vf_camera_events.head(5)
# Out:
#                               Message     Unnamed: 1  \
# 11  {"notificationType":"CameraEvent"  sn:"6B3101F7"
# 22  {"notificationType":"CameraEvent"  sn:"6B3101F7"
# 38  {"notificationType":"CameraEvent"  sn:"6B3101F7"
# 52  {"notificationType":"CameraEvent"  sn:"6B3101F7"
# 76  {"notificationType":"CameraEvent"  sn:"6B3101F7"
#
#                                        Unnamed: 2    Unnamed: 3  \
# 11  tripID:"3e69dc3b-e40b-4cdb-a922-f7a9cdbb6b8b"  vehicleID:""
# 22  tripID:"3e69dc3b-e40b-4cdb-a922-f7a9cdbb6b8b"  vehicleID:""
# 38  tripID:"3e69dc3b-e40b-4cdb-a922-f7a9cdbb6b8b"  vehicleID:""
# 52  tripID:"3e69dc3b-e40b-4cdb-a922-f7a9cdbb6b8b"  vehicleID:""
# 76  tripID:"8060befc-a8fc-4755-8c5e-12be02c03908"  vehicleID:""
#
#                            Unnamed: 4                         Unnamed: 5  \
# 11                event:"NO_SEATBELT"                eventCategory:"DMS"
# 22                event:"NO_SEATBELT"                eventCategory:"DMS"
# ...

# %%
vf_camera_events_filtered=vf_camera_events[['Unnamed: 4','Unnamed: 5','Unnamed: 6']]
vf_camera_events_filtered['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"NO_SEATBELT"                  3
# event:"USING_PHONE"                  3
# event:"FORWARD_COLLISION_WARNING"    1
# Name: count, dtype: int64

# %%
vf_camera_events_filtered['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"DMS"                  6
# eventCategory:"FORWARD_COLLISION"    1
# Name: count, dtype: int64

# %%
vf_camera_events_filtered['Unnamed: 6'].value_counts()
# Out:
# Unnamed: 6
# eventLevel:"DEFAULT"    6
# eventLevel:"WARNING"    1
# Name: count, dtype: int64
