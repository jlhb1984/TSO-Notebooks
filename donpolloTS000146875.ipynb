# %%
import pandas as pd
import numpy as np

# %%
aeu7340108=pd.read_csv('/home/jlhb1984/py-projects/data/donpollo/aeu734.csv',sep=';',encoding='latin1')
aeu7340108.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     443 non-null    int64
#  1   Unit         443 non-null    object
#  2   Events       443 non-null    object
#  3   Date         443 non-null    object
#  4   Landmark     49 non-null     object
#  5   Address      443 non-null    object
#  6   Speed        443 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       443 non-null    object
#  9   Latitude     443 non-null    float64
#  10  Longitude    443 non-null    float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 38.2+ KB

# %%
aeu7340108['Events'].value_counts()
# Out:
# Events
# Towing/Drifting?    201
# Drive                69
# Travel Stop          38
# Travel Start         38
# Parked               29
# Geofence IN          15
# Geofence OUT         14
# Alta velocidad        9
# End Speeding          8
# Landmark OUT          7
# POWER UP              6
# Landmark IN           3
# Input 2 ON            2
# Input 2 OFF           2
# PÁNICO                2
# Name: count, dtype: int64

# %%
aeu734_drive=aeu7340108[aeu7340108['Events'].str.contains('Drive')]
aeu734_drive.describe()
aeu734_drive.to_csv('/home/jlhb1984/py-projects/data/donpollo/aeu734_drive.csv')
aeu734_drive_dates=aeu734_drive[aeu734_drive['Date'].str.contains('Aug 04')]
aeu734_drive_dates
# Out:
#      Sequence     Unit Events                  Date  \
# 1         442  AEU-734  Drive  Aug 04 2025 11:51 PM
# 9         434  AEU-734  Drive  Aug 04 2025 11:43 PM
# 34        409  AEU-734  Drive  Aug 04 2025 11:08 PM
# 40        403  AEU-734  Drive  Aug 04 2025 10:33 PM
# 41        402  AEU-734  Drive  Aug 04 2025 10:32 PM
# 44        399  AEU-734  Drive  Aug 04 2025 10:26 PM
# 45        398  AEU-734  Drive  Aug 04 2025 10:24 PM
# 46        397  AEU-734  Drive  Aug 04 2025 10:22 PM
# 47        396  AEU-734  Drive  Aug 04 2025 10:20 PM
# 48        395  AEU-734  Drive  Aug 04 2025 10:20 PM
# 49        394  AEU-734  Drive  Aug 04 2025 10:19 PM
# 50        393  AEU-734  Drive  Aug 04 2025 10:18 PM
# 51        392  AEU-734  Drive  Aug 04 2025 10:18 PM
# 52        391  AEU-734  Drive  Aug 04 2025 10:18 PM
# 53        390  AEU-734  Drive  Aug 04 2025 10:16 PM
# 54        389  AEU-734  Drive  Aug 04 2025 10:14 PM
# 55        388  AEU-734  Drive  Aug 04 2025 10:13 PM
# ...

# %% [markdown]
# Análisis después de corrección de desarrollo

# %%
rdu082025=pd.read_csv('/home/jlhb1984/py-projects/data/donpollo/Travels_Daily_Summary_Unified_0825.csv')
rdu082025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5177 entries, 0 to 5176
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UnitName         5177 non-null   object
#  1   DayDate          5177 non-null   object
#  2   Decelerations    5177 non-null   int64
#  3   Accelerations    5177 non-null   int64
#  4   HarshTurns       5177 non-null   int64
#  5   DistanceDriven1  5177 non-null   object
#  6   DriveTime        5177 non-null   object
#  7   OffTime          5177 non-null   object
#  8   IdleTime         5177 non-null   object
#  9   Textbox17        5177 non-null   object
#  10  MaxSpeed         5177 non-null   object
#  11  DriverName       2382 non-null   object
#  12  GroupName        4588 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 525.9+ KB

# %%
rdu082025_off=rdu082025[rdu082025['OffTime'].str.contains('-')]
rdu082025_off
# Out:
#      UnitName     DayDate  Decelerations  Accelerations  HarshTurns  \
# 696   BCY-928  15/08/2025              0              0           0
# 1326  BFM-768  25/08/2025              0              0           0
# 1461  BTW-833   5/08/2025              0              0           0
# 1479  BTW-833  23/08/2025              0              0           0
# 1485  BTW-833  29/08/2025              0              0           0
# 3789  C0T-903   8/08/2025              0              0           0
#
#      DistanceDriven1 DriveTime     OffTime   IdleTime  Textbox17 MaxSpeed  \
# 696             0,00   0:00:00  -215:28:18  238:31:42  238:31:42    0 kph
# 1326            0,00   0:00:00   -48:14:49   71:45:11   71:45:11    0 kph
# 1461            0,81   0:02:07   -12:12:36   35:45:17   35:47:24   10 kph
# 1479           65,47   1:09:24    -6:56:20   27:54:16   29:03:40   80 kph
# 1485            0,24   0:00:45    -3:00:51   26:58:24   26:59:09   13 kph
# ...

# %% [markdown]
# BCY-928, script 55.182, Firmware 85f

# %%
hlBCY_928=pd.read_csv('/home/jlhb1984/py-projects/data/donpollo/historicallocationsBCY_928.csv',sep=';',encoding='latin1')
hlBCY_928.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     3340 non-null   int64
#  1   Unit         3340 non-null   object
#  2   Events       3340 non-null   object
#  3   Date         3340 non-null   object
#  4   Landmark     725 non-null    object
#  5   Address      3338 non-null   object
#  6   Speed        3340 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       3340 non-null   object
#  9   Latitude     3340 non-null   float64
#  10  Longitude    3340 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 287.2+ KB

# %%
hlBCY_928['Events'].value_counts()
# Out:
# Events
# Drive               1562
# Travel Start         346
# Travel Stop          339
# Idle - Stop          197
# Ignition ON          167
# Ignition OFF         159
# Landmark OUT         143
# Idle Alert           104
# Landmark IN           99
# Parked                91
# POWER UP              41
# Geofence IN           38
# Geofence OUT          38
# Towing/Drifting?      16
# Name: count, dtype: int64

# %%
hlBCY_928.head(5)
# Out:
#    Sequence     Unit        Events                  Date  \
# 0      3340  BCY-928        Parked  Aug 26 2025 03:28 PM
# 1      3339  BCY-928  Landmark OUT  Aug 26 2025 11:28 AM
# 2      3338  BCY-928        Parked  Aug 26 2025 11:28 AM
# 3      3337  BCY-928  Ignition OFF  Aug 26 2025 11:18 AM
# 4      3336  BCY-928   Idle - Stop  Aug 26 2025 11:18 AM
#
#                                   Landmark                 Address  Speed  \
# 0                                      NaN          Gulf of Guinea      0
# 1  Cliente Huicungo 1 (x confirmar nombre)  4MM5+X8 Varillal, Peru      0
# 2  Cliente Huicungo 1 (x confirmar nombre)  4MM5+X8 Varillal, Peru      0
# 3                                      NaN          Gulf of Guinea      0
# 4                                      NaN          Gulf of Guinea      0
#
#    Temperature                Driver  Latitude  Longitude
# 0          NaN  MANUEL, PEZO HIDALGO  0.000000   0.000000
# 1          NaN  MANUEL, PEZO HIDALGO -3.865032 -73.341735
# ...

# %%
hlBCY_928_ignition=hlBCY_928[hlBCY_928['Events'].str.contains('Ignition')]
hlBCY_928_ignition_1508=hlBCY_928_ignition[hlBCY_928_ignition['Date'].str.contains('Aug 15 2025')]
hlBCY_928_ignition_1508_ON=hlBCY_928_ignition[hlBCY_928_ignition['Events'].str.contains('ON')]
hlBCY_928_ignition_1508_ON.to_csv('/home/jlhb1984/py-projects/data/donpollo/historicallocationsBCY_928_ON.csv')

# %%
hlREEFER_V1=pd.read_csv('/home/jlhb1984/py-projects/data/donpollo/REEFER V1.csv',sep=';',encoding='latin1')
hlREEFER_V1['Events'].value_counts()
# Out:
# Events
# Drive                 7060
# Idle Alert            1547
# Travel Start           309
# Travel Stop            308
# Idle - Stop             80
# Harsh Turn              42
# Geofence OUT            21
# Geofence IN             20
# Landmark IN             10
# Speed alert              8
# Landmark OUT             8
# End Speeding             8
# Ignition ON              2
# Harsh Deceleration       1
# POWER UP                 1
# Ignition OFF             1
# Name: count, dtype: int64

# %%
hlREEFER_V1_ignition=hlREEFER_V1[hlREEFER_V1['Events'].str.contains('Ignition')]
hlREEFER_V1_ignition
# Out:
#       Sequence       Unit        Events                  Date Landmark  \
# 9422         4  REEFER V1   Ignition ON  Aug 20 2025 12:14 PM      NaN
# 9424         2  REEFER V1  Ignition OFF  Aug 20 2025 12:13 PM      NaN
# 9425         1  REEFER V1   Ignition ON  Aug 20 2025 12:13 PM      NaN
#
#                                                 Address  Speed Temperature  \
# 9422  FJPV+J75, Vía de Evitamiento, Tarapoto 22200, ...      0     28.13°C
# 9424                     FMV4+XPJ, Tarapoto 22200, Peru      0     28.13°C
# 9425                     FMV4+XPJ, Tarapoto 22200, Peru      0     28.13°C
#
#       Driver  Latitude  Longitude
# 9422     NaN -6.512723 -76.356214
# 9424     NaN -6.505787 -76.343958
# 9425     NaN -6.505787 -76.343958
