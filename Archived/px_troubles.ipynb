# %%
import pandas as pd
import numpy as np

# %%
aaa000=pd.read_csv('/home/jlhb1984/py-projects/data/px_troubles/vehicleTrails_cb8444b0-8fe4-4407-80ac-1c6b76b7d892.csv')
aaa000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unit         99 non-null     object
#  1   Driver       0 non-null      float64
#  2   Event        99 non-null     object
#  3   Lat / Long   99 non-null     object
#  4   Date / Time  99 non-null     object
#  5   Speed        75 non-null     object
#  6   Address      99 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 5.5+ KB

# %%
aaa000['Date / Time'].value_counts()
# Out:
# Date / Time
# Friday, November 14 2025, 08:42:07 am    1
# Friday, November 14 2025, 08:41:45 am    1
# Friday, November 14 2025, 08:40:15 am    1
# Friday, November 14 2025, 08:40:14 am    1
# Friday, November 14 2025, 08:38:52 am    1
#                                         ..
# Friday, November 14 2025, 07:17:21 am    1
# Friday, November 14 2025, 07:17:19 am    1
# Friday, November 14 2025, 07:17:07 am    1
# Friday, November 14 2025, 07:16:41 am    1
# Friday, November 14 2025, 07:15:42 am    1
# Name: count, Length: 99, dtype: int64
