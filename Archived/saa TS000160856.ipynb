# %%
import pandas as pd
import numpy as np

# %% [markdown]
# PM-03 01-09-2025 to 30-09-2025.

# %%
pm03092025_tso=pd.read_csv('/home/jlhb1984/py-projects/data/saa/pm03.csv',sep=';',encoding='latin1')
pm03092025_tso.info()
pm03092025_tso['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3295 entries, 0 to 3294
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     3295 non-null   int64
#  1   Unit         3295 non-null   object
#  2   Events       3295 non-null   object
#  3   Date         3295 non-null   object
#  4   Landmark     2 non-null      object
#  5   Address      3295 non-null   object
#  6   Speed        3295 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     3295 non-null   float64
#  10  Longitude    3295 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 283.3+ KB
# Events
# Idle - Stop         1542
# Drive                931
# Ignition OFF         351
# Ignition ON          351
# Parked               116
# Towing/Drifting?       1
# Panic button           1
# Geofence OUT           1
# Geofence IN            1
# ...

# %%
pm03092025_tso_raw_data=pd.read_csv('/home/jlhb1984/py-projects/data/saa/rawdata_tso_pm03_m.csv',sep=';',encoding='latin1')
pm03092025_tso_raw_data.info()
pm03092025_tso_raw_data['Unnamed: 1'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3381 entries, 0 to 3380
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      3381 non-null   object
#  1   Unnamed: 1   3381 non-null   object
#  2   Unnamed: 2   3381 non-null   object
#  3   Unnamed: 3   3381 non-null   object
#  4   Unnamed: 4   3381 non-null   object
#  5   Unnamed: 5   3381 non-null   object
#  6   Unnamed: 6   3381 non-null   object
#  7   Unnamed: 7   3381 non-null   object
#  8   Unnamed: 8   3381 non-null   object
#  9   Unnamed: 9   3381 non-null   object
#  10  Unnamed: 10  3381 non-null   object
#  11  Unnamed: 11  3372 non-null   object
#  12  Unnamed: 12  3372 non-null   object
#  13  Unnamed: 13  3357 non-null   object
#  14  Unnamed: 14  3357 non-null   object
#  15  Unnamed: 15  3357 non-null   object
#  16  Unnamed: 16  3357 non-null   object
# dtypes: object(17)
# memory usage: 449.2+ KB
# Unnamed: 1
# ...

# %%
pm03092025_px=pd.read_csv('/home/jlhb1984/py-projects/data/saa/trail_pm03.csv')
pm03092025_px.info()
pm03092025_px['Event'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 733 entries, 0 to 732
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unit         733 non-null    object
#  1   Driver       0 non-null      float64
#  2   Event        733 non-null    object
#  3   Lat / Long   733 non-null    object
#  4   Date / Time  733 non-null    object
#  5   Speed        420 non-null    object
#  6   Address      733 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.2+ KB
# Event
# Driving         344
# Ignition Off    143
# Ignition On     141
# Travel Start     55
# Travel Stop      48
# Tow               1
# User Update       1
# Name: count, dtype: int64

# %%
pm03092025_px_raw_data=pd.read_csv('/home/jlhb1984/py-projects/data/saa/rawdata_px_pm03_0925.csv')
pm03092025_px_raw_data.info()
pm03092025_px_raw_data['Event Name'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 733 entries, 0 to 732
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     733 non-null    int64
#  1   Sequence #                 0 non-null      float64
#  2   Account Id                 733 non-null    int64
#  3   Server Time                733 non-null    object
#  4   Unit Time                  733 non-null    object
#  5   Latitude                   733 non-null    float64
#  6   Longitude                  733 non-null    float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 733 non-null    object
#  9   Raw Event                  733 non-null    object
#  10  GPS Speed                  420 non-null    float64
#  11  ECU Speed                  0 non-null      float64
#  12  Address                    733 non-null    object
# ...
