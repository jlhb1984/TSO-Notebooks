# %%
import pandas as pd
import numpy as np

# %%
rio1bzu=pd.read_csv('/home/jlhb1984/py-projects/data/riopaila/1bzu_m.csv',sep=';',encoding='latin1')
rio1bzu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26093 entries, 0 to 26092
# Columns: 116 entries, Message to Unnamed: 115
# dtypes: object(116)
# memory usage: 23.1+ MB
# /tmp/ipykernel_90316/4043357534.py:1: DtypeWarning: Columns (92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   rio1bzu=pd.read_csv('/home/jlhb1984/py-projects/data/riopaila/1bzu_m.csv',sep=';',encoding='latin1')

# %%
raw_data_CameraEvent=rio1bzu[rio1bzu['Message'].str.contains('CameraEvent')]
raw_data_CameraEvent
# Out:
#                                  Message     Unnamed: 1  \
# 28     {"notificationType":"CameraEvent"  sn:"8B5141Q6"
# 59     {"notificationType":"CameraEvent"  sn:"8B5141Q6"
# 63     {"notificationType":"CameraEvent"  sn:"8B5141Q6"
# 68     {"notificationType":"CameraEvent"  sn:"8B5141Q6"
# 84     {"notificationType":"CameraEvent"  sn:"8B5141Q6"
# ...                                  ...            ...
# 18028  {"notificationType":"CameraEvent"  sn:"8B5141Q6"
# 18037  {"notificationType":"CameraEvent"  sn:"8B5141Q6"
# 19700  {"notificationType":"CameraEvent"  sn:"8B5141Q6"
# 22720  {"notificationType":"CameraEvent"  sn:"8B5141Q6"
# 23175  {"notificationType":"CameraEvent"  sn:"8B5141Q6"
#
#                                           Unnamed: 2    Unnamed: 3  \
# 28     tripID:"3b51930d-28c8-4981-a73b-59b1a380509c"  vehicleID:""
# 59     tripID:"3b51930d-28c8-4981-a73b-59b1a380509c"  vehicleID:""
# 63     tripID:"3b51930d-28c8-4981-a73b-59b1a380509c"  vehicleID:""
# ...

# %%
raw_data_CameraEvent['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"STOP_SIGN_VIOLATION"       117
# event:"NO_SEATBELT"                71
# event:"USING_PHONE"                57
# event:"DROWSINESS"                 13
# event:"POTENTIAL_INCIDENT_LOW"      7
# event:"YAWN"                        3
# Name: count, dtype: int64

# %%
raw_data_CameraEvent['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"DMS"                    144
# eventCategory:"STOP_SIGN_VIOLATION"    117
# eventCategory:"POTENTIAL_INCIDENT"       7
# Name: count, dtype: int64

# %%
event_time=raw_data_CameraEvent[raw_data_CameraEvent['Unnamed: 4'].str.contains('NO_SEATBELT')]
event_time['Unnamed: 9']
# Out:
# 28       time:1759280026000
# 84       time:1759284040000
# 226      time:1759304207000
# 283      time:1759308033000
# 324      time:1759310684000
#                 ...
# 16545    time:1761630450000
# 16776    time:1761654370000
# 16903    time:1761666631000
# 17062    time:1761687197000
# 17549    time:1761762692000
# Name: Unnamed: 9, Length: 71, dtype: object

# %%
crm_info=pd.read_csv('/home/jlhb1984/py-projects/data/riopaila/1bzu.csv',sep=';')
crm_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26093 entries, 0 to 26092
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  26093 non-null  object
#  1   Message  26093 non-null  object
#  2   Status   26093 non-null  object
# dtypes: object(3)
# memory usage: 611.7+ KB

# %%
# Out:
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []
