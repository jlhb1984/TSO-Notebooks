# %%
import pandas as pd
import numpy as np

# %%
cfv839=pd.read_csv('/home/jlhb1984/py-projects/data/sakura/cfv-839.csv',sep=';',encoding='latin1')
cfv839.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     76 non-null     int64
#  1   Unit         76 non-null     object
#  2   Events       76 non-null     object
#  3   Date         76 non-null     object
#  4   Landmark     0 non-null      float64
#  5   Address      76 non-null     object
#  6   Speed        76 non-null     int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     76 non-null     float64
#  10  Longitude    76 non-null     float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 6.7+ KB

# %%
cfv839['Events'].value_counts()
# Out:
# Events
# Idle - Stop     50
# Parked           8
# Ignition OFF     7
# Ignition ON      7
# Drive            4
# Name: count, dtype: int64

# %%
cfv839['Speed'].sort_values(ascending=False)
# Out:
# 1     9
# 2     9
# 20    9
# 19    9
# 27    8
#      ..
# 71    0
# 72    0
# 73    0
# 74    0
# 75    0
# Name: Speed, Length: 76, dtype: int64

# %%
cfv839['Speed'].max()
# Out:
# np.int64(9)
