# %%
import pandas as pd
import numpy as np

# %%
a1r3=pd.read_csv('/home/jlhb1984/py-projects/data/amarante/1ar3.csv',sep=';',encoding='latin1')
a1r3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7093 entries, 0 to 7092
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     7093 non-null   int64
#  1   Unit         7093 non-null   object
#  2   Events       7017 non-null   object
#  3   Date         7093 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      7092 non-null   object
#  6   Speed        7093 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     7093 non-null   float64
#  10  Longitude    7093 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 609.7+ KB

# %%
a1r3['Events'].value_counts()
# Out:
# Events
# Parked              6654
# Idle - Stop          266
# Drive                 80
# Start Charging         4
# Power Restored         4
# Battery Warning        3
# Stopped Charging       3
# Power Cut              3
# Name: count, dtype: int64
