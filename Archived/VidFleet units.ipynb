# %%
import pandas as pd
import numpy as np

# %%
raw_data6B301407=pd.read_csv('/home/jlhb1984/py-projects/data/VidFleet_units/6B301407.csv')
raw_data6B301407.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  364 non-null    object
#  1   Message  364 non-null    object
#  2   Status   364 non-null    object
# dtypes: object(3)
# memory usage: 8.7+ KB

# %%
raw_data6B301407_CameraEvent=raw_data6B301407[raw_data6B301407['Message'].str.contains('CameraEvent')]
raw_data6B301407_CameraEvent.info()
raw_data6B301407_CameraEvent
#raw_data6B301407_CameraEvent['Message']
#raw_data6B301407_CameraEvent.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/VidFleet raw data/6B301407_CameraEvent.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 7 to 292
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  12 non-null     object
#  1   Message  12 non-null     object
#  2   Status   12 non-null     object
# dtypes: object(3)
# memory usage: 384.0+ bytes
#                      Created  \
# 7    2025-05-21 09:52:05.394
# 12   2025-05-21 09:52:51.595
# 18   2025-05-21 10:21:57.147
# 49   2025-05-21 11:00:51.320
# 109  2025-05-21 12:24:57.190
# 117  2025-05-21 21:24:53.054
# 247  2025-05-22 00:15:24.681
# 255  2025-05-22 00:40:34.186
# 261  2025-05-22 00:47:47.568
# 267  2025-05-22 10:02:17.204
# 276  2025-05-22 10:08:54.146
# 292  2025-05-22 10:36:32.067
#
#                                                Message  \
# 7    {"notificationType":"CameraEvent","sn":"6B3014...
# 12   {"notificationType":"CameraEvent","sn":"6B3014...
# 18   {"notificationType":"CameraEvent","sn":"6B3014...
# ...

# %%
crm_units=pd.read_csv('/home/jlhb1984/py-projects/data/VidFleet_units/CRM.csv')
#crm_units.info()
#crm_units.head(2)
crm_units_vf=crm_units[crm_units['UnitType'].str.contains('Fleet')]
crm_units_vf.info()
crm_units_vf_2025=crm_units_vf[crm_units_vf['LastContactOn'].str.contains('2025')]
crm_units_vf_2025_05=crm_units_vf_2025[crm_units_vf_2025['LastContactOn'].str.contains('5/29')]
crm_units_vf_2025_05_report=crm_units_vf_2025_05.sort_values(['LastContactOn'],ascending=False)
crm_units_vf_2025_05_report.head(22)
crm_units_vf_2025_05_report.to_csv('/home/jlhb1984/py-projects/data/VidFleet_units/vfreport.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 967 entries, 3 to 25516
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Dealer                967 non-null    object
#  1   Company1              967 non-null    object
#  2   FEIN                  943 non-null    object
#  3   DNI                   269 non-null    object
#  4   Peripherals           967 non-null    object
#  5   ServiceName           905 non-null    object
#  6   IsRenting             967 non-null    object
#  7   UnitID1               967 non-null    object
#  8   ShortName             967 non-null    object
#  9   UnitType              967 non-null    object
#  10  Carrier               759 non-null    object
#  11  MonthlyFee            967 non-null    float64
#  12  BillingGroup          111 non-null    object
#  13  BillingPeriod         944 non-null    object
#  14  LastServicePaidUntil  967 non-null    object
# ...

# %% [markdown]
# ## Video request

# %%
vf6b301418=pd.read_csv('/home/jlhb1984/py-projects/data/VidFleet_units/6B301418.csv')
vf6b301418.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1621 entries, 0 to 1620
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1621 non-null   object
#  1   Message  1621 non-null   object
#  2   Status   1621 non-null   object
# dtypes: object(3)
# memory usage: 38.1+ KB

# %%
vf6b301418_clipid=vf6b301418[vf6b301418['Message'].str.contains('clipID')]
vf6b301418_clipid.info()
vf6b301418_clipid.to_csv('/home/jlhb1984/py-projects/data/VidFleet_units/vf6B301418_clipid.csv')
#vf6b301418_clipid.to_excel('/home/jlhb1984/py-projects/data/VidFleet_units/vf6B301418_clipid.xls')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 3 to 1613
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  34 non-null     object
#  1   Message  34 non-null     object
#  2   Status   34 non-null     object
# dtypes: object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# Problemas de excesos de velocidad overspeed

# %% [markdown]
# BKR-828 VF

# %%
bkr828vf=pd.read_csv('/home/jlhb1984/py-projects/data/VidFleet_units/bkr828.csv',sep=';',encoding='latin1')
bkr828vf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1242 entries, 0 to 1241
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     1242 non-null   int64
#  1   Unit         1242 non-null   object
#  2   Events       1238 non-null   object
#  3   Date         1242 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      1242 non-null   object
#  6   Speed        1242 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     1242 non-null   float64
#  10  Longitude    1242 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 106.9+ KB

# %%
cont=0
for i in range(0,1242):
    if bkr828vf.iloc[i,6]>45:
        #print(bkr828vf.loc[i])
        print(bkr828vf.iloc[i,6])
        cont=cont+1
print('Se encontró ', cont,'excesos de velocidad!')
# Out:
# 49
# 48
# 51
# 53
# 53
# 51
# 57
# 64
# 48
# 61
# 48
# 59
# 59
# 56
# 53
# 56
# 56
# 53
# 49
# 49
# 46
# 62
# 48
# 70
# 54
# 74
# 48
# 49
# 49
# 61
# 51
# 53
# 46
# 49
# 59
# 46
# 61
# 48
# 65
# 46
# 64
# 67
# 49
# 57
# 53
# 57
# 57
# 69
# 54
# 67
# 69
# 65
# 69
# 67
# 67
# 67
# 62
# 62
# 62
# 69
# 61
# 65
# 67
# 53
# 64
# 69
# 62
# 65
# 67
# 64
# 46
# 65
# 70
# 62
# 67
# 62
# 62
# 61
# 72
# 62
# 67
# 62
# 54
# 67
# 65
# 67
# 54
# 64
# 64
# 54
# 67
# 57
# 70
# 57
# 62
# 65
# 65
# 61
# 49
# 51
# 59
# 62
# 56
# 49
# 48
# 54
# 59
# 48
# 54
# 59
# 46
# 53
# 51
# 46
# 51
# 49
# 53
# 46
# 46
# 53
# 70
# 51
# 69
# 62
# 59
# 67
# 59
# 57
# 53
# 53
# 48
# 46
# 48
# 56
# 62
# 51
# 51
# 46
# 48
# 64
# 48
# 57
# 46
# 53
# 51
# 46
# 65
# 72
# 57
# 57
# 65
# 57
# 53
# 46
# 62
# 54
# 57
# 57
# 46
# 53
# 61
# 48
# 48
# 53
# 48
# 46
# 57
# 57
# 57
# 67
# 69
# 69
# 61
# 61
# 57
# 49
# 54
# 53
# 51
# 51
# 51
# 46
# 46
# 59
# 57
# 59
# 62
# 56
# 53
# 56
# 62
# 62
# 57
# 54
# 57
# 64
# 48
# 48
# 67
# 59
# ...

# %% [markdown]
# Baja cantidad de eventos DMS

# %% [markdown]
# air2_8B514WL entre 18-09-2025 a 26-09-2025 en CRM (VEO-706) Pasar Express. Le aumenté la sensibilidad.

# %%
air2_8B514WL=pd.read_csv('/home/jlhb1984/py-projects/data/VidFleet_units/8B5141WL.csv',sep=';',encoding='latin1')
air2_8B514WL
# Out:
#                      Created  \
# 0    2025-09-18 20:32:53.335
# 1    2025-09-18 20:33:00.723
# 2    2025-09-18 20:34:19.686
# 3    2025-09-18 20:34:19.801
# 4    2025-09-18 20:34:25.481
# ..                       ...
# 378  2025-09-26 21:45:29.832
# 379  2025-09-26 21:46:02.646
# 380  2025-09-26 21:46:40.097
# 381  2025-09-26 21:48:51.435
# 382  2025-09-26 21:50:35.778
#
#                                                Message  \
# 0    {"notificationType":"TripInfo","sn":"8B5141WL"...
# 1    {"notificationType":"MaintenanceWarning","sn":...
# 2    {"notificationType":"IgnitionStatus","sn":"8B5...
# 3    {"notificationType":"PowerEvent","sn":"8B5141W...
# 4    {"notificationType":"AutoSnapshot","sn":"8B514...
# ..                                                 ...
# 378  {"notificationType":"DataUsage","sn":"8B5141WL...
# 379  {"notificationType":"CameraEvent","sn":"8B5141...
# 380  {"notificationType":"TripInfo","sn":"8B5141WL"...
# ...

# %%
air2_8B514WL_m=pd.read_csv('/home/jlhb1984/py-projects/data/VidFleet_units/8B5141WL_m.csv',sep=';',encoding='latin1')
air2_8B514WL_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 68 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      383 non-null    object
#  1   Unnamed: 1   383 non-null    object
#  2   Unnamed: 2   383 non-null    object
#  3   Unnamed: 3   383 non-null    object
#  4   Unnamed: 4   383 non-null    object
#  5   Unnamed: 5   383 non-null    object
#  6   Unnamed: 6   383 non-null    object
#  7   Unnamed: 7   383 non-null    object
#  8   Unnamed: 8   383 non-null    object
#  9   Unnamed: 9   383 non-null    object
#  10  Unnamed: 10  383 non-null    object
#  11  Unnamed: 11  383 non-null    object
#  12  Unnamed: 12  383 non-null    object
#  13  Unnamed: 13  383 non-null    object
#  14  Unnamed: 14  383 non-null    object
#  15  Unnamed: 15  380 non-null    object
#  16  Unnamed: 16  380 non-null    object
#  17  Unnamed: 17  380 non-null    object
# ...

# %%
air2_8B514WL_m['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              130
# {"notificationType":"CameraRunningInfo"      73
# {"notificationType":"AutoSnapshot"           68
# {"notificationType":"IgnitionStatus"         53
# {"notificationType":"DataUsage"              35
# {"notificationType":"CameraEvent"            13
# {"notificationType":"MaintenanceWarning"      5
# {"notificationType":"PowerEvent"              3
# {"notificationType":"ParkingHeartbeat"        3
# Name: count, dtype: int64

# %%
air2_8B514WL_camera_events=air2_8B514WL_m[air2_8B514WL_m['Message'].str.contains('CameraEvent')]
air2_8B514WL_camera_events.head(5)
# Out:
#                                Message     Unnamed: 1  \
# 173  {"notificationType":"CameraEvent"  sn:"8B5141WL"
# 176  {"notificationType":"CameraEvent"  sn:"8B5141WL"
# 210  {"notificationType":"CameraEvent"  sn:"8B5141WL"
# 227  {"notificationType":"CameraEvent"  sn:"8B5141WL"
# 234  {"notificationType":"CameraEvent"  sn:"8B5141WL"
#
#                                         Unnamed: 2    Unnamed: 3  \
# 173  tripID:"ef3fc88a-5073-4770-be3f-79b0b53c389e"  vehicleID:""
# 176  tripID:"ef3fc88a-5073-4770-be3f-79b0b53c389e"  vehicleID:""
# 210  tripID:"ef3fc88a-5073-4770-be3f-79b0b53c389e"  vehicleID:""
# 227  tripID:"ef3fc88a-5073-4770-be3f-79b0b53c389e"  vehicleID:""
# 234  tripID:"ef3fc88a-5073-4770-be3f-79b0b53c389e"  vehicleID:""
#
#                          Unnamed: 4                          Unnamed: 5  \
# 173              event:"SHARP_TURN"          eventCategory:"SHARP_TURN"
# 176              event:"SHARP_TURN"          eventCategory:"SHARP_TURN"
# ...

# %% [markdown]
# Eventos:

# %%
air2_8B514WL_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"SHARP_TURN"                      5
# event:"POTENTIAL_INCIDENT_LOW"          4
# event:"NO_SEATBELT"                     2
# event:"HEADWAY_MONITORING_EMERGENCY"    1
# event:"FORWARD_COLLISION_WARNING"       1
# Name: count, dtype: int64

# %% [markdown]
# Categorías:

# %%
air2_8B514WL_camera_events['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"SHARP_TURN"            5
# eventCategory:"POTENTIAL_INCIDENT"    4
# eventCategory:"DMS"                   2
# eventCategory:"HEADWAY_MONITORING"    1
# eventCategory:"FORWARD_COLLISION"     1
# Name: count, dtype: int64

# %% [markdown]
# air2_8B514WL entre 26-09-2025 a 24-10-2025 en pm (VEO-706).

# %%
air2_8B514WL_pm=pd.read_csv('/home/jlhb1984/py-projects/data/VidFleet_units/veo706pm.csv')
air2_8B514WL_pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2639 entries, 0 to 2638
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     2639 non-null   int64
#  1   Sequence #                 0 non-null      float64
#  2   Server Time                2639 non-null   object
#  3   Unit Time                  2639 non-null   object
#  4   Last Message Time          2639 non-null   object
#  5   Latitude                   2639 non-null   float64
#  6   Longitude                  2639 non-null   float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 2639 non-null   object
#  9   Raw Event                  2639 non-null   object
#  10  Address                    2638 non-null   object
#  11  GPS Speed                  2299 non-null   float64
#  12  ECU Speed                  0 non-null      float64
# ...

# %%
air2_8B514WL_pm['Raw Event'].value_counts()
# Out:
# Raw Event
# GpsData.Moving                              1165
# AutoSnapshot                                 670
# IgnitionStatus.parking                       211
# IgnitionStatus.driving                       210
# TravelStart                                  165
# TravelStop                                   162
# CameraEvent.STOP_SIGN_VIOLATION               16
# CameraEvent.NO_SEATBELT                       14
# CameraEvent.HEADWAY_MONITORING_EMERGENCY      13
# CameraEvent.FORWARD_COLLISION_WARNING          4
# CameraEvent.POTENTIAL_INCIDENT_MEDIUM          3
# GpsData.Idling                                 2
# CameraEvent.SHARP_TURN                         2
# CameraEvent.USING_PHONE                        1
# CameraEvent.HARSH_TURN                         1
# Name: count, dtype: int64

# %% [markdown]
# air2JYX459 en pm entre 20-10-2025 a 24-10-2025 Supercarnes, también tiene la sensibilidad aumentada.

# %%
air2jyx459=pd.read_csv('/home/jlhb1984/py-projects/data/VidFleet_units/JYX459_pm.csv')
air2jyx459.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     870 non-null    int64
#  1   Sequence #                 0 non-null      float64
#  2   Server Time                870 non-null    object
#  3   Unit Time                  870 non-null    object
#  4   Last Message Time          870 non-null    object
#  5   Latitude                   870 non-null    float64
#  6   Longitude                  870 non-null    float64
#  7   Driver Name                115 non-null    object
#  8   Event Name                 870 non-null    object
#  9   Raw Event                  870 non-null    object
#  10  Address                    869 non-null    object
#  11  GPS Speed                  841 non-null    float64
#  12  ECU Speed                  0 non-null      float64
# ...

# %%
air2jyx459['Raw Event'].value_counts()
# Out:
# Raw Event
# GpsData.Moving                           410
# AutoSnapshot                             293
# TravelStart                               58
# TravelStop                                56
# IgnitionStatus.driving                    24
# IgnitionStatus.parking                    23
# CameraEvent.STOP_SIGN_VIOLATION            3
# CameraEvent.POTENTIAL_INCIDENT_MEDIUM      1
# GpsData.Idling                             1
# CameraEvent.POWER_LOST                     1
# Name: count, dtype: int64
