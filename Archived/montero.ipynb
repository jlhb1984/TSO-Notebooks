# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## TS000153262

# %% [markdown]
# ## Análisis de geocercas en todas las unidades.

# %%
montero_gio=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/Geofences InOut Report.csv')
montero_gio.info()
montero_gio.sort_values(by=['EventTime'], ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4006 entries, 0 to 4005
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   textbox12       4006 non-null   object
#  1   UnitName        4006 non-null   object
#  2   textbox18       0 non-null      float64
#  3   EventTime       4006 non-null   object
#  4   GeofenceName    4006 non-null   object
#  5   GeofenceEvent1  4006 non-null   object
#  6   Schedule        0 non-null      float64
# dtypes: float64(2), object(5)
# memory usage: 219.2+ KB
#      textbox12     UnitName  textbox18                 EventTime  \
# 2946   Group:   Unit:WHI947        NaN   20/05/2025 9:58:14 a.m.
# 2945   Group:   Unit:WHI947        NaN   20/05/2025 9:57:14 a.m.
# 325    Group:   Unit:SPH808        NaN   20/05/2025 9:54:37 a.m.
# 3914   Group:   Unit:UAO056        NaN   20/05/2025 9:44:57 a.m.
# 2336   Group:   Unit:UAN646        NaN   20/05/2025 9:43:52 a.m.
# ...

# %%
unit_name=montero_gio['UnitName']
unit_name_conts=unit_name.value_counts()
unit_name_conts
# Out:
# UnitName
# Unit:XVU383     193
# Unit:XVO358     185
# Unit:SLP174     176
# Unit:XMB461     169
# Unit:UAN790     153
# Unit:XVN243     150
# Unit:XVO410     147
# Unit:XVP649     146
# Unit:XVO853     145
# Unit:UAR598     143
# Unit:TPQ091     141
# Unit:UAP929     141
# Unit:TKI593     140
# Unit:WHI947     136
# Unit:UAO041     134
# Unit:SJR801     117
# Unit:SRR661     117
# Unit:UAO056     117
# Unit:SRR902     115
# Unit:TNF678     115
# Unit:UAO940     113
# Unit:UAN646     107
# Unit:TPY950     106
# Unit:TPR 078    103
# Unit:UAO890     103
# Unit:SPH808      99
# Unit:UAO861      95
# Unit:UAM325      93
# Unit:SLP442      92
# Unit:XVO856      83
# Unit:UAR494      74
# Unit:UAQ054      38
# Unit:TKI052      20
# Name: count, dtype: int64

# %%
geo_fences=montero_gio['GeofenceName']
geo_fences_conts=geo_fences.value_counts()
geo_fences_conts
# Out:
# GeofenceName
# 4.- Tienda El Tope : cartagena sanfernando cartagena                                                 1036
# 1. Turno de despacho : Calle 34 # 17 231 Cartagena                                                    605
# 5.,- Entrada a Blas de Lezo : cartagena blasdelezo cartagena                                          356
# 7.- Antiguo Peaje Manga : Cartagena manga cartagena                                                   352
# 9.- Olimpica Bocagrande Cra. 3º : cartagena bocagrande cartagena                                      340
# 8.- Parque Espiritu del Manglar : cartagena centro cartagena                                          302
# 2.- Reloj Rodeo : cartagena rodeo cartagena                                                           260
# 12.- Estbas del Bosque. : cartagena bosque cartagena                                                  223
# 6.- Seguro Social : cartagena traversal 54 cartagena                                                  181
# ...

# %% [markdown]
# ## UAR598

# %% [markdown]
# R00A12V03, 0102

# %%
uar_598=montero_gio[montero_gio['UnitName'].str.contains('598')]
uar_598_16_05=uar_598[uar_598['EventTime'].str.contains('18/05')]
uar_598_16_05
# Out:
#     textbox12     UnitName  textbox18                 EventTime  \
# 583   Group:   Unit:UAR598        NaN   18/05/2025 7:31:27 a.m.
# 584   Group:   Unit:UAR598        NaN   18/05/2025 7:31:28 a.m.
# 585   Group:   Unit:UAR598        NaN   18/05/2025 7:32:12 a.m.
# 586   Group:   Unit:UAR598        NaN   18/05/2025 7:33:28 a.m.
# 587   Group:   Unit:UAR598        NaN   18/05/2025 7:34:28 a.m.
# 588   Group:   Unit:UAR598        NaN   18/05/2025 8:55:34 a.m.
# 589   Group:   Unit:UAR598        NaN  18/05/2025 10:45:22 a.m.
# 590   Group:   Unit:UAR598        NaN  18/05/2025 11:28:23 a.m.
# 591   Group:   Unit:UAR598        NaN  18/05/2025 11:28:48 a.m.
# 592   Group:   Unit:UAR598        NaN  18/05/2025 11:56:19 a.m.
# 593   Group:   Unit:UAR598        NaN  18/05/2025 11:57:19 a.m.
# 594   Group:   Unit:UAR598        NaN  18/05/2025 12:57:45 p.m.
# 595   Group:   Unit:UAR598        NaN   18/05/2025 1:01:20 p.m.
# 596   Group:   Unit:UAR598        NaN   18/05/2025 2:40:26 p.m.
# ...

# %%
uar_598_geo_fences=uar_598['GeofenceName']
uar_598_geo_fences_conts=uar_598_geo_fences.value_counts()
uar_598_geo_fences_conts
# Out:
# GeofenceName
# 4.- Tienda El Tope : cartagena sanfernando cartagena                    40
# 5.,- Entrada a Blas de Lezo : cartagena blasdelezo cartagena            18
# 1. Turno de despacho : Calle 34 # 17 231 Cartagena                      17
# 7.- Antiguo Peaje Manga : Cartagena manga cartagena                     17
# 9.- Olimpica Bocagrande Cra. 3º : cartagena bocagrande cartagena        14
# 12.- Estbas del Bosque. : cartagena bosque cartagena                     8
# 8.- Parque Espiritu del Manglar : cartagena centro cartagena             8
# 2.- Reloj Rodeo : cartagena rodeo cartagena                              6
# 6.- Seguro Social : cartagena traversal 54 cartagena                     4
# prueba mon                                                               3
# 3.- Olimpica San Fernando : cartagena sanfernando Cartagena              3
# 10.- Clinica San Jose de Torices : cartagena barrio torice cartagena     2
# ...

# %% [markdown]
# ## Análisis después de configurar la geocerca. Incialmente se hizo circular para GEOID=0, pero se actualizó a poligonal el 15-05-2025. No funcionó la geocerca poligonal, volvió a crearse la circular 17-05-2025.

# %%
raw_data=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/Export.xlsx - Sheet1.csv')
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5116 entries, 0 to 5115
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  5116 non-null   object
#  1   Message  5116 non-null   object
#  2   Status   5116 non-null   object
# dtypes: object(3)
# memory usage: 120.0+ KB

# %%
resp_gtgeo=raw_data[raw_data['Message'].str.contains('RESP:GTGEO')]
resp_gtgeo.to_csv('/home/jlhb1984/py-projects/data/geofences_on_device/resp_gtgeo.csv')
resp_gtgeo
# Out:
#                       Created  \
# 15    2025-05-18 00:10:11.945
# 16    2025-05-18 00:10:35.656
# 31    2025-05-18 00:21:35.940
# 32    2025-05-18 00:21:56.842
# 64    2025-05-18 00:38:02.911
# ...                       ...
# 5050  2025-05-21 16:33:08.349
# 5052  2025-05-21 16:33:17.235
# 5090  2025-05-21 16:53:33.395
# 5094  2025-05-21 16:54:57.871
# 5095  2025-05-21 16:55:09.264
#
#                                                 Message  \
# 15    +RESP:GTGEO,500700,868574042858816,,,11,1,1,10...
# 16    +RESP:GTGEO,500700,868574042858816,,,10,1,1,14...
# 31    +RESP:GTGEO,500700,868574042858816,,,C1,1,1,19...
# 32    +RESP:GTGEO,500700,868574042858816,,,C0,1,1,21...
# 64    +RESP:GTGEO,500700,868574042858816,,,81,1,1,36...
# ...                                                 ...
# 5050  +RESP:GTGEO,500700,868574042858816,,,31,1,1,24...
# 5052  +RESP:GTGEO,500700,868574042858816,,,30,1,1,34...
# 5090  +RESP:GTGEO,500700,868574042858816,,,01,1,1,13...
# ...

# %%
resp_gtpeo=raw_data[raw_data['Message'].str.contains('ACK')]
resp_gtpeo
# Out:
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
resp_gtgin=raw_data[raw_data['Message'].str.contains('GTGIN')]
resp_gtgin
# Out:
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
resp_gtgot=raw_data[raw_data['Message'].str.contains('GTGOT')]
resp_gtgot
# Out:
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
resp_gtfri=raw_data[raw_data['Message'].str.contains('GTFRI')]
resp_gtfri
# Out:
#                       Created  \
# 0     2025-05-18 00:00:05.768
# 1     2025-05-18 00:01:05.159
# 2     2025-05-18 00:02:05.249
# 3     2025-05-18 00:03:06.509
# 4     2025-05-18 00:03:20.953
# ...                       ...
# 5111  2025-05-21 17:05:16.748
# 5112  2025-05-21 17:06:16.770
# 5113  2025-05-21 17:07:16.805
# 5114  2025-05-21 17:08:16.810
# 5115  2025-05-21 17:09:16.813
#
#                                                 Message  \
# 0     +RESP:GTFRI,500700,868574042858816,,,10,1,1,25...
# 1     +RESP:GTFRI,500700,868574042858816,,,10,1,1,21...
# 2     +RESP:GTFRI,500700,868574042858816,,,10,1,1,21...
# 3     +RESP:GTFRI,500700,868574042858816,,,10,1,1,0....
# 4     +RESP:GTFRI,500700,868574042858816,,,11,1,1,18...
# ...                                                 ...
# 5111  +RESP:GTFRI,500700,868574042858816,,,10,1,1,0....
# 5112  +RESP:GTFRI,500700,868574042858816,,,10,1,1,0....
# 5113  +RESP:GTFRI,500700,868574042858816,,,10,1,1,0....
# ...

# %% [markdown]
# ## TPR078

# %%
tpr078=montero_gio[montero_gio['UnitName'].str.contains('078')]
#tpr078_17_05=tpr078[tpr078['EventTime'].str.contains('18/05')]
tpr078
# Out:
#      textbox12      UnitName  textbox18                EventTime  \
# 937    Group:   Unit:TPR 078        NaN  15/05/2025 5:10:40 a.m.
# 938    Group:   Unit:TPR 078        NaN  15/05/2025 5:11:05 a.m.
# 939    Group:   Unit:TPR 078        NaN  15/05/2025 5:55:46 a.m.
# 940    Group:   Unit:TPR 078        NaN  15/05/2025 5:56:46 a.m.
# 941    Group:   Unit:TPR 078        NaN  15/05/2025 7:42:08 a.m.
# ...        ...           ...        ...                      ...
# 1035   Group:   Unit:TPR 078        NaN  20/05/2025 3:24:11 p.m.
# 1036   Group:   Unit:TPR 078        NaN  20/05/2025 3:24:57 p.m.
# 1037   Group:   Unit:TPR 078        NaN  20/05/2025 4:20:12 p.m.
# 1038   Group:   Unit:TPR 078        NaN  20/05/2025 4:21:13 p.m.
# 1039   Group:   Unit:TPR 078        NaN  20/05/2025 4:23:13 p.m.
#
#                                            GeofenceName GeofenceEvent1  \
# 937   12.- Estbas del Bosque. : cartagena bosque car...             IN
# ...

# %%
tpr078_geo_fences=tpr078['GeofenceName']
tpr078_geo_fences_conts=tpr078_geo_fences.value_counts()
tpr078_geo_fences_conts
# Out:
# GeofenceName
# 4.- Tienda El Tope : cartagena sanfernando cartagena                27
# 1. Turno de despacho : Calle 34 # 17 231 Cartagena                  17
# 2.- Reloj Rodeo : cartagena rodeo cartagena                         13
# 5.,- Entrada a Blas de Lezo : cartagena blasdelezo cartagena        11
# 11.- Avenida del Lago : cartagena avenida el lago cartagena         10
# 12.- Estbas del Bosque. : cartagena bosque cartagena                 8
# 9.- Olimpica Bocagrande Cra. 3º : cartagena bocagrande cartagena     8
# 8.- Parque Espiritu del Manglar : cartagena centro cartagena         7
# 7.- Antiguo Peaje Manga : Cartagena manga cartagena                  2
# Name: count, dtype: int64

# %% [markdown]
# ## Hoy 17-05-2025 se envió comando para geocerca poligonal 1. Turno de despacho

# %%
raw_data_TPR078=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/Export.xlsx - Sheet2.csv')
raw_data_TPR078.info()
raw_data_TPR078_GTGEO=raw_data_TPR078[raw_data_TPR078['Message'].str.contains('RESP:GTGEO')]
raw_data_TPR078_GTGEO
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17396 entries, 0 to 17395
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  17396 non-null  object
#  1   Message  17396 non-null  object
#  2   Status   17396 non-null  object
# dtypes: object(3)
# memory usage: 407.8+ KB
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
resp_gtgeo_=raw_data_TPR078[raw_data_TPR078['Message'].str.contains('GTPEO')]
#resp_gtgeo_TPR078.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Geofence on device/resp_gtgeo.csv')
resp_gtgeo_
# Out:
#                       Created  \
# 1224  2025-05-17 21:19:13.050
# 2323  2025-05-19 15:20:06.353
# 2330  2025-05-19 15:24:41.875
# 2371  2025-05-19 15:47:52.096
# 4441  2025-05-20 22:36:55.323
# 4443  2025-05-20 22:37:14.948
# 4450  2025-05-20 22:41:21.048
#
#                                                 Message  \
# 1224  +ACK:GTPEO,500700,868574042857875,,0,FFFF,2025...
# 2323  +ACK:GTPEO,500700,868574042857875,,1,FFFF,2025...
# 2330  +ACK:GTPEO,500700,868574042857875,,1,FFFF,2025...
# 2371  +ACK:GTPEO,500700,868574042857875,,1,FFFF,2025...
# 4441  +ACK:GTPEO,500700,868574042857875,,0,FFFF,2025...
# 4443  +ACK:GTPEO,500700,868574042857875,,1,FFFF,2025...
# 4450  +ACK:GTPEO,500700,868574042857875,,0,FFFF,2025...
#
#                                                  Status
# 1224  0x2B41434B3A475450454F2C3530303730302C38363835...
# 2323  0x2B41434B3A475450454F2C3530303730302C38363835...
# 2330  0x2B41434B3A475450454F2C3530303730302C38363835...
# ...

# %% [markdown]
# Se procedió a crear una geocerca poligonal de 4 coordenadas cerca a Tienda El Tope.
#
# Comando para borrar coordenadas en geocerca 0:
# AT+GTPEO=gv55w,0,0,1,10,,,,,,,,,,,,,,,,,,,,,30,0,0,0,0,0,,,,FFFF$
#
# Comando para borrar coordenadas en geocerca 1:
# AT+GTPEO=gv55w,1,0,1,10,,,,,,,,,,,,,,,,,,,,,30,0,0,0,0,0,,,,FFFF$
#
# Comando para crear una geocerca 0 cuadrada en El Tope (puse GEOID 0 por silas pero en realidad es 6):
# AT+GTPEO=gv55w,0,3,1,4,-75.471595,10.378294,-75.471568,10.378721,-75.471450,10.378599,-75.471490,10.378165,30,0,0,0,0,0,,,,FFFF$

# %% [markdown]
# ## XVU383

# %% [markdown]
# ## XVU383 para pruebas de End Speeding
#
# Se envió AT+GTSPD=gv55w,3,0,10,10,300,0,0,0,0,,,,,,,,,,,,FFFF$ el 23-05-2025 14:26

# %%
xvu383=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/xvu383.csv')
xvu383.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23423 entries, 0 to 23422
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  23423 non-null  object
#  1   Message  23423 non-null  object
#  2   Status   23423 non-null  object
# dtypes: object(3)
# memory usage: 549.1+ KB

# %%
xvu_383_gtspd=xvu383[xvu383['Message'].str.contains('GTSPD')]
xvu_383_gtspd
xvu_383_gtspd.to_csv('/home/jlhb1984/py-projects/data/geofences_on_device/xvu383_gtspd.csv')

# %% [markdown]
# ## LA TORTU GTU922

# %% [markdown]
# Se establece ubicaciones históricas 22-05-2025 a 29-05-2025
# R00A10V09, 102

# %%
gtu922=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hlgtu922.csv',sep=';',encoding='latin1')
gtu922.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9190 entries, 0 to 9189
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     9190 non-null   int64
#  1   Unit         9190 non-null   object
#  2   Events       9190 non-null   object
#  3   Date         9190 non-null   object
#  4   Landmark     939 non-null    object
#  5   Address      9190 non-null   object
#  6   Speed        9190 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       9190 non-null   object
#  9   Latitude     9190 non-null   float64
#  10  Longitude    9190 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 789.9+ KB

# %%
gtu922_addresses=gtu922['Address'].value_counts()
gtu922_addresses
# Out:
# Address
# 13-47 Carrera 6                               491
# 1337 Carrera 6                                349
# Av 50, Manizales, Caldas                      261
# Via Principal, Manizales, Caldas, Colombia    162
# Av 25, Manizales, Caldas                      128
#                                              ...
# Cl67a 40-16, Manizales, Caldas                  1
# Cl67a 40-81, Manizales, Caldas, Colombia        1
# Kr41 67f-23, Manizales, Caldas                  1
# Cl68 41-72, Manizales, Caldas                   1
# Kr42 66c-76, Manizales, Caldas                  1
# Name: count, Length: 3025, dtype: int64

# %%
gtu922['Address'].fillna('Empty',inplace=True)
gtu922
gtu922_landmarks=gtu922[gtu922['Address'].str.contains('Av 50, Manizales, Caldas')]
gtu922_landmarks
# Out:
# /tmp/ipykernel_33721/2425314806.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gtu922['Address'].fillna('Empty',inplace=True)
#       Sequence             Unit Events                  Date Landmark  \
# 1150      8040  LA TORTU GTU922  Drive  Jun 19 2025 10:37 AM      NaN
# 1370      7820  LA TORTU GTU922  Drive  Jun 19 2025 08:56 AM      NaN
# 1371      7819  LA TORTU GTU922  Drive  Jun 19 2025 08:56 AM      NaN
# 1372      7818  LA TORTU GTU922  Drive  Jun 19 2025 08:56 AM      NaN
# ...

# %%
gtu922['Address'].fillna('Empty',inplace=True)
gtu922
gtu922_landmarks=gtu922[gtu922['Address'].str.contains('Cra. 6 #13-47, Villamaría, Caldas, Colombia')]
gtu922_landmarks
# Out:
#       Sequence             Unit       Events                  Date Landmark  \
# 8695       495  LA TORTU GTU922  Idle - Stop  Jun 04 2025 04:04 PM      NaN
# 8696       494  LA TORTU GTU922  Idle - Stop  Jun 04 2025 04:04 PM      NaN
# 8697       493  LA TORTU GTU922  Idle - Stop  Jun 04 2025 04:03 PM      NaN
# 8698       492  LA TORTU GTU922  Idle - Stop  Jun 04 2025 04:02 PM      NaN
# 8699       491  LA TORTU GTU922  Idle - Stop  Jun 04 2025 04:02 PM      NaN
# 8700       490  LA TORTU GTU922  Idle - Stop  Jun 04 2025 04:01 PM      NaN
# 8701       489  LA TORTU GTU922  Idle - Stop  Jun 04 2025 04:01 PM      NaN
# 8702       488  LA TORTU GTU922  Idle - Stop  Jun 04 2025 04:00 PM      NaN
# 8703       487  LA TORTU GTU922  Idle - Stop  Jun 04 2025 03:59 PM      NaN
# 8704       486  LA TORTU GTU922  Idle - Stop  Jun 04 2025 03:58 PM      NaN
# 8705       485  LA TORTU GTU922  Idle - Stop  Jun 04 2025 03:57 PM      NaN
# ...

# %%
gtu922_latitudes=gtu922['Latitude'].value_counts()
gtu922_latitudes
# Out:
# Latitude
# 5.042008    55
# 5.042743    55
# 4.856003    48
# 5.041959    47
# 5.042120    40
#             ..
# 5.058442     1
# 5.055748     1
# 5.055384     1
# 5.055386     1
# 5.064611     1
# Name: count, Length: 6347, dtype: int64

# %%
gtu922_longitude=gtu922['Longitude'].value_counts()
gtu922_longitude
# Out:
# Longitude
# -75.510445    77
# -75.655514    48
# -75.510354    47
# -75.510387    45
# -75.511123    39
#               ..
# -75.509147     1
# -75.506683     1
# -75.505418     1
# -75.503653     1
# -75.522101     1
# Name: count, Length: 6421, dtype: int64

# %% [markdown]
# ## LA TORTU GTU206

# %% [markdown]
# Se establece ubicaciones históricas 22-05-2025 a 29-05-2025
# R00A10V09, 102

# %%
gtu206=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hlgtu206.csv',sep=';',encoding='latin1')
gtu206.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 gtu206=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hlgtu206.csv',sep=';',encoding='latin1')
#       2 gtu206.info()
#
# ...

# %%
gtu206_addresses=gtu206['Address'].value_counts()
gtu206_addresses
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 gtu206_addresses=gtu206['Address'].value_counts()
#       2 gtu206_addresses
#
# NameError: name 'gtu206' is not defined

# %%
gtu206['Address'].fillna('Empty',inplace=True)
gtu206
gtu206_landmarks=gtu206[gtu206['Address'].str.contains('Kr6 13-39, Villamaria, Caldas, Colombia')]
gtu206_landmarks
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 gtu206['Address'].fillna('Empty',inplace=True)
#       2 gtu206
#       3 gtu206_landmarks=gtu206[gtu206['Address'].str.contains('Kr6 13-39, Villamaria, Caldas, Colombia')]
#
# NameError: name 'gtu206' is not defined

# %%
gtu206_gtspd=gtu206[gtu206['Message'].str.contains('GTSPD')]
gtu206_gtspd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 gtu206_gtspd=gtu206[gtu206['Message'].str.contains('GTSPD')]
#       2 gtu206_gtspd
#
# NameError: name 'gtu206' is not defined

# %% [markdown]
# Pruebas GTU922:
# gtu922:5.042872	-75.503047 AT+GTSPD=gv55w,3,0,10,10,300,0,0,0,0,,,,,,,,,,,,FFFF$ el 31-05-2025
# gtu922:AT+GTGEO=gv55w,1,3,-75.51020900,5.04212400,299,0,0,0,0,0,0,0,0,,FFFF$     el 04-06-2025
# gtu922:AT+GTGEO=gv55w,2,3,-75.51037600,5.04197700,310,0,0,0,0,0,0,0,0,,FFFF$
# gtu922:AT+GTGEO=gv55w,1,3,-75.51020900,5.04212400,299,0,0,0,0,0,0,0,0,,FFFF$     el 21-06-2025 10:30am

# %% [markdown]
# Pruebas GTU206:
# gtu206:5.042124,-75.510209 AT+GTGEO=gv55w,0,3,-75.510209,5.042124,100,30,0,0,0,0,0,0,0,,FFFF$ 290520251844
# gtu206: AT+GTSPD=gv55w,3,0,10,10,300,0,0,0,0,,,,,,,,,,,,FFFF$ el 04-06-2025

# %%
gtu922_landmarks=gtu922[gtu922['Address'].str.contains('Av 50, Manizales, Caldas')]

# %% [markdown]
# ## Nuevas pruebas 19062025

# %%
new_gio=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/Geofences InOut Report_19062025.csv')
new_gio.info()
new_gio.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8846 entries, 0 to 8845
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   textbox12       8846 non-null   object
#  1   UnitName        8846 non-null   object
#  2   Textbox3        0 non-null      float64
#  3   EventTime       8846 non-null   object
#  4   GeofenceName    8846 non-null   object
#  5   GeofenceEvent1  8846 non-null   object
#  6   Textbox4        0 non-null      float64
# dtypes: float64(2), object(5)
# memory usage: 483.9+ KB
#   textbox12       UnitName  Textbox3                EventTime  \
# 0   Grupo:   Unidad:SRR902       NaN  31/05/2025 5:41:44 a.m.
# 1   Grupo:   Unidad:SRR902       NaN  31/05/2025 5:42:34 a.m.
# 2   Grupo:   Unidad:SRR902       NaN  31/05/2025 8:09:19 a.m.
# 3   Grupo:   Unidad:SRR902       NaN  31/05/2025 8:44:34 a.m.
# 4   Grupo:   Unidad:SRR902       NaN  31/05/2025 8:45:35 a.m.
#
# ...

# %%
new_gio_geo1=new_gio[new_gio['GeofenceName'].str.contains('Turno')]
new_gio_geo1['UnitName'].value_counts()
# Out:
# UnitName
# Unidad:UAP929     80
# Unidad:XVO856     64
# Unidad:UAN790     62
# Unidad:UAO890     61
# Unidad:XMB461     55
# Unidad:XVO410     50
# Unidad:UAR598     48
# Unidad:XVN243     48
# Unidad:XVO358     46
# Unidad:TNF678     42
# Unidad:TPY950     39
# Unidad:TPQ091     37
# Unidad:XVO853     37
# Unidad:SRR661     37
# Unidad:SPH808     36
# Unidad:SLP174     36
# Unidad:UAN646     35
# Unidad:WHI947     34
# Unidad:TPR 078    33
# Unidad:TKI593     30
# Unidad:UAQ054     29
# Unidad:UAO041     29
# Unidad:UAR494     28
# Unidad:SLP442     28
# Unidad:XVU383     27
# Unidad:UAO056     25
# Unidad:SRR902     23
# Unidad:UAO940     21
# Unidad:UAO861     19
# Unidad:XVP649     18
# Unidad:SJR801     16
# Unidad:UAO586     13
# Unidad:UAM325     10
# Name: count, dtype: int64

# %% [markdown]
# ## UAN790

# %%
uan790_geo1=new_gio_geo1[new_gio_geo1['UnitName'].str.contains('UAN790')]
uan790_geo1.info()
uan790_geo1.sort_values('EventTime')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 3721 to 4088
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   textbox12       62 non-null     object
#  1   UnitName        62 non-null     object
#  2   Textbox3        0 non-null      float64
#  3   EventTime       62 non-null     object
#  4   GeofenceName    62 non-null     object
#  5   GeofenceEvent1  62 non-null     object
#  6   Textbox4        0 non-null      float64
# dtypes: float64(2), object(5)
# memory usage: 3.9+ KB
#      textbox12       UnitName  Textbox3                 EventTime  \
# 3927   Grupo:   Unidad:UAN790       NaN  10/06/2025 12:47:07 p.m.
# 3928   Grupo:   Unidad:UAN790       NaN   10/06/2025 1:13:54 p.m.
# 3910   Grupo:   Unidad:UAN790       NaN   10/06/2025 5:10:58 a.m.
# 3911   Grupo:   Unidad:UAN790       NaN   10/06/2025 5:24:58 a.m.
# 3921   Grupo:   Unidad:UAN790       NaN   10/06/2025 8:49:57 a.m.
# ...

# %% [markdown]
# ## UAR598

# %% [markdown]
# 19-06-2025

# %%
raw_data_uar598=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/raw_data_uar598.csv',sep=';',encoding='latin1')
raw_data_uar598.info()
raw_data_uar598_gtgeo=raw_data_uar598[raw_data_uar598['Message'].str.contains('ACK')]
raw_data_uar598_gtgeo
#raw_data_uar598_gtgeo['Created'].sort_values(ascending=False)
#report=raw_data_uar598_gtgeo[raw_data_uar598_gtgeo['Created'].str.contains('2025-06-18')]
#report
#report.to_csv('/home/jlhb1984/py-projects/data/geofences_on_device/reportgtgeo_uar598.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28055 entries, 0 to 28054
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  28055 non-null  object
#  1   Message  28055 non-null  object
#  2   Status   28055 non-null  object
# dtypes: object(3)
# memory usage: 657.7+ KB
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
hluar598=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hluar598.csv',sep=';',encoding='latin1')
hluar598.info()
hluar598.fillna('Nan',inplace=True)
hluar598_gtgeo_1=hluar598[hluar598['Pt. Referencia'].str.contains('Turno')]
hluar598_gtgeo_1.info()
hluar598_gtgeo_1.head(25)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26516 entries, 0 to 26515
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Secuencia       26516 non-null  int64
#  1   Unidad          26516 non-null  object
#  2   Eventos         26516 non-null  object
#  3   Fecha           26516 non-null  object
#  4   Pt. Referencia  5251 non-null   object
#  5   Dirección       26516 non-null  object
#  6   Velocidad       26516 non-null  int64
#  7   Temperatura     0 non-null      float64
#  8   Conductor       26516 non-null  object
#  9   Latitud         26516 non-null  float64
#  10  Longitud        26516 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 2.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 1467 to 26392
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
# ...

# %%
uar598_new_rd=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/uar598_new_rd.csv',sep=';',encoding='latin1')
uar598_new_rd.info()
uar598_new_rd_gtgeo=uar598_new_rd[uar598_new_rd['Message'].str.contains('ACK:GTGEO')]
uar598_new_rd_gtgeo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72211 entries, 0 to 72210
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  72211 non-null  object
#  1   Message  72211 non-null  object
#  2   Status   72211 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB
#                        Created  \
# 8187   2025-05-09 15:58:54.812
# 11076  2025-05-11 13:00:53.592
# 20725  2025-05-17 16:53:22.136
# 20729  2025-05-17 16:55:03.623
# 20734  2025-05-17 16:56:25.358
# 20742  2025-05-17 16:58:45.267
# 20743  2025-05-17 16:58:45.827
# 20744  2025-05-17 16:58:46.310
# 20745  2025-05-17 16:58:46.928
# 20746  2025-05-17 16:58:47.548
# 20747  2025-05-17 16:58:48.089
# 20748  2025-05-17 16:58:48.609
# 20749  2025-05-17 16:58:49.150
# 20779  2025-05-17 17:12:31.088
# 20780  2025-05-17 17:12:51.429
# 20784  2025-05-17 17:14:11.813
# 21243  2025-05-17 21:39:32.439
# 21249  2025-05-17 21:42:13.169
# ...

# %%
raw_data_uan790=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/raw_data_uan790.csv',sep=';',encoding='latin1')
raw_data_uan790.info()
raw_data_uan790_gtgeo=raw_data_uan790[raw_data_uan790['Message'].str.contains('GTGEO')]
raw_data_uan790_gtgeo.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2978 entries, 0 to 2977
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  2978 non-null   object
#  1   Message  2978 non-null   object
#  2   Status   2978 non-null   object
# dtypes: object(3)
# memory usage: 69.9+ KB
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
raw_data_sjr801=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/raw_data_sjr801.csv',sep=';',encoding='latin1')
raw_data_sjr801.info()
raw_data_sjr801_gtgeo=raw_data_sjr801[raw_data_sjr801['Message'].str.contains('GTGEO')]
raw_data_sjr801_gtgeo.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20729 entries, 0 to 20728
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  20729 non-null  object
#  1   Message  20729 non-null  object
#  2   Status   20729 non-null  object
# dtypes: object(3)
# memory usage: 486.0+ KB
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
raw_data_slp442=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/raw_data_slp442.csv',sep=';',encoding='latin1')
raw_data_slp442.info()
raw_data_slp442_gtgeo=raw_data_slp442[raw_data_slp442['Message'].str.contains('GTGEO')]
raw_data_slp442_gtgeo.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19732 entries, 0 to 19731
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  19732 non-null  object
#  1   Message  19732 non-null  object
#  2   Status   19732 non-null  object
# dtypes: object(3)
# memory usage: 462.6+ KB
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
raw_data_sph808=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/raw_data_sph808.csv',sep=';',encoding='latin1')
raw_data_sph808.info()
raw_data_sph808_gtgeo=raw_data_sph808[raw_data_sph808['Message'].str.contains('GTGEO')]
raw_data_sph808_gtgeo.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22748 entries, 0 to 22747
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  22748 non-null  object
#  1   Message  22748 non-null  object
#  2   Status   22748 non-null  object
# dtypes: object(3)
# memory usage: 533.3+ KB
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
raw_data_spr902=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/raw_data_sph808.csv',sep=';',encoding='latin1')
raw_data_spr902.info()
raw_data_spr902_gtgeo=raw_data_spr902[raw_data_sph808['Message'].str.contains('GTGEO')]
raw_data_spr902_gtgeo.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22748 entries, 0 to 22747
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  22748 non-null  object
#  1   Message  22748 non-null  object
#  2   Status   22748 non-null  object
# dtypes: object(3)
# memory usage: 533.3+ KB
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %% [markdown]
# ## Nuevas pruebas GTU922. 21-06-2025.

# %%
gtu922_210625=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/gtu922.csv')
gtu922_210625.info()
gtu922_210625_gtgeo=gtu922_210625[gtu922_210625['Message'].str.contains('ACK')]
gtu922_210625_gtgeo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942 entries, 0 to 941
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  942 non-null    object
#  1   Message  942 non-null    object
#  2   Status   942 non-null    object
# dtypes: object(3)
# memory usage: 22.2+ KB
#                      Created  \
# 280  2025-06-04 21:15:00.659
#
#                                                Message  \
# 280  +ACK:GTRTO,500501,868574042763735,,RTL,FFFF,20...
#
#                                                 Status
# 280  0x2B41434B3A475452544F2C3530303530312C38363835...

# %% [markdown]
# Se obtuvo el archivo hlgtu922 en la página en inglés.

# %%
gtu_922_hl=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hlgtu922.csv',sep=';',encoding='latin1')
gtu_922_hl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9190 entries, 0 to 9189
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     9190 non-null   int64
#  1   Unit         9190 non-null   object
#  2   Events       9190 non-null   object
#  3   Date         9190 non-null   object
#  4   Landmark     939 non-null    object
#  5   Address      9190 non-null   object
#  6   Speed        9190 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       9190 non-null   object
#  9   Latitude     9190 non-null   float64
#  10  Longitude    9190 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 789.9+ KB

# %% [markdown]
# Landmarks:

# %%
gtu922_landmarks=gtu_922_hl[gtu_922_hl['Events'].str.contains('Landmark')]
gtu922_landmarks.info()
gtu922_landmarks.to_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hlgtu922_landmark.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 84 to 8100
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     41 non-null     int64
#  1   Unit         41 non-null     object
#  2   Events       41 non-null     object
#  3   Date         41 non-null     object
#  4   Landmark     41 non-null     object
#  5   Address      41 non-null     object
#  6   Speed        41 non-null     int64
#  7   Temperature  0 non-null      float64
#  8   Driver       41 non-null     object
#  9   Latitude     41 non-null     float64
#  10  Longitude    41 non-null     float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 3.8+ KB

# %% [markdown]
# Teleamigo:

# %%
telea_0406_0506=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/teleamigo.csv',sep=';',encoding='latin1')
telea_0406_0506.info()
telea_0406_0506_message=telea_0406_0506[telea_0406_0506['text'].str.contains('GTGEO')]
telea_0406_0506_message
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3819 entries, 0 to 3818
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   requestType         3819 non-null   object
#  1   inbound             0 non-null      float64
#  2   outbound            3819 non-null   object
#  3   sendAt              3819 non-null   object
#  4   doneAt              3819 non-null   object
#  5   sender              3819 non-null   object
#  6   destination         3791 non-null   float64
#  7   externalMessageId   3819 non-null   object
#  8   status              3819 non-null   object
#  9   text                3819 non-null   object
#  10  error               3819 non-null   object
#  11  errorGroup          3819 non-null   object
#  12  seenAt              3819 non-null   object
#  13  ivrResponses        0 non-null      float64
#  14  ivrMappedResponses  0 non-null      float64
# ...

# %% [markdown]
# ## Conclusiones 21-06-2025:
# 1. Solo está funcionando la detección de landmarks en el dispositio UAR598 porque se le envió el comando desde CRM y con Teleamigo operativo, es muy probable que cuando se envió los comandos con el módulo de Carlos, había fallas en Teleamigo.
# 2. Cuando la unidad recibe el comando exitosamente, debe haber un ACK, que solo llegó a la unidad UAR598, cuando se envió desde el CRM en la etapa de pruebas antes de pasar el caso a desarrollo.
# 3. Se procede a buscar otra unidad de pruebas, diferente a la unidad UAR598 y con una cuenta que no esté en mora.
# 4. La placa GTU206 de Harold mantiene en estado de parqueado, por lo tanto no es una buena opción para pruebas.

# %%
new_units=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/ubd21062025.csv',sep=';',encoding='latin1')
new_units.info()
queclink_units=new_units[new_units['Unit Type'].str.contains('Queclink GV55W')]
queclink_units_reporting=queclink_units[['Unit Type','Unit ID','Carrier','Phone Number','Last Event Date','Company','Unit']]
queclink_units_reporting[queclink_units_reporting['Last Event Date'].str.contains('6/21')]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12067 entries, 0 to 12066
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Dealer               12067 non-null  object
#  1   Company              12067 non-null  object
#  2   VIP                  12067 non-null  bool
#  3   FEIN                 12067 non-null  object
#  4   DNI                  1789 non-null   object
#  5   Peripherals          12067 non-null  object
#  6   Service Name         10373 non-null  object
#  7   Owner                12067 non-null  object
#  8   Unit ID              12067 non-null  object
#  9   Unit                 12067 non-null  object
#  10  Unit Type            12067 non-null  object
#  11  Carrier              11450 non-null  object
#  12  Monthly Fee          12067 non-null  object
#  13  Billing Group        628 non-null    object
#  14  Billing Period       11979 non-null  object
# ...

# %% [markdown]
# ## HSR591

# %% [markdown]
# R00A10V09 0102
#
# Envío de coordenada 3.181024,-75.220932 por CRM, a 0 segundos AT+GTGEO=gv55w,1,3,-75.220932,3.181024,50,0,0,0,0,0,0,0,0,,FFFF$ 21-06-2025 11:55am
# Recibió ACK: +ACK:GTGEO,500501,868574042783121,,1,FFFF,20250621165502,5C5E$
#
# Envío de coordenada 3.182345,-75.220595 por CRM, a 30 segundos AT+GTGEO=gv55w,2,3,-75.220595,3.182345,150,30,0,0,0,0,0,0,0,,FFFF$
# Recibió ACK: +ACK:GTGEO,500501,868574042783121,,2,FFFF,20250621174603,5CA3$
#
# Ambos fueron verificados como recepción exitosa en Teleamigo!

# %%
hlhsr591=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hlhsr591.csv',sep=';',encoding='latin1')
hlhsr591.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     513 non-null    int64
#  1   Unit         513 non-null    object
#  2   Events       513 non-null    object
#  3   Date         513 non-null    object
#  4   Landmark     0 non-null      float64
#  5   Address      513 non-null    object
#  6   Speed        513 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     513 non-null    float64
#  10  Longitude    513 non-null    float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 44.2+ KB

# %%
hlhsr591_Address=hlhsr591['Address'].value_counts()
hlhsr591_Address
# Out:
# Address
# Villavieja, Tello, Huila, Colombia                             82
# Neiva - Baraya- Villa Vieja-4, Villavieja, Huila, Colombia     39
# 5QMH+FQ Villavieja, Huila, Colombia                            26
# Neiva - Baraya- Villa Vieja-39, Villavieja, Huila, Colombia    20
# 5QMH+CR Villavieja, Huila, Colombia                            16
#                                                                ..
# Cl18 52-4, Neiva, Huila, Colombia                               1
# Cra. 52, Neiva, Neiva, Huila, Colombia                          1
# Cl. 8 #41-516 a 41-612, Neiva, Neiva, Huila, Colombia           1
# C. 8 # 46-62, Neiva, Huila, Colombia                            1
# C. 8 #46-18, Neiva, Huila, Colombia                             1
# Name: count, Length: 186, dtype: int64

# %%
hlhsr591_lat_long_1=hlhsr591[hlhsr591['Address'].str.contains('Neiva - Baraya- Villa Vieja-4, Villavieja, Huila, Colombia')]
hlhsr591_lat_long_1
# Out:
#      Sequence    Unit                        Events                  Date  \
# 9         504  HSR591                   Idle - Stop  Jun 21 2025 11:17 AM
# 20        493  HSR591            Ignición Encendida  Jun 21 2025 11:09 AM
# 21        492  HSR591                   Idle - Stop  Jun 21 2025 11:09 AM
# 22        491  HSR591                        Parked  Jun 21 2025 11:09 AM
# 23        490  HSR591                        Parked  Jun 21 2025 11:09 AM
# 24        489  HSR591  Desplazándose - Ign. apagada  Jun 21 2025 11:09 AM
# 25        488  HSR591              Ignición Apagada  Jun 21 2025 11:09 AM
# 26        487  HSR591                         Drive  Jun 21 2025 11:08 AM
# 27        486  HSR591                   Idle - Stop  Jun 21 2025 11:08 AM
# 28        485  HSR591            Ignición Encendida  Jun 21 2025 11:08 AM
# 29        484  HSR591                        Parked  Jun 21 2025 10:45 AM
# 30        483  HSR591                        Parked  Jun 21 2025 10:44 AM
# ...

# %% [markdown]
# ## HFX606

# %% [markdown]
# R00A12V03 0102
#
# Envío de coordenada 2 veces 4.645272,-74.198755 desde CRM. AT+GTGEO=gv55w,2,3,-74.198755,4.645272,50,30,0,0,0,0,0,0,0,,FFFF$ 21-06-2025 12:28pm
#
# Recepción ACK: +ACK:GTGEO,500700,868574042894548,,2,FFFF,20250621172858,43A4$
#
# Ambos fueron verificados como recepción exitosa en Teleamigo!

# %%
hlhfx606=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hlhfx606.csv',sep=';',encoding='latin1')
hlhfx606.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6303 entries, 0 to 6302
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     6303 non-null   int64
#  1   Unit         6303 non-null   object
#  2   Events       6303 non-null   object
#  3   Date         6303 non-null   object
#  4   Landmark     619 non-null    object
#  5   Address      6303 non-null   object
#  6   Speed        6303 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     6303 non-null   float64
#  10  Longitude    6303 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 541.8+ KB

# %%
hlhfx606_Address=hlhfx606['Address'].value_counts()
hlhfx606_Address
# Out:
# Address
# 67P7JRW2+3F                                                                760
# Carrera 106 A                                                              582
# 67P7JRW2+4F                                                                539
# 67P7JRW2+5C                                                                264
# 67P7JRW2+2G                                                                219
#                                                                           ...
# Cl10e 7-24, Soacha, Cundinamarca, Colombia                                   1
# Cl. 11 #9 Este-2 a 9 Este-42, Soacha, Soacha, Cundinamarca, Colombia         1
# Cl11e 11c-34, Soacha, Cundinamarca, Colombia                                 1
# Tv. 12 Este #11-8 a 11-34, Soacha, Soacha, Cundinamarca, Colombia            1
# Transversal 6 Este #7-26 a 7-76, Soacha, Soacha, Cundinamarca, Colombia      1
# Name: count, Length: 861, dtype: int64

# %%
hlhfx606_lat_long_1=hlhfx606[hlhfx606['Address'].str.contains('3F')]
hlhfx606_lat_long_1
# Out:
#       Sequence    Unit       Events                  Date Landmark  \
# 593       5710  HFX606  Idle - Stop  Jun 19 2025 01:40 PM      NaN
# 594       5709  HFX606  Idle - Stop  Jun 19 2025 01:40 PM      NaN
# 595       5708  HFX606  Idle - Stop  Jun 19 2025 01:40 PM      NaN
# 596       5707  HFX606  Idle - Stop  Jun 19 2025 01:39 PM      NaN
# 597       5706  HFX606  Idle - Stop  Jun 19 2025 01:38 PM      NaN
# ...        ...     ...          ...                   ...      ...
# 6259        44  HFX606  Idle - Stop  Jun 01 2025 08:23 AM      NaN
# 6260        43  HFX606  Idle - Stop  Jun 01 2025 08:22 AM      NaN
# 6261        42  HFX606  Idle - Stop  Jun 01 2025 08:21 AM      NaN
# 6262        41  HFX606  Idle - Stop  Jun 01 2025 08:20 AM      NaN
# 6263        40  HFX606  Idle - Stop  Jun 01 2025 08:19 AM      NaN
#
#           Address  Speed  Temperature  Driver  Latitude  Longitude
# 593   67P7JRW2+3F      0          NaN     NaN  4.645272 -74.198755
# ...

# %% [markdown]
# ## LKO873

# %% [markdown]
# R00A10V09, 0102

# %%
hllko873=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hllko873.csv',sep=';',encoding='latin1')
hllko873.info()
hllko873.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17057 entries, 0 to 17056
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     17057 non-null  int64
#  1   Unit         17057 non-null  object
#  2   Events       17057 non-null  object
#  3   Date         17057 non-null  object
#  4   Landmark     0 non-null      float64
#  5   Address      17057 non-null  object
#  6   Speed        17057 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     17057 non-null  float64
#  10  Longitude    17057 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.4+ MB
#    Sequence    Unit       Events                  Date  Landmark  \
# 0     17057  LKO873  Idle - Stop  Jun 21 2025 01:17 PM       NaN
# 1     17056  LKO873  Idle - Stop  Jun 21 2025 01:17 PM       NaN
# ...

# %%
hllko873['Date'].sort_values(ascending=False)
# Out:
# 35       Jun 21 2025 12:59 PM
# 37       Jun 21 2025 12:58 PM
# 36       Jun 21 2025 12:58 PM
# 38       Jun 21 2025 12:57 PM
# 40       Jun 21 2025 12:56 PM
#                  ...
# 17053    Jun 01 2025 03:43 AM
# 17042    Jun 01 2025 02:45 PM
# 17054    Jun 01 2025 02:43 AM
# 17043    Jun 01 2025 01:44 PM
# 17055    Jun 01 2025 01:42 AM
# Name: Date, Length: 17057, dtype: object

# %%
hllko873_Address=hllko873['Address'].value_counts()
hllko873_Address
# Out:
# Address
# Cl22d 127-37, Bogota, Cundinamarca, Colombia                    583
# Carrera 132 # 22A-1 a 22A-99, Bogotá, Cundinamarca, Colombia    260
# Cl22d 127-45, Bogota, Cundinamarca, Colombia                    168
# Kr132 22a-20, Bogota, Cundinamarca, Colombia                    152
# Cl22d 127-39, Bogota, Cundinamarca, Colombia                    132
#                                                                ...
# Cl63-64, Bogota, Cundinamarca                                     1
# Tr85 63-82, Bogota, Cundinamarca                                  1
# Cl63b 80a-53, Bogota, Cundinamarca                                1
# Cl63b 79-73, Bogota, Cundinamarca                                 1
# Cl26 99-34, Bogota, Cundinamarca, Colombia                        1
# Name: count, Length: 6477, dtype: int64

# %%
hllko873_lat_long_1=hllko873[hllko873['Address'].str.contains('Cl22d 127-37, Bogota, Cundinamarca, Colombia')]
hllko873_lat_long_1
# Out:
#        Sequence    Unit       Events                  Date  Landmark  \
# 2587      14470  LKO873  Idle - Stop  Jun 19 2025 08:56 AM       NaN
# 2588      14469  LKO873  Idle - Stop  Jun 19 2025 08:55 AM       NaN
# 2607      14450  LKO873  Idle - Stop  Jun 19 2025 08:45 AM       NaN
# 2708      14349  LKO873  Idle - Stop  Jun 19 2025 06:14 AM       NaN
# 2709      14348  LKO873  Ignition ON  Jun 19 2025 06:14 AM       NaN
# ...         ...     ...          ...                   ...       ...
# 17052         5  LKO873       Parked  Jun 01 2025 04:43 AM       NaN
# 17053         4  LKO873       Parked  Jun 01 2025 03:43 AM       NaN
# 17054         3  LKO873       Parked  Jun 01 2025 02:43 AM       NaN
# 17055         2  LKO873       Parked  Jun 01 2025 01:42 AM       NaN
# 17056         1  LKO873       Parked  Jun 01 2025 12:42 AM       NaN
#
#                                             Address  Speed  Temperature  \
# ...

# %% [markdown]
# Se hizo 3 intentos desde el módulo de Carlos pero no se recibió ACK:
#
# AT+GTGEO=gv55w,1,3,-74.15611200,4.69529200,310,30,0,0,0,0,0,0,0,,FFFF$
#
# Se hizo un nuevo envío de este mismo comando desde CRM sin éxito.
#
# Se verificó recepción exitosa en Teleamigo.
#
# Se hizo un nuevo intento usando Manage tool para generar:
# AT+GTGEO=gv55w,1,3,-74.156112,4.695292,50,0,0,0,0,0,0,0,0,,FFFF$ Se envió desde CRM y se generó ACK:+ACK:GTGEO,500501,868574042430053,,1,FFFF,20250621205934,0AD8$
#
# Se debe intentar solo con 6 cifras decimales.
#
# Actualizar caso en JIRA.
#
# https://gpstrackit.atlassian.net/browse/TSO-3420

# %% [markdown]
# Nuevas pruebas 24-06-2025.
# Unidades de Zona Logistica SAS

# %%
zona_logistica_units=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/zona_logisitica_units.csv',sep=';',encoding='latin1')
zona_logistica_units.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       53 non-null     int64
#  1   Owner                    53 non-null     object
#  2   Unit ID                  53 non-null     object
#  3   Unit                     53 non-null     object
#  4   Peripherals              41 non-null     object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          53 non-null     object
#  9   Monthly Fee              53 non-null     int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              53 non-null     object
#  12  Linked Mode              53 non-null     int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
zona_logistica_units_queclink=zona_logistica_units[zona_logistica_units['Unit Type'].str.contains('Queclink')]
zona_logistica_units_queclink[['Unit','Unit ID','Unit Type','IMEI','Last Event Date']]
# Out:
#       Unit Unit ID       Unit Type             IMEI Last Event Date
# 9   LKO880    S533  Queclink GV55W  868574042430335      25/06/2025
# 10  LKO879    252H  Queclink GV55W  868574042434865      25/06/2025
# 11  LKO878    J844  Queclink GV55W  868574042447461      25/06/2025
# 12  LKO877    S540  Queclink GV55W  868574042413703      25/06/2025
# 13  LKO876    163F  Queclink GV55W  868574042429733      25/06/2025
# 14  LKO875    102R  Queclink GV55W  868574042448980      25/06/2025
# 15  LKO874    L263  Queclink GV55W  868574042435128      25/06/2025
# 16  LKO873    790Z  Queclink GV55W  868574042430053      25/06/2025
# 18  GTX653    0JF8  Queclink GV55W  868574042956263      25/06/2025
# 45  ESP852    0KA0  Queclink GV55W  868574041343141      25/06/2025

# %% [markdown]
# Después de exponer el caso a desarrollo, se hizo la modificación a 6 cifras decimales. Inicio pruebas con la unidad LKO873 porque tiene acceso a configuración.

# %%
hllko873_lat_long_2=hllko873[hllko873['Address'].str.contains('Carrera 132 # 22A-1 a 22A-99, Bogotá, Cundinamarca, Colombia')]
hllko873_lat_long_2
#print('Latitudes y longitudes')
hllko873_lat_2=hllko873_lat_long_2['Latitude'].value_counts()
hllko873_long_2=hllko873_lat_long_2['Longitude'].value_counts()
hllko873_lat_2.head(5)
# Out:
# Latitude
# 4.698290    44
# 4.698248    24
# 4.698398    20
# 4.698292    19
# 4.698254    18
# Name: count, dtype: int64

# %%
hllko873_long_2.head(5)
# Out:
# Longitude
# -74.161505    50
# -74.161555    24
# -74.161576    23
# -74.161560    21
# -74.161559    20
# Name: count, dtype: int64

# %% [markdown]
# Tramas de prueba:
# Landmark3: AT+GTGEO=gv55w,3,3,-74.161555,4.698248,50,30,0,0,0,0,0,0,0,,FFFF$ x
# Landmark4: AT+GTGEO=gv55w,4,3,-74.161576,4.698398,50,30,0,0,0,0,0,0,0,,FFFF$
# Landmark5: AT+GTGEO=gv55w,5,3,-74.161560,4.698292,50,30,0,0,0,0,0,0,0,,FFFF$
# Landmark6: AT+GTGEO=gv55w,6,3,-74.161559,4.698254,50,30,0,0,0,0,0,0,0,,FFFF$

# %% [markdown]
# ## LKO878

# %% [markdown]
# R00A10V09, 0102
#
# Se envió AT+GTGEO=gv55w,1,3,-74.161440,4.698221,50000,30,0,0,0,0,0,0,0,,FFFF$
# con ACK +ACK:GTGEO,500501,868574042447461,,1,FFFF,20250626135033,FA83$ y +RESP:GTGEO,500501,868574042447461,,,10,1,1,0.0,345,43.0,-74.850652,10.932023,20250626135056,0732,0101,3AA3,BB81806,04,12,56774.6,20250626135057,FA84$
# Aquí nos dimos cuenta del error en el radio, pusimos 50 y se generó 50000

# %% [markdown]
# Se usó Landmark3: AT+GTGEO=gv55w,3,3,-74.161555,4.698248,50,30,0,0,0,0,0,0,0,,FFFF$ 01-07-2025 12:18 Falló porque Teleamigo no está operativo.

# %%
lko878_260625=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/lko878.csv',sep=';',encoding='latin1')
lko878_260625.info()
print(lko878_260625.loc[0:1])
print(lko878_260625.loc[5464:5465])
lko878_260625_GTGEO=lko878_260625[lko878_260625['Message'].str.contains('GTGEO')]
lko878_260625_GTGEO
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5465 entries, 0 to 5464
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  5465 non-null   object
#  1   Message  5465 non-null   object
#  2   Status   5465 non-null   object
# dtypes: object(3)
# memory usage: 128.2+ KB
#                    Created                                            Message  \
# 0  2025-06-26 00:00:09.738  +RESP:GTFRI,500501,868574042447461,,,10,1,1,73...
# 1  2025-06-26 00:01:10.122  +RESP:GTFRI,500501,868574042447461,,,10,1,1,75...
#
#                                               Status
# 0  0x2B524553503A47544652492C3530303530312C383638...
# 1  0x2B524553503A47544652492C3530303530312C383638...
#                       Created  \
# 5464  2025-07-01 20:10:36.458
#
#                                                 Message  \
# 5464  +RESP:GTFRI,500501,868574042447461,,,11,1,1,6....
#
# ...

# %% [markdown]
# 08-07-2025:
# Se ejecutó resend command + save para LKO878 08-07-2025 12:54
#
# AT+GTGEO=gv55w,1,3,-74.161555,4.698248,59,30,0,0,0,0,0,0,0,,FFFF$
# +ACK:GTGEO,500501,868574042447461,,1,FFFF,20250708180022,2549$
# +RESP:GTGEO,500501,868574042447461,,,10,1,1,0.0,109,56.2,-74.802674,10.904695,20250708180056,0732,0101,3A9A,BB81BC6,04,12,58946.8,20250708180055,254B$

# %%
raw_data_lko878_08072025=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/raw_data_lko878_08072025.csv',sep=';',encoding='latin1')
gtgeo_events=raw_data_lko878_08072025[raw_data_lko878_08072025['Message'].str.contains('GTGEO')]
gtgeo_events
# Out:
#                                                 Message  \
# 1841  +ACK:GTGEO,500501,868574042447461,,1,FFFF,2025...
# 1843  +RESP:GTGEO,500501,868574042447461,,,10,1,1,0....
#
#                                                  Status
# 1841  0x2B41434B3A475447454F2C3530303530312C38363835...
# 1843  0x2B524553503A475447454F2C3530303530312C383638...

# %% [markdown]
# Análisis de coordenadas para establecer las mas visitadas:

# %%
hllko878=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hllko8780106202511072025.csv',sep=';',encoding='latin1')
hllko878.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31529 entries, 0 to 31528
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     31529 non-null  int64
#  1   Unit         31529 non-null  object
#  2   Events       31529 non-null  object
#  3   Date         31529 non-null  object
#  4   Landmark     1 non-null      object
#  5   Address      31529 non-null  object
#  6   Speed        31529 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       31529 non-null  object
#  9   Latitude     31529 non-null  float64
#  10  Longitude    31529 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 2.6+ MB

# %%
hllko878['Latitude'].value_counts()
# Out:
# Latitude
# 10.986733    249
# 10.931861    213
# 10.931903    154
# 10.943217    143
# 10.931915    141
#             ...
# 10.932573      1
# 10.932751      1
# 10.921895      1
# 10.921972      1
# 10.922216      1
# Name: count, Length: 15308, dtype: int64

# %%
hllko878['Longitude'].value_counts()
# Out:
# Longitude
# -74.850429    226
# -74.850301    155
# -74.767904    149
# -74.844132    135
# -74.850445    129
#              ...
# -75.486506      1
# -75.485294      1
# -75.485309      1
# -75.508716      1
# -75.485176      1
# Name: count, Length: 15463, dtype: int64

# %% [markdown]
# 11072025: Se creó landmark TSO trial 110720251037 10.931861 y -74.850429, radio 1Km:
# AT+GTGEO=gv55w,2,3,-74.850429,10.931861,999,30,0,0,0,0,0,0,0,,FFFF$
# +ACK:GTGEO,500501,868574042447461,,2,FFFF,20250711155032,2FDD$
# +RESP:GTGEO,500501,868574042447461,,,21,1,1,0.0,325,38.7,-74.853211,10.937871,20250711155059,0732,0101,3AA3,BB817B7,04,12,59203.8,20250711155059,2FDE$

# %% [markdown]
# 14-07-2025:
# Se generó rdlko8781007_1407

# %%
raw_data_lko878=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/rawdatalko8781007_1407.csv',sep=';',encoding='latin1')
raw_data_lko878.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3656 entries, 0 to 3655
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  3656 non-null   object
#  1   Message  3656 non-null   object
#  2   Status   3656 non-null   object
# dtypes: object(3)
# memory usage: 85.8+ KB

# %%
gtgeo_events_lko878=raw_data_lko878[raw_data_lko878['Message'].str.contains('GTGEO')]
gtgeo_events_lko878.info()
gtgeo_events_lko878.to_csv('/home/jlhb1984/py-projects/data/geofences_on_device/raw_data_report_gtgeo.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 1772 to 3373
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  18 non-null     object
#  1   Message  18 non-null     object
#  2   Status   18 non-null     object
# dtypes: object(3)
# memory usage: 576.0+ bytes

# %%
hllko878_10071407=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/hllko8781007_1407.csv',sep=';',encoding='latin1')
hllko878_10071407.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3212 entries, 0 to 3211
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Secuencia       3212 non-null   int64
#  1   Unidad          3212 non-null   object
#  2   Eventos         3212 non-null   object
#  3   Fecha           3212 non-null   object
#  4   Pt. Referencia  376 non-null    object
#  5   Dirección       3212 non-null   object
#  6   Velocidad       3212 non-null   int64
#  7   Temperatura     0 non-null      float64
#  8   Conductor       3212 non-null   object
#  9   Latitud         3212 non-null   float64
#  10  Longitud        3212 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 276.2+ KB

# %%
hllko878_10071407['Eventos'].value_counts()
# Out:
# Eventos
# Inmóvil - Detenido              2066
# Conduciendo                      952
# Estacionado                      112
# Ignición Encendida                24
# Ignición Apagada                  23
# Entrando a Landmark               14
# Saliendo de Landmark              11
# Desplazándose - Ign. apagada      10
# Name: count, dtype: int64

# %%
hllko878_10071407['Pt. Referencia'].value_counts()
# Out:
# Pt. Referencia
# TSO trial 110720251037    376
# Name: count, dtype: int64

# %%
hllko878_10071407['Eventos'].value_counts()
# Out:
# Eventos
# Inmóvil - Detenido              2066
# Conduciendo                      952
# Estacionado                      112
# Ignición Encendida                24
# Ignición Apagada                  23
# Entrando a Landmark               14
# Saliendo de Landmark              11
# Desplazándose - Ign. apagada      10
# Name: count, dtype: int64

# %%
hllko878_10071407.fillna('Empty',inplace=True)
pt_ref=hllko878_10071407[hllko878_10071407['Eventos'].str.contains('Landmark')]
pt_ref
# Out:
# /tmp/ipykernel_33721/3151258754.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Empty' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   hllko878_10071407.fillna('Empty',inplace=True)
#       Secuencia  Unidad               Eventos                 Fecha  \
# 292        2920  LKO878  Saliendo de Landmark  Jul 14 2025 06:42 AM
# 465        2747  LKO878   Entrando a Landmark  Jul 12 2025 01:18 PM
# 467        2745  LKO878   Entrando a Landmark  Jul 12 2025 01:18 PM
# 548        2664  LKO878  Saliendo de Landmark  Jul 12 2025 12:23 PM
# 552        2660  LKO878   Entrando a Landmark  Jul 12 2025 12:21 PM
# 592        2620  LKO878  Saliendo de Landmark  Jul 12 2025 12:01 PM
# 594        2618  LKO878   Entrando a Landmark  Jul 12 2025 11:59 AM
# 657        2555  LKO878  Saliendo de Landmark  Jul 12 2025 10:36 AM
# ...

# %%
customer_units_0108=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/cu01082025.csv',sep=';',encoding='latin1')
customer_units_0108.info()
customer_units_0108.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       49 non-null     int64
#  1   Owner                    49 non-null     object
#  2   Unit ID                  49 non-null     object
#  3   Unit                     49 non-null     object
#  4   Peripherals              0 non-null      float64
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          49 non-null     object
#  9   Monthly Fee              49 non-null     int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              49 non-null     object
#  12  Linked Mode              49 non-null     int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
units_god_01082025=customer_units_0108[customer_units_0108['Last Event Date'].str.contains('1/08/2025')]
units_god_01082025.info()
units_god_01082025['Unit'].value_counts()
#c=input("Digite la placa: ")
#units_god_01082025_placa=units_god_01082025[units_god_01082025['Unit'].str.contains(c)]
#units_god_01082025_placa
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 1 to 48
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       40 non-null     int64
#  1   Owner                    40 non-null     object
#  2   Unit ID                  40 non-null     object
#  3   Unit                     40 non-null     object
#  4   Peripherals              0 non-null      float64
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          40 non-null     object
#  9   Monthly Fee              40 non-null     int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              40 non-null     object
#  12  Linked Mode              40 non-null     int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
raw_data_sjr801_01082025=pd.read_csv('/home/jlhb1984/py-projects/data/geofences_on_device/rdsjr801_01082025.csv',sep=';',encoding='latin1')
raw_data_sjr801_01082025.info()
ack_gtgeo=raw_data_sjr801_01082025[raw_data_sjr801_01082025['Message'].str.contains('ACK')]
ack_gtgeo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 719 entries, 0 to 718
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  719 non-null    object
#  1   Message  719 non-null    object
#  2   Status   719 non-null    object
# dtypes: object(3)
# memory usage: 17.0+ KB
#                      Created  \
# 405  2025-08-01 14:09:23.470
# 433  2025-08-01 14:40:19.723
# 434  2025-08-01 15:10:41.748
# 436  2025-08-01 15:40:27.471
# 437  2025-08-01 16:09:33.371
# 439  2025-08-01 16:40:33.287
# 440  2025-08-01 17:09:37.172
# 442  2025-08-01 17:39:57.312
# 443  2025-08-01 18:10:40.558
# 445  2025-08-01 18:40:17.311
# 446  2025-08-01 19:10:35.982
# 503  2025-08-01 19:40:21.819
#
#                                                Message  \
# 405  +ACK:GTGEO,500700,868574042924162,,1,FFFF,2025...
# 433  +ACK:GTGEO,500700,868574042924162,,2,FFFF,2025...
# 434  +ACK:GTGEO,500700,868574042924162,,11,FFFF,202...
# ...
