# %%
import pandas as pd
import numpy as np

# %%
cu=pd.read_csv('/home/jlhb1984/py-projects/data/COMERCIALIZADORA VICTOR ALVAREZ/cu.csv',sep=';',encoding='latin1')
cu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       32 non-null     int64
#  1   Owner                    32 non-null     object
#  2   Unit ID                  32 non-null     object
#  3   Unit                     32 non-null     object
#  4   Peripherals              4 non-null      object
#  5   BillingPeriod            32 non-null     object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            0 non-null      float64
#  9   Last Event Date          32 non-null     object
#  10  Monthly Fee              32 non-null     object
#  11  Bill To                  32 non-null     object
#  12  Assigned To              32 non-null     object
#  13  Linked Mode              32 non-null     int64
# ...

# %%
vf4K_units=cu[cu['Unit Type'].str.contains('4K')]
vf4K_units['IMEI'].to_csv('/home/jlhb1984/py-projects/data/COMERCIALIZADORA VICTOR ALVAREZ/cu_4K_21125.csv')
vfAIR2_units=cu[cu['Unit Type'].str.contains('AIR2')]
vfAIR2_units['IMEI'].to_csv('//home/jlhb1984/py-projects/data/COMERCIALIZADORA VICTOR ALVAREZ/cu_AIR2201125.csv')
