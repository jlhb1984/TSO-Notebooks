# %%
import pandas as pd
import numpy as np

# %%
logistic_units=pd.read_csv('/home/jlhb1984/py-projects/data/logistic/cu.csv',sep=';',encoding='latin1')
logistic_units_vf=logistic_units[logistic_units['Unit'].str.contains('VF')]
logistic_units_vf['Unit'].to_csv('/home/jlhb1984/py-projects/data/logistic/cu_vf.csv')

# %%
raw_data_8B5141XC=pd.read_csv('/home/jlhb1984/py-projects/data/logistic/raw_data_crm_m.csv',sep=';')
raw_data_8B5141XC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15325 entries, 0 to 15324
# Columns: 128 entries, Message to Unnamed: 127
# dtypes: object(128)
# memory usage: 15.0+ MB
# /tmp/ipykernel_1043/2350079642.py:1: DtypeWarning: Columns (116,117,118,119,120,121,122,123,124,125,126,127) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data_8B5141XC=pd.read_csv('/home/jlhb1984/py-projects/data/logistic/raw_data_crm_m.csv',sep=';')

# %%
raw_data_8B5141XC_CameraEvent=raw_data_8B5141XC[raw_data_8B5141XC['Message'].str.contains('CameraEvent')]
raw_data_8B5141XC_CameraEvent
# Out:
#                                  Message     Unnamed: 1  \
# 4      {"notificationType":"CameraEvent"  sn:"8B5141XC"
# 37     {"notificationType":"CameraEvent"  sn:"8B5141XC"
# 41     {"notificationType":"CameraEvent"  sn:"8B5141XC"
# 66     {"notificationType":"CameraEvent"  sn:"8B5141XC"
# 83     {"notificationType":"CameraEvent"  sn:"8B5141XC"
# ...                                  ...            ...
# 15130  {"notificationType":"CameraEvent"  sn:"8B5141XC"
# 15244  {"notificationType":"CameraEvent"  sn:"8B5141XC"
# 15246  {"notificationType":"CameraEvent"  sn:"8B5141XC"
# 15257  {"notificationType":"CameraEvent"  sn:"8B5141XC"
# 15287  {"notificationType":"CameraEvent"  sn:"8B5141XC"
#
#                                           Unnamed: 2    Unnamed: 3  \
# 4      tripID:"f47f0e15-0a97-4124-a870-59f2555e6f58"  vehicleID:""
# 37     tripID:"060337e6-d051-46c8-8f8c-639954a1d048"  vehicleID:""
# 41     tripID:"060337e6-d051-46c8-8f8c-639954a1d048"  vehicleID:""
# ...

# %%
raw_data_8B5141XC_CameraEvent['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"DROWSINESS"                      273
# event:"USING_PHONE"                     196
# event:"HEADWAY_MONITORING_EMERGENCY"    122
# event:"POTENTIAL_INCIDENT_LOW"           40
# event:"YAWN"                             34
# event:"HARD_BRAKE"                       22
# event:"FORWARD_COLLISION_WARNING"        10
# event:"SHARP_TURN"                        8
# event:"POTENTIAL_INCIDENT_MEDIUM"         5
# event:"NO_SEATBELT"                       3
# event:"HARD_ACCEL"                        2
# event:"POTENTIAL_INCIDENT_HIGH"           1
# Name: count, dtype: int64

# %%
raw_data_8B5141XC_CameraEvent['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"DMS"                   506
# eventCategory:"HEADWAY_MONITORING"    122
# eventCategory:"POTENTIAL_INCIDENT"     46
# eventCategory:"HARD_BRAKE"             22
# eventCategory:"FORWARD_COLLISION"      10
# eventCategory:"SHARP_TURN"              8
# eventCategory:"HARD_ACCEL"              2
# Name: count, dtype: int64

# %%
raw_data_8B5141XC_31100511=pd.read_csv('/home/jlhb1984/py-projects/data/logistic/8B5141XC_m_31100511.csv',sep=';')
raw_data_8B5141XC_CameraEvent_31100511=raw_data_8B5141XC_31100511[raw_data_8B5141XC_31100511['Message'].str.contains('CameraEvent')]

# %%
raw_data_8B5141XC_CameraEvent_31100511['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"DROWSINESS"                      31
# event:"HEADWAY_MONITORING_EMERGENCY"    11
# event:"USING_PHONE"                      8
# event:"YAWN"                             8
# event:"HARD_BRAKE"                       5
# event:"POTENTIAL_INCIDENT_LOW"           4
# event:"POTENTIAL_INCIDENT_MEDIUM"        1
# event:"NO_SEATBELT"                      1
# Name: count, dtype: int64

# %%
raw_data_8B5141XC_CameraEvent_31100511['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"DMS"                   48
# eventCategory:"HEADWAY_MONITORING"    11
# eventCategory:"HARD_BRAKE"             5
# eventCategory:"POTENTIAL_INCIDENT"     5
# Name: count, dtype: int64

# %%
raw_data_8B5141XC_05111311=pd.read_csv('/home/jlhb1984/py-projects/data/logistic/8B5141XC_m_05111311.csv',sep=';')
raw_data_8B5141XC_CameraEvent_05111311=raw_data_8B5141XC_05111311[raw_data_8B5141XC_05111311['Message'].str.contains('CameraEvent')]

# %%
raw_data_8B5141XC_CameraEvent_05111311['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"USING_PHONE"                     17
# event:"DROWSINESS"                      17
# event:"HEADWAY_MONITORING_EMERGENCY"    14
# event:"POTENTIAL_INCIDENT_LOW"           8
# event:"YAWN"                             6
# event:"HARD_BRAKE"                       3
# event:"FORWARD_COLLISION_WARNING"        1
# event:"POTENTIAL_INCIDENT_MEDIUM"        1
# Name: count, dtype: int64

# %%
raw_data_8B5141XC_CameraEvent_05111311['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"DMS"                   40
# eventCategory:"HEADWAY_MONITORING"    14
# eventCategory:"POTENTIAL_INCIDENT"     9
# eventCategory:"HARD_BRAKE"             3
# eventCategory:"FORWARD_COLLISION"      1
# Name: count, dtype: int64

# %%
cu=pd.read_csv('/home/jlhb1984/py-projects/data/logistic/cu.csv',sep=';',encoding='latin1')
cu.info()
cu['Unit Type'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       86 non-null     int64
#  1   Owner                    86 non-null     object
#  2   Unit ID                  86 non-null     object
#  3   Unit                     86 non-null     object
#  4   Peripherals              1 non-null      object
#  5   BillingPeriod            86 non-null     object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            10 non-null     object
#  9   Last Event Date          86 non-null     object
#  10  Monthly Fee              86 non-null     int64
#  11  Bill To                  58 non-null     object
#  12  Assigned To              86 non-null     object
#  13  Linked Mode              86 non-null     int64
# ...

# %%
vf4k=cu[cu['Unit Type'].str.contains('4K')]
vf4k[['Unit Type','IMEI','Serial Number']]
vf4k[['Unit Type','IMEI','Serial Number']].to_csv('/home/jlhb1984/py-projects/data/logistic/imeis_4k.csv')

# %%
air2=cu[cu['Unit Type'].str.contains('AIR2')]
air2[['Unit Type','IMEI','Serial Number']]
air2[['Unit Type','IMEI','Serial Number']].to_csv('/home/jlhb1984/py-projects/data/logistic/imies_air2.csv')
