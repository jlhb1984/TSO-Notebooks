# %%
# !pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 1.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 669.1 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.7/323.7 kB 1.3 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 830.1 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 770.1 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 897.9 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 865.3 kB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
units=pd.read_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileageSummaryReport_2025-05-14_1747252854059_sgflkf09s.csv')
units.info()
units.head(6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527 entries, 0 to 526
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unit          527 non-null    object
#  1   Driver        0 non-null      float64
#  2   Date          527 non-null    object
#  3   Mileage (km)  488 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 16.6+ KB
#      Unit  Driver                                             Date  \
# 0  CGQ270     NaN                                       12/05/2025
# 1  CGQ270     NaN                                       13/05/2025
# 2  CSC274     NaN  No data available for the selected time period.
# 3  EQY796     NaN                                       12/05/2025
# 4  EQY796     NaN                                       13/05/2025
# 5  EQY796     NaN                                       14/05/2025
#
#    Mileage (km)
# 0         17.32
# 1          1.59
# 2           NaN
# ...

# %%
units.sort_values(by='Mileage (km)', ascending=False).head(8)
# Out:
#        Unit  Driver        Date  Mileage (km)
# 352  TDS986     NaN  12/05/2025     133710.07
# 508  WOU053     NaN  13/05/2025     122274.56
# 154  JKW075     NaN  14/05/2025      91394.81
# 354  TDS986     NaN  14/05/2025      67206.75
# 353  TDS986     NaN  13/05/2025      67067.64
# 156  JUY258     NaN  13/05/2025      59602.31
# 219  NNZ901     NaN  12/05/2025      47431.98
# 203  NNZ730     NaN  12/05/2025      44783.36

# %% [markdown]
# ##WOU053

# %%
wou053=pd.read_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/Export.xlsx - Sheet1.csv')
wou053.info()
wou053.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4583 entries, 0 to 4582
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  4583 non-null   object
#  1   Message  4583 non-null   object
#  2   Status   4583 non-null   object
# dtypes: object(3)
# memory usage: 107.5+ KB
#                    Created                                            Message  \
# 0  2025-05-12 00:00:11.629  +RESP:GTSTT,500501,868574042794136,,22,0,0.0,1...
# 1  2025-05-12 00:00:11.937  +RESP:GTFRI,500501,868574042794136,,,10,1,1,0....
# 2  2025-05-12 00:13:06.554  +RESP:GTFRI,500501,868574042794136,,,11,1,1,36...
# 3  2025-05-12 00:13:07.234  +RESP:GTFRI,500501,868574042794136,,,11,1,1,39...
# 4  2025-05-12 00:13:08.073  +RESP:GTFRI,500501,868574042794136,,,11,1,1,41...
#
#                                               Status
# 0  0x2B524553503A47545354542C3530303530312C383638...
# ...

# %%
wou053_1305=wou053[wou053['Created'].str.contains('2025-05-13')]
wou053_1305.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/wou053_1305.csv')

# %%
wou053_1305_events=wou053_1305
wou053_1305_events['Message_format']=wou053_1305['Message'].str[0:11]
wou053_1305_events.groupby(['Message_format']).count()
# Out:
# <ipython-input-34-e90f6c1bef28>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wou053_1305_events['Message_format']=wou053_1305['Message'].str[0:11]
#                 Created  Message  Status
# Message_format
# +BUFF:GTDOG          15       15      15
# +BUFF:GTFRI         727      727     727
# +BUFF:GTHBM           1        1       1
# +BUFF:GTIDF           3        3       3
# +BUFF:GTIDN           3        3       3
# +BUFF:GTIGF           1        1       1
# +BUFF:GTIGL           2        2       2
# +BUFF:GTIGN           1        1       1
# +BUFF:GTPFA          15       15      15
# +BUFF:GTPNA          15       15      15
# +BUFF:GTRTL          15       15      15
# +BUFF:GTSTT          21       21      21
# ...

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTDOG')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTDOG.csv')

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTFRI')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTFRI.csv')

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTHBM')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTHBM.csv')

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTIDF')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIDF.csv')

# %% [markdown]
# Error en trama GTIDF

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTIDN')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIDN.csv')

# %% [markdown]
# Error en trama GTIDN

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTIGF')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIGF.csv')

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTIGL')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIGL.csv')

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTIGN')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIGN.csv')

# %% [markdown]
# Error en trama GTIGN

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTPFA')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTPFA.csv')

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTPNA')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTPNA.csv')

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTRTL')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTRTL.csv')

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTSTT')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTSTT.csv')

# %% [markdown]
# Error en trama GTSTT

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTPDP')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTPDP.csv')

# %%
mileage_report_detailed_GTDOG=wou053_1305_events[wou053_1305_events['Message'].str.contains('GTSPD')]
mileage_report_detailed_GTDOG.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTSPD.csv')

# %% [markdown]
# ##	TDS986

# %%
tds986=pd.read_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/Export (1).xlsx - Sheet1.csv')
tds986.info()
tds986.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  614 non-null    object
#  1   Message  614 non-null    object
#  2   Status   614 non-null    object
# dtypes: object(3)
# memory usage: 14.5+ KB
#                    Created                                            Message  \
# 0  2025-05-15 00:00:54.870  +RESP:GTFRI,500501,868574042785993,,,10,1,1,0....
# 1  2025-05-15 00:01:54.966  +RESP:GTFRI,500501,868574042785993,,,10,1,1,0....
# 2  2025-05-15 00:02:54.800  +RESP:GTFRI,500501,868574042785993,,,10,1,1,0....
# 3  2025-05-15 00:03:55.028  +RESP:GTFRI,500501,868574042785993,,,10,1,1,0....
# 4  2025-05-15 00:04:54.873  +RESP:GTFRI,500501,868574042785993,,,10,1,1,0....
#
#                                               Status
# 0  0x2B524553503A47544652492C3530303530312C383638...
# 1  0x2B524553503A47544652492C3530303530312C383638...
# ...

# %%
tds986_1505_events=tds986
tds986_1505_events['Message_format']=tds986_1505_events['Message'].str[0:11]
tds986_1505_events.groupby(['Message_format']).count()
# Out:
#                 Created  Message  Status
# Message_format
# +BUFF:GTFRI           8        8       8
# +RESP:GTFRI         480      480     480
# +RESP:GTIGF          10       10      10
# +RESP:GTIGL          19       19      19
# +RESP:GTIGN           9        9       9
# +RESP:GTPDP          20       20      20
# +RESP:GTSTT          68       68      68

# %%
mileage_report_detailed_GTIGN_1=tds986_1505_events[tds986_1505_events['Message'].str.contains('GTIGN')]
mileage_report_detailed_GTIGN_1.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIGN_1.csv')

# %% [markdown]
# Error de trama GTIGN

# %% [markdown]
# ##JKW075

# %%
jkw075=pd.read_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/Export (2).xlsx - Sheet1.csv')
jkw075.info()
jkw075.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3566 entries, 0 to 3565
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  3566 non-null   object
#  1   Message  3566 non-null   object
#  2   Status   3566 non-null   object
# dtypes: object(3)
# memory usage: 83.7+ KB
#                    Created                                            Message  \
# 0  2025-05-14 00:00:13.639  +RESP:GTFRI,500501,868574042789789,,,10,1,1,8....
# 1  2025-05-14 00:01:12.677  +RESP:GTFRI,500501,868574042789789,,,10,1,1,4....
# 2  2025-05-14 00:01:15.016  +RESP:GTFRI,500501,868574042789789,,,11,1,1,5....
# 3  2025-05-14 00:01:21.257  +RESP:GTFRI,500501,868574042789789,,,11,1,1,3....
# 4  2025-05-14 00:01:54.676  +RESP:GTFRI,500501,868574042789789,,,11,1,1,8....
#
#                                               Status
# 0  0x2B524553503A47544652492C3530303530312C383638...
# 1  0x2B524553503A47544652492C3530303530312C383638...
# ...

# %%
jkw075_1505_events=jkw075
jkw075_1505_events['Message_format']=jkw075_1505_events['Message'].str[0:11]
jkw075_1505_events.groupby(['Message_format']).count()
# Out:
#                 Created  Message  Status
# Message_format
# +BUFF:GTFRI          48       48      48
# +BUFF:GTSTT           2        2       2
# +RESP:GTFRI        3290     3290    3290
# +RESP:GTHBM           8        8       8
# +RESP:GTIDF           3        3       3
# +RESP:GTIDN           3        3       3
# +RESP:GTIGF           8        8       8
# +RESP:GTIGL          16       16      16
# +RESP:GTIGN           8        8       8
# +RESP:GTPDP          18       18      18
# +RESP:GTSTT         162      162     162

# %%
mileage_report_detailed_GTIGN_2=jkw075_1505_events[jkw075_1505_events['Message'].str.contains('GTIGN')]
mileage_report_detailed_GTIGN_2.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIGN_2.csv')

# %% [markdown]
# Error de trama GTIGN

# %% [markdown]
# ##EQY796

# %%
eqy796=pd.read_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/Export (3).xlsx - Sheet1.csv')
eqy796.info()
eqy796.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3566 entries, 0 to 3565
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  3566 non-null   object
#  1   Message  3566 non-null   object
#  2   Status   3566 non-null   object
# dtypes: object(3)
# memory usage: 83.7+ KB
#                    Created                                            Message  \
# 0  2025-05-14 00:00:13.639  +RESP:GTFRI,500501,868574042789789,,,10,1,1,8....
# 1  2025-05-14 00:01:12.677  +RESP:GTFRI,500501,868574042789789,,,10,1,1,4....
# 2  2025-05-14 00:01:15.016  +RESP:GTFRI,500501,868574042789789,,,11,1,1,5....
# 3  2025-05-14 00:01:21.257  +RESP:GTFRI,500501,868574042789789,,,11,1,1,3....
# 4  2025-05-14 00:01:54.676  +RESP:GTFRI,500501,868574042789789,,,11,1,1,8....
#
#                                               Status
# 0  0x2B524553503A47544652492C3530303530312C383638...
# 1  0x2B524553503A47544652492C3530303530312C383638...
# ...

# %%
eqy796_1505_events=eqy796
eqy796_1505_events['Message_format']=eqy796_1505_events['Message'].str[0:11]
eqy796_1505_events.groupby(['Message_format']).count()
# Out:
#                 Created  Message  Status
# Message_format
# +BUFF:GTFRI          48       48      48
# +BUFF:GTSTT           2        2       2
# +RESP:GTFRI        3290     3290    3290
# +RESP:GTHBM           8        8       8
# +RESP:GTIDF           3        3       3
# +RESP:GTIDN           3        3       3
# +RESP:GTIGF           8        8       8
# +RESP:GTIGL          16       16      16
# +RESP:GTIGN           8        8       8
# +RESP:GTPDP          18       18      18
# +RESP:GTSTT         162      162     162

# %%
mileage_report_detailed_GTIGN_3=eqy796_1505_events[eqy796_1505_events['Message'].str.contains('GTIGN')]
mileage_report_detailed_GTIGN_3.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIGN_3.csv')

# %% [markdown]
# Error de trama GTIGN

# %% [markdown]
# ##JUY258

# %%
juy258=pd.read_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/Export (4).xlsx - Sheet1.csv')
juy258.info()
juy258.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1801 entries, 0 to 1800
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1801 non-null   object
#  1   Message  1801 non-null   object
#  2   Status   1801 non-null   object
# dtypes: object(3)
# memory usage: 42.3+ KB
#                    Created                                            Message  \
# 0  2025-05-14 00:33:19.083  +RESP:GTPDP,500700,868574042866918,,2025051400...
# 1  2025-05-14 01:03:37.226  +RESP:GTPDP,500700,868574042866918,,2025051401...
# 2  2025-05-14 01:08:16.481  +RESP:GTFRI,500700,868574042866918,,,10,1,1,0....
# 3  2025-05-14 01:52:28.908  +RESP:GTPDP,500700,868574042866918,,2025051401...
# 4  2025-05-14 02:07:24.540  +RESP:GTFRI,500700,868574042866918,,,10,1,1,0....
#
#                                               Status
# 0  0x2B524553503A47545044502C3530303730302C383638...
# 1  0x2B524553503A47545044502C3530303730302C383638...
# ...

# %%
juy258_1505_events=juy258
juy258_1505_events['Message_format']=juy258_1505_events['Message'].str[0:11]
juy258_1505_events.groupby(['Message_format']).count()
# Out:
#                 Created  Message  Status
# Message_format
# +BUFF:GTDOG           2        2       2
# +BUFF:GTFRI         203      203     203
# +BUFF:GTIDN           1        1       1
# +BUFF:GTIGF           4        4       4
# +BUFF:GTIGL           8        8       8
# +BUFF:GTIGN           4        4       4
# +BUFF:GTPFA           2        2       2
# +BUFF:GTPNA           2        2       2
# +BUFF:GTRTL           2        2       2
# +BUFF:GTSTT          87       87      87
# +RESP:GTFRI        1181     1181    1181
# +RESP:GTIDF           6        6       6
# +RESP:GTIDN           6        6       6
# +RESP:GTIGF          10       10      10
# +RESP:GTIGL          20       20      20
# +RESP:GTIGN          10       10      10
# +RESP:GTPDP          38       38      38
# +RESP:GTSTT         215      215     215

# %%
mileage_report_detailed_GTIGN_4=juy258_1505_events[juy258_1505_events['Message'].str.contains('GTIGN')]
mileage_report_detailed_GTIGN_4.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIGN_4.csv')

# %% [markdown]
# ##NNZ901

# %%
nnz901=pd.read_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/Export (5).xlsx - Sheet1.csv')
nnz901.info()
nnz901.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1839 entries, 0 to 1838
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1839 non-null   object
#  1   Message  1839 non-null   object
#  2   Status   1839 non-null   object
# dtypes: object(3)
# memory usage: 43.2+ KB
#                    Created                                            Message  \
# 0  2025-05-14 00:04:28.675  +RESP:GTPDP,500501,868574042797378,,2025051400...
# 1  2025-05-14 00:34:11.302  +RESP:GTFRI,500501,868574042797378,,,10,1,1,0....
# 2  2025-05-14 01:05:03.317  +RESP:GTPDP,500501,868574042797378,,2025051401...
# 3  2025-05-14 01:33:12.389  +RESP:GTFRI,500501,868574042797378,,,10,1,1,0....
# 4  2025-05-14 02:03:28.597  +RESP:GTPDP,500501,868574042797378,,2025051402...
#
#                                               Status
# 0  0x2B524553503A47545044502C3530303530312C383638...
# 1  0x2B524553503A47544652492C3530303530312C383638...
# ...

# %%
nnz901_1505_events=nnz901
nnz901_1505_events['Message_format']=nnz901_1505_events['Message'].str[0:11]
nnz901_1505_events.groupby(['Message_format']).count()
# Out:
#                 Created  Message  Status
# Message_format
# +BUFF:GTFRI           7        7       7
# +BUFF:GTIGF           1        1       1
# +BUFF:GTSTT           2        2       2
# +RESP:GTFRI        1622     1622    1622
# +RESP:GTIGF           4        4       4
# +RESP:GTIGL          11       11      11
# +RESP:GTIGN           6        6       6
# +RESP:GTPDP          34       34      34
# +RESP:GTSTT         152      152     152

# %%
mileage_report_detailed_nnz901_4=nnz901_1505_events[nnz901_1505_events['Message'].str.contains('GTIGN')]
mileage_report_detailed_GTIGN_4.to_csv('/content/drive/MyDrive/TSO Mobile/Colab/Mileage/mileage_report_detailed_GTIGN_5.csv')
