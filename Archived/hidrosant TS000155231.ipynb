# %%
import pandas as pd
import numpy as np

# %%
hl=pd.read_csv('/home/jlhb1984/py-projects/data/hidrosant/hlHBZN580NKLAH21750.csv',sep=';',encoding='latin1')
hl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23672 entries, 0 to 23671
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     23672 non-null  int64
#  1   Unit         23672 non-null  object
#  2   Events       23672 non-null  object
#  3   Date         23672 non-null  object
#  4   Landmark     126 non-null    object
#  5   Address      23672 non-null  object
#  6   Speed        23672 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     23672 non-null  float64
#  10  Longitude    23672 non-null  float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 2.0+ MB

# %%
hl['Events'].value_counts()
# Out:
# Events
# POWER UP            12371
# ENCENDIDO           10793
# Parked                138
# APAGADO                84
# Towing/Drifting?       76
# Idle - Stop            63
# Landmark OUT           63
# Idle Alert             47
# Travel Start           17
# Drive                  10
# Travel Stop             9
# Low Battery             1
# Name: count, dtype: int64
