# %%
import pandas as pd

# %%
jdn648=pd.read_csv('/home/jlhb1984/py-projects/data/TSO_overspeed/jdn648.xlsx - Sheet1.csv')
jdn648.info()
jdn648_speed=jdn648[jdn648['Created'].str.contains('12:4')]
jdn648_speed
jdn648_speed.to_csv('/home/jlhb1984/py-projects/data/TSO_overspeed/jdn648_speed.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1003 non-null   object
#  1   Message  1003 non-null   object
#  2   Status   1003 non-null   object
# dtypes: object(3)
# memory usage: 23.6+ KB

# %%
utb52f=pd.read_csv('/home/jlhb1984/py-projects/data/TSO_overspeed/utb52f.xlsx - Sheet1.csv')
utb52f.info()
utb52f_speed=pd.concat([utb52f[utb52f['Created'].str.contains('20:5')],utb52f[utb52f['Created'].str.contains('21:0')]],axis=0)
utb52f_speed
utb52f_speed.to_csv('/home/jlhb1984/py-projects/data/TSO_overspeed/utb52f_speed.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  243 non-null    object
#  1   Message  243 non-null    object
#  2   Status   243 non-null    object
# dtypes: object(3)
# memory usage: 5.8+ KB
