# %%
import pandas as pd
import numpy as np

# %%
mrr_vf=pd.read_csv('/home/jlhb1984/py-projects/data/vidfleets TS000157877/CRMUnitsDealersReports_16072025.csv',sep=';',encoding='latin1')
mrr_vf['Unit Type'].fillna('EMPTY',inplace=True)
mrr_vf_total=mrr_vf[mrr_vf['Unit Type'].str.contains('Fleet')]
#mrr_vf_total.info()
mrr_vf_total_col=mrr_vf_total[mrr_vf_total['Dealer'].str.contains('TSO Mobile - Colombia')]
#mrr_vf_total_col.info()
print('MRR_VF Colombia USD: ',(int(mrr_vf_total_col['Monthly Fee'].head(1))*520)/4000)
mrr_vf_total_per=mrr_vf_total[mrr_vf_total['Dealer'].str.contains('TRACKING SOLUTION')]
#mrr_vf_total_per.info()
# Out:
# MRR_VF Colombia USD:  21840.0
# /tmp/ipykernel_51988/2860331277.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   mrr_vf['Unit Type'].fillna('EMPTY',inplace=True)
# /tmp/ipykernel_51988/2860331277.py:7: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('MRR_VF Colombia USD: ',(int(mrr_vf_total_col['Monthly Fee'].head(1))*520)/4000)

# %%
vf1=pd.read_csv('/home/jlhb1984/py-projects/data/vidfleets TS000157877/6B31111V.csv',sep=';',encoding='latin1')
vf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14560 entries, 0 to 14559
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  14560 non-null  object
#  1   Message  14560 non-null  object
#  2   Status   14560 non-null  object
# dtypes: object(3)
# memory usage: 341.4+ KB

# %%
vf1_m=pd.read_csv('/home/jlhb1984/py-projects/data/vidfleets TS000157877/6B31111V_m.csv',sep=';',encoding='latin1')
vf1_m.head(5)
# Out:
# /tmp/ipykernel_51988/2254302817.py:1: DtypeWarning: Columns (128,129,130,131,132,133,134,135,136,137,138,139) have mixed types. Specify dtype option on import or set low_memory=False.
#   vf1_m=pd.read_csv('/home/jlhb1984/py-projects/data/vidfleets TS000157877/6B31111V_m.csv',sep=';',encoding='latin1')
#                                    Message     Unnamed: 1  \
# 0           {"notificationType":"TripInfo"  sn:"6B31111V"
# 1           {"notificationType":"TripInfo"  sn:"6B31111V"
# 2  {"notificationType":"CameraRunningInfo"  sn:"6B31111V"
# 3           {"notificationType":"TripInfo"  sn:"6B31111V"
# 4     {"notificationType":"IgnitionStatus"  sn:"6B31111V"
#
#                                       Unnamed: 2  \
# 0  tripID:"c8fdc4ff-8a7e-47c1-ac30-937afb1d6e2a"
# 1  tripID:"c8fdc4ff-8a7e-47c1-ac30-937afb1d6e2a"
# 2  tripID:"c8fdc4ff-8a7e-47c1-ac30-937afb1d6e2a"
# 3  tripID:"c8fdc4ff-8a7e-47c1-ac30-937afb1d6e2a"
# 4                                   vehicleID:""
#
# ...

# %%
vf1_m['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              7946
# {"notificationType":"CameraRunningInfo"     2966
# {"notificationType":"AutoSnapshot"          2121
# {"notificationType":"IgnitionStatus"         755
# {"notificationType":"CameraEvent"            397
# {"notificationType":"DataUsage"              342
# {"notificationType":"ParkingHeartbeat"        24
# {"notificationType":"MaintenanceWarning"       9
# Name: count, dtype: int64

# %%
vf_camera_events=vf1_m[vf1_m['Message'].str.contains('CameraEvent')]
vf_camera_events.head(5)
# Out:
#                                Message     Unnamed: 1  \
# 48   {"notificationType":"CameraEvent"  sn:"6B31111V"
# 532  {"notificationType":"CameraEvent"  sn:"6B31111V"
# 538  {"notificationType":"CameraEvent"  sn:"6B31111V"
# 697  {"notificationType":"CameraEvent"  sn:"6B31111V"
# 832  {"notificationType":"CameraEvent"  sn:"6B31111V"
#
#                                         Unnamed: 2    Unnamed: 3  \
# 48   tripID:"e119498d-2bde-4092-85dc-04adc5d55915"  vehicleID:""
# 532  tripID:"4c71f44b-f4fe-4001-984f-2d19e48512cb"  vehicleID:""
# 538  tripID:"4c71f44b-f4fe-4001-984f-2d19e48512cb"  vehicleID:""
# 697  tripID:"950b5a58-5d48-4759-8dba-794e9f875a85"  vehicleID:""
# 832  tripID:"2f686028-3c88-4cd6-ae5c-a965d8c5a915"  vehicleID:""
#
#                             Unnamed: 4                          Unnamed: 5  \
# 48   event:"FORWARD_COLLISION_WARNING"   eventCategory:"FORWARD_COLLISION"
# 532  event:"FORWARD_COLLISION_WARNING"   eventCategory:"FORWARD_COLLISION"
# ...

# %% [markdown]
# # Eventos

# %%
vf_camera_events_filtered=vf_camera_events[['Unnamed: 4','Unnamed: 5','Unnamed: 6']]
vf_camera_events['Unnamed: 4'].value_counts()#.to_csv('/home/jlhb1984/py-projects/data/vidfleets TS000157877/6B31111V_events.csv')
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"       138
# event:"SHARP_TURN"                      103
# event:"SMOKING"                          75
# event:"HARD_BRAKE"                       20
# event:"POTENTIAL_INCIDENT_LOW"           14
# event:"STOP_SIGN_VIOLATION"              14
# event:"POTENTIAL_INCIDENT_MEDIUM"         8
# event:"USING_PHONE"                       7
# event:"DROWSINESS"                        6
# event:"HARD_ACCEL"                        5
# event:"HEADWAY_MONITORING_EMERGENCY"      2
# event:"LANE_DEPARTURE_WARNING"            2
# event:"MANUAL"                            1
# event:"NO_SEATBELT"                       1
# event:"YAWN"                              1
# Name: count, dtype: int64

# %% [markdown]
# # Categorías

# %%
vf_camera_events['Unnamed: 5'].value_counts()
vf_camera_events['Unnamed: 5'].value_counts().to_csv('/home/jlhb1984/py-projects/data/vidfleets TS000157877/6B31111V_categories.csv')

# %% [markdown]
# # Niveles

# %%
vf_camera_events['Unnamed: 6'].value_counts().to_csv('/home/jlhb1984/py-projects/data/vidfleets TS000157877/6B31111V_level.csv')
