# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## VCU-776

# %% [markdown]
# SETPARAMS 125=79;126=82;ENDPARAMS 24-06-2025 6:03am
#
# Puse mi mail para la recepción de notificaciones 24-06-2025 10:31am
#
# SETPARAMS 125=79;126=82;ENDPARAMS 24-06-2025 10:46am

# %%
vcu776=pd.read_csv('/home/jlhb1984/py-projects/data/ricopollo/hlvcu776.csv',sep=';',encoding='latin1')
vcu776.info()

vcu776.sort_values(by='Speed',ascending=False)
#print('Sequence - Speed')
#vcu776['Speed'].sort_values(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     592 non-null    int64
#  1   Unit         592 non-null    object
#  2   Events       592 non-null    object
#  3   Date         592 non-null    object
#  4   Landmark     44 non-null     object
#  5   Address      592 non-null    object
#  6   Speed        592 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       201 non-null    object
#  9   Latitude     592 non-null    float64
#  10  Longitude    592 non-null    float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 51.0+ KB
#      Sequence     Unit       Events                  Date Landmark  \
# 235       357  VCU-776        Drive  Jun 24 2025 06:26 AM      NaN
# 570        22  VCU-776        Drive  Jun 24 2025 12:17 AM      NaN
# ...

# %%
for i in range(0,592):
    if vcu776.iloc[i,6]>=60:
        print(vcu776.loc[i])
# Out:
# Sequence                                                   592
# Unit                                                   VCU-776
# Events                                                   Drive
# Date                                      Jun 24 2025 10:14 AM
# Landmark                                                   NaN
# Address        Pe-3sg PE-3SG,0, Pallpata, Espinar, Cusco, Perú
# Speed                                                       72
# Temperature                                                NaN
# Driver                       CHIARELLA ZEVALLOS,, MIGUEL ANGEL
# Latitude                                            -14.925188
# Longitude                                           -71.191554
# Name: 0, dtype: object
# Sequence                                       591
# Unit                                       VCU-776
# Events                                       Drive
# Date                          Jun 24 2025 10:14 AM
# ...
