# %%
# !pip install pandas

# %%
import pandas as pd

# %%
xvu383=pd.read_csv('/home/jlhb1984/py-projects/data/end_speed/Export.xlsx - Sheet1.csv')
xvu383.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2925 entries, 0 to 2924
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  2925 non-null   object
#  1   Message  2925 non-null   object
#  2   Status   2925 non-null   object
# dtypes: object(3)
# memory usage: 68.7+ KB

# %%
xvu383=pd.read_csv('/home/jlhb1984/py-projects/data/end_speed/Export.xlsx - Sheet1.csv')
xvu383_GTSPD=xvu383[xvu383['Message'].str.contains('GTSPD')]
xvu383_GTSPD
xvu383_GTSPD.sort_values(by=['Created'],ascending=True)
# Out:
#                       Created  \
# 65    2025-05-22 00:31:29.700
# 163   2025-05-22 01:33:43.598
# 221   2025-05-22 02:01:50.396
# 223   2025-05-22 02:02:49.889
# 235   2025-05-22 02:10:10.641
# 337   2025-05-22 10:06:43.317
# 627   2025-05-22 12:56:59.397
# 650   2025-05-22 13:11:41.884
# 679   2025-05-22 13:33:48.733
# 1081  2025-05-22 17:45:19.442
# 1424  2025-05-22 21:06:06.769
# 1454  2025-05-22 21:22:29.486
# 1465  2025-05-22 21:26:00.073
# 1568  2025-05-22 22:18:43.481
# 1898  2025-05-23 01:59:57.223
# 1904  2025-05-23 02:01:54.533
# 2094  2025-05-23 12:04:59.597
# 2099  2025-05-23 12:08:20.850
# 2446  2025-05-23 15:42:54.906
# 2501  2025-05-23 16:18:54.110
# 2839  2025-05-23 19:48:34.350
# 2851  2025-05-23 19:52:40.624
# 2852  2025-05-23 19:53:01.907
# 2910  2025-05-23 20:32:04.883
#
#                                                 Message  \
# 65    +RESP:GTSPD,500700,868574042857057,,,00,1,1,57...
# 163   +RESP:GTSPD,500700,868574042857057,,,00,1,1,51...
# ...

# %%
xvu3832205_010725=pd.read_csv('/home/jlhb1984/py-projects/data/end_speed/xvu3832205_010725.csv',sep=';',encoding='latin1')
xvu3832205_010725_GTSPD=xvu3832205_010725[xvu3832205_010725['Message'].str.contains('GTSPD')]
xvu3832205_010725_GTSPD
# Out:
#                        Created  \
# 65     2025-05-22 00:31:29.700
# 163    2025-05-22 01:33:43.598
# 221    2025-05-22 02:01:50.396
# 223    2025-05-22 02:02:49.889
# 235    2025-05-22 02:10:10.641
# ...                        ...
# 70388  2025-07-01 21:22:14.203
# 70389  2025-07-01 21:22:32.027
# 70392  2025-07-01 21:24:32.449
# 70403  2025-07-01 21:31:15.794
# 70406  2025-07-01 21:32:35.699
#
#                                                  Message  \
# 65     +RESP:GTSPD,500700,868574042857057,,,00,1,1,57...
# 163    +RESP:GTSPD,500700,868574042857057,,,00,1,1,51...
# 221    +RESP:GTSPD,500700,868574042857057,,,00,1,1,61...
# 223    +RESP:GTSPD,500700,868574042857057,,,00,1,1,62...
# 235    +RESP:GTSPD,500700,868574042857057,,,00,1,1,62...
# ...                                                  ...
# 70388  +RESP:GTSPD,500700,868574042857057,,,01,1,1,0....
# 70389  +RESP:GTSPD,500700,868574042857057,,,00,1,1,41...
# 70392  +RESP:GTSPD,500700,868574042857057,,,01,1,1,0....
# ...

# %% [markdown]
# ## 	TTV207

# %% [markdown]
# Se envió:
# AT+GTSPD=gv55w,3,0,80,10,300,0,0,0,0,,,,,,,,,,,,FFFF$ 01-07-2025
# Teleamigo caído, no se pudo hacer pruebas.

# %% [markdown]
# El sistema está aproximando al entero menor siguiente si hay decimales en mph, razón por la cual, si se establece máxima velocidad a 80Km/h, 80.2Km/h que sería 49.84mph, quedaría como 49mph que sería igual a 78Km/h y esto es lo que aparecerá en el reporte. Según Carlos Morante, la columna que guarda esta información en la base de datos está configurada como entero y no se puede modificar.
