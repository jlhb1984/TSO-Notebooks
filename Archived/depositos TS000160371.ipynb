# %%
import pandas as pd
import numpy as np
from collections import Counter
import csv

# %% [markdown]
# 0OFE unidad de pruebas, Script 7.72 y firmware actualizado. Basic Accum with iButton.
# LMU2630-01, GEMALTO HSPA, BATT, INT ANT, RADIO JAMMING

# %%
unit_0ofe=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/hl0ofe.csv',sep=';',encoding='latin1')
unit_0ofe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     26 non-null     int64
#  1   Unit         26 non-null     object
#  2   Events       26 non-null     object
#  3   Date         26 non-null     object
#  4   Landmark     26 non-null     object
#  5   Address      26 non-null     object
#  6   Speed        26 non-null     int64
#  7   Temperature  0 non-null      float64
#  8   Driver       15 non-null     object
#  9   Latitude     26 non-null     float64
#  10  Longitude    26 non-null     float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 2.4+ KB

# %%
unit_0ofe['Events'].value_counts()
# Out:
# Events
# iButton IN      5
# iButton OUT     4
# Ignition ON     3
# Idle - Stop     3
# Ignition OFF    3
# Encender        3
# Parked          2
# PÁNICO          2
# Idle Alert      1
# Name: count, dtype: int64

# %% [markdown]
# BUW-137
# Script 7.72 de iButton y firmware 85f actualizado.
# Se modificó el perfil a Basic Accum with iButton.
# LMU2630-01, GEMALTO HSPA, BATT, INT ANT, RADIO JAMMING

# %%
buw137=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/buw137.csv',sep=';',encoding='latin1')
buw137.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17080 entries, 0 to 17079
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  17080 non-null  object
#  1   Message  17080 non-null  object
#  2   Status   17080 non-null  object
# dtypes: object(3)
# memory usage: 400.4+ KB

# %%
hlbuw137=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/hlbuw137.csv',sep=';',encoding='latin1')
hlbuw137.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19126 entries, 0 to 19125
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     19126 non-null  int64
#  1   Unit         19126 non-null  object
#  2   Events       19126 non-null  object
#  3   Date         19126 non-null  object
#  4   Landmark     2437 non-null   object
#  5   Address      19126 non-null  object
#  6   Speed        19126 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       625 non-null    object
#  9   Latitude     19126 non-null  float64
#  10  Longitude    19126 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.6+ MB

# %%
hlbuw137['Events'].value_counts()
# Out:
# Events
# Drive                 7126
# Travel Start          2786
# Travel Stop           2498
# Ignition OFF          1324
# Ignition ON           1324
# Geofence OUT          1129
# Geofence IN           1128
# Idle - Stop            738
# Parked                 547
# iButton IN             251
# Idle Alert             177
# Landmark OUT            39
# Landmark IN             39
# Towing/Drifting?        13
# Harsh Deceleration       7
# Name: count, dtype: int64

# %%
hlbuw137_ibutton=hlbuw137[hlbuw137['Events'].str.contains('iButton')]
hlbuw137_ibutton['Date'].sort_values(ascending=True)
# Out:
# 18202    Sep 02 2025 01:06 PM
# 18180    Sep 02 2025 01:26 PM
# 18163    Sep 02 2025 01:36 PM
# 18149    Sep 02 2025 01:46 PM
# 18124    Sep 02 2025 02:03 PM
#                  ...
# 1042     Sep 29 2025 12:11 AM
# 356      Sep 30 2025 01:35 AM
# 285      Sep 30 2025 05:27 AM
# 258      Sep 30 2025 05:50 AM
# 19       Sep 30 2025 10:44 AM
# Name: Date, Length: 251, dtype: object

# %% [markdown]
# Nuevo analisis 23-10-2025

# %%
units=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/cu.csv',sep=';',encoding='latin1')
units.info()
units.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       9 non-null      int64
#  1   Owner                    9 non-null      object
#  2   Unit ID                  9 non-null      object
#  3   Unit                     9 non-null      object
#  4   Peripherals              3 non-null      object
#  5   BillingPeriod            9 non-null      object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            0 non-null      float64
#  9   Last Event Date          9 non-null      object
#  10  Monthly Fee              9 non-null      object
#  11  Bill To                  0 non-null      float64
#  12  Assigned To              9 non-null      object
#  13  Linked Mode              9 non-null      int64
# ...

# %%
units_calamp=units[units['Unit Type'].str.contains('CalAmp')]
units_calamp
units_calamp_imei=units_calamp['IMEI']
units_calamp_imei.to_csv('/home/jlhb1984/py-projects/data/depositos/cu_calamp_imeis.csv')

# %%
cal_units={
    'Unit_ID':['Config','Script','IMEI','Short name','Accum'],
    '0OUE':['Touch and go with autologout','7.72','352556102465056','CEP-433','51/674','Basic Accum with iButton'],
    '18E3':['Touch and go with autologout','7.72','352556102276784','CCX-791','155/155','None'],
    '0OUX':['Touch and go with autologout','7.72','354514101223156','BUW-137','69/477','Basic Accum with iButton'],
    '847Q':['Touch and go with autologout','7.72','352556102442352','BED-836','54/54','None'],
    '0OUT':['Touch and go with autologout','55.161','354514101228718','B3P-885','Fuel sensor'],
    '6861':['Touch and go with autologout','7.72','354514102310655','AWN-709','14/275','Basic Accum with iButton']}
cal_units
# Out:
# {'Unit_ID': ['Config', 'Script', 'IMEI', 'Short name', 'Accum'],
#  '0OUE': ['Touch and go with autologout',
#   '7.72',
#   '352556102465056',
#   'CEP-433',
#   '51/674',
#   'Basic Accum with iButton'],
#  '18E3': ['Touch and go with autologout',
#   '7.72',
#   '352556102276784',
#   'CCX-791',
#   '155/155',
#   'None'],
#  '0OUX': ['Touch and go with autologout',
#   '7.72',
#   '354514101223156',
#   'BUW-137',
#   '69/477',
#   'Basic Accum with iButton'],
#  '847Q': ['Touch and go with autologout',
#   '7.72',
#   '352556102442352',
#   'BED-836',
#   '54/54',
#   'None'],
#  '0OUT': ['Touch and go with autologout',
#   '55.161',
#   '354514101228718',
#   'B3P-885',
#   'Fuel sensor'],
#  '6861': ['Touch and go with autologout',
#   '7.72',
#   '354514102310655',
#   'AWN-709',
#   '14/275',
#   'Basic Accum with iButton']}

# %%
with open('cal_units.csv', mode='a', newline='') as file:
    file.write('\n')
    csv_writer = csv. DictWriter(file, fieldnames = cal_units.keys())
    csv_writer.writerow(cal_units)

# %%
cep433=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/cep433_2310.csv',sep=';',encoding='latin1')
cep433.info()
cep433['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11471 entries, 0 to 11470
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     11471 non-null  int64
#  1   Unit         11471 non-null  object
#  2   Events       11471 non-null  object
#  3   Date         11471 non-null  object
#  4   Landmark     1194 non-null   object
#  5   Address      11470 non-null  object
#  6   Speed        11471 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     11471 non-null  float64
#  10  Longitude    11471 non-null  float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 985.9+ KB
# Events
# Drive                 4132
# Travel Start          1669
# Travel Stop           1518
# iButton OUT            674
# Ignition OFF           668
# Ignition ON            668
# Geofence OUT           564
# Geofence IN            562
# ...

# %%
cep433_ibutton=cep433[cep433['Events'].str.contains('iButton')]
cep433_ibutton.head(20)
# Out:
#      Sequence     Unit       Events                  Date Landmark  \
# 0       11471  CEP-433  iButton OUT  Oct 23 2025 02:28 PM      NaN
# 17      11454  CEP-433  iButton OUT  Oct 23 2025 02:00 PM      NaN
# 20      11451  CEP-433  iButton OUT  Oct 23 2025 02:00 PM      NaN
# 23      11448  CEP-433  iButton OUT  Oct 23 2025 01:51 PM      NaN
# 52      11419  CEP-433  iButton OUT  Oct 23 2025 01:19 PM      NaN
# 120     11351  CEP-433  iButton OUT  Oct 23 2025 12:33 PM      NaN
# 154     11317  CEP-433  iButton OUT  Oct 23 2025 11:41 AM      NaN
# 167     11304  CEP-433  iButton OUT  Oct 23 2025 11:25 AM      NaN
# 181     11290  CEP-433  iButton OUT  Oct 23 2025 11:14 AM      NaN
# 194     11277  CEP-433  iButton OUT  Oct 23 2025 10:47 AM      NaN
# 195     11276  CEP-433   iButton IN  Oct 23 2025 10:47 AM      NaN
# 196     11275  CEP-433  iButton OUT  Oct 23 2025 10:46 AM      NaN
# 214     11257  CEP-433  iButton OUT  Oct 23 2025 10:07 AM      NaN
# ...

# %%
ccx791=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/ccx791_2310.csv',sep=';',encoding='latin1')
ccx791.info()
ccx791['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5640 entries, 0 to 5639
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     5640 non-null   int64
#  1   Unit         5640 non-null   object
#  2   Events       5640 non-null   object
#  3   Date         5640 non-null   object
#  4   Landmark     453 non-null    object
#  5   Address      5640 non-null   object
#  6   Speed        5640 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     5640 non-null   float64
#  10  Longitude    5640 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 484.8+ KB
# Events
# Drive                 1830
# Travel Start           791
# Travel Stop            741
# Idle - Stop            394
# Ignition OFF           372
# Ignition ON            372
# Parked                 275
# Geofence IN            227
# ...

# %%
ccx791_ibutton=ccx791[ccx791['Events'].str.contains('iButton')]
ccx791_ibutton.head(20)
# Out:
#      Sequence     Unit       Events                  Date Landmark  \
# 1        5639  CCX-791  iButton OUT  Oct 23 2025 01:55 PM      NaN
# 33       5607  CCX-791   iButton IN  Oct 23 2025 12:43 PM      NaN
# 34       5606  CCX-791  iButton OUT  Oct 23 2025 12:38 PM      NaN
# 60       5580  CCX-791   iButton IN  Oct 23 2025 12:27 PM      NaN
# 65       5575  CCX-791  iButton OUT  Oct 23 2025 11:17 AM      NaN
# 75       5565  CCX-791   iButton IN  Oct 23 2025 11:07 AM      NaN
# 85       5555  CCX-791  iButton OUT  Oct 23 2025 10:47 AM      NaN
# 107      5533  CCX-791   iButton IN  Oct 23 2025 10:34 AM      NaN
# 152      5488  CCX-791  iButton OUT  Oct 23 2025 09:55 AM      NaN
# 174      5466  CCX-791   iButton IN  Oct 23 2025 09:44 AM      NaN
# 201      5439  CCX-791  iButton OUT  Oct 23 2025 07:50 AM      NaN
# 207      5433  CCX-791   iButton IN  Oct 23 2025 07:48 AM      NaN
# 208      5432  CCX-791  iButton OUT  Oct 23 2025 07:46 AM      NaN
# ...

# %%
buw137=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/buw137_2310.csv',sep=';',encoding='latin1')
buw137.info()
buw137['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8286 entries, 0 to 8285
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     8286 non-null   int64
#  1   Unit         8286 non-null   object
#  2   Events       8286 non-null   object
#  3   Date         8286 non-null   object
#  4   Landmark     912 non-null    object
#  5   Address      8286 non-null   object
#  6   Speed        8286 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     8286 non-null   float64
#  10  Longitude    8286 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 712.2+ KB
# Events
# Drive                 2821
# Travel Start          1198
# Travel Stop           1130
# iButton OUT            477
# Ignition ON            450
# Ignition OFF           450
# Geofence IN            406
# Geofence OUT           405
# ...

# %%
bed836=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/bed836_2310.csv',sep=';',encoding='latin1')
bed836.info()
bed836['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6301 entries, 0 to 6300
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     6301 non-null   int64
#  1   Unit         6301 non-null   object
#  2   Events       6301 non-null   object
#  3   Date         6301 non-null   object
#  4   Landmark     622 non-null    object
#  5   Address      6300 non-null   object
#  6   Speed        6301 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     6301 non-null   float64
#  10  Longitude    6301 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 541.6+ KB
# Events
# Drive                 2220
# Travel Start          1001
# Travel Stop            892
# Ignition ON            400
# Ignition OFF           399
# Idle - Stop            345
# Geofence OUT           299
# Geofence IN            280
# ...

# %%
bed836_ibutton=bed836[bed836['Events'].str.contains('iButton')]
bed836_ibutton.head(2)
# Out:
#      Sequence     Unit       Events                  Date Landmark  \
# 565      5736  BED-836  iButton OUT  Oct 21 2025 03:56 PM      NaN
# 621      5680  BED-836   iButton IN  Oct 21 2025 03:17 PM      NaN
#
#                                       Address  Speed  Temperature  Driver  \
# 565  Av Atalaya, Callao, Callao, Callao, Perú      0          NaN     NaN
# 621  Av Atalaya, Callao, Callao, Callao, Perú      0          NaN     NaN
#
#       Latitude  Longitude
# 565 -12.050000 -77.139546
# 621 -12.050025 -77.139598

# %%
awn709=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/awn709_2310.csv',sep=';',encoding='latin1')
awn709.info()
awn709['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     4008 non-null   int64
#  1   Unit         4008 non-null   object
#  2   Events       4008 non-null   object
#  3   Date         4008 non-null   object
#  4   Landmark     258 non-null    object
#  5   Address      4008 non-null   object
#  6   Speed        4008 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     4008 non-null   float64
#  10  Longitude    4008 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 344.6+ KB
# Events
# Drive                 1306
# Travel Start           562
# Travel Stop            503
# iButton OUT            275
# Ignition OFF           274
# Ignition ON            274
# Parked                 236
# Idle - Stop            232
# ...

# %%
awn709_ibutton=awn709[awn709['Events'].str.contains('iButton')]
awn709_ibutton.head(2)
# Out:
#    Sequence     Unit       Events                  Date Landmark  \
# 1      4007  AWN-709  iButton OUT  Oct 23 2025 02:07 PM      NaN
# 9      3999  AWN-709  iButton OUT  Oct 23 2025 10:23 AM      NaN
#
#                                     Address  Speed  Temperature  Driver  \
# 1  Av Atalaya, Callao, Callao, Callao, Perú      0          NaN     NaN
# 9        Av Atalaya, Callao, Callao, Callao      0          NaN     NaN
#
#     Latitude  Longitude
# 1 -12.049970 -77.139197
# 9 -12.049987 -77.139515

# %%
ccx791_rd=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/ccx791rd.csv',sep=';',encoding='latin1')
ccx791_rd.info()
cep433_rd=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/cep433rd.csv',sep=';',encoding='latin1')
cep433_rd.info()
buw137_rd=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/buw137rd.csv',sep=';',encoding='latin1')
buw137_rd.info()
awn709_rd=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/awn709rd.csv',sep=';',encoding='latin1')
awn709_rd.info()
bed836_rd=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/bed836rd.csv',sep=';',encoding='latin1')
bed836_rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4919 entries, 0 to 4918
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  4919 non-null   object
#  1   Message  4919 non-null   object
#  2   Status   4919 non-null   object
# dtypes: object(3)
# memory usage: 115.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9877 entries, 0 to 9876
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  9877 non-null   object
#  1   Message  9877 non-null   object
#  2   Status   9877 non-null   object
# dtypes: object(3)
# memory usage: 231.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7182 entries, 0 to 7181
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  7182 non-null   object
#  1   Message  7182 non-null   object
# ...

# %%
key_id_aux='0000000000000000'
ibutton_key=[]
for i in range(0,4919):
    message=ccx791_rd.iloc[i,2]
    key_id=message[92:108]
    #print(key_id)
    if (key_id_aux)!=(key_id):
        ibutton_key.append(key_id)
#print(ibutton_key)
counts=Counter(ibutton_key)
print("ccx791: ",counts)
# Out:
# ccx791:  Counter({'9E64FD01EA00001F': 2020, '9EEAC3017D00001F': 2})

# %%
key_id_aux='0000000000000000'
ibutton_key=[]
for i in range(0,9877):
    message=cep433_rd.iloc[i,2]
    key_id=message[92:108]
    #print(key_id)
    if (key_id_aux)!=(key_id):
        ibutton_key.append(key_id)
#print(ibutton_key)
counts=Counter(ibutton_key)
print("cep433: ",counts)
# Out:
# cep433:  Counter({'9E6EB2010600001F': 405, '9E634C018B00001F': 76})

# %%
key_id_aux='0000000000000000'
ibutton_key=[]
for i in range(0,7182):
    message=buw137_rd.iloc[i,2]
    key_id=message[92:108]
    #print(key_id)
    if (key_id_aux)!=(key_id):
        ibutton_key.append(key_id)
#print(ibutton_key)
counts=Counter(ibutton_key)
print("buw137: ",counts)
# Out:
# buw137:  Counter({'9E6EB2010600001F': 1110, '9E634C018B00001F': 141})

# %%
key_id_aux='0000000000000000'
ibutton_key=[]
for i in range(0,3585):
    message=awn709_rd.iloc[i,2]
    key_id=message[92:108]
    #print(key_id)
    if (key_id_aux)!=(key_id):
        ibutton_key.append(key_id)
#print(ibutton_key)
counts=Counter(ibutton_key)
print("awn709: ",counts)
# Out:
# awn709:  Counter({'9E0A24010B00001F': 136})

# %%
key_id_aux='0000000000000000'
ibutton_key=[]
for i in range(0,3585):
    message=bed836_rd.iloc[i,2]
    key_id=message[108:127]
    #print(key_id)
    if (key_id_aux)!=(key_id):
        ibutton_key.append(key_id)
#print(ibutton_key)
counts=Counter(ibutton_key)
print("bed836: ",counts)
# Out:
# bed836:  Counter({'9EEAC3017D00001F': 482})

# %% [markdown]
# Llaves registradas por las unidades:
#
#
# 9E0A24010B00001F
# 9E6EB2010600001F
# 9E634C018B00001F
# 9E64FD01EA00001F
# 9EEAC3017D00001F
#
# Llaves registradas por el usuario:
# 9E6EB2010600001F
# 9E0A24010B00001F
# 9E397D017900001F
# 9EEAC3017D00001F
# 9E6EB2010600001
# 9E64FD01EA00001F

# %% [markdown]
# Nuevo análisis después de liberación del caso de Desarrollo 07-11-2025.

# %%
cu1911=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/cu_1911.csv',sep=';',encoding='latin1')
cu1911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       9 non-null      int64
#  1   Owner                    9 non-null      object
#  2   Unit ID                  9 non-null      object
#  3   Unit                     9 non-null      object
#  4   Peripherals              3 non-null      object
#  5   BillingPeriod            9 non-null      object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            0 non-null      float64
#  9   Last Event Date          9 non-null      object
#  10  Monthly Fee              9 non-null      object
#  11  Bill To                  0 non-null      float64
#  12  Assigned To              9 non-null      object
#  13  Linked Mode              9 non-null      int64
# ...

# %%
cu1911['Peripherals'].value_counts()
# Out:
# Peripherals
# MDVR - 009901C514,    1
# MDVR - 007102572C,    1
# MDVR - 007102572F,    1
# Name: count, dtype: int64

# %%
cu1911['Unit Type'].value_counts()
# Out:
# Unit Type
# CalAmp 2630 - CINTERION GSM - LMU30H30BT3-G1000    3
# CalAmp 2630 - GEMALTO HSPA -LMU26H3001-JAM01       3
# VidFleet 4K                                        1
# Queclink GV55W                                     1
# Queclink GV55Lite                                  1
# Name: count, dtype: int64

# %%
cu1911_calamp=cu1911[cu1911['Unit Type'].str.contains('CalAmp')]
cu1911_calamp_f=cu1911_calamp[['Unit Type','Unit ID','Unit','Last Event Date','IMEI']]

# %%
cu1911_calamp_f.to_csv('/home/jlhb1984/py-projects/data/depositos/cu_1911_imeis.csv')

# %%
cu_scripts_firmawre=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/devices-11-19-2025.csv')
cu_scripts_firmawre_f=cu_scripts_firmawre[['ID','Model','Script Identifier','Firmware Version','IMEI']]
cu_scripts_firmawre_f
# Out:
#         ID    Model  Script Identifier Firmware Version             IMEI
# 0  4111809  LMU2630              7.720              85f  352556102442352
# 1  4111723  LMU2630              7.720              85f  352556102276784
# 2  4232849  LMU2630              7.720              85f  354514102310655
# 3  4111227  LMU2630              7.720              85f  352556102465056
# 4  4109872  LMU2630              7.720              85f  354514101223156
# 5  4109867  LMU2630             55.161              85f  354514101228718

# %% [markdown]
# CEP-433 01-09-2025 19-11-2025:

# %%
cep433_rd_01091911=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/cep433_01091911m.csv',sep=';',encoding='latin1')
cep433_rd_01091911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24329 entries, 0 to 24328
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      24329 non-null  int64
#  1   Unnamed: 1   24329 non-null  int64
#  2   Unnamed: 2   24329 non-null  int64
#  3   Unnamed: 3   24329 non-null  int64
#  4   Unnamed: 4   24329 non-null  int64
#  5   Unnamed: 5   24329 non-null  int64
#  6   Unnamed: 6   24329 non-null  int64
#  7   Unnamed: 7   24329 non-null  int64
#  8   Unnamed: 8   24329 non-null  int64
#  9   Unnamed: 9   24329 non-null  object
#  10  Unnamed: 10  24329 non-null  object
#  11  Unnamed: 11  24329 non-null  int64
#  12  Unnamed: 12  24329 non-null  int64
#  13  Unnamed: 13  24329 non-null  int64
#  14  Unnamed: 14  24329 non-null  int64
#  15  Unnamed: 15  24329 non-null  object
#  16  Unnamed: 16  24329 non-null  int64
#  17  Unnamed: 17  24329 non-null  int64
#  18  Unnamed: 18  24329 non-null  int64
# ...

# %%
key_id_aux='0x000000000000000000000000000000000000000000000000|'
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_cep433=pd.DataFrame()

for i in range(0,24329):
    key_id=cep433_rd_01091911.iloc[i,21]
    if (key_id_aux)!=(key_id):
        unix_time_aux=cep433_rd_01091911.iloc[i,8]
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        ibutton_key.append(key_id[10:26])
        date_time.append(date_time_aux)

        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_cep433['Date_Time']=date_time
df_aux_cep433['ibutton_key']=ibutton_key
#print(date_time,ibutton_key)   
df_aux_cep433.to_csv('/home/jlhb1984/py-projects/data/depositos/cep433_01091911_iButton_date.csv')

# %% [markdown]
# CCX-791 01-09-2025 19-11-2025:

# %%
ccx791_rd_01091911=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/ccx791_01091911m.csv',sep=';',encoding='latin1')
ccx791_rd_01091911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18447 entries, 0 to 18446
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      18447 non-null  int64
#  1   Unnamed: 1   18447 non-null  int64
#  2   Unnamed: 2   18447 non-null  int64
#  3   Unnamed: 3   18447 non-null  int64
#  4   Unnamed: 4   18447 non-null  int64
#  5   Unnamed: 5   18447 non-null  int64
#  6   Unnamed: 6   18447 non-null  int64
#  7   Unnamed: 7   18447 non-null  int64
#  8   Unnamed: 8   18447 non-null  int64
#  9   Unnamed: 9   18447 non-null  object
#  10  Unnamed: 10  18447 non-null  object
#  11  Unnamed: 11  18447 non-null  int64
#  12  Unnamed: 12  18447 non-null  int64
#  13  Unnamed: 13  18447 non-null  int64
#  14  Unnamed: 14  18447 non-null  int64
#  15  Unnamed: 15  18447 non-null  object
#  16  Unnamed: 16  18447 non-null  int64
#  17  Unnamed: 17  18447 non-null  int64
#  18  Unnamed: 18  18447 non-null  int64
# ...

# %%
key_id_aux='0x000000000000000000000000000000000000000000000000|'
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_ccx791=pd.DataFrame()

for i in range(0,18447):
    key_id=ccx791_rd_01091911.iloc[i,21]
    if (key_id_aux)!=(key_id):
        unix_time_aux=ccx791_rd_01091911.iloc[i,8]
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        ibutton_key.append(key_id[10:26])
        date_time.append(date_time_aux)

        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_ccx791['Date_Time']=date_time
df_aux_ccx791['ibutton_key']=ibutton_key
#print(date_time,ibutton_key)   
df_aux_ccx791.to_csv('/home/jlhb1984/py-projects/data/depositos/ccx791_01091911_iButton_date.csv')

# %% [markdown]
# BUW-137 01-09-2025 19-11-2025:

# %%
buw137_rd_01091911=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/buw137_01091911m.csv',sep=';',encoding='latin1')
buw137_rd_01091911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33383 entries, 0 to 33382
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      33383 non-null  int64
#  1   Unnamed: 1   33383 non-null  int64
#  2   Unnamed: 2   33383 non-null  int64
#  3   Unnamed: 3   33383 non-null  int64
#  4   Unnamed: 4   33383 non-null  int64
#  5   Unnamed: 5   33383 non-null  int64
#  6   Unnamed: 6   33383 non-null  int64
#  7   Unnamed: 7   33383 non-null  int64
#  8   Unnamed: 8   33383 non-null  int64
#  9   Unnamed: 9   33383 non-null  object
#  10  Unnamed: 10  33383 non-null  object
#  11  Unnamed: 11  33383 non-null  int64
#  12  Unnamed: 12  33383 non-null  int64
#  13  Unnamed: 13  33383 non-null  int64
#  14  Unnamed: 14  33383 non-null  int64
#  15  Unnamed: 15  33383 non-null  object
#  16  Unnamed: 16  33383 non-null  int64
#  17  Unnamed: 17  33383 non-null  int64
#  18  Unnamed: 18  33383 non-null  int64
# ...

# %%
key_id_aux='0x000000000000000000000000000000000000000000000000|'
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_buw137=pd.DataFrame()

for i in range(0,33383):
    key_id=buw137_rd_01091911.iloc[i,21]
    if (key_id_aux)!=(key_id):
        unix_time_aux=buw137_rd_01091911.iloc[i,8]
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        ibutton_key.append(key_id[10:26])
        date_time.append(date_time_aux)

        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_buw137['Date_Time']=date_time
df_aux_buw137['ibutton_key']=ibutton_key
#print(date_time,ibutton_key)   
df_aux_buw137.to_csv('/home/jlhb1984/py-projects/data/depositos/buw137_01091911_iButton_date.csv')

# %% [markdown]
# BED-836 01-09-2025 19-11-2025:

# %%
bed836_rd_01091911=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/bed836_01091911m.csv',sep=';',encoding='latin1')
bed836_rd_01091911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22290 entries, 0 to 22289
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      22290 non-null  int64
#  1   Unnamed: 1   22290 non-null  int64
#  2   Unnamed: 2   22290 non-null  int64
#  3   Unnamed: 3   22290 non-null  int64
#  4   Unnamed: 4   22290 non-null  int64
#  5   Unnamed: 5   22290 non-null  int64
#  6   Unnamed: 6   22290 non-null  int64
#  7   Unnamed: 7   22290 non-null  int64
#  8   Unnamed: 8   22290 non-null  int64
#  9   Unnamed: 9   22290 non-null  object
#  10  Unnamed: 10  22290 non-null  object
#  11  Unnamed: 11  22290 non-null  int64
#  12  Unnamed: 12  22290 non-null  int64
#  13  Unnamed: 13  22290 non-null  int64
#  14  Unnamed: 14  22290 non-null  int64
#  15  Unnamed: 15  22290 non-null  object
#  16  Unnamed: 16  22290 non-null  int64
#  17  Unnamed: 17  22290 non-null  int64
#  18  Unnamed: 18  22290 non-null  int64
# ...

# %%
key_id_aux='00'
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_bed836=pd.DataFrame()

for i in range(0,22290):
    key_id=bed836_rd_01091911.iloc[i,21]
    if (key_id_aux)!=(key_id[40:42]):
        #print(key_id[40:42])
        unix_time_aux=bed836_rd_01091911.iloc[i,8]
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        ibutton_key.append(key_id[26:42])
        date_time.append(date_time_aux)

        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_bed836['Date_Time']=date_time
df_aux_bed836['ibutton_key']=ibutton_key
#print(date_time,ibutton_key)   
df_aux_bed836.to_csv('/home/jlhb1984/py-projects/data/depositos/bed836_01091911_iButton_date.csv')

# %% [markdown]
# AWN-709 01-09-2025 19-11-2025:

# %%
awn709_rd_01091911=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/awn709_01091911m.csv',sep=';',encoding='latin1')
awn709_rd_01091911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13740 entries, 0 to 13739
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      13740 non-null  int64
#  1   Unnamed: 1   13740 non-null  int64
#  2   Unnamed: 2   13740 non-null  int64
#  3   Unnamed: 3   13740 non-null  int64
#  4   Unnamed: 4   13740 non-null  int64
#  5   Unnamed: 5   13740 non-null  int64
#  6   Unnamed: 6   13740 non-null  int64
#  7   Unnamed: 7   13740 non-null  int64
#  8   Unnamed: 8   13740 non-null  int64
#  9   Unnamed: 9   13740 non-null  object
#  10  Unnamed: 10  13740 non-null  object
#  11  Unnamed: 11  13740 non-null  int64
#  12  Unnamed: 12  13740 non-null  int64
#  13  Unnamed: 13  13740 non-null  int64
#  14  Unnamed: 14  13740 non-null  int64
#  15  Unnamed: 15  13740 non-null  object
#  16  Unnamed: 16  13740 non-null  int64
#  17  Unnamed: 17  13740 non-null  int64
#  18  Unnamed: 18  13740 non-null  int64
# ...

# %%
key_id_aux='0x000000000000000000000000000000000000000000000000|'
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_awn709=pd.DataFrame()

for i in range(0,13740):
    key_id=awn709_rd_01091911.iloc[i,21]
    if (key_id_aux)!=(key_id):
        unix_time_aux=awn709_rd_01091911.iloc[i,8]
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        ibutton_key.append(key_id[10:26])
        date_time.append(date_time_aux)

        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_awn709['Date_Time']=date_time
df_aux_awn709['ibutton_key']=ibutton_key
#print(date_time,ibutton_key)   
df_aux_awn709.to_csv('/home/jlhb1984/py-projects/data/depositos/awn709_01091911_iButton_date.csv')

# %%
df_aux_awn709['ibutton_key'].value_counts()
# Out:
# ibutton_key
# 9E0A24010B00001F    1262
# 9EEAC3017D00001F      81
# Name: count, dtype: int64

# %%
df_aux_bed836['ibutton_key'].value_counts()
# Out:
# ibutton_key
# 9EEAC3017D00001F    3796
# 9E397D017900001F     934
# 9EB0D901C100001F      22
# Name: count, dtype: int64

# %%
df_aux_buw137['ibutton_key'].value_counts()
# Out:
# ibutton_key
# 9E6EB2010600001F    5149
# 9E634C018B00001F     226
# Name: count, dtype: int64

# %%
df_aux_ccx791['ibutton_key'].value_counts()
# Out:
# ibutton_key
# 9E64FD01EA00001F    6766
# 9EEAC3017D00001F       8
# Name: count, dtype: int64

# %%
df_aux_cep433['ibutton_key'].value_counts()
# Out:
# ibutton_key
# 9E6EB2010600001F    950
# 9E397D017900001F    215
# 9E634C018B00001F     76
# 9E64FD01EA00001F     15
# Name: count, dtype: int64

# %% [markdown]
# 9E6EB2010600001F 0600001F9E6EB201   AREA VIGILANCIA
# 9E397D017900001F 7900001F9E397D01   AREA MANTENIMIENTO
# 9E634C018B00001F 8B00001F9E634C01   Sin asignar
# 9E64FD01EA00001F EA00001F9E64FD01   AREA SSO
# 9EEAC3017D00001F 7D00001F9EEAC301   AREA OPERACIONES
#
# 9E6EB2010600001F
# 9E0A24010B00001F No existe en data cruda
# 9E397D017900001F
# 9EEAC3017D00001F
# 9E6EB2010600001 No existe en data cruda (le falta un caracter)
# 9E64FD01EA00001F
#
# ![image.png](attachment:image.png)

# %% [markdown]
# BFA5450126000018 en raw data y 26000018BFA54501 en TSO asignado a Juan Zambrano

# %% [markdown]
# Probar colocando email y phone number. AREA MANTENIMIENTO se le puso email y pn

# %% [markdown]
# Inversión de llaves:
# ![image.png](attachment:image.png)

# %%
cal_units={
    'Unit_ID':['Script','IMEI','Short name','Accumulator profile','iButton Type','Accum3','Accum4','Number of Accums','Working?'],
    '1BL4':['7.72','016074000215183','1BL4','Basic Accum with iButton','Touch and Go with Auto LogOut','BFA54501','26000018','5','Yes'],
    '0OUE':['7.72','352556102465056','CEP-433','Basic Accum with iButton','Touch and Go with Auto LogOut','9E6EB201','0600001F','8','No'],
    '18E3':['7.72','352556102276784','CCX-791','Basic Accum with iButton','Touch and Go with Auto LogOut','9E64FD01','EA00001F','8','No'],
    '0OUX':['7.72','354514101223156','BUW-137','Basic Accum with iButton','Touch and Go with Auto LogOut','9E6EB201','0600001F','8','No'],
    '847Q':['7.72','352556102442352','BED-836','None->Basic Accum with iButton','Touch and Go with Auto LogOut','9EB0D901','C100001F','5','No'],
    '0OUT':['55.161','354514101228718','B3P-885','Fuel sensor'],
    '6861':['7.72','354514102310655','AWN-709','Basic Accum with iButton','Touch and Go with Auto LogOut','9E0A2401','0B00001F','8','No']}
cal_units
# Out:
# {'Unit_ID': ['Script',
#   'IMEI',
#   'Short name',
#   'Accumulator profile',
#   'iButton Type',
#   'Accum3',
#   'Accum4',
#   'Number of Accums',
#   'Working?'],
#  '1BL4': ['7.72',
#   '016074000215183',
#   '1BL4',
#   'Basic Accum with iButton',
#   'Touch and Go with Auto LogOut',
#   'BFA54501',
#   '26000018',
#   '5',
#   'Yes'],
#  '0OUE': ['7.72',
#   '352556102465056',
#   'CEP-433',
#   'Basic Accum with iButton',
#   'Touch and Go with Auto LogOut',
#   '9E6EB201',
#   '0600001F',
#   '8',
#   'No'],
#  '18E3': ['7.72',
#   '352556102276784',
#   'CCX-791',
#   'Basic Accum with iButton',
#   'Touch and Go with Auto LogOut',
#   '9E64FD01',
#   'EA00001F',
#   '8',
#   'No'],
#  '0OUX': ['7.72',
#   '354514101223156',
#   'BUW-137',
#   'Basic Accum with iButton',
#   'Touch and Go with Auto LogOut',
#   '9E6EB201',
#   '0600001F',
#   '8',
#   'No'],
#  '847Q': ['7.72',
#   '352556102442352',
#   'BED-836',
#   'None->Basic Accum with iButton',
# ...

# %%
unit_id=input('Type Unit ID')
print(unit_id,":",cal_units[unit_id])
# Out:
# 1BL4 : ['7.72', '016074000215183', '1BL4', 'Basic Accum with iButton', 'Touch and Go with Auto LogOut', 'BFA54501', '26000018', '5', 'Yes']

# %% [markdown]
# Hice nueva inversión de llaves 20-11-2025 según el diccionario cal_units. Revisar nuevamente hoy 21-11-2025.
# Actualicé script en CTC.

# %% [markdown]
# # Nuevo análisis 21-11-2025:

# %% [markdown]
# CEP-433 01-09-2025 21-11-2025. No está reportando iButton desde 04-11-2025.

# %%
cep433_rd_01092111=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/cep433_01092111m.csv',sep=';',encoding='latin1')
cep433_rd_01092111.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24423 entries, 0 to 24422
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      24423 non-null  int64
#  1   Unnamed: 1   24423 non-null  int64
#  2   Unnamed: 2   24423 non-null  int64
#  3   Unnamed: 3   24423 non-null  int64
#  4   Unnamed: 4   24423 non-null  int64
#  5   Unnamed: 5   24423 non-null  int64
#  6   Unnamed: 6   24423 non-null  int64
#  7   Unnamed: 7   24423 non-null  int64
#  8   Unnamed: 8   24423 non-null  int64
#  9   Unnamed: 9   24423 non-null  object
#  10  Unnamed: 10  24423 non-null  object
#  11  Unnamed: 11  24423 non-null  int64
#  12  Unnamed: 12  24423 non-null  int64
#  13  Unnamed: 13  24423 non-null  int64
#  14  Unnamed: 14  24423 non-null  int64
#  15  Unnamed: 15  24423 non-null  object
#  16  Unnamed: 16  24423 non-null  int64
#  17  Unnamed: 17  24423 non-null  int64
#  18  Unnamed: 18  24423 non-null  int64
# ...

# %%
key_id_aux='0x000000000000000000000000000000000000000000000000|'
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_cep433=pd.DataFrame()                                        #editable

for i in range(0,24336): #Cambie el límite por error en 24337
    key_id=cep433_rd_01092111.iloc[i,21]                            #editable
    #print(i)
    if (key_id_aux)!=(key_id):
        unix_time_aux=cep433_rd_01092111.iloc[i,8]                  #editable 
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        ibutton_key.append(key_id[10:26])
        date_time.append(date_time_aux)

        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_cep433['Date_Time']=date_time                                #editable
df_aux_cep433['ibutton_key']=ibutton_key                            #editable
#print(date_time,ibutton_key)   
df_aux_cep433.to_csv('/home/jlhb1984/py-projects/data/depositos/cep433_01092111_iButton_date.csv')  #editable

# %% [markdown]
# CCX-791 01-09-2025 21-11-2025: ültimo iButton 20-11 ****

# %%
ccx791_rd_01092111=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/ccx791_01092111m.csv',sep=';',encoding='latin1')
ccx791_rd_01092111.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19104 entries, 0 to 19103
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      19104 non-null  int64
#  1   Unnamed: 1   19104 non-null  int64
#  2   Unnamed: 2   19104 non-null  int64
#  3   Unnamed: 3   19104 non-null  int64
#  4   Unnamed: 4   19104 non-null  int64
#  5   Unnamed: 5   19104 non-null  int64
#  6   Unnamed: 6   19104 non-null  int64
#  7   Unnamed: 7   19104 non-null  int64
#  8   Unnamed: 8   19104 non-null  int64
#  9   Unnamed: 9   19104 non-null  object
#  10  Unnamed: 10  19104 non-null  object
#  11  Unnamed: 11  19104 non-null  int64
#  12  Unnamed: 12  19104 non-null  int64
#  13  Unnamed: 13  19104 non-null  int64
#  14  Unnamed: 14  19104 non-null  int64
#  15  Unnamed: 15  19104 non-null  object
#  16  Unnamed: 16  19104 non-null  int64
#  17  Unnamed: 17  19104 non-null  int64
#  18  Unnamed: 18  19104 non-null  int64
# ...

# %%
key_id_aux='0x000000000000000000000000000000000000000000000000|'
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_ccx791=pd.DataFrame()                                        #editable

for i in range(0,19104):                                            #editable
    key_id=ccx791_rd_01092111.iloc[i,21]                            #editable
    #print(i)
    if (key_id_aux)!=(key_id):
        unix_time_aux=ccx791_rd_01092111.iloc[i,8]                  #editable 
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        ibutton_key.append(key_id[10:26])
        date_time.append(date_time_aux)

        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_ccx791['Date_Time']=date_time                                #editable
df_aux_ccx791['ibutton_key']=ibutton_key                            #editable
#print(date_time,ibutton_key)   
df_aux_ccx791.to_csv('/home/jlhb1984/py-projects/data/depositos/ccx791_01092111_iButton_date.csv')  #editable x2

# %% [markdown]
# BUW-137 01-09-2025 21-11-2025:

# %%
buw137_rd_01092111=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/buw137_01092111m.csv',sep=';',encoding='latin1')
buw137_rd_01092111.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34576 entries, 0 to 34575
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      34576 non-null  int64
#  1   Unnamed: 1   34576 non-null  int64
#  2   Unnamed: 2   34576 non-null  int64
#  3   Unnamed: 3   34576 non-null  int64
#  4   Unnamed: 4   34576 non-null  int64
#  5   Unnamed: 5   34576 non-null  int64
#  6   Unnamed: 6   34576 non-null  int64
#  7   Unnamed: 7   34576 non-null  int64
#  8   Unnamed: 8   34576 non-null  int64
#  9   Unnamed: 9   34576 non-null  object
#  10  Unnamed: 10  34576 non-null  object
#  11  Unnamed: 11  34576 non-null  int64
#  12  Unnamed: 12  34576 non-null  int64
#  13  Unnamed: 13  34576 non-null  int64
#  14  Unnamed: 14  34576 non-null  int64
#  15  Unnamed: 15  34576 non-null  object
#  16  Unnamed: 16  34576 non-null  int64
#  17  Unnamed: 17  34576 non-null  int64
#  18  Unnamed: 18  34576 non-null  int64
# ...

# %%
key_id_aux='0x000000000000000000000000000000000000000000000000|'
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_buw137=pd.DataFrame()                                        #editable

for i in range(0,34576):                                            #editable
    key_id=buw137_rd_01092111.iloc[i,21]                            #editable
    #print(i)
    if (key_id_aux)!=(key_id):
        unix_time_aux=buw137_rd_01092111.iloc[i,8]                  #editable 
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        ibutton_key.append(key_id[10:26])
        date_time.append(date_time_aux)

        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_buw137['Date_Time']=date_time                                #editable
df_aux_buw137['ibutton_key']=ibutton_key                            #editable
#print(date_time,ibutton_key)   
df_aux_buw137.to_csv('/home/jlhb1984/py-projects/data/depositos/buw137_01092111_iButton_date.csv')  #editable x2

# %% [markdown]
# BED-836 01-09-2025 24-11-2025:

# %%
bed836_rd_01092111=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/bed836_01092411m.csv',sep=';',encoding='latin1')
bed836_rd_01092111.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23636 entries, 0 to 23635
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      23636 non-null  int64
#  1   Unnamed: 1   23636 non-null  int64
#  2   Unnamed: 2   23636 non-null  int64
#  3   Unnamed: 3   23636 non-null  int64
#  4   Unnamed: 4   23636 non-null  int64
#  5   Unnamed: 5   23636 non-null  int64
#  6   Unnamed: 6   23636 non-null  int64
#  7   Unnamed: 7   23636 non-null  int64
#  8   Unnamed: 8   23636 non-null  int64
#  9   Unnamed: 9   23636 non-null  object
#  10  Unnamed: 10  23636 non-null  object
#  11  Unnamed: 11  23636 non-null  int64
#  12  Unnamed: 12  23636 non-null  int64
#  13  Unnamed: 13  23636 non-null  int64
#  14  Unnamed: 14  23636 non-null  int64
#  15  Unnamed: 15  23636 non-null  object
#  16  Unnamed: 16  23636 non-null  int64
#  17  Unnamed: 17  23636 non-null  int64
#  18  Unnamed: 18  23636 non-null  int64
# ...

# %%
key_id_aux='0x000000000000000000000000000000000000000000000000|'    #Esta unidad no guarda el iButton como las otras.
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_bed836=pd.DataFrame()                                        #editable

for i in range(0,23636):                                            #editable
    key_id=bed836_rd_01092111.iloc[i,21]                            #editable
    #print(i)
    if (key_id_aux)!=(key_id):
        unix_time_aux=bed836_rd_01092111.iloc[i,8]                  #editable 
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        if (key_id[26:42]!="0000000000000000"):
            ibutton_key.append(key_id[26:42])
            date_time.append(date_time_aux)
        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_bed836['Date_Time']=date_time                                #editable
df_aux_bed836['ibutton_key']=ibutton_key                            #editable
#print(date_time,ibutton_key)   
df_aux_bed836.to_csv('/home/jlhb1984/py-projects/data/depositos/bed836_01092411_iButton_date.csv')  #editable x2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 1BL4

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# AWN-709 01-09-2025 21-11-2025:

# %%
awn709_rd_01092111=pd.read_csv('/home/jlhb1984/py-projects/data/depositos/awn709_01092111m.csv',sep=';',encoding='latin1')
awn709_rd_01092111.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14457 entries, 0 to 14456
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      14457 non-null  int64
#  1   Unnamed: 1   14457 non-null  int64
#  2   Unnamed: 2   14457 non-null  int64
#  3   Unnamed: 3   14457 non-null  int64
#  4   Unnamed: 4   14457 non-null  int64
#  5   Unnamed: 5   14457 non-null  int64
#  6   Unnamed: 6   14457 non-null  int64
#  7   Unnamed: 7   14457 non-null  int64
#  8   Unnamed: 8   14457 non-null  int64
#  9   Unnamed: 9   14457 non-null  object
#  10  Unnamed: 10  14457 non-null  object
#  11  Unnamed: 11  14457 non-null  int64
#  12  Unnamed: 12  14457 non-null  int64
#  13  Unnamed: 13  14457 non-null  int64
#  14  Unnamed: 14  14457 non-null  int64
#  15  Unnamed: 15  14457 non-null  object
#  16  Unnamed: 16  14457 non-null  int64
#  17  Unnamed: 17  14457 non-null  int64
#  18  Unnamed: 18  14457 non-null  int64
# ...

# %%
key_id_aux='0x000000000000000000000000000000000000000000000000|'
ibutton_key=[]
unix_time=[]
date_time=[]
df_aux_awn709=pd.DataFrame()                                        #editable

for i in range(0,14457):                                            #editable
    key_id=awn709_rd_01092111.iloc[i,21]                            #editable
    #print(i)
    if (key_id_aux)!=(key_id):
        unix_time_aux=awn709_rd_01092111.iloc[i,8]                  #editable 
        date_time_aux=pd.to_datetime(int(unix_time_aux),unit='s')
        ibutton_key.append(key_id[10:26])
        date_time.append(date_time_aux)

        #date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
df_aux_awn709['Date_Time']=date_time                                #editable
df_aux_awn709['ibutton_key']=ibutton_key                            #editable
#print(date_time,ibutton_key)   
df_aux_awn709.to_csv('/home/jlhb1984/py-projects/data/depositos/awn709_01092111_iButton_date.csv')  #editable x2

# %%
cal_units={
    'Unit_ID':['Script','IMEI','Short name','Accumulator profile','iButton Type','Accum3','Accum4','Number of Accums','Working?','Last iButton report'],
    '1BL4':['7.72','016074000215183','1BL4','Basic Accum with iButton','Touch and Go with Auto LogOut','BFA54501','26000018','5','Yes','Na'],
    '0OUE':['7.72','352556102465056','CEP-433','Basic Accum with iButton','Touch and Go with Auto LogOut','9E6EB201','0600001F','8','No','04-11'],
    '18E3':['7.72','352556102276784','CCX-791','Basic Accum with iButton','Touch and Go with Auto LogOut','9E64FD01','EA00001F','8','No','20-11'],
    '0OUX':['7.72','354514101223156','BUW-137','Basic Accum with iButton','Touch and Go with Auto LogOut','9E6EB201','0600001F','8','No','19-11'],
    '847Q':['7.72','352556102442352','BED-836','None->Basic Accum with iButton','Touch and Go with Auto LogOut','9EB0D901','C100001F','5','No','20-11'],
    '0OUT':['55.161','354514101228718','B3P-885','Fuel sensor'],
    '6861':['7.72','354514102310655','AWN-709','Basic Accum with iButton','Touch and Go with Auto LogOut','9E0A2401','0B00001F','8','No','18-11']}
cal_units
# Out:
# {'Unit_ID': ['Script',
#   'IMEI',
#   'Short name',
#   'Accumulator profile',
#   'iButton Type',
#   'Accum3',
#   'Accum4',
#   'Number of Accums',
#   'Working?',
#   'Last iButton report'],
#  '1BL4': ['7.72',
#   '016074000215183',
#   '1BL4',
#   'Basic Accum with iButton',
#   'Touch and Go with Auto LogOut',
#   'BFA54501',
#   '26000018',
#   '5',
#   'Yes',
#   'Na'],
#  '0OUE': ['7.72',
#   '352556102465056',
#   'CEP-433',
#   'Basic Accum with iButton',
#   'Touch and Go with Auto LogOut',
#   '9E6EB201',
#   '0600001F',
#   '8',
#   'No',
#   '04-11'],
#  '18E3': ['7.72',
#   '352556102276784',
#   'CCX-791',
#   'Basic Accum with iButton',
#   'Touch and Go with Auto LogOut',
#   '9E64FD01',
#   'EA00001F',
#   '8',
#   'No',
#   '20-11'],
#  '0OUX': ['7.72',
#   '354514101223156',
#   'BUW-137',
#   'Basic Accum with iButton',
#   'Touch and Go with Auto LogOut',
#   '9E6EB201',
#   '0600001F',
#   '8',
#   'No',
#   '19-11'],
#  '847Q': ['7.72',
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
