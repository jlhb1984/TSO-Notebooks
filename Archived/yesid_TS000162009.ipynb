# %%
import pandas as pd
import numpy as np

# %%
hl=pd.read_csv('/home/jlhb1984/py-projects/data/YESID FRANCISCO GALINDO MESA/hlSY013CCD17238.csv',sep=';',encoding='latin1')
hl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6334 entries, 0 to 6333
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     6334 non-null   int64
#  1   Unit         6334 non-null   object
#  2   Events       6334 non-null   object
#  3   Date         6334 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      5939 non-null   object
#  6   Speed        6334 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     6334 non-null   float64
#  10  Longitude    6334 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 544.5+ KB

# %%
hl['Events'].value_counts()
# Out:
# Events
# Idle - Stop           3378
# Parked                2072
# Ping                   202
# Self Test/Reboot       202
# POWER UP               202
# Poder apagado          202
# Ignicin Apagada        28
# Ignicin Encendida      28
# Towing/Drifting?        20
# Name: count, dtype: int64

# %%
igniciones=hl[hl['Events'].str.contains('Igni')]
igniciones
# Out:
#       Sequence           Unit              Events                  Date  \
# 106       6228  SY013CCD17238    Ignicin Apagada  Oct 09 2025 05:06 PM
# 385       5949  SY013CCD17238  Ignicin Encendida  Oct 09 2025 01:15 PM
# 403       5931  SY013CCD17238    Ignicin Apagada  Oct 09 2025 12:19 PM
# 512       5822  SY013CCD17238  Ignicin Encendida  Oct 09 2025 10:53 AM
# 804       5530  SY013CCD17238    Ignicin Apagada  Oct 08 2025 03:57 PM
# 1017      5317  SY013CCD17238  Ignicin Encendida  Oct 08 2025 01:13 PM
# 1040      5294  SY013CCD17238    Ignicin Apagada  Oct 08 2025 11:51 AM
# 1135      5199  SY013CCD17238  Ignicin Encendida  Oct 08 2025 10:40 AM
# 1140      5194  SY013CCD17238    Ignicin Apagada  Oct 08 2025 10:38 AM
# 1300      5034  SY013CCD17238  Ignicin Encendida  Oct 08 2025 08:26 AM
# 1304      5030  SY013CCD17238    Ignicin Apagada  Oct 08 2025 08:16 AM
# 1307      5027  SY013CCD17238  Ignicin Encendida  Oct 08 2025 08:15 AM
# ...

# %%
igniciones['Events'].value_counts()
# Out:
# Events
# Ignicin Apagada      28
# Ignicin Encendida    28
# Name: count, dtype: int64
