# %%
import pandas as pd
import numpy as np

# %%
report=pd.read_csv('/home/jlhb1984/py-projects/data/invertrans/report.csv')
report['Analyzed']='Empty'
report.head(5)
# Out:
#    GroupName UnitID             UnitName1  MaxSpeed MilesDriven  \
# 0        NaN   15IK  KBY321CASTIL/CAMIONE       100       46,51
# 1        NaN   15I7  KDW525RIOPAILA/CAMIO        95       53,51
# 2        NaN   0T8Q        LFL197CASTILLA        43       52,13
# 3        NaN   16GU   MHO224 RIOPAILA(CAM        95      140,00
# 4        NaN   15BZ        TDK954RIOPAILA        51       74,00
#
#   TravelTimeSecs Textbox3 IdleTimeSecs Textbox6 IdleTimeSecs2 Textbox11  \
# 0     1H:15M:28S     1,26   0H:54M:47S     0,91    2H:10M:15S      2,17
# 1     1H:12M:43S     1,21   0H:38M:34S     0,64    1H:51M:17S      1,85
# 2       3H:7M:5S     3,12   2H:12M:22S     2,21    5H:19M:27S      5,32
# 3     2H:49M:21S     2,82   0H:18M:35S     0,31     3H:7M:56S      3,13
# 4     3H:41M:19S     3,69    2H:32M:5S     2,53    6H:13M:24S      6,22
#
#   Textbox15      Textbox16 Textbox17      Textbox18 Textbox19       Textbox22  \
# ...

# %%
report_filtered=report[['UnitName1','MaxSpeed','MilesDriven','TravelTimeSecs']]
report_filtered
# Out:
#                UnitName1  MaxSpeed MilesDriven TravelTimeSecs
# 0   KBY321CASTIL/CAMIONE       100       46,51     1H:15M:28S
# 1   KDW525RIOPAILA/CAMIO        95       53,51     1H:12M:43S
# 2         LFL197CASTILLA        43       52,13       3H:7M:5S
# 3    MHO224 RIOPAILA(CAM        95      140,00     2H:49M:21S
# 4         TDK954RIOPAILA        51       74,00     3H:41M:19S
# 5         TDL580RIOPAILA        51       55,81     1H:47M:29S
# 6         TDL582CASTILLA        55       72,81      4H:29M:3S
# 7       TDL584 RISARALDA         0        0,00       0H:0M:0S
# 8        TDL585 RIOPAILA        47       46,80     3H:48M:43S
# 9         TDL587RIOPAILA         0        0,00       0H:0M:0S
# 10        TDL588CASTILLA        10        1,00     0H:13M:45S
# 11       TJV781RISARALDA         0        0,00       0H:0M:0S
# 12        TRM025RIOPAILA         0        0,00       0H:0M:0S
# 13        TRM032CASTILLA         0        0,00       0H:0M:0S
# ...

# %%
unit_name='MHO224 RIOPAIL'
unit=report_filtered[report_filtered['UnitName1'].str.contains(unit_name)]
unit
# Out:
#              UnitName1  MaxSpeed MilesDriven TravelTimeSecs
# 3  MHO224 RIOPAILA(CAM        95      140,00     2H:49M:21S

# %%
unit_name='TDL580RIOPAILA'
unit=report_filtered[report_filtered['UnitName1'].str.contains(unit_name)]
unit
# Out:
#         UnitName1  MaxSpeed MilesDriven TravelTimeSecs
# 5  TDL580RIOPAILA        51       55,81     1H:47M:29S

# %%
unit_name='TDL582CASTILLA'
unit=report_filtered[report_filtered['UnitName1'].str.contains(unit_name)]
unit
# Out:
#         UnitName1  MaxSpeed MilesDriven TravelTimeSecs
# 6  TDL582CASTILLA        55       72,81      4H:29M:3S

# %%
unit_name='WDM183CASTILLA'
unit=report_filtered[report_filtered['UnitName1'].str.contains(unit_name)]
unit
# Out:
#          UnitName1  MaxSpeed MilesDriven TravelTimeSecs
# 18  WDM183CASTILLA        48       44,21     2H:35M:49S

# %%
unit_name='WDM281INCAUCA'
unit=report_filtered[report_filtered['UnitName1'].str.contains(unit_name)]
unit
# Out:
#         UnitName1  MaxSpeed MilesDriven TravelTimeSecs
# 24  WDM281INCAUCA        71       50,00       3H:9M:9S

# %%
analyzed_units=pd.read_csv('/home/jlhb1984/py-projects/data/invertrans/report_analyzed.csv')
analyzed_units_ok=analyzed_units[analyzed_units['Analyzed'].str.contains('ok')]
analyzed_units_ok
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, UnitName1, MaxSpeed, MilesDriven, TravelTimeSecs, Analyzed]
# Index: []
