# %%
import pandas as pd
import numpy as np

# %%
ajf810_vf=pd.read_csv('/home/jlhb1984/py-projects/data/gld_transport/ajf810air2.csv',encoding='latin1',sep=';')
ajf810_vf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  737 non-null    object
#  1   Message  737 non-null    object
#  2   Status   737 non-null    object
# dtypes: object(3)
# memory usage: 17.4+ KB

# %%
ajf810vf_messages=pd.read_csv('/home/jlhb1984/py-projects/data/gld_transport/ajf810air2_messages.csv',sep=';',encoding='latin1')
ajf810vf_events=ajf810vf_messages[ajf810vf_messages['Message'].str.contains('CameraEvent')]
ajf810vf_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    13
# Name: count, dtype: int64

# %%
#Camera events.
ajf810vf_events=ajf810vf_messages[ajf810vf_messages['Message'].str.contains('CameraEvent')]
ajf810vf_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"USING_PHONE"                  7
# event:"DROWSINESS"                   4
# event:"POTENTIAL_INCIDENT_LOW"       1
# event:"POTENTIAL_INCIDENT_MEDIUM"    1
# Name: count, dtype: int64
