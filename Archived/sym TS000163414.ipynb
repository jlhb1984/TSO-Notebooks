# %%
import pandas as pd
import numpy as np

# %%
cu_crm=pd.read_csv('/home/jlhb1984/py-projects/data/sym/cu.csv',sep=';',encoding='latin1')
cu_crm.info()
cu=cu_crm[['IMEI','Unit Type','Last Contact On','Carrier','Peripherals']]
cu['Unit Type'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       168 non-null    int64
#  1   Owner                    168 non-null    object
#  2   Unit ID                  168 non-null    object
#  3   Unit                     168 non-null    object
#  4   Peripherals              43 non-null     object
#  5   BillingPeriod            166 non-null    object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            1 non-null      object
#  9   Last Event Date          168 non-null    object
#  10  Monthly Fee              168 non-null    int64
#  11  Bill To                  0 non-null      float64
#  12  Assigned To              168 non-null    object
#  13  Linked Mode              168 non-null    int64
# ...

# %%
calamp_units=cu[cu['Unit Type'].str.contains('CalAmp')]
queclink_units=cu[cu['Unit Type'].str.contains('Queclink')]
topfly_units=cu[cu['Unit Type'].str.contains('Topfly')]
vf4k_units=cu[cu['Unit Type'].str.contains('VidFleet')]

# %%
geoi_o=pd.read_csv('/home/jlhb1984/py-projects/data/sym/Geofences InOut Report0110_0711.csv',sep=',',encoding='latin1')
geoi_o['GeofenceName'].value_counts()
# Out:
# GeofenceName
# BAQ12                                                                               4985
# BAQ10                                                                               3603
# PATIO SYM 30 CON 14                                                                 3415
# BAQ14                                                                               3299
# BODEGA LA 30--ZONA DE SALIDA DE TRABAJO : Kr14 18-21, Soledad, Atlantico SOLEDAD    3053
#                                                                                     ...
# BODEGA LA 30--ZONA DE SALIDA DE TRABAJO : Cl18 28a-26, Soledad, Atlantico              1
# BAQ11 : Cl29 35a-27, Soledad, Atlantico                                                1
# SEGUIMIENTO LLR 244 : Kr42 55e-37, Barranquilla, Atlantico                             1
# MULTIFAMIIAR SEGUIMIENTO : 14-06 18139 18453-181 Carrera 14 Carrera 14 Calle 18        1
# ...

# %%
calamp_units_reporting=calamp_units[calamp_units['Last Contact On'].str.contains('/11/2025')]
calamp_units_reporting['Unit Type'].value_counts()
queclink_units_reporting=queclink_units[queclink_units['Last Contact On'].str.contains('/11/2025')]
queclink_units_reporting['Unit Type'].value_counts()
topfly_units_reporting=topfly_units[topfly_units['Last Contact On'].str.contains('/11/2025')]
topfly_units_reporting['Unit Type'].value_counts()
# Out:
# Unit Type
# Topfly PioneerX    5
# Name: count, dtype: int64

# %%
calamp_units_reporting['IMEI'].to_csv('/home/jlhb1984/py-projects/data/sym/calamp_imei.csv')
queclink_units_reporting['IMEI'].to_csv('/home/jlhb1984/py-projects/data/sym/queclink_imei.csv')
topfly_units_reporting['IMEI'].to_csv('/home/jlhb1984/py-projects/data/sym/topfly_imei.csv')

# %%
queclink_devices=pd.read_csv('/home/jlhb1984/py-projects/data/sym/queclink_devices.csv',sep=';',encoding='latin1')
queclink_devices.info()
queclink_devices['Firmware Version'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Device Name                     36 non-null     float64
#  1   Last Report Date                60 non-null     object
#  2   Create Time                     55 non-null     object
#  3   IMEI                            60 non-null     int64
#  4   Device Type                     60 non-null     object
#  5   Group                           60 non-null     object
#  6   Iccid                           60 non-null     object
#  7   MCU Firmware Version            0 non-null      float64
#  8   Modem Version                   0 non-null      float64
#  9   Firmware Version                60 non-null     object
#  10  Configuration Version           60 non-null     int64
#  11  Hardware Version                60 non-null     float64
# ...

# %%
topfly_devices=pd.read_csv('/home/jlhb1984/py-projects/data/sym/topfly_devices.csv',sep=';',encoding='latin1')
topfly_devices.info()
topfly_devices['APP version'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   IMEI                        5 non-null      int64
#  1   Company                     5 non-null      object
#  2   Model                       5 non-null      object
#  3   Added date                  5 non-null      object
#  4   Group                       0 non-null      float64
#  5   Specified firmware version  0 non-null      float64
#  6   APP version                 5 non-null      object
#  7   Shipping Date               5 non-null      object
#  8   OBD Version                 0 non-null      float64
#  9   Invoice Number              5 non-null      object
#  10  OBD Boot Version            0 non-null      float64
#  11  OBD Data Version            0 non-null      float64
#  12  MCU Version                 0 non-null      float64
# ...

# %%
topfly_devices['IMEI'].to_csv('/home/jlhb1984/py-projects/data/sym/topfly_devices_trial.csv')

# %%
calamp_devices=pd.read_csv('/home/jlhb1984/py-projects/data/sym/devices-11-07-2025.csv',encoding='latin1')
calamp_devices.value_counts('Firmware Version')
calamp_devices_to_u=calamp_devices[~calamp_devices['Firmware Version'].str.contains('85f')]
calamp_devices_to_u['IMEI'].to_csv('/home/jlhb1984/py-projects/data/sym/calamp_imeis_to_u.csv')

# %%
calamp_devices_to_u[['Model','Firmware Version']]
# Out:
#       Model Firmware Version
# 16  LMU2630              74b
# 31  LMU2630              81a
# 34   LMU330              29f

# %% [markdown]
# Se procederá a ejecutar upgrade de firmware a las unidades CalAmp:
# 358077093584833, 9103401230
# 358077092198965, 9103456016
# 354514101458588, 9101170009
