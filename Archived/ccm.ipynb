# %%
import pandas as pd
import numpy as np

# %%
ccm_units=pd.read_csv('/home/jlhb1984/py-projects/data/ccm/Customer-Units.csv',sep=';',encoding='latin1')
ccm_units.info()
ccm_units.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       23 non-null     int64
#  1   Owner                    23 non-null     object
#  2   Unit ID                  23 non-null     object
#  3   Unit                     23 non-null     object
#  4   Peripherals              0 non-null      float64
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          23 non-null     object
#  9   Monthly Fee              23 non-null     int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              23 non-null     object
#  12  Linked Mode              23 non-null     int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
ccm_units['Unit Type'].value_counts()
# Out:
# Unit Type
# VidFleet 4K       12
# Queclink GV55W    11
# Name: count, dtype: int64

# %%
vidfleet_units_ccm=ccm_units[ccm_units['Unit Type'].str.contains('Vid')]
vidfleet_units_ccm[['Unit','IMEI']]
# Out:
#          Unit      IMEI
# 0   TZN341 VF  6B301AMG
# 2   TJV298 VF  6B301AYU
# 4   TJV078 VF  6B301ALB
# 6   SXJ945 VF  6B301GR3
# 8   SXJ934 VF  6B301AE7
# 10  SDW585 VF  6B301BVE
# 11  NPR856 VF  6B301AYJ
# 13  LFQ645 VF  6B301AFU
# 15  KRM052 VF  6B301AAX
# 17  KRM008 VF  6B301AW3
# 19  JZX136 VF  6B301A84
# 21  GSM322 VF  6B301AT5

# %%
queclink_units=ccm_units[ccm_units['Unit Type'].str.contains('Queclink')]
queclink_units.info()
queclink_units['Carrier'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 1 to 22
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       11 non-null     int64
#  1   Owner                    11 non-null     object
#  2   Unit ID                  11 non-null     object
#  3   Unit                     11 non-null     object
#  4   Peripherals              0 non-null      float64
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          11 non-null     object
#  9   Monthly Fee              11 non-null     int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              11 non-null     object
#  12  Linked Mode              11 non-null     int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
ccm_units_report=queclink_units[['IMEI','SIM #','Phone Number','Unit']]
ccm_units_report.rename(columns={'SIM #':'ICCID','Phone Number':'MSISDN'},inplace=True)
ccm_units_report.info()
ccm_units_report.to_csv('/home/jlhb1984/py-projects/data/ccm/devicesQueclink.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 1 to 22
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   IMEI    11 non-null     object
#  1   ICCID   11 non-null     int64
#  2   MSISDN  11 non-null     int64
#  3   Unit    11 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 440.0+ bytes
# /tmp/ipykernel_32162/50040889.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ccm_units_report.rename(columns={'SIM #':'ICCID','Phone Number':'MSISDN'},inplace=True)
