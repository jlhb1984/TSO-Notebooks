# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 21-09-2025 to 01-10-2025

# %%
result={#'unit':['num_events,dms_events'],
        '6B31111D-pmx778':[1630,6],
        '6B31114Z-prz047':[2911,43],
        '6B311142-prz060':[3420,19],
        '6B31117C-prz061':[3293,22],
        '8B51426E-prz505':[1219,6],
        '8B5141PU-prz506':[1358,3],
        '8B514208-prz507':[2277,10]
        }
print(result)
# Out:
# {'6B31111D-pmx778': [1630, 6], '6B31114Z-prz047': [2911, 43], '6B311142-prz060': [3420, 19], '6B31117C-prz061': [3293, 22], '8B51426E-prz505': [1219, 6], '8B5141PU-prz506': [1358, 3], '8B514208-prz507': [2277, 10]}

# %%
x_values=[]
y_values=[]

for key in result.keys():
    print(key,result[key])    
    x_values.append(result[key][1])
    y_values.append(result[key][0])

plt.bar(x_values,y_values)
sns.scatterplot(y_values)
# Out:
# 6B31111D-pmx778 [1630, 6]
# 6B31114Z-prz047 [2911, 43]
# 6B311142-prz060 [3420, 19]
# 6B31117C-prz061 [3293, 22]
# 8B51426E-prz505 [1219, 6]
# 8B5141PU-prz506 [1358, 3]
# 8B514208-prz507 [2277, 10]
# <Axes: >

# %% [markdown]
# PRZ507 AIR2

# %%
prz507vf_01102025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ507VF_01102025.csv',sep=';',encoding='latin1')
prz507vf_01102025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3427 entries, 0 to 3426
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  3427 non-null   object
#  1   Message  3427 non-null   object
#  2   Status   3427 non-null   object
# dtypes: object(3)
# memory usage: 80.4+ KB

# %%
prz507vf_01102025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ507VF_01102025_messages.csv',sep=';',encoding='latin1')
prz507vf_01102025_events=prz507vf_01102025_messages[prz507vf_01102025_messages['Message'].str.contains('CameraEvent')]
prz507vf_01102025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    1
# Name: count, dtype: int64

# %%
#Camera events.
prz507vf_0110205_events=prz507vf_01102025_messages[prz507vf_01102025_messages['Message'].str.contains('CameraEvent')]
prz507vf_01102025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_LOW"    1
# Name: count, dtype: int64

# %% [markdown]
# PRZ506 AIR2

# %%
prz506vf_25092025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ506VF_25092025.csv',sep=';',encoding='latin1')
prz506vf_25092025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1358 entries, 0 to 1357
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1358 non-null   object
#  1   Message  1358 non-null   object
#  2   Status   1358 non-null   object
# dtypes: object(3)
# memory usage: 32.0+ KB

# %%
prz506vf_25092025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ506VF_25092025_messages.csv',sep=';',encoding='latin1')
prz506vf_25092025_events=prz506vf_25092025_messages[prz506vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz506vf_25092025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    3
# Name: count, dtype: int64

# %%
#Camera events.
prz506vf_250925_events=prz506vf_25092025_messages[prz506vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz506vf_25092025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_LOW"     2
# event:"POTENTIAL_INCIDENT_HIGH"    1
# Name: count, dtype: int64

# %% [markdown]
# PRZ505 AIR2

# %%
prz505vf_25092025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ505VF_25092025.csv',sep=';',encoding='latin1')
prz505vf_25092025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1219 entries, 0 to 1218
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1219 non-null   object
#  1   Message  1219 non-null   object
#  2   Status   1219 non-null   object
# dtypes: object(3)
# memory usage: 28.7+ KB

# %%
prz505vf_25092025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ505VF_25092025_messages.csv',sep=';',encoding='latin1')
prz505vf_25092025_events=prz505vf_25092025_messages[prz505vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz505vf_25092025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    6
# Name: count, dtype: int64

# %%
#Camera events.
prz505vf_250925_events=prz505vf_25092025_messages[prz505vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz505vf_25092025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_MEDIUM"    4
# event:"MANUAL"                       2
# Name: count, dtype: int64

# %% [markdown]
# PRZ061 4K

# %%
prz061vf_25092025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ061VF_25092025.csv',sep=';',encoding='latin1')
prz061vf_25092025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3293 entries, 0 to 3292
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  3293 non-null   object
#  1   Message  3293 non-null   object
#  2   Status   3293 non-null   object
# dtypes: object(3)
# memory usage: 77.3+ KB

# %%
prz061vf_25092025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ061VF_25092025_messages.csv',sep=';',encoding='latin1')
prz061vf_25092025_events=prz061vf_25092025_messages[prz061vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz061vf_25092025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    22
# Name: count, dtype: int64

# %%
#Camera events.
prz061vf_250925_events=prz061vf_25092025_messages[prz061vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz061vf_25092025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"    18
# event:"POTENTIAL_INCIDENT_LOW"        4
# Name: count, dtype: int64

# %% [markdown]
# PRZ060 4K

# %%
prz060vf_25092025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ060VF_25092025.csv',sep=';',encoding='latin1')
prz060vf_25092025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3420 entries, 0 to 3419
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  3420 non-null   object
#  1   Message  3420 non-null   object
#  2   Status   3420 non-null   object
# dtypes: object(3)
# memory usage: 80.3+ KB

# %%
prz060vf_25092025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ060VF_25092025_messages.csv',sep=';',encoding='latin1')
prz060vf_25092025_events=prz060vf_25092025_messages[prz060vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz060vf_25092025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    19
# Name: count, dtype: int64

# %%
#Camera events.
prz060vf_250925_events=prz060vf_25092025_messages[prz060vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz060vf_25092025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"       14
# event:"POTENTIAL_INCIDENT_LOW"           3
# event:"SMOKING"                          1
# event:"HEADWAY_MONITORING_EMERGENCY"     1
# Name: count, dtype: int64

# %% [markdown]
# PRZ047 4K

# %%
prz047vf_25092025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ047VF_25092025.csv',sep=';',encoding='latin1')
prz047vf_25092025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2911 entries, 0 to 2910
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  2911 non-null   object
#  1   Message  2911 non-null   object
#  2   Status   2911 non-null   object
# dtypes: object(3)
# memory usage: 68.4+ KB

# %%
prz047vf_25092025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ047VF_25092025_messages.csv',sep=';',encoding='latin1')
prz047vf_25092025_events=prz047vf_25092025_messages[prz047vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz047vf_25092025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    43
# Name: count, dtype: int64

# %%
#Camera events.
prz047vf_250925_events=prz047vf_25092025_messages[prz047vf_25092025_messages['Message'].str.contains('CameraEvent')]
prz047vf_25092025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"    27
# event:"DROWSINESS"                    4
# event:"YAWN"                          3
# event:"POTENTIAL_INCIDENT_LOW"        3
# event:"HARD_BRAKE"                    3
# event:"POTENTIAL_INCIDENT_MEDIUM"     1
# event:"SHARP_TURN"                    1
# event:"HARD_ACCEL"                    1
# Name: count, dtype: int64

# %% [markdown]
# PMX778 4K

# %%
#Carga del df original.
pmx778vf_250925=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PMX778VF_25092025.csv',sep=';',encoding='latin1')
pmx778vf_250925.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1630 non-null   object
#  1   Message  1630 non-null   object
#  2   Status   1630 non-null   object
# dtypes: object(3)
# memory usage: 38.3+ KB

# %%
pmx778vf_250925_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PMX778VF_25092025_messages.csv',sep=';',encoding='latin1')
pmx778vf_250925_events=pmx778vf_250925_messages[pmx778vf_250925_messages['Message'].str.contains('CameraEvent')]
pmx778vf_250925_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    6
# Name: count, dtype: int64

# %%
#Camera events.
pmx778vf_250925_events=pmx778vf_250925_messages[pmx778vf_250925_messages['Message'].str.contains('CameraEvent')]
pmx778vf_250925_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"    3
# event:"HARD_ACCEL"                   2
# event:"POTENTIAL_INCIDENT_LOW"       1
# Name: count, dtype: int64

# %%
pmx778vf_250925_FCW=pmx778vf_250925[pmx778vf_250925['Message'].str.contains('POTENTIAL_INCIDENT_LOW')]
pmx778vf_250925_FCW
# Out:
#                      Created  \
# 106  2025-09-04 22:22:03.755
#
#                                                Message  \
# 106  {"notificationType":"CameraEvent","sn":"6B3111...
#
#                                Status
# 106  0x5B6F626A656374204F626A6563745D
