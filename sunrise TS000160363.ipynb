# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Análisis hecho desde el 20-08 hasta 11-09

# %% [markdown]
# PMX778

# %%
pmx778_vf=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PMX778 VF.csv',encoding='latin1',sep=';')
pmx778_vf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589 entries, 0 to 1588
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1589 non-null   object
#  1   Message  1589 non-null   object
#  2   Status   1589 non-null   object
# dtypes: object(3)
# memory usage: 37.4+ KB

# %%
pmx778_vfM=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PMX778 VFm.csv',sep=';',encoding='latin1')
pmx778_vfM.info()
pmx778_vfM.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589 entries, 0 to 1588
# Data columns (total 68 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      1589 non-null   object
#  1   Unnamed: 1   1589 non-null   object
#  2   Unnamed: 2   1589 non-null   object
#  3   Unnamed: 3   1589 non-null   object
#  4   Unnamed: 4   1589 non-null   object
#  5   Unnamed: 5   1589 non-null   object
#  6   Unnamed: 6   1589 non-null   object
#  7   Unnamed: 7   1589 non-null   object
#  8   Unnamed: 8   1589 non-null   object
#  9   Unnamed: 9   1589 non-null   object
#  10  Unnamed: 10  1589 non-null   object
#  11  Unnamed: 11  1589 non-null   object
#  12  Unnamed: 12  1589 non-null   object
#  13  Unnamed: 13  1589 non-null   object
#  14  Unnamed: 14  1589 non-null   object
#  15  Unnamed: 15  1589 non-null   object
#  16  Unnamed: 16  1550 non-null   object
#  17  Unnamed: 17  1540 non-null   object
# ...

# %%
pmx778_vfM['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              627
# {"notificationType":"CameraRunningInfo"     333
# {"notificationType":"AutoSnapshot"          270
# {"notificationType":"IgnitionStatus"        163
# {"notificationType":"MaintenanceWarning"     89
# {"notificationType":"DataUsage"              55
# {"notificationType":"ParkingHeartbeat"       39
# {"notificationType":"CameraEvent"            10
# {"notificationType":"PowerEvent"              3
# Name: count, dtype: int64

# %%
pmx778_events=pmx778_vfM[pmx778_vfM['Message'].str.contains('AutoSnapshot')]
pmx778_events.sort_index(ascending=False)
pmx778_events['Unnamed: 5'].to_csv('/home/jlhb1984/py-projects/data/sunrise/PMX778 VFm_url.csv')

# %%
pmx778_events=pmx778_vf[pmx778_vf['Message'].str.contains('AutoSnapshot')]
pmx778_events.to_csv('/home/jlhb1984/py-projects/data/sunrise/PMX778 VF AS.csv')

# %% [markdown]
# Camera events:

# %%
#Camera events daughter.
pmx778_events_others=pmx778_vfM[pmx778_vfM['Message'].str.contains('CameraEvent')]
pmx778_events_others['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_LOW"       4
# event:"FORWARD_COLLISION_WARNING"    3
# event:"HARD_ACCEL"                   2
# event:"HARD_BRAKE"                   1
# Name: count, dtype: int64

# %%
pmx778_events_as=pmx778_vf[pmx778_vf['Message'].str.contains('AutoSnapshot')]
pmx778_events_as
# Out:
#                       Created  \
# 0     2025-08-20 19:03:40.509
# 11    2025-08-20 19:12:49.457
# 12    2025-08-20 19:16:02.884
# 23    2025-08-20 19:22:04.664
# 24    2025-08-20 19:27:41.451
# ...                       ...
# 1566  2025-09-11 20:27:07.108
# 1571  2025-09-11 20:27:18.047
# 1573  2025-09-11 20:30:33.416
# 1580  2025-09-11 20:40:27.839
# 1586  2025-09-11 20:43:50.988
#
#                                                 Message  \
# 0     {"notificationType":"AutoSnapshot","sn":"6B311...
# 11    {"notificationType":"AutoSnapshot","sn":"6B311...
# 12    {"notificationType":"AutoSnapshot","sn":"6B311...
# 23    {"notificationType":"AutoSnapshot","sn":"6B311...
# 24    {"notificationType":"AutoSnapshot","sn":"6B311...
# ...                                                 ...
# 1566  {"notificationType":"AutoSnapshot","sn":"6B311...
# 1571  {"notificationType":"AutoSnapshot","sn":"6B311...
# 1573  {"notificationType":"AutoSnapshot","sn":"6B311...
# ...

# %% [markdown]
# PRZ047

# %%
prz047_vf=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ047 VF.csv',sep=';',encoding='latin1')
prz047_vf
# Out:
#                       Created  \
# 0     2025-08-01 14:15:04.308
# 1     2025-08-01 14:16:13.373
# 2     2025-08-01 14:17:01.327
# 3     2025-08-01 14:17:09.178
# 4     2025-08-01 14:17:16.633
# ...                       ...
# 1930  2025-09-11 20:43:52.197
# 1931  2025-09-11 20:44:10.230
# 1932  2025-09-11 20:44:11.191
# 1933  2025-09-11 20:44:12.183
# 1934  2025-09-11 20:44:20.521
#
#                                                 Message  \
# 0     {"notificationType":"MaintenanceWarning","sn":...
# 1     {"notificationType":"MaintenanceWarning","sn":...
# 2     {"notificationType":"MaintenanceWarning","sn":...
# 3     {"notificationType":"IgnitionStatus","sn":"6B3...
# 4     {"notificationType":"AutoSnapshot","sn":"6B311...
# ...                                                 ...
# 1930  {"notificationType":"CameraRunningInfo","sn":"...
# 1931  {"notificationType":"IgnitionStatus","sn":"6B3...
# 1932  {"notificationType":"CameraRunningInfo","sn":"...
# ...

# %%
prz047_vfM=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ047 VFm.csv',sep=';',encoding='latin1')
prz047_vfM.info()
prz047_vfM.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1935 entries, 0 to 1934
# Data columns (total 68 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      1935 non-null   object
#  1   Unnamed: 1   1935 non-null   object
#  2   Unnamed: 2   1935 non-null   object
#  3   Unnamed: 3   1935 non-null   object
#  4   Unnamed: 4   1935 non-null   object
#  5   Unnamed: 5   1935 non-null   object
#  6   Unnamed: 6   1935 non-null   object
#  7   Unnamed: 7   1935 non-null   object
#  8   Unnamed: 8   1935 non-null   object
#  9   Unnamed: 9   1935 non-null   object
#  10  Unnamed: 10  1935 non-null   object
#  11  Unnamed: 11  1935 non-null   object
#  12  Unnamed: 12  1935 non-null   object
#  13  Unnamed: 13  1934 non-null   object
#  14  Unnamed: 14  1934 non-null   object
#  15  Unnamed: 15  1934 non-null   object
#  16  Unnamed: 16  1882 non-null   object
#  17  Unnamed: 17  1871 non-null   object
# ...

# %%
prz047_vfM['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              788
# {"notificationType":"CameraRunningInfo"     399
# {"notificationType":"AutoSnapshot"          317
# {"notificationType":"IgnitionStatus"        184
# {"notificationType":"MaintenanceWarning"    100
# {"notificationType":"DataUsage"              77
# {"notificationType":"ParkingHeartbeat"       52
# {"notificationType":"CameraEvent"            17
# {"notificationType":"PowerEvent"              1
# Name: count, dtype: int64

# %%
prz047_events=prz047_vfM[prz047_vfM['Message'].str.contains('AutoSnapshot')]
prz047_events.sort_index(ascending=False)
prz047_events['Unnamed: 5'].to_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ047 VFm_url.csv')

# %%
prz047_events_others=prz047_vfM[prz047_vfM['Message'].str.contains('CameraEvent')]
prz047_events_others['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"    8
# event:"HARD_BRAKE"                   3
# event:"POTENTIAL_INCIDENT_LOW"       2
# event:"DROWSINESS"                   2
# event:"YAWN"                         1
# event:"POTENTIAL_INCIDENT_MEDIUM"    1
# Name: count, dtype: int64

# %%
prz047_events_as=prz047_vf[prz047_vf['Message'].str.contains('AutoSnapshot')]
prz047_events_as
# Out:
#                       Created  \
# 4     2025-08-01 14:17:16.633
# 9     2025-08-01 14:17:35.533
# 10    2025-08-01 14:17:37.709
# 18    2025-08-20 19:42:34.100
# 27    2025-08-20 19:44:50.422
# ...                       ...
# 1915  2025-09-11 20:27:07.465
# 1917  2025-09-11 20:30:21.360
# 1921  2025-09-11 20:31:16.560
# 1924  2025-09-11 20:35:30.835
# 1934  2025-09-11 20:44:20.521
#
#                                                 Message  \
# 4     {"notificationType":"AutoSnapshot","sn":"6B311...
# 9     {"notificationType":"AutoSnapshot","sn":"6B311...
# 10    {"notificationType":"AutoSnapshot","sn":"6B311...
# 18    {"notificationType":"AutoSnapshot","sn":"6B311...
# 27    {"notificationType":"AutoSnapshot","sn":"6B311...
# ...                                                 ...
# 1915  {"notificationType":"AutoSnapshot","sn":"6B311...
# 1917  {"notificationType":"AutoSnapshot","sn":"6B311...
# 1921  {"notificationType":"AutoSnapshot","sn":"6B311...
# ...

# %% [markdown]
# PRZ060

# %%
prz060_vf=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ060 VF.csv',sep=';',encoding='latin1')
prz060_vf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2142 entries, 0 to 2141
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  2142 non-null   object
#  1   Message  2142 non-null   object
#  2   Status   2142 non-null   object
# dtypes: object(3)
# memory usage: 50.3+ KB

# %%
prz060_vfM=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ060 VFm.csv',sep=';',encoding='latin1')
prz060_vfM.info()
prz060_vfM.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2142 entries, 0 to 2141
# Columns: 116 entries, Message to Unnamed: 115
# dtypes: object(116)
# memory usage: 1.9+ MB
#                                     Message     Unnamed: 1  \
# 0          {"notificationType":"PowerEvent"  sn:"6B311142"
# 1            {"notificationType":"TripInfo"  sn:"6B311142"
# 2  {"notificationType":"MaintenanceWarning"  sn:"6B311142"
# 3        {"notificationType":"AutoSnapshot"  sn:"6B311142"
# 4      {"notificationType":"IgnitionStatus"  sn:"6B311142"
#
#                                       Unnamed: 2  \
# 0                                   vehicleID:""
# 1  tripID:"c8e94213-fc0e-4530-9ec1-802b6dc16703"
# 2                                   vehicleID:""
# 3                pictureID:"1118201869534109696"
# 4                                   vehicleID:""
#
#                                       Unnamed: 3  \
# 0                                      tripID:""
# ...

# %%
prz060_vfM['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              795
# {"notificationType":"CameraRunningInfo"     478
# {"notificationType":"AutoSnapshot"          414
# {"notificationType":"IgnitionStatus"        290
# {"notificationType":"DataUsage"              58
# {"notificationType":"MaintenanceWarning"     51
# {"notificationType":"ParkingHeartbeat"       48
# {"notificationType":"CameraEvent"             7
# {"notificationType":"PowerEvent"              1
# Name: count, dtype: int64

# %%
prz060_events=prz060_vfM[prz060_vfM['Message'].str.contains('AutoSnapshot')]
prz060_events.sort_index(ascending=False)
prz060_events['Unnamed: 5'].to_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ060 VFm_url.csv')

# %%
prz060_events_others=prz060_vfM[prz060_vfM['Message'].str.contains('CameraEvent')]
prz060_events_others['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"    5
# event:"HARD_BRAKE"                   1
# event:"SMOKING"                      1
# Name: count, dtype: int64

# %%
prz060_events_as=prz060_vf[prz060_vf['Message'].str.contains('AutoSnapshot')]
prz060_events_as
# Out:
#                       Created  \
# 3     2025-08-20 17:41:51.868
# 9     2025-08-20 17:44:34.986
# 11    2025-08-20 17:46:44.374
# 20    2025-08-20 17:56:42.638
# 25    2025-08-20 17:57:07.933
# ...                       ...
# 2120  2025-09-11 22:57:50.964
# 2128  2025-09-11 23:04:51.499
# 2133  2025-09-11 23:05:09.965
# 2137  2025-09-11 23:06:21.019
# 2140  2025-09-11 23:06:32.852
#
#                                                 Message  \
# 3     {"notificationType":"AutoSnapshot","sn":"6B311...
# 9     {"notificationType":"AutoSnapshot","sn":"6B311...
# 11    {"notificationType":"AutoSnapshot","sn":"6B311...
# 20    {"notificationType":"AutoSnapshot","sn":"6B311...
# 25    {"notificationType":"AutoSnapshot","sn":"6B311...
# ...                                                 ...
# 2120  {"notificationType":"AutoSnapshot","sn":"6B311...
# 2128  {"notificationType":"AutoSnapshot","sn":"6B311...
# 2133  {"notificationType":"AutoSnapshot","sn":"6B311...
# ...

# %% [markdown]
# PRZ061

# %%
prz061_vf=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ061 VF.csv',sep=';',encoding='latin1')
prz061_vf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2021 entries, 0 to 2020
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  2021 non-null   object
#  1   Message  2021 non-null   object
#  2   Status   2021 non-null   object
# dtypes: object(3)
# memory usage: 47.5+ KB

# %%
prz061_vfM=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ061 VFm.csv',sep=';',encoding='latin1')
prz061_vfM.info()
prz061_vfM.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2021 entries, 0 to 2020
# Data columns (total 92 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      2021 non-null   object
#  1   Unnamed: 1   2021 non-null   object
#  2   Unnamed: 2   2021 non-null   object
#  3   Unnamed: 3   2021 non-null   object
#  4   Unnamed: 4   2021 non-null   object
#  5   Unnamed: 5   2021 non-null   object
#  6   Unnamed: 6   2021 non-null   object
#  7   Unnamed: 7   2021 non-null   object
#  8   Unnamed: 8   2021 non-null   object
#  9   Unnamed: 9   2021 non-null   object
#  10  Unnamed: 10  2021 non-null   object
#  11  Unnamed: 11  2021 non-null   object
#  12  Unnamed: 12  2021 non-null   object
#  13  Unnamed: 13  2021 non-null   object
#  14  Unnamed: 14  2021 non-null   object
#  15  Unnamed: 15  2021 non-null   object
#  16  Unnamed: 16  2004 non-null   object
#  17  Unnamed: 17  1978 non-null   object
# ...

# %%
prz061_vfM['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              901
# {"notificationType":"CameraRunningInfo"     454
# {"notificationType":"AutoSnapshot"          345
# {"notificationType":"IgnitionStatus"        199
# {"notificationType":"DataUsage"              66
# {"notificationType":"MaintenanceWarning"     30
# {"notificationType":"ParkingHeartbeat"       17
# {"notificationType":"CameraEvent"             8
# {"notificationType":"PowerEvent"              1
# Name: count, dtype: int64

# %%
prz061_events=prz061_vfM[prz061_vfM['Message'].str.contains('AutoSnapshot')]
prz061_events.sort_index(ascending=False)
prz061_events['Unnamed: 5'].to_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ061 VFm_url.csv')

# %%
prz061_events_others=prz061_vfM[prz061_vfM['Message'].str.contains('CameraEvent')]
prz061_events_others['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"    6
# event:"POTENTIAL_INCIDENT_LOW"       1
# event:"USING_PHONE"                  1
# Name: count, dtype: int64

# %%
prz061_events_as=prz061_vf[prz061_vf['Message'].str.contains('AutoSnapshot')]
prz061_events_as
# Out:
#                       Created  \
# 3     2025-08-20 15:59:15.341
# 11    2025-08-20 16:09:14.446
# 19    2025-08-20 16:19:13.461
# 24    2025-08-20 16:21:01.923
# 27    2025-08-20 16:43:28.371
# ...                       ...
# 1993  2025-09-11 20:55:00.430
# 2001  2025-09-11 21:05:00.056
# 2010  2025-09-11 21:09:21.044
# 2013  2025-09-11 21:11:40.602
# 2019  2025-09-11 21:17:20.510
#
#                                                 Message  \
# 3     {"notificationType":"AutoSnapshot","sn":"6B311...
# 11    {"notificationType":"AutoSnapshot","sn":"6B311...
# 19    {"notificationType":"AutoSnapshot","sn":"6B311...
# 24    {"notificationType":"AutoSnapshot","sn":"6B311...
# 27    {"notificationType":"AutoSnapshot","sn":"6B311...
# ...                                                 ...
# 1993  {"notificationType":"AutoSnapshot","sn":"6B311...
# 2001  {"notificationType":"AutoSnapshot","sn":"6B311...
# 2010  {"notificationType":"AutoSnapshot","sn":"6B311...
# ...

# %% [markdown]
# PRZ507

# %%
prz507_vfM=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ507 VFm.csv',sep=';')
prz507_vfM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 57 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      582 non-null    object
#  1   Unnamed: 1   582 non-null    object
#  2   Unnamed: 2   582 non-null    object
#  3   Unnamed: 3   582 non-null    object
#  4   Unnamed: 4   582 non-null    object
#  5   Unnamed: 5   582 non-null    object
#  6   Unnamed: 6   582 non-null    object
#  7   Unnamed: 7   582 non-null    object
#  8   Unnamed: 8   582 non-null    object
#  9   Unnamed: 9   582 non-null    object
#  10  Unnamed: 10  582 non-null    object
#  11  Unnamed: 11  582 non-null    object
#  12  Unnamed: 12  582 non-null    object
#  13  Unnamed: 13  582 non-null    object
#  14  Unnamed: 14  582 non-null    object
#  15  Unnamed: 15  582 non-null    object
#  16  Unnamed: 16  582 non-null    object
#  17  Unnamed: 17  566 non-null    object
# ...

# %%
prz507_vf=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ507 VF.csv',sep=';',encoding='latin1')
prz507_vf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  594 non-null    object
#  1   Message  594 non-null    object
#  2   Status   594 non-null    object
# dtypes: object(3)
# memory usage: 14.1+ KB

# %%
prz507_events_others=prz507_vfM[prz507_vfM['Message'].str.contains('CameraEvent')]
prz507_events_others['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_LOW"       6
# event:"POTENTIAL_INCIDENT_MEDIUM"    4
# Name: count, dtype: int64

# %%
prz507_events_as=prz507_vf[prz507_vf['Message'].str.contains('AutoSnapshot')]
prz507_events_as.to_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ507 VF AS.csv')

# %% [markdown]
# PRZ506

# %%
prz506_vfM=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ506 VFm.csv',sep=';',encoding='latin1')
prz506_vfM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 92 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      850 non-null    object
#  1   Unnamed: 1   850 non-null    object
#  2   Unnamed: 2   850 non-null    object
#  3   Unnamed: 3   850 non-null    object
#  4   Unnamed: 4   850 non-null    object
#  5   Unnamed: 5   850 non-null    object
#  6   Unnamed: 6   850 non-null    object
#  7   Unnamed: 7   850 non-null    object
#  8   Unnamed: 8   850 non-null    object
#  9   Unnamed: 9   850 non-null    object
#  10  Unnamed: 10  850 non-null    object
#  11  Unnamed: 11  850 non-null    object
#  12  Unnamed: 12  850 non-null    object
#  13  Unnamed: 13  849 non-null    object
#  14  Unnamed: 14  849 non-null    object
#  15  Unnamed: 15  824 non-null    object
#  16  Unnamed: 16  824 non-null    object
#  17  Unnamed: 17  812 non-null    object
# ...

# %%
prz506_events_others=prz506_vfM[prz506_vfM['Message'].str.contains('CameraEvent')]
prz506_events_others['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_LOW"     2
# event:"POTENTIAL_INCIDENT_HIGH"    1
# Name: count, dtype: int64

# %% [markdown]
# PRZ505

# %%
prz505_vfM=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/PRZ505m.csv',sep=';',encoding='latin1')
prz505_vfM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 68 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      607 non-null    object
#  1   Unnamed: 1   607 non-null    object
#  2   Unnamed: 2   607 non-null    object
#  3   Unnamed: 3   607 non-null    object
#  4   Unnamed: 4   607 non-null    object
#  5   Unnamed: 5   607 non-null    object
#  6   Unnamed: 6   607 non-null    object
#  7   Unnamed: 7   607 non-null    object
#  8   Unnamed: 8   607 non-null    object
#  9   Unnamed: 9   607 non-null    object
#  10  Unnamed: 10  607 non-null    object
#  11  Unnamed: 11  607 non-null    object
#  12  Unnamed: 12  607 non-null    object
#  13  Unnamed: 13  607 non-null    object
#  14  Unnamed: 14  607 non-null    object
#  15  Unnamed: 15  600 non-null    object
#  16  Unnamed: 16  600 non-null    object
#  17  Unnamed: 17  596 non-null    object
# ...

# %%
prz505_events_others=prz505_vfM[prz505_vfM['Message'].str.contains('CameraEvent')]
prz505_events_others['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_MEDIUM"    4
# event:"MANUAL"                       2
# Name: count, dtype: int64
