# %%
import pandas as pd
import numpy as np

# %%
ubd=pd.read_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/CRMUnitsDealersReports_16072025.csv',sep=';',encoding='latin1')
ubd.info()
ubd['Unit Type'].fillna('Empty',inplace=True)
queclink=ubd[ubd['Unit Type'].str.contains('Queclink')]
queclink.info()
calamp=ubd[ubd['Unit Type'].str.contains('Cal')]
calamp.info()
topfly=ubd[ubd['Unit Type'].str.contains('Top')]
topfly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25123 entries, 0 to 25122
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   25122 non-null  object
#  1   Company                  25122 non-null  object
#  2   VIP                      25122 non-null  object
#  3   FEIN                     22508 non-null  object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      4838 non-null   object
#  6   Peripherals              25122 non-null  object
#  7   Service                  20312 non-null  object
#  8   Owner                    25122 non-null  object
#  9   Unit ID                  25122 non-null  object
#  10  Unit                     25122 non-null  object
#  11  Unit Type                25122 non-null  object
#  12  Carrier                  23364 non-null  object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
queclink.info()
queclink.to_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/queclink_crm.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7368 entries, 1 to 25121
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   7368 non-null   object
#  1   Company                  7368 non-null   object
#  2   VIP                      7368 non-null   object
#  3   FEIN                     6805 non-null   object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      1999 non-null   object
#  6   Peripherals              7368 non-null   object
#  7   Service                  6770 non-null   object
#  8   Owner                    7368 non-null   object
#  9   Unit ID                  7368 non-null   object
#  10  Unit                     7368 non-null   object
#  11  Unit Type                7368 non-null   object
#  12  Carrier                  6776 non-null   object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
queclink['Company'].value_counts().to_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/queclinks.csv')
queclink_Domi=queclink[queclink['Company'].str.contains('DOMINION')] 
#queclink_Domi.info()
queclink_Domi_filtered=queclink_Domi[queclink_Domi['Unit Type'].str.contains('GV')]
#queclink_Domi_filtered.info()
#queclink_Domi_filtered['Unit Type'].value_counts()
queclink_Domi_filtered['Monthly Fee'].value_counts()
# Out:
# Monthly Fee
# 27000    171
# Name: count, dtype: int64

# %%
(171*27000)/4000
# Out:
# 1154.25

# %%
calamp.info()
calamp.to_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/calamp_crm.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7765 entries, 9 to 25114
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   7765 non-null   object
#  1   Company                  7765 non-null   object
#  2   VIP                      7765 non-null   object
#  3   FEIN                     7351 non-null   object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      1860 non-null   object
#  6   Peripherals              7765 non-null   object
#  7   Service                  7367 non-null   object
#  8   Owner                    7765 non-null   object
#  9   Unit ID                  7765 non-null   object
#  10  Unit                     7765 non-null   object
#  11  Unit Type                7765 non-null   object
#  12  Carrier                  7439 non-null   object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
calamp[['Unnamed: 13','Unnamed: 4']].head(2)
# Out:
#     Unnamed: 13  Unnamed: 4
# 9           NaN         NaN
# 10          NaN         NaN

# %%
topfly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1113 entries, 0 to 24955
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   1113 non-null   object
#  1   Company                  1113 non-null   object
#  2   VIP                      1113 non-null   object
#  3   FEIN                     1113 non-null   object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      333 non-null    object
#  6   Peripherals              1113 non-null   object
#  7   Service                  1096 non-null   object
#  8   Owner                    1113 non-null   object
#  9   Unit ID                  1113 non-null   object
#  10  Unit                     1113 non-null   object
#  11  Unit Type                1113 non-null   object
#  12  Carrier                  787 non-null    object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
df_book_table01=pd.read_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/calamp_ctc.csv')
df_book_table02=pd.read_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/calamp_crm.csv')
df_book_table01['IMEI'].fillna('123456',inplace=True)
# Out:
# /tmp/ipykernel_791/3799885544.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_book_table01['IMEI'].fillna('123456',inplace=True)
# /tmp/ipykernel_791/3799885544.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '123456' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_book_table01['IMEI'].fillna('123456',inplace=True)

# %%
companies=pd.read_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/coincidences.csv')
#companies.info()
companies['Company'].value_counts()
# Out:
# Company
# PROYECTOS DE INGENIERIA SA PROING SA                                   432
# TTSO MOBILE S.A.S. COLOMBIA.                                           391
# TSO INVENTARIO DISPONIBLE PERU                                         319
# DON POLLO TROPICAL SAC                                                 132
# LOGISTICA DE CARGA ESPECIALIZADA MULTIMODAL SAS LOGICEM - CARTAGENA    116
#                                                                       ...
# ASOCIACION GREMIAL AGROPECUARIA DE USUARIOS DEL RIO HUMEA                1
# MILLER DE JESUS TOBON HENAO                                              1
# FERRETERIA NIPLES YA SAS                                                 1
# LOG?STICA Y TRANSPORTE SAN MIGUEL SAS                                    1
# INDUSTRIAS VAC S.A.C.                                                    1
# Name: count, Length: 829, dtype: int64

# %% [markdown]
# # PROING:

# %%
cu_proing=pd.read_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/cu.csv',sep=';',encoding='latin1')
#cu_proing.info()
cu_proing_pn_imeis=cu_proing[['IMEI','Phone Number']]
#cu_proing.describe()
#cu_proing['Monthly Fee'].sum()
cu_proing_calamp0330=cu_proing[cu_proing['Unit Type'].str.contains('0330')]
cu_proing_calamp0330.info()
cu_proing_calamp0330['Unit Type'].value_counts()
cu_proing_queclink=cu_proing[cu_proing['Unit Type'].str.contains('Quec')]
cu_proing_queclink.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 305 entries, 1 to 728
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       305 non-null    int64
#  1   Owner                    305 non-null    object
#  2   Unit ID                  305 non-null    object
#  3   Unit                     305 non-null    object
#  4   Peripherals              3 non-null      object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      object
#  8   Last Event Date          305 non-null    object
#  9   Monthly Fee              305 non-null    int64
#  10  Bill To                  0 non-null      object
#  11  Assigned To              305 non-null    object
#  12  Linked Mode              305 non-null    int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
cu_proing_queclink.describe()
totalq=cu_proing_queclink['Monthly Fee'].sum()
totalq
# Out:
# np.int64(9870400)

# %%
cu_proing_calamp0330.describe()
total_0330=cu_proing_calamp0330['Monthly Fee'].sum()
total_0330
# Out:
# np.int64(12139000)

# %%
MRR=totalq+total_0330
Total_units=248+305
print(Total_units, MRR/4000)
# Out:
# 553 5502.35

# %%
calamp_0330_filt=pd.read_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/coincidences.csv')
calamp_0330_to_up=calamp_0330_filt[~calamp_0330_filt['Firmware'].str.contains('85f')]
calamp_0330_to_up.to_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/calamp_0330_proing_to_up.csv')

# %% [markdown]
# ## COMPARADOR DE TABLAS

# %%
df_book_table01=cu_proing_calamp0330[cu_proing_calamp0330['Last Event Date'].str.contains('07/2025')]
df_book_table02=pd.read_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/coincidences_calamp_crm.csv')
df_book_table01.info()
df_book_table02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 249 entries, 2 to 728
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       249 non-null    int64
#  1   Owner                    249 non-null    object
#  2   Unit ID                  249 non-null    object
#  3   Unit                     249 non-null    object
#  4   Peripherals              0 non-null      object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      object
#  8   Last Event Date          249 non-null    object
#  9   Monthly Fee              249 non-null    int64
#  10  Bill To                  0 non-null      object
#  11  Assigned To              249 non-null    object
#  12  Linked Mode              249 non-null    int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])       
cont=0
df_aux=pd.DataFrame()        
list_field01=[]
list_field02=[]
list_field03=[]
list_field04=[]
list_field05=[]
list_field06=[]       
#print("df_book_table01[8,0]: ",df_book_table01.iloc[8,0]) #UnitsByDealer.csv_r.csv
#print("df_book_table02[8,5]: ",df_book_table02.iloc[8,5]) #6MB.        
print("\nInformación de las tablas: ")
print("\nTabla 1:")
print(df_book_table01.info())
print("\nTabla 2:")
print(df_book_table02.info())
attribute_name_table01='IMEI'#Digitar el índice de la tabla 1.#input("\nDigita el atributo a comparar de la tabla 1: ")
attribute_name_table02='IMEI'#Digitar el índice de la tabla 2.#input("Digita el atribito a comparar de la tabla 2: ")
position_table01=int(df_book_table01.columns.get_loc(attribute_name_table01))
position_table02=int(df_book_table02.columns.get_loc(attribute_name_table02))
print("\nAtributo de la tabla1: ",position_table01)
print("Atributo de la tabla2: ",position_table02,"\n")
print("Trabajando...")

print(int(df_book_table01.iloc[1,position_table01]))
print(df_book_table02.iloc[1,position_table02])

                          
for i in range(0,num_filas_table01):
    for j in range(0,num_filas_table02):
        #if str(df_book_table01.iloc[i,5])==str(df_book_table02.iloc[j,3]): 
        if str(df_book_table01.iloc[i,position_table01])==str(int(df_book_table02.iloc[j,position_table02])):
            list_field01.append(df_book_table01.iloc[i,18])                                            
            list_field02.append(df_book_table01.iloc[i,20])
            list_field03.append(df_book_table02.iloc[i,5])
            print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
            print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
            cont=cont+1
df_aux['IMEI']=list_field01
df_aux['Phone number']=list_field02
df_aux['Firmware']=list_field03
#df_aux['Last Event Date']=list_field04
#df_aux['Firmware']=list_field05
#df_aux['Company']=list_field06
print("Cont= ",cont)
print(df_aux.head(5))
option_exp=input("\n¿Desea generar un reporte de coincidencias en formato csv S/N?\n")
if option_exp=="S":
    df_aux.to_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/coincidences.csv')
cont=0
option_exp=input("¿Desea generar un reporte de diferencias en formato csv S/N?\n")        
df_book_table02['ACTION']="Keep"
if option_exp=="S":
    print("Trabajando...")
    for i in range(0,num_filas_table01):
        for j in range(0,num_filas_table02):
            if str(int(df_book_table01.iloc[i,position_table01]))==str(df_book_table02.iloc[j,position_table02]):
                df_book_table02.iloc[j,5]=np.nan
                print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
                print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
    df_book_table02.dropna(axis=0,inplace=True)
    #print(df_book_table02)
    df_book_table02.to_csv('/home/jlhb1984/py-projects/data/bulk_upgrade/differences.csv')

#lista_combinada=[lista_simcard,lista_linea]
# Out:
# Información de las tablas:
#
# Tabla 1:
# <class 'pandas.core.frame.DataFrame'>
# Index: 249 entries, 2 to 728
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       249 non-null    int64
#  1   Owner                    249 non-null    object
#  2   Unit ID                  249 non-null    object
#  3   Unit                     249 non-null    object
#  4   Peripherals              0 non-null      object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      object
#  8   Last Event Date          249 non-null    object
#  9   Monthly Fee              249 non-null    int64
#  10  Bill To                  0 non-null      object
#  11  Assigned To              249 non-null    object
#  12  Linked Mode              249 non-null    int64
# ...
