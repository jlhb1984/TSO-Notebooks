# %%
import pandas as pd
import numpy as np

# %%
cu=pd.read_csv('/home/jlhb1984/py-projects/data/gruas telescopicas/cu.csv',sep=';',encoding='latin1')
cu.info()
cu['Unit Type'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       7 non-null      int64
#  1   Owner                    7 non-null      object
#  2   Unit ID                  7 non-null      object
#  3   Unit                     7 non-null      object
#  4   Peripherals              1 non-null      object
#  5   BillingPeriod            7 non-null      object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            0 non-null      float64
#  9   Last Event Date          7 non-null      object
#  10  Monthly Fee              7 non-null      int64
#  11  Bill To                  0 non-null      float64
#  12  Assigned To              7 non-null      object
#  13  Linked Mode              7 non-null      int64
# ...

# %%
calamp_units=cu[cu['Unit Type'].str.contains('CalAmp')]
calamp_units[['Unit Type','IMEI','Unit','Phone Number','Last Event Date']]
# Out:
#                                       Unit Type             IMEI    Unit  \
# 1        CalAmp 2630 - 3G - LMU2631H-H000-G1000  354514101197087  ZDA257
# 3  CalAmp 2630 - GEMALTO HSPA -LMU26H3001-JAM01  354514101223396  ZAP716
# 4       CalAmp 0330H - 3G - LMU0330H-SKM6-G1000  359369091076832  SKO991
# 5  CalAmp 2630 - GEMALTO HSPA -LMU26H3001-JAM01  354514101590067  LAW518
# 6  CalAmp 2630 - GEMALTO HSPA -LMU26H3001-JAM01  354514101581710  KIF104
#
#    Phone Number Last Event Date
# 1    9103436084       3/12/2025
# 3    9101145634       3/12/2025
# 4    9103436091       3/12/2025
# 5    9103976951       3/12/2025
# 6    9103419949       3/12/2025

# %%
calamp_units={'Unit':['IMEI','Phone Number','Received'],
              'ZDA257':['354514101197087','9103436084','!RP,257,1,2361'],
              'ZAP716':['354514101223396','9101145634','!RP,257,1,2361'],
              'SKO991':['359369091076832','9103436091','!RP,257,1,2361'],
              'LAW518':['354514101590067','9103976951','!RP,257,1,2361'],
              'KIF104':['354514101581710','9103419949','!RP,257,1,2361']    
}

calamp_units
# Out:
# {'Unit': ['IMEI', 'Phone Number', 'Received'],
#  'ZDA257': ['354514101197087', '9103436084', '!RP,257,1,2361'],
#  'ZAP716': ['354514101223396', '9101145634', '!RP,257,1,2361'],
#  'SKO991': ['359369091076832', '9103436091', '!RP,257,1,2361'],
#  'LAW518': ['354514101590067', '9103976951', '!RP,257,1,2361'],
#  'KIF104': ['354514101581710', '9103419949', '!RP,257,1,2361']}
