# %%
import pandas as pd
import numpy as np

# %%
plate_list=pd.read_csv('data/gps_drift_dimo/Listado Placas.csv',sep=';',encoding='latin1')
plate_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10 non-null     int64
#  1   Propietario                   10 non-null     object
#  2   ID Unidad                     10 non-null     object
#  3   Unidad                        10 non-null     object
#  4   Fecha Último Evento           10 non-null     object
#  5   Assignada a                   10 non-null     object
#  6   Tipo de Unidad                10 non-null     object
#  7   IMEI                          10 non-null     int64
#  8   Serial                        10 non-null     object
#  9   Número de Teléfono            10 non-null     int64
#  10  Postador                      10 non-null     object
#  11  SIM #                         10 non-null     object
# ...

# %%
units=plate_list[['Tipo de Unidad','Fecha Último Evento','IMEI','Serial','Unidad']]
units
summary=units.to_csv('data/gps_drift_dimo/summary.csv')

# %%
calamp_units=plate_list[plate_list['Tipo de Unidad'].str.contains('CalAmp')]
calamp_serials=calamp_units[['Serial']]
calamp_serials.to_csv('data/gps_drift_dimo/calamp_serials.csv')

# %%
queclink_units=plate_list[plate_list['Tipo de Unidad'].str.contains('Queclink')]
queclink_serials=queclink_units[['IMEI']]
queclink_serials.to_csv('data/gps_drift_dimo/queclink_imei.csv')

# %%
topfly_units=plate_list[plate_list['Tipo de Unidad'].str.contains('Topfly')]
topfly_units=topfly_units[['IMEI']]
topfly_units.to_csv('data/gps_drift_dimo/topfly_imei.csv')

# %%
calamp_units_info_CTC=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/calamp_devices-06-11-2025.csv')
calamp_units_info_CTC.info()
calamp_units_info_CTC[['Model','ESN','Firmware Version','Script Identifier']]

# %%
queclink_units_info_QMS=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/queclink_devices 06-11-2025.csv',sep=';')
queclink_units_info_QMS.info()
queclink_units_info_QMS[['Device Name','Last Report Date','IMEI','Device Type','Firmware Version','Configuration Version']]

# %%
topfly_units_info_DMS=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/topfly devices 2025-06-11.csv',sep=';',encoding='latin1')
topfly_units_info_DMS.info()
topfly_units_info_DMS[['IMEI','Modelo','Versión de la aplicación','Versión del archivo de configuración']]

# %% [markdown]
# ## LZM117

# %%
lzm117=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/lzm117.csv',sep=';',encoding='latin1')
lzm117.info()
lzm117['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10628 entries, 0 to 10627
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     10628 non-null  int64
#  1   Unit         10628 non-null  object
#  2   Events       10628 non-null  object
#  3   Date         10628 non-null  object
#  4   Landmark     0 non-null      float64
#  5   Address      10628 non-null  object
#  6   Speed        10628 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     10628 non-null  float64
#  10  Longitude    10628 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 913.5+ KB
# Events
# Drive               4441
# Parked              2614
# Travel Start        1317
# Travel Stop         1279
# Idle - Stop          285
# Idle Alert           253
# Ignition ON          155
# Ignition OFF         153
# Harsh Turn            38
# ...

# %%
lzm117_towing_drifting=lzm117[lzm117['Events'].str.contains('Towing')]
lzm117_towing_drifting

# %% [markdown]
# ## NOY235

# %%
noy235=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/noy235.csv',sep=';',encoding='latin1')
noy235.info()
noy235['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4333 entries, 0 to 4332
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     4333 non-null   int64
#  1   Unit         4333 non-null   object
#  2   Events       4333 non-null   object
#  3   Date         4333 non-null   object
#  4   Landmark     5 non-null      object
#  5   Address      4333 non-null   object
#  6   Speed        4333 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     4333 non-null   float64
#  10  Longitude    4333 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 372.5+ KB
# Events
# Drive               2311
# Travel Start         709
# Travel Stop          692
# Idle - Stop          164
# Ignition OFF         134
# Ignition ON          133
# Parked                83
# Idle Alert            43
# End Speeding          15
# ...

# %%
noy235_towing_drifting=noy235[noy235['Events'].str.contains('Towing')]
noy235_towing_drifting
# Out:
#       Sequence    Unit            Events                  Date Landmark  \
# 1419      2914  NOY235  Towing/Drifting?  Jun 09 2025 08:52 AM      NaN
# 2107      2226  NOY235  Towing/Drifting?  Jun 08 2025 07:49 AM      NaN
# 2751      1582  NOY235  Towing/Drifting?  Jun 07 2025 01:06 PM      NaN
# 2752      1581  NOY235  Towing/Drifting?  Jun 07 2025 01:06 PM      NaN
# 2755      1578  NOY235  Towing/Drifting?  Jun 07 2025 01:02 PM      NaN
# 2756      1577  NOY235  Towing/Drifting?  Jun 07 2025 01:02 PM      NaN
# 2770      1563  NOY235  Towing/Drifting?  Jun 07 2025 06:10 AM      NaN
# 2771      1562  NOY235  Towing/Drifting?  Jun 07 2025 06:10 AM      NaN
# 2772      1561  NOY235  Towing/Drifting?  Jun 07 2025 06:08 AM      NaN
# 3417       916  NOY235  Towing/Drifting?  Jun 06 2025 11:03 AM      NaN
# 4264        69  NOY235  Towing/Drifting?  Jun 05 2025 02:15 PM      NaN
# 4268        65  NOY235  Towing/Drifting?  Jun 05 2025 01:58 PM      NaN
# ...

# %% [markdown]
# ## MYY520

# %%
myy520=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/myy520.csv',sep=';',encoding='latin1')
myy520.info()
myy520['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8566 entries, 0 to 8565
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     8566 non-null   int64
#  1   Unit         8566 non-null   object
#  2   Events       8566 non-null   object
#  3   Date         8566 non-null   object
#  4   Landmark     6 non-null      object
#  5   Address      8566 non-null   object
#  6   Speed        8566 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     8566 non-null   float64
#  10  Longitude    8566 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 736.3+ KB
# Events
# Drive               4809
# Travel Start        1211
# Travel Stop         1196
# Idle - Stop          312
# End Speeding         279
# Speed alert          277
# Ignition OFF         108
# Ignition ON          107
# Harsh Turn            89
# ...

# %%
myy520_towing_drifting=myy520[myy520['Events'].str.contains('Towing')]
myy520_towing_drifting
# Out:
#       Sequence    Unit            Events                  Date Landmark  \
# 95        8471  MYY520  Towing/Drifting?  Jun 11 2025 06:14 AM      NaN
# 96        8470  MYY520  Towing/Drifting?  Jun 11 2025 06:14 AM      NaN
# 4029      4537  MYY520  Towing/Drifting?  Jun 06 2025 05:09 AM      NaN
# 4030      4536  MYY520  Towing/Drifting?  Jun 06 2025 05:09 AM      NaN
# 4031      4535  MYY520  Towing/Drifting?  Jun 06 2025 05:09 AM      NaN
# 6410      2156  MYY520  Towing/Drifting?  Jun 03 2025 07:10 AM      NaN
# 6411      2155  MYY520  Towing/Drifting?  Jun 03 2025 07:09 AM      NaN
# 8541        25  MYY520  Towing/Drifting?  May 27 2025 07:14 PM      NaN
# 8542        24  MYY520  Towing/Drifting?  May 27 2025 07:14 PM      NaN
# 8544        22  MYY520  Towing/Drifting?  May 27 2025 07:13 PM      NaN
#
#                                                 Address  Speed  Temperature  \
# 95          Kr76a 8a-49, Bogota, Cundinamarca, Colombia     99          NaN
# ...

# %% [markdown]
# ## LPY964

# %%
lpy964=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/lpy964.csv',sep=';',encoding='latin1')
lpy964.info()
lpy964['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6516 entries, 0 to 6515
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     6516 non-null   int64
#  1   Unit         6516 non-null   object
#  2   Events       6516 non-null   object
#  3   Date         6516 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      6516 non-null   object
#  6   Speed        6516 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     6516 non-null   float64
#  10  Longitude    6516 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 560.1+ KB
# Events
# Drive               3174
# Travel Start        1054
# Travel Stop         1041
# Idle - Stop          245
# Speed alert          233
# End Speeding         232
# Ignition OFF         150
# Ignition ON          149
# Parked               110
# ...

# %%
lpy964_towing_drifting=lpy964[lpy964['Events'].str.contains('Towing')]
lpy964_towing_drifting
# Out:
#       Sequence    Unit            Events                  Date  Landmark  \
# 433       6083  LPY964  Towing/Drifting?  Jun 09 2025 02:47 PM       NaN
# 435       6081  LPY964  Towing/Drifting?  Jun 09 2025 02:47 PM       NaN
# 447       6069  LPY964  Towing/Drifting?  Jun 09 2025 02:21 PM       NaN
# 448       6068  LPY964  Towing/Drifting?  Jun 09 2025 02:21 PM       NaN
# 449       6067  LPY964  Towing/Drifting?  Jun 09 2025 02:21 PM       NaN
# 450       6066  LPY964  Towing/Drifting?  Jun 09 2025 02:21 PM       NaN
# 457       6059  LPY964  Towing/Drifting?  Jun 09 2025 02:13 PM       NaN
# 462       6054  LPY964  Towing/Drifting?  Jun 09 2025 02:07 PM       NaN
# 465       6051  LPY964  Towing/Drifting?  Jun 09 2025 02:05 PM       NaN
# 466       6050  LPY964  Towing/Drifting?  Jun 09 2025 02:05 PM       NaN
# 467       6049  LPY964  Towing/Drifting?  Jun 09 2025 02:05 PM       NaN
# 468       6048  LPY964  Towing/Drifting?  Jun 09 2025 02:05 PM       NaN
# ...

# %% [markdown]
# ## LLQ608

# %%
llq608=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/llq608.csv',sep=';',encoding='latin1')
llq608.info()
llq608['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6346 entries, 0 to 6345
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     6346 non-null   int64
#  1   Unit         6346 non-null   object
#  2   Events       6346 non-null   object
#  3   Date         6346 non-null   object
#  4   Landmark     2 non-null      object
#  5   Address      6344 non-null   object
#  6   Speed        6346 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     6346 non-null   float64
#  10  Longitude    6346 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 545.5+ KB
# Events
# Drive                 2826
# Travel Start          1228
# Travel Stop           1181
# Idle - Stop            288
# Ignition ON            229
# Ignition OFF           229
# Parked                 204
# Idle Alert              99
# ...

# %%
llq608_towing_drifting=llq608[llq608['Events'].str.contains('Towing')]
llq608_towing_drifting
# Out:
#       Sequence    Unit            Events                  Date Landmark  \
# 90        6256  LLQ608  Towing/Drifting?  Jun 11 2025 05:04 AM      NaN
# 110       6236  LLQ608  Towing/Drifting?  Jun 11 2025 03:21 AM      NaN
# 116       6230  LLQ608  Towing/Drifting?  Jun 11 2025 02:59 AM      NaN
# 1292      5054  LLQ608  Towing/Drifting?  Jun 08 2025 11:58 PM      NaN
# 1439      4907  LLQ608  Towing/Drifting?  Jun 08 2025 08:12 AM      NaN
# 1450      4896  LLQ608  Towing/Drifting?  Jun 08 2025 06:18 AM      NaN
# 1456      4890  LLQ608  Towing/Drifting?  Jun 08 2025 04:56 AM      NaN
# 1457      4889  LLQ608  Towing/Drifting?  Jun 08 2025 04:55 AM      NaN
# 2219      4127  LLQ608  Towing/Drifting?  Jun 07 2025 03:20 AM      NaN
# 2244      4102  LLQ608  Towing/Drifting?  Jun 06 2025 09:56 PM      NaN
# 2245      4101  LLQ608  Towing/Drifting?  Jun 06 2025 09:56 PM      NaN
# 2246      4100  LLQ608  Towing/Drifting?  Jun 06 2025 09:55 PM      NaN
# ...

# %% [markdown]
# ## GUU552

# %%
guu552=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/guu552.csv',sep=';',encoding='latin1')
guu552.info()
guu552['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9333 entries, 0 to 9332
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     9333 non-null   int64
#  1   Unit         9333 non-null   object
#  2   Events       9333 non-null   object
#  3   Date         9333 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      9333 non-null   object
#  6   Speed        9333 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     9333 non-null   float64
#  10  Longitude    9333 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 802.2+ KB
# Events
# Drive               3793
# Parked              1812
# Travel Start        1245
# Travel Stop         1210
# Speed alert          294
# End Speeding         293
# Idle - Stop          178
# Ignition OFF         127
# Ignition ON          126
# ...

# %%
guu552_towing_drifting=guu552[guu552['Events'].str.contains('Towing')]
guu552_towing_drifting
# Out:
#       Sequence    Unit            Events                  Date  Landmark  \
# 1335      7998  GUU552  Towing/Drifting?  Jun 10 2025 02:03 PM       NaN
# 1342      7991  GUU552  Towing/Drifting?  Jun 10 2025 01:45 PM       NaN
# 2192      7141  GUU552  Towing/Drifting?  Jun 09 2025 03:48 PM       NaN
# 2283      7050  GUU552  Towing/Drifting?  Jun 09 2025 11:09 AM       NaN
# 2290      7043  GUU552  Towing/Drifting?  Jun 09 2025 10:48 AM       NaN
# 2293      7040  GUU552  Towing/Drifting?  Jun 09 2025 10:45 AM       NaN
# 2294      7039  GUU552  Towing/Drifting?  Jun 09 2025 10:45 AM       NaN
# 2295      7038  GUU552  Towing/Drifting?  Jun 09 2025 10:45 AM       NaN
# 2296      7037  GUU552  Towing/Drifting?  Jun 09 2025 10:44 AM       NaN
# 2440      6893  GUU552  Towing/Drifting?  Jun 09 2025 12:46 AM       NaN
# 2450      6883  GUU552  Towing/Drifting?  Jun 09 2025 12:25 AM       NaN
# 3364      5969  GUU552  Towing/Drifting?  Jun 07 2025 09:27 PM       NaN
# ...

# %% [markdown]
# ## NUZ020

# %%
nuz020=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/nuz020.csv',sep=';',encoding='latin1')
nuz020.info()
nuz020['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8575 entries, 0 to 8574
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     8575 non-null   int64
#  1   Unit         8575 non-null   object
#  2   Events       8575 non-null   object
#  3   Date         8575 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      8575 non-null   object
#  6   Speed        8575 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     8575 non-null   float64
#  10  Longitude    8575 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 737.0+ KB
# Events
# Idle - Stop           1905
# Towing/Drifting?      1765
# Parked                1718
# Ignition OFF          1073
# Ignition ON           1073
# Drive                 1003
# Ping                    13
# POWER UP                 7
# ...

# %%
nuz020_towing_drifting=nuz020[nuz020['Events'].str.contains('Towing')]
nuz020_towing_drifting
# Out:
#       Sequence    Unit            Events                  Date  Landmark  \
# 0         8575  NUZ020  Towing/Drifting?  Jun 11 2025 08:11 PM       NaN
# 2         8573  NUZ020  Towing/Drifting?  Jun 11 2025 08:10 PM       NaN
# 6         8569  NUZ020  Towing/Drifting?  Jun 11 2025 08:08 PM       NaN
# 7         8568  NUZ020  Towing/Drifting?  Jun 11 2025 08:08 PM       NaN
# 8         8567  NUZ020  Towing/Drifting?  Jun 11 2025 08:00 PM       NaN
# ...        ...     ...               ...                   ...       ...
# 8534        41  NUZ020  Towing/Drifting?  May 26 2025 03:10 PM       NaN
# 8549        26  NUZ020  Towing/Drifting?  May 26 2025 03:02 PM       NaN
# 8558        17  NUZ020  Towing/Drifting?  May 26 2025 03:00 PM       NaN
# 8571         4  NUZ020  Towing/Drifting?  May 26 2025 02:33 PM       NaN
# 8572         3  NUZ020  Towing/Drifting?  May 26 2025 02:33 PM       NaN
#
#                                                 Address  Speed  Temperature  \
# ...

# %% [markdown]
# ## NUV009

# %%
nuv009=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/nuv009.csv',sep=';',encoding='latin1')
nuv009.info()
nuv009['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7195 entries, 0 to 7194
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     7195 non-null   int64
#  1   Unit         7195 non-null   object
#  2   Events       7195 non-null   object
#  3   Date         7195 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      7195 non-null   object
#  6   Speed        7195 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     7195 non-null   float64
#  10  Longitude    7195 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 618.4+ KB
# Events
# Towing/Drifting?      2022
# Idle - Stop           1303
# Parked                1025
# Drive                  997
# Ignition ON            916
# Ignition OFF           909
# Ping                     8
# POWER UP                 4
# ...

# %%
nuv009_towing_drifting=nuv009[nuv009['Events'].str.contains('Towing')]
nuv009_towing_drifting
# Out:
#       Sequence    Unit            Events                  Date  Landmark  \
# 3         7192  NUV009  Towing/Drifting?  Jun 11 2025 07:28 PM       NaN
# 7         7188  NUV009  Towing/Drifting?  Jun 11 2025 07:28 PM       NaN
# 8         7187  NUV009  Towing/Drifting?  Jun 11 2025 07:28 PM       NaN
# 10        7185  NUV009  Towing/Drifting?  Jun 11 2025 07:21 PM       NaN
# 11        7184  NUV009  Towing/Drifting?  Jun 11 2025 07:21 PM       NaN
# ...        ...     ...               ...                   ...       ...
# 7103        92  NUV009  Towing/Drifting?  May 27 2025 11:27 PM       NaN
# 7104        91  NUV009  Towing/Drifting?  May 27 2025 11:27 PM       NaN
# 7139        56  NUV009  Towing/Drifting?  May 27 2025 10:59 PM       NaN
# 7140        55  NUV009  Towing/Drifting?  May 27 2025 10:59 PM       NaN
# 7185        10  NUV009  Towing/Drifting?  May 27 2025 10:30 PM       NaN
#
#                                                 Address  Speed  Temperature  \
# ...

# %% [markdown]
# ## PMW840

# %%
pmw840=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/pmw840.csv',sep=';',encoding='latin1')
pmw840.info()
pmw840['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19195 entries, 0 to 19194
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     19195 non-null  int64
#  1   Unit         19195 non-null  object
#  2   Events       19195 non-null  object
#  3   Date         19195 non-null  object
#  4   Landmark     0 non-null      float64
#  5   Address      19195 non-null  object
#  6   Speed        19195 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     19195 non-null  float64
#  10  Longitude    19195 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.6+ MB
# Events
# Drive               11841
# Idle - Stop          5730
# Ignition ON           491
# Ignition OFF          490
# Parked                417
# Towing/Drifting?       87
# End Speeding           46
# Alta velocidad         46
# ...

# %%
pmw840_towing_drifting=pmw840[pmw840['Events'].str.contains('Towing')]
pmw840_towing_drifting
# Out:
#        Sequence    Unit            Events                  Date  Landmark  \
# 5         19190  PMW840  Towing/Drifting?  Jun 11 2025 03:39 PM       NaN
# 6         19189  PMW840  Towing/Drifting?  Jun 11 2025 03:39 PM       NaN
# 85        19110  PMW840  Towing/Drifting?  Jun 11 2025 08:17 AM       NaN
# 86        19109  PMW840  Towing/Drifting?  Jun 11 2025 08:07 AM       NaN
# 87        19108  PMW840  Towing/Drifting?  Jun 11 2025 08:05 AM       NaN
# ...         ...     ...               ...                   ...       ...
# 18278       917  PMW840  Towing/Drifting?  May 14 2025 09:57 AM       NaN
# 18280       915  PMW840  Towing/Drifting?  May 14 2025 08:47 AM       NaN
# 18281       914  PMW840  Towing/Drifting?  May 14 2025 08:47 AM       NaN
# 18282       913  PMW840  Towing/Drifting?  May 14 2025 08:47 AM       NaN
# 18283       912  PMW840  Towing/Drifting?  May 14 2025 08:31 AM       NaN
#
#                                           Address  Speed  Temperature  Driver  \
# ...

# %% [markdown]
# ## JTP836

# %%
jtp836=pd.read_csv('/home/jlhb1984/py-projects/data/gps_drift_dimo/jtp836.csv',sep=';',encoding='latin1')
jtp836.info()
jtp836['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10718 entries, 0 to 10717
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     10718 non-null  int64
#  1   Unit         10718 non-null  object
#  2   Events       10718 non-null  object
#  3   Date         10718 non-null  object
#  4   Landmark     0 non-null      float64
#  5   Address      10718 non-null  object
#  6   Speed        10718 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     10718 non-null  float64
#  10  Longitude    10718 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 921.2+ KB
# Events
# Drive               3700
# Towing/Drifting?    3686
# Idle - Stop         1945
# Parked               868
# Ignition OFF         252
# Ignition ON          252
# Alta velocidad         4
# End Speeding           4
# Idle Alert             3
# ...

# %%
jtp836_towing_drifting=jtp836[jtp836['Events'].str.contains('Towing')]
jtp836_towing_drifting

# %% [markdown]
# ## Value count

# %%
final_report=pd.concat([lzm117,noy235,myy520,lpy964,llq608,guu552,nuz020,nuv009,pmw840,jtp836],axis=0)
final_report.info()
final_report_summary=final_report[final_report['Events'].str.contains('Towing')]
final_report_summary['Unit'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91405 entries, 0 to 10717
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     91405 non-null  int64
#  1   Unit         91405 non-null  object
#  2   Events       91405 non-null  object
#  3   Date         91405 non-null  object
#  4   Landmark     13 non-null     object
#  5   Address      91403 non-null  object
#  6   Speed        91405 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     91405 non-null  float64
#  10  Longitude    91405 non-null  float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 8.4+ MB
# Unit
# JTP836    3686
# NUV009    2022
# NUZ020    1765
# PMW840      87
# LZM117      35
# GUU552      30
# LPY964      22
# LLQ608      19
# NOY235      13
# MYY520      10
# Name: count, dtype: int64

# %% [markdown]
# Este análisis se hizo con datos de reportes de Historical Locations desde 01-05-2025 a 11-06-2025.
#
# Se requiere revisar conexiones en los vehículos NUZ020, NUV009 según Ubicaciones Históricas del 11-06-2025, confirmar que efectivamente el vehículo no haya sido remolcado.
# Para los vehículos JTP836 y MYY520 se requiere modificar la ubicación del dispositivo dentro del vehículo.
