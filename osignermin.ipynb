# %%
import pandas as pd
import numpy as np

# %%
ubd=pd.read_csv('/home/jlhb1984/py-projects/data/Osignermin/UnitsByDealer.csv',sep=';',encoding='latin1')
ubd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7312 entries, 0 to 7311
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Dealer               7312 non-null   object
#  1   Company              7312 non-null   object
#  2   VIP                  7312 non-null   bool
#  3   FEIN                 7312 non-null   object
#  4   DNI                  3152 non-null   object
#  5   Peripherals          7312 non-null   object
#  6   Service Name         5737 non-null   object
#  7   Owner                7312 non-null   object
#  8   Unit ID              7312 non-null   object
#  9   Unit                 7311 non-null   object
#  10  Unit Type            7312 non-null   object
#  11  Carrier              6802 non-null   object
#  12  Monthly Fee          7312 non-null   object
#  13  Billing Group        3449 non-null   object
#  14  Billing Period       7212 non-null   object
# ...

# %%
fuel_units=ubd[ubd['Company'].str.contains('DRAGON')]
fuel_units.info()
fuel_units['Company'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 142 to 1075
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Dealer               12 non-null     object
#  1   Company              12 non-null     object
#  2   VIP                  12 non-null     bool
#  3   FEIN                 12 non-null     object
#  4   DNI                  12 non-null     object
#  5   Peripherals          12 non-null     object
#  6   Service Name         12 non-null     object
#  7   Owner                12 non-null     object
#  8   Unit ID              12 non-null     object
#  9   Unit                 12 non-null     object
#  10  Unit Type            12 non-null     object
#  11  Carrier              10 non-null     object
#  12  Monthly Fee          12 non-null     object
#  13  Billing Group        2 non-null      object
#  14  Billing Period       11 non-null     object
# ...
