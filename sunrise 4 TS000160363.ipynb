# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 01-10-2025 - 01-12-2025:

# %%
result={#'unit':['num_events,dms_events'],
    '8B514208-PRZ507 VF-AR2':[7432,7],
    '8B5141PU-PRZ506 VF-AIR2':[6122,7],
    '8B51426E-PRZ505 AIR2':[7779,4],
    '6B31117C-PRZ061 VF':[7789,90],
    'PRZ060 VF-6B31111D':[8575,39],	
    '6B31114Z-PRZ047 VF':[9555,58],
    '6B31111D-PMX778 VF':[8594,28],
    '8B514256-OJX106 AIR2':[243,3],
    '8B5141SX-OJX103 AIR2':[578,3]
        }
print(result)
# Out:
# {'8B514208-PRZ507 VF-AR2': [7432, 7], '8B5141PU-PRZ506 VF-AIR2': [6122, 7], '8B51426E-PRZ505 AIR2': [7779, 4], '6B31117C-PRZ061 VF': [7789, 90], 'PRZ060 VF-6B31111D': [8575, 39], '6B31114Z-PRZ047 VF': [9555, 58], '6B31111D-PMX778 VF': [8594, 28], '8B514256-OJX106 AIR2': [243, 3], '8B5141SX-OJX103 AIR2': [578, 3]}

# %%
x_values=[]
y_values=[]

for key in result.keys():
    print(key,result[key])    
    x_values.append(result[key][1])
    y_values.append(result[key][0])

plt.bar(x_values,y_values)
sns.scatterplot(y_values)
# Out:
# 8B514208-PRZ507 VF-AR2 [7432, 7]
# 8B5141PU-PRZ506 VF-AIR2 [6122, 7]
# 8B51426E-PRZ505 AIR2 [7779, 4]
# 6B31117C-PRZ061 VF [7789, 90]
# PRZ060 VF-6B31111D [8575, 39]
# 6B31114Z-PRZ047 VF [9555, 58]
# 6B31111D-PMX778 VF [8594, 28]
# 8B514256-OJX106 AIR2 [243, 3]
# 8B5141SX-OJX103 AIR2 [578, 3]
# <Axes: >

# %%
cu3011=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/cu30112025.csv',sep=';',encoding='latin1')
cu3011.info()
cu3011['Unit Type'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       18 non-null     int64
#  1   Owner                    18 non-null     object
#  2   Unit ID                  18 non-null     object
#  3   Unit                     18 non-null     object
#  4   Peripherals              1 non-null      object
#  5   BillingPeriod            18 non-null     object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            0 non-null      float64
#  9   Last Event Date          18 non-null     object
#  10  Monthly Fee              18 non-null     int64
#  11  Bill To                  1 non-null      object
#  12  Assigned To              18 non-null     object
#  13  Linked Mode              18 non-null     int64
# ...

# %%
cu_f=cu3011[['Unit','Unit Type','Last Event Date','IMEI']]
cu_f_vf=cu_f[cu_f['Unit Type'].str.contains('Fleet')]
cu_f_vf['IMEI'].to_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/imeis.csv')

# %% [markdown]
# PRZ507 VF-AR2:

# %%
prz507vf_01102025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ507 VF-AR2.csv',sep=';',encoding='latin1')
prz507vf_01102025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7432 entries, 0 to 7431
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  7432 non-null   object
#  1   Message  7432 non-null   object
#  2   Status   7432 non-null   object
# dtypes: object(3)
# memory usage: 174.3+ KB

# %%
prz507vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ507 VF-AR2m.csv',sep=';',encoding='latin1')
prz507vf_01122025_events=prz507vf_01122025_messages[prz507vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz507vf_01122025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    7
# Name: count, dtype: int64

# %%
prz507vf_01122025_events=prz507vf_01122025_messages[prz507vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz507vf_01122025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"HARD_BRAKE"                      3
# event:"DROWSINESS"                      2
# event:"HEADWAY_MONITORING_EMERGENCY"    1
# event:"POTENTIAL_INCIDENT_LOW"          1
# Name: count, dtype: int64

# %% [markdown]
# PRZ506 VF-AIR2:

# %%
prz506vf_01102025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ506 VF-AIR2m.csv',sep=';',encoding='latin1')
prz506vf_01102025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6122 entries, 0 to 6121
# Data columns (total 92 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      6122 non-null   object
#  1   Unnamed: 1   6122 non-null   object
#  2   Unnamed: 2   6122 non-null   object
#  3   Unnamed: 3   6122 non-null   object
#  4   Unnamed: 4   6122 non-null   object
#  5   Unnamed: 5   6122 non-null   object
#  6   Unnamed: 6   6122 non-null   object
#  7   Unnamed: 7   6122 non-null   object
#  8   Unnamed: 8   6122 non-null   object
#  9   Unnamed: 9   6122 non-null   object
#  10  Unnamed: 10  6122 non-null   object
#  11  Unnamed: 11  6122 non-null   object
#  12  Unnamed: 12  6122 non-null   object
#  13  Unnamed: 13  6122 non-null   object
#  14  Unnamed: 14  6122 non-null   object
#  15  Unnamed: 15  6087 non-null   object
#  16  Unnamed: 16  6087 non-null   object
#  17  Unnamed: 17  6076 non-null   object
# ...

# %%
prz506vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ506 VF-AIR2m.csv',sep=';',encoding='latin1')
prz506vf_01122025_events=prz506vf_01122025_messages[prz506vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz506vf_01122025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    7
# Name: count, dtype: int64

# %%
prz506vf_01122025_events=prz506vf_01122025_messages[prz506vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz506vf_01122025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"HARD_BRAKE"                5
# event:"POTENTIAL_INCIDENT_LOW"    2
# Name: count, dtype: int64

# %% [markdown]
# PRZ505 AIR2

# %%
prz505vf_01102025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ505 AIR2m.csv',sep=';',encoding='latin1')
prz505vf_01102025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7779 entries, 0 to 7778
# Data columns (total 68 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      7779 non-null   object
#  1   Unnamed: 1   7779 non-null   object
#  2   Unnamed: 2   7779 non-null   object
#  3   Unnamed: 3   7779 non-null   object
#  4   Unnamed: 4   7779 non-null   object
#  5   Unnamed: 5   7779 non-null   object
#  6   Unnamed: 6   7779 non-null   object
#  7   Unnamed: 7   7779 non-null   object
#  8   Unnamed: 8   7779 non-null   object
#  9   Unnamed: 9   7779 non-null   object
#  10  Unnamed: 10  7779 non-null   object
#  11  Unnamed: 11  7779 non-null   object
#  12  Unnamed: 12  7779 non-null   object
#  13  Unnamed: 13  7779 non-null   object
#  14  Unnamed: 14  7779 non-null   object
#  15  Unnamed: 15  7776 non-null   object
#  16  Unnamed: 16  7776 non-null   object
#  17  Unnamed: 17  7763 non-null   object
# ...

# %%
prz505vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ505 AIR2m.csv',sep=';',encoding='latin1')
prz505vf_01122025_events=prz505vf_01122025_messages[prz505vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz505vf_01122025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    4
# Name: count, dtype: int64

# %%
prz505vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ505 AIR2m.csv',sep=';',encoding='latin1')
prz505vf_01122025_events=prz505vf_01122025_messages[prz505vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz505vf_01122025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"HEADWAY_MONITORING_EMERGENCY"    2
# event:"YAWN"                            1
# event:"POTENTIAL_INCIDENT_LOW"          1
# Name: count, dtype: int64

# %% [markdown]
# PRZ061 VF

# %%
prz061vf_01122025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ061 VF.csv',sep=';',encoding='latin1')
prz061vf_01122025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  7789 non-null   object
#  1   Message  7789 non-null   object
#  2   Status   7789 non-null   object
# dtypes: object(3)
# memory usage: 182.7+ KB

# %%
prz061vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ061 VFm.csv',sep=';',encoding='latin1')
prz061vf_01122025_events=prz061vf_01122025_messages[prz061vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz061vf_01122025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    90
# Name: count, dtype: int64

# %%
prz061vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ061 VFm.csv',sep=';',encoding='latin1')
prz061vf_01122025_events=prz061vf_01122025_messages[prz061vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz061vf_01122025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"       64
# event:"HARD_BRAKE"                      13
# event:"POTENTIAL_INCIDENT_LOW"           7
# event:"HEADWAY_MONITORING_EMERGENCY"     3
# event:"HARD_ACCEL"                       2
# event:"POTENTIAL_INCIDENT_HIGH"          1
# Name: count, dtype: int64

# %% [markdown]
# PRZ060 VF:

# %%
prz060vf_01122025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ060 VF.csv',sep=';',encoding='latin1')
prz060vf_01122025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8575 entries, 0 to 8574
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  8575 non-null   object
#  1   Message  8575 non-null   object
#  2   Status   8575 non-null   object
# dtypes: object(3)
# memory usage: 201.1+ KB

# %%
prz060vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ060 VFm.csv',sep=';',encoding='latin1')
prz060vf_01122025_events=prz060vf_01122025_messages[prz060vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz060vf_01122025_events['Message'].value_counts()
# Out:
# /tmp/ipykernel_69332/2305760536.py:1: DtypeWarning: Columns (68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103) have mixed types. Specify dtype option on import or set low_memory=False.
#   prz060vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ060 VFm.csv',sep=';',encoding='latin1')
# Message
# {"notificationType":"CameraEvent"    39
# Name: count, dtype: int64

# %%
prz060vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ060 VFm.csv',sep=';',encoding='latin1')
prz060vf_01122025_events=prz060vf_01122025_messages[prz060vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz060vf_01122025_events['Unnamed: 4'].value_counts()
# Out:
# /tmp/ipykernel_69332/915310528.py:1: DtypeWarning: Columns (68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103) have mixed types. Specify dtype option on import or set low_memory=False.
#   prz060vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ060 VFm.csv',sep=';',encoding='latin1')
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"       20
# event:"HEADWAY_MONITORING_EMERGENCY"     6
# event:"DROWSINESS"                       3
# event:"YAWN"                             3
# event:"USING_PHONE"                      3
# event:"HARD_BRAKE"                       3
# event:"POTENTIAL_INCIDENT_LOW"           1
# Name: count, dtype: int64

# %% [markdown]
# PRZ047 VF

# %%
prz047vf_01122025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ047 VF.csv',sep=';',encoding='latin1')
prz047vf_01122025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9555 entries, 0 to 9554
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  9555 non-null   object
#  1   Message  9555 non-null   object
#  2   Status   9555 non-null   object
# dtypes: object(3)
# memory usage: 224.1+ KB

# %%
prz047vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ047 VFm.csv',sep=';',encoding='latin1')
prz047vf_01122025_events=prz047vf_01122025_messages[prz047vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz047vf_01122025_events['Message'].value_counts()
# Out:
# /tmp/ipykernel_69332/1108432990.py:1: DtypeWarning: Columns (57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91) have mixed types. Specify dtype option on import or set low_memory=False.
#   prz047vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ047 VFm.csv',sep=';',encoding='latin1')
# Message
# {"notificationType":"CameraEvent"    58
# Name: count, dtype: int64

# %%
prz047vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ047 VFm.csv',sep=';',encoding='latin1')
prz047vf_01122025_events=prz047vf_01122025_messages[prz047vf_01122025_messages['Message'].str.contains('CameraEvent')]
prz047vf_01122025_events['Unnamed: 4'].value_counts()
# Out:
# /tmp/ipykernel_69332/276832123.py:1: DtypeWarning: Columns (57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91) have mixed types. Specify dtype option on import or set low_memory=False.
#   prz047vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PRZ047 VFm.csv',sep=';',encoding='latin1')
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"       24
# event:"DROWSINESS"                       8
# event:"SHARP_TURN"                       6
# event:"USING_PHONE"                      6
# event:"POTENTIAL_INCIDENT_LOW"           5
# event:"YAWN"                             3
# event:"MANUAL"                           3
# event:"HARD_BRAKE"                       2
# event:"HEADWAY_MONITORING_EMERGENCY"     1
# Name: count, dtype: int64

# %% [markdown]
# PMX778 VF

# %%
pmx778vf_01122025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PMX778 VF.csv',sep=';',encoding='latin1')
pmx778vf_01122025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8594 entries, 0 to 8593
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  8594 non-null   object
#  1   Message  8594 non-null   object
#  2   Status   8594 non-null   object
# dtypes: object(3)
# memory usage: 201.6+ KB

# %%
pmx778vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PMX778 VFm.csv',sep=';',encoding='latin1')
pmx778vf_01122025_events=pmx778vf_01122025_messages[pmx778vf_01122025_messages['Message'].str.contains('CameraEvent')]
pmx778vf_01122025_events['Message'].value_counts()
# Out:
# /tmp/ipykernel_69332/3211584498.py:1: DtypeWarning: Columns (56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   pmx778vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PMX778 VFm.csv',sep=';',encoding='latin1')
# Message
# {"notificationType":"CameraEvent"    28
# Name: count, dtype: int64

# %%
pmx778vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PMX778 VFm.csv',sep=';',encoding='latin1')
pmx778vf_01122025_events=pmx778vf_01122025_messages[pmx778vf_01122025_messages['Message'].str.contains('CameraEvent')]
pmx778vf_01122025_events['Unnamed: 4'].value_counts()
# Out:
# /tmp/ipykernel_69332/1775081338.py:1: DtypeWarning: Columns (56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   pmx778vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/PMX778 VFm.csv',sep=';',encoding='latin1')
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"       13
# event:"HARD_BRAKE"                       6
# event:"POTENTIAL_INCIDENT_LOW"           6
# event:"HEADWAY_MONITORING_EMERGENCY"     2
# event:"USING_PHONE"                      1
# Name: count, dtype: int64

# %% [markdown]
# OJX106 AIR2:

# %%
ojx106vf_01122025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/OJX106 AIR2.csv',sep=';',encoding='latin1')
ojx106vf_01122025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  243 non-null    object
#  1   Message  243 non-null    object
#  2   Status   243 non-null    object
# dtypes: object(3)
# memory usage: 5.8+ KB

# %%
ojx106vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/OJX106 AIR2m.csv',sep=';',encoding='latin1')
ojx106vf_01122025_events=ojx106vf_01122025_messages[ojx106vf_01122025_messages['Message'].str.contains('CameraEvent')]
ojx106vf_01122025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    3
# Name: count, dtype: int64

# %%
ojx106vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/OJX106 AIR2m.csv',sep=';',encoding='latin1')
ojx106vf_01122025_events=ojx106vf_01122025_messages[ojx106vf_01122025_messages['Message'].str.contains('CameraEvent')]
ojx106vf_01122025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_MEDIUM"    1
# event:"DROWSINESS"                   1
# event:"USING_PHONE"                  1
# Name: count, dtype: int64

# %% [markdown]
# OJX103 AIR2:

# %%
ojx103vf_01122025=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/OJX103 AIR2.csv',sep=';',encoding='latin1')
ojx103vf_01122025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  578 non-null    object
#  1   Message  578 non-null    object
#  2   Status   578 non-null    object
# dtypes: object(3)
# memory usage: 13.7+ KB

# %%
ojx103vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/OJX103 AIR2m.csv',sep=';',encoding='latin1')
ojx103vf_01122025_events=ojx103vf_01122025_messages[ojx103vf_01122025_messages['Message'].str.contains('CameraEvent')]
ojx103vf_01122025_events['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    3
# Name: count, dtype: int64

# %%
ojx103vf_01122025_messages=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/OJX103 AIR2m.csv',sep=';',encoding='latin1')
ojx103vf_01122025_events=ojx103vf_01122025_messages[ojx103vf_01122025_messages['Message'].str.contains('CameraEvent')]
ojx103vf_01122025_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_MEDIUM"    1
# event:"DROWSINESS"                   1
# event:"YAWN"                         1
# Name: count, dtype: int64

# %%
df_total=pd.concat([ojx103vf_01122025_messages,ojx106vf_01122025_messages,pmx778vf_01122025_messages,prz047vf_01122025_messages,prz060vf_01122025_messages,prz061vf_01122025_messages,prz505vf_01122025_messages,prz506vf_01122025_messages,prz507vf_01122025_messages])
#df_total.head(2)
df_total_fields=df_total[['Message','Unnamed: 1','Unnamed: 4']]
df_total_fields_f=df_total_fields[df_total_fields['Message'].str.contains('CameraEvent')]
df_total_fields_f_fcw=df_total_fields_f[df_total_fields_f['Unnamed: 4'].str.contains('FORWARD_COLLISION_WARNING')]
df_total_fields_f_fcw['Unnamed: 1'].value_counts()
# Out:
# Unnamed: 1
# sn:"6B31117C"    64
# sn:"6B31114Z"    24
# sn:"6B311142"    20
# sn:"6B31111D"    13
# Name: count, dtype: int64

# %%
df_total_fields_f['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"       121
# event:"HARD_BRAKE"                       32
# event:"POTENTIAL_INCIDENT_LOW"           23
# event:"DROWSINESS"                       15
# event:"HEADWAY_MONITORING_EMERGENCY"     15
# event:"USING_PHONE"                      11
# event:"YAWN"                              8
# event:"SHARP_TURN"                        6
# event:"MANUAL"                            3
# event:"POTENTIAL_INCIDENT_MEDIUM"         2
# event:"HARD_ACCEL"                        2
# event:"POTENTIAL_INCIDENT_HIGH"           1
# Name: count, dtype: int64

# %%
ce=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/CameraEvents.csv',sep=';',encoding='latin1')
ce[['Unit','YAWN','DROWSINESS','USING_PHONE']]
# Out:
#              Unit  YAWN  DROWSINESS  USING_PHONE
# 0   PRZ507 VF-AR2   NaN         2.0          NaN
# 1  PRZ506 VF-AIR2   NaN         NaN          NaN
# 2     PRZ505 AIR2   1.0         NaN          NaN
# 3       PRZ061 VF   NaN         NaN          NaN
# 4       PRZ060 VF   3.0         3.0          3.0
# 5       PRZ047 VF   3.0         8.0          6.0
# 6       PMX778 VF   NaN         NaN          1.0
# 7     OJX106 AIR2   NaN         1.0          1.0
# 8     OJX103 AIR2   1.0         1.0          NaN

# %%
ce['IMEI'].to_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/imeis_05122025.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/py-projects/venv00/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IMEI'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ...
