# %%
import pandas as pd
import numpy as np

# %%
cu=pd.read_csv('/home/jlhb1984/py-projects/data/banco_de_alimentos/cu.csv',sep=';',encoding='latin10')
cu.info()
cu_vf=cu[cu['Unit Type'].str.contains('Fleet')]
cu_vf
cu_vf_imei=cu_vf[['IMEI','Unit ID','Serial Number','Unit']]
cu_vf_imei.to_csv('/home/jlhb1984/py-projects/data/banco_de_alimentos/vf_imeis_plate_numbers.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       26 non-null     int64
#  1   Owner                    26 non-null     object
#  2   Unit ID                  26 non-null     object
#  3   Unit                     26 non-null     object
#  4   Peripherals              0 non-null      float64
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          26 non-null     object
#  9   Monthly Fee              26 non-null     int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              26 non-null     object
#  12  Linked Mode              26 non-null     int64
#  13  Paired GPS               0 non-null      float64
# ...
