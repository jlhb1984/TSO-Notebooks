# %%
import pandas as pd
import numpy as np

# %%
hl_vkk624=pd.read_csv('/home/jlhb1984/py-projects/data/transliquidos/vkk624.csv',encoding='latin1',sep=';')
hl_vkk624['Landmark'].fillna('Empty',inplace=True)
hl_vkk624.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4035 entries, 0 to 4034
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     4035 non-null   int64
#  1   Unit         4035 non-null   object
#  2   Events       4035 non-null   object
#  3   Date         4035 non-null   object
#  4   Landmark     4035 non-null   object
#  5   Address      4035 non-null   object
#  6   Speed        4035 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     4035 non-null   float64
#  10  Longitude    4035 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 346.9+ KB
# /tmp/ipykernel_69290/1704205437.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
hl_vkk624['Landmark'].value_counts()
# Out:
# Landmark
# Empty                          2782
# Quimpac Palmira                 170
# Sucroal Porteria                118
# Belleza Express S.A.             54
# CDA Itac                         51
#                                ...
# PROCESOS Y SERVICIOS S.A.S.       2
# Version 3 B/v La Guaira           2
# Ingreso Parq TLQ                  2
# Lavadero KATANGA Martin           1
# POINT_1_869                       1
# Name: count, Length: 76, dtype: int64

# %%
hl_vkk624['Events'].value_counts()
# Out:
# Events
# Drive               1789
# Idle - Stop         1526
# Parked               178
# Landmark IN          132
# Landmark OUT         129
# Ignition OFF         115
# Ignition ON          110
# Towing/Drifting?      22
# Ping                  17
# POWER UP               4
# Self Test/Reboot       4
# Power OFF              4
# Geofence OUT           3
# Geofence IN            2
# Name: count, dtype: int64

# %%
unilever_palmira=hl_vkk624[hl_vkk624['Landmark'].str.contains('Cali')]
unilever_palmira
# Out:
#      Sequence    Unit        Events                  Date       Landmark  \
# 30       4005  VKK624         Drive  Dec 10 2025 07:40 AM  Unilever Cali
# 31       4004  VKK624   Landmark IN  Dec 10 2025 07:40 AM  Unilever Cali
# 66       3969  VKK624         Drive  Dec 10 2025 07:22 AM  Unilever Cali
# 67       3968  VKK624  Landmark OUT  Dec 10 2025 07:22 AM  Unilever Cali
# 68       3967  VKK624   Idle - Stop  Dec 10 2025 07:21 AM  Unilever Cali
# 114      3921  VKK624   Idle - Stop  Dec 10 2025 03:19 AM  Unilever Cali
# 115      3920  VKK624   Idle - Stop  Dec 10 2025 03:19 AM  Unilever Cali
# 116      3919  VKK624   Idle - Stop  Dec 10 2025 03:19 AM  Unilever Cali
# 117      3918  VKK624   Idle - Stop  Dec 10 2025 03:18 AM  Unilever Cali
# 118      3917  VKK624   Ignition ON  Dec 10 2025 03:18 AM  Unilever Cali
# 119      3916  VKK624        Parked  Dec 10 2025 02:28 AM  Unilever Cali
# 120      3915  VKK624        Parked  Dec 10 2025 01:28 AM  Unilever Cali
# ...

# %%
landmarks10122025=pd.read_csv('/home/jlhb1984/py-projects/data/transliquidos/landmarks.csv',sep=';',encoding='latin1')
landmarks_counts=landmarks10122025['Name'].value_counts()
landmarks_counts.to_csv('/home/jlhb1984/py-projects/data/transliquidos/landmarks_counts.csv')
