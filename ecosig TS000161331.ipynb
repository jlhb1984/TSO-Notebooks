# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 01-09-2025 to 30-09-2025

# %%
hlafk949_092025=pd.read_csv('/home/jlhb1984/py-projects/data/ecosig/afk949.csv', sep=';',encoding='latin1')
hlafk949_092025.info()
hlafk949_092025['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14297 entries, 0 to 14296
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     14297 non-null  int64
#  1   Unit         14297 non-null  object
#  2   Events       14297 non-null  object
#  3   Date         14297 non-null  object
#  4   Landmark     2020 non-null   object
#  5   Address      13845 non-null  object
#  6   Speed        14297 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     14297 non-null  float64
#  10  Longitude    14297 non-null  float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.2+ MB
# Events
# Drive                 6976
# Idle - Stop           4509
# Parked                 876
# Ignition ON            338
# Ignition OFF           333
# Landmark OUT           227
# Landmark IN            209
# Ping                   187
# ...

# %%
hlafk949_092025_landmarks=hlafk949_092025[hlafk949_092025['Events'].str.contains('Landmark')]
hlafk949_092025_landmarks.sort_values('Date')
# Out:
#        Sequence     Unit        Events                  Date  \
# 13893       404  AFK-949   Landmark IN  Sep 01 2025 01:20 PM
# 13891       406  AFK-949   Landmark IN  Sep 01 2025 01:21 PM
# 13889       408  AFK-949   Landmark IN  Sep 01 2025 01:21 PM
# 13887       410  AFK-949   Landmark IN  Sep 01 2025 01:22 PM
# 13885       412  AFK-949   Landmark IN  Sep 01 2025 01:22 PM
# ...         ...      ...           ...                   ...
# 1678      12619  AFK-949   Landmark IN  Sep 27 2025 07:54 AM
# 1670      12627  AFK-949  Landmark OUT  Sep 27 2025 07:55 AM
# 1673      12624  AFK-949  Landmark OUT  Sep 27 2025 07:55 AM
# 1666      12631  AFK-949  Landmark OUT  Sep 27 2025 07:56 AM
# 1298      12999  AFK-949  Landmark OUT  Sep 27 2025 12:59 PM
#
#                                          Landmark  \
# 13893                        Hospital H. Valdizan
# 13891                        Hospital H. Valdizan
# 13889                        Hospital H. Valdizan
# ...

# %%
hlafk949_092025['Landmark'].value_counts()
# Out:
# Landmark
# RELLENO DE SEGURIDAD HUAYCOLORO - PETRAMAS    955
# Hospital Sergio E. Bernales                   457
# Balanza Petramas                              324
# Hospital H. Valdizan                          221
# INCOR                                          39
# Balanza Gri                                    24
# Name: count, dtype: int64

# %%
hlamx932_092025=pd.read_csv('/home/jlhb1984/py-projects/data/ecosig/amx932.csv', sep=';',encoding='latin1')
hlamx932_092025.info()
hlamx932_092025['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42257 entries, 0 to 42256
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     42257 non-null  int64
#  1   Unit         42257 non-null  object
#  2   Events       42257 non-null  object
#  3   Date         42257 non-null  object
#  4   Landmark     9829 non-null   object
#  5   Address      42200 non-null  object
#  6   Speed        42257 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     42257 non-null  float64
#  10  Longitude    42257 non-null  float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 3.5+ MB
# Events
# Idle - Stop            22349
# Drive                  17026
# Parked                   598
# Landmark OUT             520
# Landmark IN              506
# Ignition ON              420
# Ignition OFF             416
# Ping                      90
# ...

# %%
hlamx932_092025['Landmark'].value_counts()
# Out:
# Landmark
# RELLENO DE SEGURIDAD HUAYCOLORO - PETRAMAS    4017
# INCOR                                         1298
# Hospital Sergio E. Bernales                    903
# S.E. San Camilo                                608
# Balanza Petramas                               542
# Hospital H. Valdizan                           431
# Renexa                                         364
# Dialcare                                       356
# U.R. Divino Niño                               306
# C.M. Jesus Maria                               300
# Dirincri Centro                                269
# Policlinico Odontologico Angamos               253
# Centro Biomedico de la Videna                   95
# Rehabilitación Valdizan ÑaÑa                    55
# MEDICINE & VISION                               28
# Policlinico Walter Rosales                       4
# Name: count, dtype: int64

# %%
hlamx932_landmarks=hlamx932_092025[hlamx932_092025['Events'].str.contains('Landmark')]
hlamx932_landmarks.sort_values('Date')
# Out:
#        Sequence     Unit        Events                  Date  \
# 41369       888  AMX-932   Landmark IN  Sep 01 2025 02:03 PM
# 41364       893  AMX-932  Landmark OUT  Sep 01 2025 02:05 PM
# 41360       897  AMX-932  Landmark OUT  Sep 01 2025 02:08 PM
# 41358       899  AMX-932  Landmark OUT  Sep 01 2025 02:09 PM
# 41342       915  AMX-932   Landmark IN  Sep 01 2025 02:18 PM
# ...         ...      ...           ...                   ...
# 4190      38067  AMX-932  Landmark OUT  Sep 28 2025 06:46 AM
# 4187      38070  AMX-932   Landmark IN  Sep 28 2025 06:47 AM
# 4185      38072  AMX-932   Landmark IN  Sep 28 2025 06:48 AM
# 4182      38075  AMX-932  Landmark OUT  Sep 28 2025 06:49 AM
# 4133      38124  AMX-932  Landmark OUT  Sep 28 2025 07:31 AM
#
#                                          Landmark         Address  Speed  \
# 41369  RELLENO DE SEGURIDAD HUAYCOLORO - PETRAMAS  Vía Sin Nombre     20
# 41364                            Balanza Petramas  Vía Sin Nombre      0
# ...

# %%
hlbkd913_092025=pd.read_csv('/home/jlhb1984/py-projects/data/ecosig/bkd913.csv', sep=';',encoding='latin1')
hlbkd913_092025.info()
hlbkd913_092025['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23652 entries, 0 to 23651
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     23652 non-null  int64
#  1   Unit         23652 non-null  object
#  2   Events       23652 non-null  object
#  3   Date         23652 non-null  object
#  4   Landmark     148 non-null    object
#  5   Address      23652 non-null  object
#  6   Speed        23652 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     23652 non-null  float64
#  10  Longitude    23652 non-null  float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 2.0+ MB
# Events
# Drive                 13276
# Idle - Stop            8093
# Parked                  846
# Ignition ON             578
# Ignition OFF            578
# Towing/Drifting?        149
# Power Cut                35
# Power Restored           35
# ...

# %%
hlbkd913_092025_landmarks=hlbkd913_092025[hlbkd913_092025['Events'].str.contains('Landmark')]
hlbkd913_092025_landmarks.sort_values('Date')
# Out:
#        Sequence     Unit        Events                  Date  \
# 20143      3509  BKD-913   Landmark IN  Sep 03 2025 12:45 PM
# 20140      3512  BKD-913  Landmark OUT  Sep 03 2025 12:47 PM
# 16780      6872  BKD-913  Landmark OUT  Sep 08 2025 01:36 PM
# 16784      6868  BKD-913  Landmark OUT  Sep 08 2025 01:36 PM
# 16775      6877  BKD-913  Landmark OUT  Sep 08 2025 01:38 PM
# 16772      6880  BKD-913  Landmark OUT  Sep 08 2025 01:39 PM
# 16767      6885  BKD-913   Landmark IN  Sep 08 2025 01:41 PM
# 16754      6898  BKD-913   Landmark IN  Sep 08 2025 01:50 PM
# 16750      6902  BKD-913   Landmark IN  Sep 08 2025 01:51 PM
# 16747      6905  BKD-913   Landmark IN  Sep 08 2025 01:52 PM
# 16745      6907  BKD-913  Landmark OUT  Sep 08 2025 01:54 PM
# 16713      6939  BKD-913   Landmark IN  Sep 08 2025 02:01 PM
# 16711      6941  BKD-913   Landmark IN  Sep 08 2025 02:01 PM
# 16709      6943  BKD-913   Landmark IN  Sep 08 2025 02:02 PM
# ...

# %%
hlbkd913_092025['Landmark'].value_counts()
# Out:
# Landmark
# RELLENO DE SEGURIDAD HUAYCOLORO - PETRAMAS    122
# Balanza Petramas                               21
# P.S. Poligono IV                                5
# Name: count, dtype: int64

# %%
hlbvs828_092025=pd.read_csv('/home/jlhb1984/py-projects/data/ecosig/bvs828.csv', sep=';',encoding='latin1')
hlbvs828_092025.info()
hlbvs828_092025['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30552 entries, 0 to 30551
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     30552 non-null  int64
#  1   Unit         30552 non-null  object
#  2   Events       30552 non-null  object
#  3   Date         30552 non-null  object
#  4   Landmark     6920 non-null   object
#  5   Address      30552 non-null  object
#  6   Speed        30552 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     30552 non-null  float64
#  10  Longitude    30552 non-null  float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 2.6+ MB
# Events
# Drive                 16292
# Idle - Stop            9012
# Parked                 1458
# Ignition OFF            951
# Ignition ON             951
# Landmark IN             827
# Landmark OUT            817
# Towing/Drifting?        151
# ...

# %%
hlbvs828_092025['Landmark'].value_counts()
# Out:
# Landmark
# RELLENO DE SEGURIDAD HUAYCOLORO - PETRAMAS            1536
# Balanza Petramas                                       581
# C.S. Materno Infantil Pachacutec Peru Corea            210
# C.S. Bellavista Peru Corea                             157
# C.S. Marquez                                           154
#                                                       ...
# P.S. Ventanilla Baja                                    30
# Sanidad Maritima                                        28
# Direccion de Laboratorio de Salud Publica               27
# P.S. Boterin                                            21
# Unidad Funcional de Seguridad y Salud en el Trabaj      21
# Name: count, Length: 61, dtype: int64

# %%
hlbvs828_092025_landmarks=hlbvs828_092025[hlbvs828_092025['Events'].str.contains('Landmark')]
hlbvs828_092025_landmarks.sort_values('Date')
# Out:
#        Sequence     Unit        Events                  Date  \
# 30085       467  BVS-828   Landmark IN  Sep 01 2025 01:49 PM
# 30083       469  BVS-828  Landmark OUT  Sep 01 2025 01:54 PM
# 30071       481  BVS-828   Landmark IN  Sep 01 2025 01:58 PM
# 30065       487  BVS-828  Landmark OUT  Sep 01 2025 02:03 PM
# 30031       521  BVS-828   Landmark IN  Sep 01 2025 02:19 PM
# ...         ...      ...           ...                   ...
# 2777      27775  BVS-828   Landmark IN  Sep 27 2025 12:35 PM
# 2773      27779  BVS-828  Landmark OUT  Sep 27 2025 12:36 PM
# 2774      27778  BVS-828  Landmark OUT  Sep 27 2025 12:36 PM
# 2761      27791  BVS-828   Landmark IN  Sep 27 2025 12:43 PM
# 2753      27799  BVS-828  Landmark OUT  Sep 27 2025 12:57 PM
#
#                          Landmark  \
# 30085               C.S. Acapulco
# 30083               C.S. Acapulco
# 30071          P.S. Juan Pablo II
# 30065          P.S. Juan Pablo II
# 30031                C.S. Marquez
# ...
