# %%
import pandas as pd
import numpy as np

# %%
hlttv173=pd.read_csv('/home/jlhb1984/py-projects/data/jumps_2630/hlttv173.csv',sep=';',encoding='latin1')
hlttv173.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     617 non-null    int64
#  1   Unit         617 non-null    object
#  2   Events       617 non-null    object
#  3   Date         617 non-null    object
#  4   Landmark     279 non-null    object
#  5   Address      617 non-null    object
#  6   Speed        617 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     617 non-null    float64
#  10  Longitude    617 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 53.2+ KB
