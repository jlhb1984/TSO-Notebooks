# %%
import pandas as pd

# %%
cu=pd.read_csv('/home/jlhb1984/py-projects/data/transliquidos/cu.csv',sep=';',encoding='latin1')
cu_filtered=cu[['Unit ID','Unit','IMEI','Unit Type','Serial Number','Last Event Date']]
cu_filtered.info()
cu_filtered['Unit Type'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unit ID          26 non-null     object
#  1   Unit             26 non-null     object
#  2   IMEI             26 non-null     int64
#  3   Unit Type        26 non-null     object
#  4   Serial Number    26 non-null     object
#  5   Last Event Date  26 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.3+ KB
# Unit Type
# Queclink GV55W                            15
# GenX 656BV                                 7
# GenX 656B                                  2
# CalAmp 2630 - 3G - LMU2631H-H000-G1000     1
# Queclink GV55                              1
# Name: count, dtype: int64

# %%
cu_queclink=cu_filtered[cu_filtered['Unit Type'].str.contains('Queclink')]
cu_queclink.info()
cu_genx=cu_filtered[cu_filtered['Unit Type'].str.contains('GenX')]
cu_genx.info()
cu_calamp=cu_filtered[cu_filtered['Unit Type'].str.contains('Cal')]
cu_calamp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unit ID          16 non-null     object
#  1   Unit             16 non-null     object
#  2   IMEI             16 non-null     int64
#  3   Unit Type        16 non-null     object
#  4   Serial Number    16 non-null     object
#  5   Last Event Date  16 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 896.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 6 to 25
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unit ID          9 non-null      object
#  1   Unit             9 non-null      object
#  2   IMEI             9 non-null      int64
#  3   Unit Type        9 non-null      object
#  4   Serial Number    9 non-null      object
# ...

# %%
queclink_imeis=cu_queclink['IMEI']
queclink_imeis.to_csv('/home/jlhb1984/py-projects/data/transliquidos/queclink_imeis.csv')
genx_imeis=cu_genx['IMEI']
genx_imeis.to_csv('/home/jlhb1984/py-projects/data/transliquidos/genx_imeis.csv')
calamp_imeis=cu_calamp['IMEI']
calamp_imeis.to_csv('/home/jlhb1984/py-projects/data/transliquidos/calamp_imeis.csv')

# %% [markdown]
# Calamp.
# 351628098533071 81a,55.166, 9103448549

# %% [markdown]
# Queclink.

# %%
queclink_qms=pd.read_csv('/home/jlhb1984/py-projects/data/transliquidos/queclink_qms.csv',sep=';',encoding='latin1')
queclink_qms.info()
queclink_qms_filtered=queclink_qms[['Device Name','Last Report Date','IMEI','Device Type','Iccid','Firmware Version','Configuration Version']]
queclink_qms_filtered
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Device Name                     15 non-null     float64
#  1   Last Report Date                16 non-null     object
#  2   Create Time                     13 non-null     object
#  3   IMEI                            16 non-null     int64
#  4   Device Type                     16 non-null     object
#  5   Group                           16 non-null     object
#  6   Iccid                           16 non-null     object
#  7   MCU Firmware Version            0 non-null      float64
#  8   Modem Version                   0 non-null      float64
#  9   Firmware Version                16 non-null     object
#  10  Configuration Version           16 non-null     int64
#  11  Hardware Version                16 non-null     float64
# ...

# %%
queclink_qms_to_up=queclink_qms_filtered[queclink_qms_filtered['Firmware Version'].str.contains('R00A10V09')]
queclink_qms_to_up['IMEI'].to_csv('/home/jlhb1984/py-projects/data/transliquidos/queclink_qms_to_up.csv')

# %%
hlstx820=pd.read_csv('/home/jlhb1984/py-projects/data/transliquidos/hlstx820.csv',sep=';',encoding='latin1')
hlznn824=pd.read_csv('/home/jlhb1984/py-projects/data/transliquidos/hlznn824.csv',sep=';',encoding='latin1')
hlstx820.info()
hlznn824.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Secuencia       133 non-null    int64
#  1   Unidad          133 non-null    object
#  2   Eventos         133 non-null    object
#  3   Fecha           133 non-null    object
#  4   Pt. Referencia  58 non-null     object
#  5   Dirección       133 non-null    object
#  6   Velocidad       133 non-null    int64
#  7   Temperatura     0 non-null      float64
#  8   Conductor       133 non-null    object
#  9   Latitud         133 non-null    float64
#  10  Longitud        133 non-null    float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 11.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2479 entries, 0 to 2478
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
# ...

# %%
hlstx820['Eventos'].value_counts()
# Out:
# Eventos
# Conduciendo              75
# Entrando a Landmark       9
# Ignición Apagada          8
# Saliendo de Landmark      8
# Inmóvil - Detenido        7
# Ignición Encendida        6
# Estacionado               6
# Primer Registro           3
# Alerta de Inmovilidad     3
# En Cobertura              2
# Fuera de Cobertura        2
# Encender                  2
# Salida de Geocerca        1
# Entrada a Geocerca        1
# Name: count, dtype: int64

# %%
hlstx820_landmark=hlstx820[hlstx820['Eventos'].str.contains('Landmark')]
hlstx820_landmark
# Out:
#     Secuencia  Unidad               Eventos                 Fecha  \
# 4         129  STX820   Entrando a Landmark  Aug 01 2025 10:55 AM
# 10        123  STX820  Saliendo de Landmark  Aug 01 2025 10:48 AM
# 18        115  STX820   Entrando a Landmark  Aug 01 2025 10:12 AM
# 20        113  STX820  Saliendo de Landmark  Aug 01 2025 10:09 AM
# 29        104  STX820   Entrando a Landmark  Aug 01 2025 08:08 AM
# 32        101  STX820  Saliendo de Landmark  Aug 01 2025 07:57 AM
# 37         96  STX820   Entrando a Landmark  Aug 01 2025 07:55 AM
# 39         94  STX820  Saliendo de Landmark  Aug 01 2025 07:47 AM
# 42         91  STX820   Entrando a Landmark  Aug 01 2025 07:14 AM
# 48         85  STX820  Saliendo de Landmark  Aug 01 2025 07:08 AM
# 50         83  STX820   Entrando a Landmark  Aug 01 2025 07:06 AM
# 58         75  STX820  Saliendo de Landmark  Aug 01 2025 06:47 AM
# 61         72  STX820   Entrando a Landmark  Aug 01 2025 06:38 AM
# ...

# %%
hlznn824_landmark=hlznn824[hlznn824['Eventos'].str.contains('Landmark')]
hlznn824_landmark
# Out:
#       Secuencia  Unidad               Eventos                 Fecha  \
# 59         2420  ZNN824  Saliendo de Landmark  Aug 02 2025 08:31 PM
# 61         2418  ZNN824   Entrando a Landmark  Aug 02 2025 08:30 PM
# 623        1856  ZNN824  Saliendo de Landmark  Aug 02 2025 02:36 PM
# 624        1855  ZNN824   Entrando a Landmark  Aug 02 2025 02:35 PM
# 644        1835  ZNN824  Saliendo de Landmark  Aug 02 2025 02:21 PM
# 646        1833  ZNN824   Entrando a Landmark  Aug 02 2025 02:20 PM
# 941        1538  ZNN824  Saliendo de Landmark  Aug 02 2025 12:38 PM
# 942        1537  ZNN824   Entrando a Landmark  Aug 02 2025 12:37 PM
# 1616        863  ZNN824  Saliendo de Landmark  Aug 02 2025 07:11 AM
# 1618        861  ZNN824  Saliendo de Landmark  Aug 02 2025 07:10 AM
# 1620        859  ZNN824   Entrando a Landmark  Aug 02 2025 07:09 AM
# 1702        777  ZNN824  Saliendo de Landmark  Aug 02 2025 05:58 AM
# 1741        738  ZNN824   Entrando a Landmark  Aug 01 2025 06:58 PM
# ...
