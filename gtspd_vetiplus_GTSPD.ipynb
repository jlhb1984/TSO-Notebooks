# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## DGZ415

# %% [markdown]
# AT+GTSPD=gv55w,3,0,10,10,300,0,0,0,0,,,,,,,,,,,,FFFF$ generado por Manage tool, no enviado a esta unidad
# AT+GTSPD=gv55w,3,0,80,10,300,0,0,0,0,,,,,,,,,,,,FFFF$   24-06-2025 5:57am

# %%
hldgz415=pd.read_csv('/home/jlhb1984/py-projects/data/vetiplus/hldgz415.csv',sep=';',encoding='latin1')
hldgz415.info()
print('Sequence - Speed')
hldgz415['Speed'].sort_values(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     225 non-null    int64
#  1   Unit         225 non-null    object
#  2   Events       225 non-null    object
#  3   Date         225 non-null    object
#  4   Landmark     4 non-null      object
#  5   Address      225 non-null    object
#  6   Speed        225 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     225 non-null    float64
#  10  Longitude    225 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 19.5+ KB
# Sequence - Speed
# 52     82
# 57     78
# 49     75
# 142    74
# 53     72
#        ..
# 220     0
# 221     0
# 222     0
# 223     0
# 224     0
# Name: Speed, Length: 225, dtype: int64

# %%
for i in range(0,225):
    if hldgz415.iloc[i,6]>=80:
        print(hldgz415.loc[i])
# Out:
# Sequence                                           173
# Unit                                            DGZ415
# Events                                           Drive
# Date                              Jun 24 2025 07:12 AM
# Landmark                                           NaN
# Address        GQXM+58 Don Matías, Antioquia, Colombia
# Speed                                               82
# Temperature                                        NaN
# Driver                                             NaN
# Latitude                                      6.547869
# Longitude                                   -75.216788
# Name: 52, dtype: object

# %% [markdown]
# El sistema está aproximando al entero menor siguiente si hay decimales en mph, razón por la cual, si se establece máxima velocidad a 80Km/h, 80.2Km/h que sería 49.84mph, quedaría como 49mph que sería igual a 78Km/h y esto es lo que aparecerá en el reporte. Según Carlos Morante, la columna que guarda esta información en la base de datos está configurada como entero y no se puede modificar.
