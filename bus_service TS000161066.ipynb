# %%
import pandas as pd
import numpy as np

# %%
cu_26112025=pd.read_csv('/home/jlhb1984/py-projects/data/bus_service/cu.csv',sep=';',encoding='latin1')
cu_26112025_f=cu_26112025[['Unit','Last Event Date','IMEI']]
cu_26112025_f_vf=cu_26112025_f[cu_26112025_f['Unit'].str.contains('VF')]
cu_26112025_f_vf
# Out:
#            Unit Last Event Date      IMEI
# 0    CSM-068 VF      26/11/2025  6B3101B7
# 2    CSL-139 VF      17/10/2025  6B3101GC
# 4   CSL-089 VF2      17/10/2025  6B31113H
# 6    CSD-004 VF      26/11/2025  6B3013YV
# 8     CSC426 VF      26/11/2025  6B3013ZJ
# 10   CSC-403 VF      26/11/2025  6B3013ZT
# 12    CSB585 VF      26/11/2025  6B30140X
# 13    CSB504 VF      26/11/2025  6B3013WV
# 16    CSA164 VF      26/11/2025  6B3013X7
# 17   CSA-643 VF      26/11/2025  6B3101EB
# 19   CSA-553 VF      26/11/2025  6B301415
# 21   CSA-494 VF      26/11/2025  6B3013XB
# 23   CSA-291 VF       2/07/2025  6B301403
# 25   CSA-234 VF      26/11/2025  6B301412
# 28   CFR-716 VF      26/11/2025  6B31115A
# 32   C8H-952 VF      23/09/2025  6B31116H
# 34   BWR-603 VF      26/11/2025  6B311163
# 36   BWR-185 VF      26/11/2025  6B31115R
# 38   AWT-825 VF      26/11/2025  6B3101CU

# %%
cu_26112025_f_vf['IMEI'].to_csv('/home/jlhb1984/py-projects/data/bus_service/cu_imei.csv')

# %%
cu_04122025=pd.read_csv('/home/jlhb1984/py-projects/data/bus_service/cu041225.csv',sep=';',encoding='latin1')
cu_04122025_f=cu_04122025[['Unit','Last Event Date','IMEI']]
cu_04122025_f_vf=cu_04122025_f[cu_04122025_f['Unit'].str.contains('VF')]
cu_04122025_f_vf
# Out:
#            Unit Last Event Date      IMEI
# 0    CSM-068 VF       4/12/2025  6B3101B7
# 2    CSL-139 VF      17/10/2025  6B3101GC
# 4   CSL-089 VF2      17/10/2025  6B31113H
# 6    CSD-004 VF       4/12/2025  6B3013YV
# 8     CSC426 VF       4/12/2025  6B3013ZJ
# 10   CSC-403 VF       4/12/2025  6B3013ZT
# 12    CSB585 VF       4/12/2025  6B30140X
# 13    CSB504 VF       4/12/2025  6B3013WV
# 16    CSA164 VF       4/12/2025  6B3013X7
# 17   CSA-643 VF       4/12/2025  6B3101EB
# 19   CSA-553 VF       4/12/2025  6B301415
# 21   CSA-494 VF       4/12/2025  6B3013XB
# 23   CSA-291 VF       2/07/2025  6B301403
# 25   CSA-234 VF       4/12/2025  6B301412
# 28   CFR-716 VF       4/12/2025  6B31115A
# 32   C8H-952 VF      23/09/2025  6B31116H
# 34   BWR-603 VF       4/12/2025  6B311163
# 36   BWR-185 VF       4/12/2025  6B31115R
# 38   AWT-825 VF       4/12/2025  6B3101CU

# %%
cu_04122025_f_vf['IMEI'].to_csv('/home/jlhb1984/py-projects/data/bus_service/cu_imei_04122025.csv')

# %%
cu_dict={'IMEI': ['Short_name','Error'],
         '6B3101GC':['CSL-139 VF','5 pin error'],
         '6B31113H':['CSL-089 VF2','SIM Card error',],
         '6B301403':['CSA-291 VF','5 pin error'],
         '6B31116H':['C8H-952 VF','BatteryVoltageLow_CheckWiring']}

cu_dict
# Out:
# {'IMEI': ['Short_name', 'Error'],
#  '6B3101GC': ['CSL-139 VF', '5 pin error'],
#  '6B31113H': ['CSL-089 VF2', 'SIM Card error'],
#  '6B301403': ['CSA-291 VF', '5 pin error'],
#  '6B31116H': ['C8H-952 VF', 'BatteryVoltageLow_CheckWiring']}
