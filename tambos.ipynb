# %%
import pandas as pd
import numpy as np

# %%
customer_template=pd.read_csv('/home/jlhb1984/py-projects/data/tambos/WayPoints_Template (6).csv',encoding='latin1')
customer_template.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Latitude   48 non-null     float64
#  1   Longitude  48 non-null     float64
#  2   Name       48 non-null     object
#  3   Radius     48 non-null     float64
#  4   Type       48 non-null     object
#  5   Sequence   48 non-null     int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.4+ KB

# %%
for i in range(0,48):
    cad=customer_template.iloc[i,2][0:4]
    customer_template.iloc[i,2]=cad
    print(cad)

customer_template.head(5)
customer_template.to_csv('/home/jlhb1984/py-projects/data/tambos/WayPoints_Template_5char.csv')
# Out:
# GARR
# COND
# RUIZ
# PONT
# CALV
# BARB
# MEND
# VELA
# DOMI
# MARI
# VILL
# LEON
# PACH
# ESPI
# DURA
# SALD
# ZUDI
# HONO
# DIAZ
# MOSQ
# UBIL
# REYE
# FLOR
# COJA
# CHAM
# BAZA
# MURG
# VALL
# ARIA
# NIÑO
# MUÑO
# SALA
# SOTE
# ANGE
# CAST
# LECC
# IZQU
# HUAP
# TOSC
# ROJA
# BONT
# ALVA
# CORD
# CALD
# LORE
# ROME
# BARB
# SALV
