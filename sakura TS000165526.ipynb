# %%
import pandas as pd
import numpy as np

# %%
raw_data=pd.read_csv('/home/jlhb1984/py-projects/data/sakura/cfv839.csv',sep=';',encoding='latin1')
raw_datam=pd.read_csv('/home/jlhb1984/py-projects/data/sakura/cfv839m.csv',sep=';',encoding='latin1')
raw_datam.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam.info()
raw_datam.to_csv('/home/jlhb1984/py-projects/data/sakura/cfv839_decoded.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2764 entries, 0 to 2763
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           2764 non-null   object
#  1   Message Type      2764 non-null   object
#  2   Protocole         2764 non-null   object
#  3   IMEI              2764 non-null   object
#  4   Serial            2764 non-null   object
#  5   Mileage           2764 non-null   object
#  6   Date              2764 non-null   object
#  7   Ignition          2764 non-null   object
#  8   Latitude          2764 non-null   object
#  9   Longitude         2764 non-null   object
#  10  Altitude          2764 non-null   object
#  11  External Power    2759 non-null   object
#  12  RPM               2759 non-null   object
#  13  Speed             2749 non-null   object
#  14  Satellite Number  2749 non-null   object
#  15  Azimuth           2749 non-null   object
# ...

# %%
raw_datam['Speed'].value_counts(ascending=True)
# Out:
# Speed
# Speed:89.0       1
# Speed:104.0      1
# Speed:86.0       2
# Speed:81.0       4
# Speed:77.0       6
#               ...
# Speed:8.0       63
# Speed:74.0      66
# Speed:6.0       69
# Speed:5.0      101
# Speed:0.0      749
# Name: count, Length: 78, dtype: int64

# %%
raw_datam_rows=raw_datam.shape[0]
raw_data_104=raw_data[raw_data['Created'].str.contains('2025-12-17 22:31')]
raw_data_104['Status'].to_csv('/home/jlhb1984/py-projects/data/sakura/cfv839_104.csv')

for i in range(0,raw_datam_rows):
    #print(raw_datam.iloc[i,13])
    if str(raw_datam.iloc[i,13])=='Speed:104.0':
        print(raw_datam.iloc[i-1,6],raw_datam.iloc[i-1,5],raw_datam.iloc[i-1,13],raw_datam.iloc[i,6],raw_datam.iloc[i,5],raw_datam.iloc[i,13])

vf=float(input('Type vf in Km/h: '))*(10/36)
vi=float(input('Type v0 in Km/h: '))*(10/36)
t=float(input('Type delta time in s: '))
odometeri=float(input('Type odometer f in meters: '))
odometerf=float(input('Type odometer i in meters: '))

a1=((vf-vi))/t
a2=(pow(vf,2)-pow(vi,2))/(2*(odometerf-odometeri))
print('a1: ',a1,'m/s^2','Vf: ',vf,'m/s','vi: ',vi,'m/s','t: ',t,'s')#,'a2',a2)
# Out:
# Date:"2025-12-17T22:30:28Z" Mileage:8572002 Speed:26.0 Date:"2025-12-17T22:31:34Z" Mileage:8572115 Speed:104.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[33], line 17
#      14 odometerf=float(input('Type odometer i in meters: '))
#      16 a1=((vf-vi))/t
# ---> 17 a2=(pow(vf,2)-pow(vi,2))/(2*(odometerf-odometeri))
#      18 print('a1: ',a1,'m/s^2','Vf: ',vf,'m/s','vi: ',vi,'m/s','t: ',t,'s')#,'a2',a2)
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# 0x2525130059792B0869487064453904003C38402D000028374500000007000061000000FFFFFFFFFFFFFFFFFFFF00D50082CCD3972512172231343333834267AAA0C269F99CC0104000BA03892743FFFFFF00001B0010FFFFFF
#
# ![image.png](attachment:image.png)

# %% [markdown]
# New analysis after SPEED command: SPEED,0000,50#

# %%
raw_data=pd.read_csv('/home/jlhb1984/py-projects/data/sakura/cfv839.csv',sep=';',encoding='latin1')
raw_datam=pd.read_csv('/home/jlhb1984/py-projects/data/sakura/cfv839m.csv',sep=';',encoding='latin1')
raw_datam.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam.info()
raw_datam.to_csv('/home/jlhb1984/py-projects/data/sakura/cfv839_decoded_after_speed.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1616 entries, 0 to 1615
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           1616 non-null   object
#  1   Message Type      1616 non-null   object
#  2   Protocole         1616 non-null   object
#  3   IMEI              1616 non-null   object
#  4   Serial            1616 non-null   object
#  5   Mileage           1616 non-null   object
#  6   Date              1616 non-null   object
#  7   Ignition          1616 non-null   object
#  8   Latitude          1616 non-null   object
#  9   Longitude         1616 non-null   object
#  10  Altitude          1616 non-null   object
#  11  External Power    1614 non-null   object
#  12  RPM               1614 non-null   object
#  13  Speed             1610 non-null   object
#  14  Satellite Number  1610 non-null   object
#  15  Azimuth           1610 non-null   object
# ...

# %%
raw_datam['Speed'].fillna('Speed:0.0',inplace=True)
raw_datam_rows=raw_datam.shape[0]
raw_data_104=raw_data[raw_data['Created'].str.contains('2025-12-17 22:31')]
raw_data_104['Status'].to_csv('/home/jlhb1984/py-projects/data/sakura/cfv839_104.csv')


for i in range(0,raw_datam_rows):
    #print(raw_datam.iloc[i,13][6:10])
    if float(raw_datam.iloc[i,13][6:9])>50:
        print(raw_datam.iloc[i,13][6:10],raw_datam.iloc[i,6],raw_datam.iloc[i,1])
# Out:
# 67.0 Date:"2025-12-22T03:49:41Z" MessageType:"LocationInfoMessage"
# 54.0 Date:"2025-12-22T05:18:55Z" MessageType:"LocationInfoMessage"
# 68.0 Date:"2025-12-22T05:50:55Z" MessageType:"LocationInfoMessage"
# 62.0 Date:"2025-12-22T05:51:55Z" MessageType:"LocationInfoMessage"
# 51.0 Date:"2025-12-22T05:54:56Z" MessageType:"LocationInfoMessage"
# 53.0 Date:"2025-12-22T06:32:55Z" MessageType:"LocationInfoMessage"
# 63.0 Date:"2025-12-22T06:33:54Z" MessageType:"LocationInfoMessage"
# 64.0 Date:"2025-12-22T06:34:54Z" MessageType:"LocationInfoMessage"
# 53.0 Date:"2025-12-22T07:05:55Z" MessageType:"LocationInfoMessage"
# 62.0 Date:"2025-12-22T07:06:55Z" MessageType:"LocationInfoMessage"
# 64.0 Date:"2025-12-22T07:33:55Z" MessageType:"LocationInfoMessage"
# 53.0 Date:"2025-12-22T07:34:54Z" MessageType:"LocationInfoMessage"
# 61.0 Date:"2025-12-22T07:51:55Z" MessageType:"LocationInfoMessage"
# 59.0 Date:"2025-12-22T07:52:55Z" MessageType:"LocationInfoMessage"
# ...

# %%
raw_datam['Speed'].value_counts()
# Out:
# Speed
# Speed:0.0     649
# Speed:5.0      72
# Speed:10.0     68
# Speed:6.0      66
# Speed:11.0     66
#              ...
# Speed:58.0      2
# Speed:31.0      2
# Speed:59.0      1
# Speed:71.0      1
# Speed:56.0      1
# Name: count, Length: 64, dtype: int64

# %%
raw_datam['Message Type'].value_counts()
# Out:
# Message Type
# MessageType:"LocationInfoMessage"     1532
# MessageType:"LocationAlarmMessage"      78
# MessageType:"SignInMessage"              4
# MessageType:"NetworkInfoMessage"         2
# Name: count, dtype: int64
