# %%
import pandas as pd
import numpy as np

# %%
ubd_nf=pd.read_csv('/home/jlhb1984/py-projects/data/cases/CRMUnitsDealersReports_15724_20251202140152.csv',sep=';',encoding='latin1')
ubd=ubd_nf[ubd_nf['Last Event Date'].str.contains('2025')]
ubd_nf.info()
ubd.info()
dollar=float(input('Digite el valor actual del dolar: '))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27473 entries, 0 to 27472
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   27473 non-null  object
#  1   Company                  27473 non-null  object
#  2   VIP                      27473 non-null  object
#  3   FEIN                     24940 non-null  object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      6258 non-null   object
#  6   Peripherals              27473 non-null  object
#  7   Service                  22486 non-null  object
#  8   Owner                    27473 non-null  object
#  9   Unit ID                  27473 non-null  object
#  10  Unit                     27473 non-null  object
#  11  Unit Type                27473 non-null  object
#  12  Carrier                  24672 non-null  object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
ubd_per=ubd['Peripherals'].value_counts()
ubd_per.to_csv('/home/jlhb1984/py-projects/data/cases/ubd_per.csv')

# %%
vec_aux=[]
for i in range(0,14578):
    aux=ubd.iloc[i,14].replace(',','.')
    vec_aux.append(float(aux))
ubd['Dec_Monthly_fee']=vec_aux

ubd.info()
#ubd.to_csv('/home/jlhb1984/py-projects/data/cases/mrr.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14578 entries, 0 to 27472
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   14578 non-null  object
#  1   Company                  14578 non-null  object
#  2   VIP                      14578 non-null  object
#  3   FEIN                     14134 non-null  object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      5365 non-null   object
#  6   Peripherals              14578 non-null  object
#  7   Service                  14205 non-null  object
#  8   Owner                    14578 non-null  object
#  9   Unit ID                  14578 non-null  object
#  10  Unit                     14578 non-null  object
#  11  Unit Type                14578 non-null  object
#  12  Carrier                  14364 non-null  object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
ubd['Dealer'].value_counts()
# Out:
# Dealer
# TSO Mobile - Colombia             6739
# TSO Mobile Peru                   3758
# TSO Colombia - IBO IDCOM          1804
# TSO Colombia - IBO SEGTEC         1323
# UTS Sistemas Kalo MX               953
# TSO Peru -   FG SATELITAL EIRL       1
# Name: count, dtype: int64

# %%
tso_mobile_colombia=ubd[ubd['Dealer'].str.contains('TSO Mobile - Colombia')]
tso_mobile_peru=ubd[ubd['Dealer'].str.contains('TSO Mobile Peru')]
uts_sistemas_kalo=ubd[ubd['Dealer'].str.contains('UTS Sistemas Kalo MX')]
tso_mobile_colombia_ibo_idcom=ubd[ubd['Dealer'].str.contains('TSO Colombia - IBO IDCOM')]
tso_mobile_colombia_ibo_segtec=ubd[ubd['Dealer'].str.contains('TSO Colombia - IBO SEGTEC')]
tso_peru_fg_satelital_eirl=ubd[ubd['Dealer'].str.contains('TSO Peru -   FG SATELITAL EIRL')]

# %%
col=pd.concat([tso_mobile_colombia,tso_mobile_colombia_ibo_idcom,tso_mobile_colombia_ibo_segtec])
per=pd.concat([tso_mobile_peru,tso_peru_fg_satelital_eirl])
mex=uts_sistemas_kalo

# %% [markdown]
# Calamp

# %%
ctc_devices=pd.read_csv('/home/jlhb1984/py-projects/data/cases/calamp_ctc.csv',encoding='latin1')
ctc_devices.info()
row_number_ctc=ctc_devices.shape[0]
row_number_ctc
aux_count=0
imeis_ibutton=[]
imeis_units=pd.DataFrame()

for i in range(0,row_number_ctc):
    if ctc_devices.iloc[i,55]==7.72:
        aux_count=aux_count+1
        imeis_ibutton.append(ctc_devices.iloc[i,43])
print("Devices with script 7.72= ",aux_count)
aux_count=0

for i in range(0,row_number_ctc):
    if ctc_devices.iloc[i,55]==7.76:
        aux_count=aux_count+1
        imeis_ibutton.append(ctc_devices.iloc[i,43])
print("Devices with script 7.76= ",aux_count)
aux_count=0
print("imeis: ",imeis_ibutton)
imeis_units['IMEIS_calamp']=imeis_ibutton
imeis_units.info()
imeis_units.to_csv('/home/jlhb1984/py-projects/data/cases/imeis_ibutton.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7260 entries, 0 to 7259
# Data columns (total 64 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID                                    7260 non-null   int64
#  1   Name                                  601 non-null    object
#  2   Identifier                            7260 non-null   int64
#  3   Model                                 7260 non-null   object
#  4   User ESN Mobile Id                    0 non-null      float64
#  5   EOL                                   7260 non-null   object
#  6   Enabled Services                      0 non-null      float64
#  7   Asset                                 0 non-null      float64
#  8   Account                               7260 non-null   object
#  9   Status                                7260 non-null   object
#  10  Last Event Time                       0 non-null      float64
# ...

# %%
mrr_ibutton=pd.read_csv('/home/jlhb1984/py-projects/data/cases/coincidences.csv',sep=',',encoding='latin1')
mrr_ibutton.info()
mrr_ibutton['Dealer'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   90 non-null     int64
#  1   Dealer       90 non-null     object
#  2   Company      90 non-null     object
#  3   Monthly fee  90 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.9+ KB
# Dealer
# TSO Mobile - Colombia        57
# TSO Mobile Peru              31
# TSO Colombia - IBO SEGTEC     2
# Name: count, dtype: int64

# %%
row_number_ibutton=mrr_ibutton.shape[0]
vec_aux=[]

for i in range(0,row_number_ibutton):
    aux=ubd.iloc[i,14].replace(',','.')
    vec_aux.append(float(aux))
mrr_ibutton['Dec_Monthly_fee']=vec_aux
mrr_ibutton.info()

print(row_number_ibutton)
mrr_ibutton_col=mrr_ibutton[~mrr_ibutton['Dealer'].str.contains('Peru')]
mrr_ibutton_per=mrr_ibutton[mrr_ibutton['Dealer'].str.contains('Peru')]

mrr_ibutton_total=(mrr_ibutton_col['Dec_Monthly_fee'].sum())/dollar+mrr_ibutton_per['Dec_Monthly_fee'].sum()
print('Mrr_Ibutton LATAM= ',mrr_ibutton_total)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       90 non-null     int64
#  1   Dealer           90 non-null     object
#  2   Company          90 non-null     object
#  3   Monthly fee      90 non-null     object
#  4   Dec_Monthly_fee  90 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.6+ KB
# 90
# Mrr_Ibutton LATAM=  1051.3030452998169

# %%
calamp_2630_col=col[col['Unit Type'].str.contains('2630')]
calamp_2630_col.info()
rows_calamp_2630_col=calamp_2630_col.shape[0]
calamp_2630_per=per[per['Unit Type'].str.contains('2630')]
calamp_2630_per.info()
rows_calamp_2630_per=calamp_2630_per.shape[0]
calamp_2630_mex=mex[mex['Unit Type'].str.contains('2630')]
calamp_2630_mex.info()
rows_calamp_2630_mex=calamp_2630_mex.shape[0]
calamp_2630_col.to_csv('/home/jlhb1984/py-projects/data/cases/col_mrr.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1866 entries, 4341 to 27309
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   1866 non-null   object
#  1   Company                  1866 non-null   object
#  2   VIP                      1866 non-null   object
#  3   FEIN                     1865 non-null   object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      344 non-null    object
#  6   Peripherals              1866 non-null   object
#  7   Service                  1815 non-null   object
#  8   Owner                    1866 non-null   object
#  9   Unit ID                  1866 non-null   object
#  10  Unit                     1866 non-null   object
#  11  Unit Type                1866 non-null   object
#  12  Carrier                  1854 non-null   object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
calamp_2630_col['Dec_Monthly_fee'].value_counts()
for i in range(0,rows_calamp_2630_col):
    if calamp_2630_col.iloc[i,28]>=5800000:
        calamp_2630_col.iloc[i,28]=calamp_2630_col.iloc[i,28]/100
#calamp_2630_col['Dec_Monthly_fee'].to_csv('/home/jlhb1984/py-projects/data/cases/col_mrr.csv')
(calamp_2630_col['Dec_Monthly_fee'].value_counts()).to_csv('/home/jlhb1984/py-projects/data/cases/col_mrr_calamp.csv')

# %%
#dollar=float(input('Digite el valor actual del dolar: '))
total_mex=calamp_2630_mex['Dec_Monthly_fee'].sum()
total_peru=calamp_2630_per['Dec_Monthly_fee'].sum()
total_col=calamp_2630_col['Dec_Monthly_fee'].sum()
average_=(total_col/dollar+total_mex+total_peru)/3
print("Mex: ",total_mex,rows_calamp_2630_mex,"Peru: ",total_peru,rows_calamp_2630_per,"Colombia: ",total_col/dollar,rows_calamp_2630_col,'Total LATAM= ',total_mex+total_peru+total_col/dollar,"Average= ",average)
# Out:
# Mex:  7487.280000000001 274 Peru:  23145.97 1163 Colombia:  24762.75871432312 1866 Total LATAM=  55396.00871432312 Average=  18465.336238107706

# %% [markdown]
# Ricopollo

# %%
ricopollo=ubd_nf[ubd_nf['Company'].str.contains('CORPORACION RICO')]
ricopollo.info()
row_number_ricopollo=ricopollo.shape[0]
vec_aux=[]

for i in range(0,row_number_ricopollo):
    aux=ricopollo.iloc[i,14].replace(',','.')
    vec_aux.append(float(aux))
    #print(aux)
ricopollo['Dec_Monthly_fee']=vec_aux

ricopollo['Dec_Monthly_fee'].sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 127 entries, 7537 to 7663
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   127 non-null    object
#  1   Company                  127 non-null    object
#  2   VIP                      127 non-null    object
#  3   FEIN                     127 non-null    object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      127 non-null    object
#  6   Peripherals              127 non-null    object
#  7   Service                  127 non-null    object
#  8   Owner                    127 non-null    object
#  9   Unit ID                  127 non-null    object
#  10  Unit                     127 non-null    object
#  11  Unit Type                127 non-null    object
#  12  Carrier                  122 non-null    object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %% [markdown]
# Queclink gl300

# %%
gl300_col=col[col['Unit Type'].str.contains('GL 300')]
gl300_col.info()
rows_gl300_col=gl300_col.shape[0]
gl300_per=per[per['Unit Type'].str.contains('GL 300')]
gl300_per.info()
rows_gl300_per=gl300_per.shape[0]
gl300_mex=mex[mex['Unit Type'].str.contains('GL 300')]
gl300_mex.info()
rows_gl300_mex=gl300_mex.shape[0]
#gl300_col.to_csv('/home/jlhb1984/py-projects/data/cases/col_mrr_GL300.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 207 entries, 4982 to 11905
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   207 non-null    object
#  1   Company                  207 non-null    object
#  2   VIP                      207 non-null    object
#  3   FEIN                     207 non-null    object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      13 non-null     object
#  6   Peripherals              207 non-null    object
#  7   Service                  207 non-null    object
#  8   Owner                    207 non-null    object
#  9   Unit ID                  207 non-null    object
#  10  Unit                     207 non-null    object
#  11  Unit Type                207 non-null    object
#  12  Carrier                  206 non-null    object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
#dollar=float(input('Digite el valor actual del dolar: '))
total_mex_gl300=gl300_mex['Dec_Monthly_fee'].sum()
total_peru_gl300=gl300_per['Dec_Monthly_fee'].sum()
total_col_gl300=gl300_col['Dec_Monthly_fee'].sum()
print('Mexico: ',total_mex_gl300,',',rows_gl300_mex,'Peru: ',total_peru_gl300,',',rows_gl300_per,',','Colombia: ',total_col_gl300/dollar,rows_gl300_col,'Mrr Total: ',total_col_gl300/dollar+total_mex_gl300+total_peru_gl300,',',rows_gl300_col+rows_gl300_per+rows_gl300_mex)
# Out:
# Mexico:  189.93 , 7 Peru:  923.3299999999998 , 40 , Colombia:  1578.9804032469233 207 Mrr Total:  2692.240403246923 , 254
