# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data from PM:

# %%
v4z_845_vf_pm=pd.read_csv('/home/jlhb1984/py-projects/data/hagemsa/data_12_25_vf.csv',sep=',')
v4z_845_vf_pm.info()
v4z_845_vf_pm['Event Name'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6498 entries, 0 to 6497
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     6498 non-null   int64
#  1   Sequence #                 0 non-null      float64
#  2   Server Time                6498 non-null   object
#  3   Unit Time                  6498 non-null   object
#  4   Last Message Time          6498 non-null   object
#  5   Latitude                   6498 non-null   float64
#  6   Longitude                  6498 non-null   float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 6498 non-null   object
#  9   Raw Event                  6498 non-null   object
#  10  Address                    6498 non-null   object
#  11  GPS Speed                  5695 non-null   float64
#  12  ECU Speed                  0 non-null      float64
# ...

# %%
v4z_845_vf_pm_ignition_off=v4z_845_vf_pm[v4z_845_vf_pm['Event Name'].str.contains('Ignition Off')]
v4z_845_vf_pm_ignition_off
# Out:
#             Row Id  Sequence #          Server Time            Unit Time  \
# 18    176719858154         NaN  2025/12/31 11:29:42  2025/12/31 11:18:31
# 151   176718294065         NaN  2025/12/31 07:09:01  2025/12/31 07:06:30
# 208   176714714857         NaN  2025/12/30 21:12:29  2025/12/30 21:12:17
# 216   176714512772         NaN  2025/12/30 20:38:48  2025/12/30 20:38:32
# 264   176714068789         NaN  2025/12/30 19:24:48  2025/12/30 19:24:37
# ...            ...         ...                  ...                  ...
# 6254  176460698556         NaN  2025/12/01 11:36:26  2025/12/01 11:25:49
# 6273  176460456834         NaN  2025/12/01 10:56:08  2025/12/01 10:55:50
# 6305  176460248746         NaN  2025/12/01 10:21:27  2025/12/01 10:10:42
# 6440  176458699921         NaN  2025/12/01 06:03:19  2025/12/01 06:03:06
# 6493  176458095773         NaN  2025/12/01 04:22:38  2025/12/01 04:22:19
#
#         Last Message Time   Latitude  Longitude  Driver Name    Event Name  \
# ...

# %%
v4z_845_vf_pm_ignition_on=v4z_845_vf_pm[v4z_845_vf_pm['Event Name'].str.contains('Ignition On')]
v4z_845_vf_pm_ignition_on
# Out:
#             Row Id  Sequence #          Server Time            Unit Time  \
# 147   176718538330         NaN  2025/12/31 07:49:43  2025/12/31 07:49:34
# 148   176719888383         NaN  2025/12/31 11:34:44  2025/12/31 07:49:34
# 207   176717545975         NaN  2025/12/31 05:04:20  2025/12/31 05:04:00
# 213   176714686893         NaN  2025/12/30 21:07:49  2025/12/30 21:07:22
# 262   176714082800         NaN  2025/12/30 19:27:08  2025/12/30 19:27:05
# ...            ...         ...                  ...                  ...
# 6271  176461393449         NaN  2025/12/01 13:32:14  2025/12/01 11:00:40
# 6438  176458960002         NaN  2025/12/01 06:46:40  2025/12/01 06:46:12
# 6439  176460330575         NaN  2025/12/01 10:35:06  2025/12/01 06:46:12
# 6492  176458249925         NaN  2025/12/01 04:48:19  2025/12/01 04:48:02
# 6497  176457995853         NaN  2025/12/01 04:05:59  2025/12/01 04:05:38
#
#         Last Message Time   Latitude  Longitude  Driver Name   Event Name  \
# ...

# %%
v4z_845_vf_pm_ignition_on_17_12=v4z_845_vf_pm_ignition_on[v4z_845_vf_pm_ignition_on['Server Time'].str.contains('2025/12/17 2')]
v4z_845_vf_pm_ignition_on_17_12
# Out:
#             Row Id  Sequence #          Server Time            Unit Time  \
# 3043  176602169479         NaN  2025/12/17 20:34:55  2025/12/17 20:34:33
# 3058  176602039457         NaN  2025/12/17 20:13:15  2025/12/17 20:09:07
#
#         Last Message Time   Latitude  Longitude  Driver Name   Event Name  \
# 3043  2025/12/17 20:34:56 -17.262856 -70.985753          NaN  Ignition On
# 3058  2025/12/17 20:13:15 -17.213782 -70.944830          NaN  Ignition On
#
#                    Raw Event  ... ECU Engine Hours + Off  Engine Odometer  \
# 3043  IgnitionStatus.driving  ...                    NaN         10532.57
# 3058  IgnitionStatus.driving  ...                    NaN         10527.50
#
#       Engine Odometer + Off  ECU Engine Odometer  ECU Engine Odometer + Off  \
# 3043                    NaN                  NaN                        NaN
# 3058                    NaN                  NaN                        NaN
#
#      HDOP VDOP RSSI  Battery Level  \
# ...

# %%
v4z_845_vf_pm_ignition_off_17_12=v4z_845_vf_pm_ignition_off[v4z_845_vf_pm_ignition_off['Server Time'].str.contains('2025/12/17 2')]
v4z_845_vf_pm_ignition_off_17_12
# Out:
#             Row Id  Sequence #          Server Time            Unit Time  \
# 3018  176602447501         NaN  2025/12/17 21:21:15  2025/12/17 21:10:34
# 3048  176602115460         NaN  2025/12/17 20:25:55  2025/12/17 20:25:45
#
#         Last Message Time   Latitude  Longitude  Driver Name    Event Name  \
# 3018  2025/12/17 21:21:17 -17.553657 -71.039012          NaN  Ignition Off
# 3048  2025/12/17 20:25:58 -17.262859 -70.985752          NaN  Ignition Off
#
#                    Raw Event  ... ECU Engine Hours + Off  Engine Odometer  \
# 3018  IgnitionStatus.parking  ...                    NaN         10556.54
# 3048  IgnitionStatus.parking  ...                    NaN         10532.57
#
#       Engine Odometer + Off  ECU Engine Odometer  ECU Engine Odometer + Off  \
# 3018                    NaN                  NaN                        NaN
# 3048                    NaN                  NaN                        NaN
#
#      HDOP VDOP RSSI  Battery Level  \
# ...

# %%
v4z_845_pm=pd.read_csv('/home/jlhb1984/py-projects/data/hagemsa/data_12_25_tf.csv',sep=',')
v4z_845_pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13475 entries, 0 to 13474
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     13475 non-null  int64
#  1   Sequence #                 0 non-null      float64
#  2   Account Id                 13475 non-null  int64
#  3   Server Time                13475 non-null  object
#  4   Unit Time                  13475 non-null  object
#  5   Latitude                   13475 non-null  float64
#  6   Longitude                  13475 non-null  float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 13475 non-null  object
#  9   Raw Event                  13475 non-null  object
#  10  GPS Speed                  12864 non-null  float64
#  11  ECU Speed                  0 non-null      float64
#  12  Address                    13475 non-null  object
# ...

# %% [markdown]
# Topfly's raw data from v4z_845

# %%
raw_data_v4z_845tf_pm=pd.read_csv('/home/jlhb1984/py-projects/data/hagemsa/raw_data_12_25_tf.csv',sep=',',encoding='ISO 8859-1')
raw_data_v4z_845tf_pm.info()
raw_data_v4z_845tf_pm.rename(columns={'Unnamed: 1':'UnitID',
                                 'Unnamed: 2':'UnitType',
                                 'Unnamed: 3':'latitude',
                                 'Unnamed: 4':'longitude',
                                 'Unnamed: 5':'heading',
                                 'Unnamed: 6':'unitTime',
                                 'Unnamed: 7':'historyID',
                                 'Unnamed: 8':'eventCode',
                                 'Unnamed: 9':'ignitionStatus',
                                 'Unnamed: 10':'Speed',
                                 'Unnamed: 11':'satelliteCount',
                                 'Unnamed: 12':'engineOdomoter',
                                 'Unnamed: 13':'licenserPlate',
                                 'Unnamed: 14':'tempSensor',
                                 'Unnamed: 15':'busSensor',
                                 },inplace=True)
raw_data_v4z_845tf_pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13475 entries, 0 to 13474
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Raw Data     13475 non-null  object
#  1   Unnamed: 1   13475 non-null  object
#  2   Unnamed: 2   13475 non-null  object
#  3   Unnamed: 3   13475 non-null  object
#  4   Unnamed: 4   13475 non-null  object
#  5   Unnamed: 5   13475 non-null  object
#  6   Unnamed: 6   13475 non-null  object
#  7   Unnamed: 7   13475 non-null  object
#  8   Unnamed: 8   13475 non-null  object
#  9   Unnamed: 9   13475 non-null  object
#  10  Unnamed: 10  13475 non-null  object
#  11  Unnamed: 11  13475 non-null  object
#  12  Unnamed: 12  10677 non-null  object
#  13  Unnamed: 13  10677 non-null  object
#  14  Unnamed: 14  10677 non-null  object
#  15  Unnamed: 15  10677 non-null  object
# dtypes: object(16)
# memory usage: 1.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
v4z_845_pm['Event Name'].value_counts()
# Out:
# Event Name
# Drive           12726
# Ignition Off      250
# Ignition On       237
# Travel Start      132
# Travel Stop       130
# Name: count, dtype: int64

# %%
v4z_845tf_ignition_pm=v4z_845_pm[v4z_845_pm['Event Name'].str.contains('Ignition')]
v4z_845tf_ignition_1712_pm=v4z_845tf_ignition_pm[v4z_845tf_ignition_pm['Unit Time'].str.contains('2025/12/17 2')]
v4z_845tf_ignition_1712_pm
# Out:
#             Row Id  Sequence #  Account Id          Server Time  \
# 6527  176602778862         NaN       31574  2025/12/17 22:16:29
# 6604  176602170461         NaN       31574  2025/12/17 20:35:05
# 6605  176602116434         NaN       31574  2025/12/17 20:26:04
# 6624  176602013787         NaN       31574  2025/12/17 20:08:58
#
#                 Unit Time   Latitude  Longitude  Driver Name    Event Name  \
# 6527  2025/12/17 21:40:07 -17.577843 -70.858139          NaN  Ignition Off
# 6604  2025/12/17 20:34:29 -17.262819 -70.985825          NaN   Ignition On
# 6605  2025/12/17 20:25:42 -17.262819 -70.985825          NaN  Ignition Off
# 6624  2025/12/17 20:08:42 -17.213705 -70.944733          NaN   Ignition On
#
#      Raw Event  ...  Engine Hours  Engine Hours + Off ECU Engine Hours  \
# 6527        02  ...        155.58                 NaN              NaN
# 6604        01  ...        154.53                 NaN              NaN
# ...

# %% [markdown]
# Raw data from CRM:

# %%
raw_data_v4z_845tf_crm=pd.read_csv('/home/jlhb1984/py-projects/data/hagemsa/raw_data_v4z_845_crm.csv',sep=';')
raw_data_v4z_845tf_crm_m=pd.read_csv('/home/jlhb1984/py-projects/data/hagemsa/raw_data_v4z_845_crm_m.csv',sep=';')
raw_data_v4z_845tf_crm_m.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_data_v4z_845tf_crm_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16962 entries, 0 to 16961
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           16962 non-null  object
#  1   Message Type      16962 non-null  object
#  2   Protocole         16962 non-null  object
#  3   IMEI              16962 non-null  object
#  4   Serial            16962 non-null  object
#  5   Mileage           16962 non-null  object
#  6   Date              16962 non-null  object
#  7   Ignition          16962 non-null  object
#  8   Latitude          16962 non-null  object
#  9   Longitude         16962 non-null  object
#  10  Altitude          16962 non-null  object
#  11  External Power    16582 non-null  object
#  12  RPM               16582 non-null  object
#  13  Speed             15992 non-null  object
#  14  Satellite Number  15992 non-null  object
#  15  Azimuth           15992 non-null  object
# ...

# %%
raw_data_v4z_845tf_crm_m['Message Type'].value_counts()
# Out:
# Message Type
# MessageType:"LocationInfoMessage"     15425
# MessageType:"SignInMessage"             590
# MessageType:"LocationAlarmMessage"      567
# MessageType:"NetworkInfoMessage"        380
# Name: count, dtype: int64

# %%
ignition_m=pd.read_csv('/home/jlhb1984/py-projects/data/hagemsa/ignition_m.csv',sep=';')
#ignition_m.info()
ignition_m['Unnamed: 1'].value_counts()
ignition_m.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
ignition_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15992 entries, 0 to 15991
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           15992 non-null  object
#  1   Message Type      15992 non-null  object
#  2   Protocole         15992 non-null  object
#  3   IMEI              15992 non-null  object
#  4   Serial            15992 non-null  object
#  5   Mileage           15992 non-null  object
#  6   Date              15992 non-null  object
#  7   Ignition          15992 non-null  object
#  8   Latitude          15992 non-null  object
#  9   Longitude         15992 non-null  object
#  10  Altitude          15992 non-null  object
#  11  External Power    15992 non-null  object
#  12  RPM               15992 non-null  object
#  13  Speed             15992 non-null  object
#  14  Satellite Number  15992 non-null  object
#  15  Azimuth           15992 non-null  object
# ...

# %%
ignition_m['Message Type'].value_counts()
# Out:
# Message Type
# MessageType:"LocationInfoMessage"     15425
# MessageType:"LocationAlarmMessage"      567
# Name: count, dtype: int64

# %%
raw_data_v4z_845tf_crm_ignition=raw_data_v4z_845tf_crm[raw_data_v4z_845tf_crm['Message'].str.contains('Ignition')]

# %%
aux=raw_data_v4z_845tf_crm_ignition.iloc[0,2][64:68]
ignition_on_counter=0
ignition_off_counter=0

if aux=="6100":
    ignition=1
else:
    ignition=0

for i in range(1,raw_data_v4z_845tf_crm_ignition.shape[0]):
    if str(raw_data_v4z_845tf_crm_ignition.iloc[i,2][64:68])=="6100":
        ignition_aux=1       
    else:
        ignition_aux=0        
    if (ignition==1)and(ignition_aux==0):
        ignition_off_counter=ignition_off_counter+1
        print("Off","Bytes ",raw_data_v4z_845tf_crm_ignition.iloc[i,2][64:68],"Date ",raw_data_v4z_845tf_crm_ignition.iloc[i,0])
    if (ignition==0)and(ignition_aux==1):
        ignition_on_counter=ignition_on_counter+1
        print("On","Bytes ",raw_data_v4z_845tf_crm_ignition.iloc[i,2][64:68],"Date ",raw_data_v4z_845tf_crm_ignition.iloc[i,0])
    ignition=ignition_aux

print("ignition_on_counter: ",ignition_on_counter,'ignition_off_counter',ignition_off_counter)
# Out:
# Off Bytes  2000 Date  2025-12-01 00:15:15.867
# On Bytes  6100 Date  2025-12-01 00:15:24.442
# Off Bytes  2000 Date  2025-12-01 00:15:30.757
# On Bytes  6100 Date  2025-12-01 09:04:14.912
# Off Bytes  2000 Date  2025-12-01 09:21:54.791
# On Bytes  6100 Date  2025-12-01 09:46:03.538
# Off Bytes  2000 Date  2025-12-01 11:02:08.399
# On Bytes  6100 Date  2025-12-01 11:45:26.607
# Off Bytes  2000 Date  2025-12-01 15:55:26.755
# On Bytes  6100 Date  2025-12-01 15:59:20.224
# Off Bytes  2000 Date  2025-12-01 20:58:34.970
# On Bytes  6100 Date  2025-12-01 20:58:35.317
# Off Bytes  2000 Date  2025-12-01 22:47:08.451
# On Bytes  6100 Date  2025-12-01 22:50:52.328
# Off Bytes  2000 Date  2025-12-02 00:30:07.233
# On Bytes  6100 Date  2025-12-02 00:38:31.278
# Off Bytes  2000 Date  2025-12-02 00:41:19.561
# On Bytes  6100 Date  2025-12-02 01:06:46.499
# Off Bytes  2000 Date  2025-12-02 01:12:31.208
# On Bytes  6100 Date  2025-12-02 01:23:34.238
# Off Bytes  2000 Date  2025-12-02 15:54:03.763
# ...
