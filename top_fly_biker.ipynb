# %%
import pandas as pd
import numpy as np

# %%
tf_1aak=pd.read_csv('/home/jlhb1984/py-projects/data/Biker script/1aak.csv',sep=';',encoding='latin1')
tf_1aak['Unnamed: 16'].fillna('Empty',inplace=True)
#tf_1aak.info()
# Out:
# /tmp/ipykernel_96366/4015284558.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tf_1aak['Unnamed: 16'].fillna('Empty',inplace=True)

# %%
tf_1aak['Unnamed: 16'].value_counts()
# Out:
# Unnamed: 16
# Empty                      223
# BatteryLevel:51}]           49
# BatteryLevel:50}]           38
# BatteryLevel:48}]           32
# BatteryLevel:49}]           22
# BatteryLevel:47}]           11
# BatteryLevel:34}]           10
# BatteryLevel:36}]           10
# OriginalAlarmCode:105}]      8
# OriginalAlarmCode:23}]       7
# BatteryLevel:39}]            7
# BatteryLevel:35}]            7
# OriginalAlarmCode:104}]      7
# BatteryLevel:33}]            6
# OriginalAlarmCode:22}]       6
# BatteryLevel:31}]            5
# BatteryLevel:10}]            4
# BatteryLevel:38}]            4
# BatteryLevel:40}]            4
# BatteryLevel:30}]            3
# BatteryLevel:37}]            3
# OriginalAlarmCode:66}]       2
# BatteryLevel:43}]            2
# BatteryLevel:45}]            2
# OriginalAlarmCode:67}]       2
# BatteryLevel:32}]            2
# BatteryLevel:46}]            2
# BatteryLevel:42}]            2
# BatteryLevel:41}]            2
# ...

# %%
new_1aak=tf_1aak[tf_1aak['Unnamed: 16'].str.contains('OriginalAlarmCode')]
#new_1aak

# %%
failure_messages_1aak=tf_1aak[tf_1aak['Unnamed: 6'].str.contains('2000')]
failure_messages_1aak['Unnamed: 6'].value_counts()
# Out:
# Unnamed: 6
# Date:"2000-01-01T00:00:04Z"    3
# Date:"2000-01-01T00:00:43Z"    2
# Date:"2000-01-01T00:00:13Z"    1
# Date:"2000-01-01T00:00:12Z"    1
# Date:"2000-01-01T00:00:10Z"    1
# Date:"2000-01-01T00:01:22Z"    1
# Date:"2000-01-01T00:01:00Z"    1
# Date:"2000-01-01T00:00:39Z"    1
# Date:"2000-01-01T00:00:37Z"    1
# Date:"2000-01-01T00:00:27Z"    1
# Name: count, dtype: int64

# %%
tf_1bde=pd.read_csv('/home/jlhb1984/py-projects/data/Biker script/1bde.csv',sep=';',encoding='latin1')
tf_1bde['Unnamed: 16'].fillna('Empty',inplace=True)
# Out:
# /tmp/ipykernel_96366/3153292310.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tf_1bde['Unnamed: 16'].fillna('Empty',inplace=True)

# %%
tf_1bde['Unnamed: 16'].value_counts()
# Out:
# Unnamed: 16
# Empty                      428
# BatteryLevel:26}]           80
# BatteryLevel:25}]           75
# BatteryLevel:24}]           47
# BatteryLevel:18}]           36
# BatteryLevel:22}]           22
# BatteryLevel:21}]           20
# BatteryLevel:20}]           20
# BatteryLevel:10}]           16
# BatteryLevel:23}]           14
# BatteryLevel:19}]            8
# BatteryLevel:17}]            5
# BatteryLevel:16}]            4
# BatteryLevel:15}]            3
# BatteryLevel:13}]            3
# OriginalAlarmCode:105}]      1
# OriginalAlarmCode:22}]       1
# BatteryLevel:14}]            1
# BatteryLevel:11}]            1
# OriginalAlarmCode:23}]       1
# Name: count, dtype: int64

# %%
new_1bde=tf_1aak[tf_1bde['Unnamed: 16'].str.contains('OriginalAlarmCode')]
# Out:
# /tmp/ipykernel_96366/510065380.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_1bde=tf_1aak[tf_1bde['Unnamed: 16'].str.contains('OriginalAlarmCode')]

# %%
failure_messages_1bde=tf_1bde[tf_1bde['Unnamed: 6'].str.contains('2000')]
failure_messages_1bde['Unnamed: 6'].value_counts()
# Out:
# Unnamed: 6
# Date:"2000-01-01T00:00:09Z"    1
# Date:"2000-01-01T00:00:10Z"    1
# Name: count, dtype: int64
