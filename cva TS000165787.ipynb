# %%
import pandas as pd
import numpy as np

# %%
smo_706=pd.read_csv('/home/jlhb1984/py-projects/data/COMERCIALIZADORA VICTOR ALVAREZ/smo706.csv',sep=';')
smo_706.info()
smo_706m=pd.read_csv('/home/jlhb1984/py-projects/data/COMERCIALIZADORA VICTOR ALVAREZ/smo706m.csv',sep=';')
smo_706m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17650 entries, 0 to 17649
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  17650 non-null  object
#  1   Message  17650 non-null  object
#  2   Status   17650 non-null  object
# dtypes: object(3)
# memory usage: 413.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17650 entries, 0 to 17649
# Columns: 128 entries, Message to Unnamed: 127
# dtypes: object(128)
# memory usage: 17.2+ MB
# /tmp/ipykernel_111945/569282056.py:3: DtypeWarning: Columns (92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127) have mixed types. Specify dtype option on import or set low_memory=False.
#   smo_706m=pd.read_csv('/home/jlhb1984/py-projects/data/COMERCIALIZADORA VICTOR ALVAREZ/smo706m.csv',sep=';')

# %%
smo706_events_0111_2612_25=smo_706m[smo_706m['Message'].str.contains('CameraEvent')]
smo706_events_0111_2612_25['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraEvent"    179
# Name: count, dtype: int64

# %%
smo706_events_0111_2612_25['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_LOW"          57
# event:"HEADWAY_MONITORING_EMERGENCY"    36
# event:"HARD_BRAKE"                      28
# event:"USING_PHONE"                     23
# event:"YAWN"                            12
# event:"SHARP_TURN"                       7
# event:"NO_SEATBELT"                      7
# event:"POTENTIAL_INCIDENT_MEDIUM"        4
# event:"DROWSINESS"                       4
# event:"FORWARD_COLLISION_WARNING"        1
# Name: count, dtype: int64
