# %%
import pandas as pd
import numpy as np

# %%
enrunr08=pd.read_csv('/home/jlhb1984/py-projects/data/pronavicola/Engine Runtime Report.csv')
enrunr08.rename(columns={'Textbox8':'Address','textbox32':'Time1'},inplace=True)

# %%
enrunr08.head(5)
# Out:
#   GroupName      UnitName               StartTime  \
# 0       NaN  Unit: SSK857  1/08/2025 6:01:17 a.m.
# 1       NaN  Unit: SSK857  1/08/2025 6:10:40 a.m.
# 2       NaN  Unit: SSK857  1/08/2025 8:19:06 a.m.
# 3       NaN  Unit: SSK857  1/08/2025 8:38:05 a.m.
# 4       NaN  Unit: SSK857  1/08/2025 9:05:00 a.m.
#
#                                              Address                 StopTime  \
# 0  LAVADO\r\nCalle 8  Guadalajara de Buga Valle d...   1/08/2025 6:07:07 a.m.
# 1  Cl9 23-43, Buga, Valle Cauca, COLOMBIA  Valle ...   1/08/2025 7:13:43 a.m.
# 2  LAVADERO LECHUGAS\r\nTulua - Cali  Guadalajara...   1/08/2025 8:35:21 a.m.
# 3           Cl9 23-41, Buga, Valle Cauca  Vca 763041   1/08/2025 8:59:26 a.m.
# 4           Cl9 23-41, Buga, Valle Cauca  Vca 763042  1/08/2025 12:35:52 p.m.
#
#   StopLengthSecs                                        ContactName  \
# 0    00h:05m:50s  OFICINAS BUGA\r\nCalle 8  Guadalajara de Buga ...
# ...

# %%
enrunr08_neg=enrunr08[enrunr08['StopLengthSecs'].str.contains('-')]
enrunr08_neg
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
enrunr08_neg=enrunr08[enrunr08['Time1'].str.contains('-')]
enrunr08_neg
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
enrunr08_neg=enrunr08[enrunr08['StopLengthSecs_1'].str.contains('-')]
enrunr08_neg
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
rdu08=pd.read_csv('/home/jlhb1984/py-projects/data/pronavicola/Travels_Daily_Summary_Unified0825.csv')
rdu08.info()
red08_neg=rdu08[rdu08['OffTime'].str.contains('-')]
red08_neg
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UnitName         1320 non-null   object
#  1   DayDate          1320 non-null   object
#  2   Decelerations    1320 non-null   int64
#  3   Accelerations    1320 non-null   int64
#  4   HarshTurns       1320 non-null   int64
#  5   DistanceDriven1  1320 non-null   object
#  6   DriveTime        1320 non-null   object
#  7   OffTime          1320 non-null   object
#  8   IdleTime         1320 non-null   object
#  9   Textbox17        1320 non-null   object
#  10  MaxSpeed         1320 non-null   object
#  11  DriverName       214 non-null    object
#  12  GroupName        1230 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 134.2+ KB
#        UnitName     DayDate  Decelerations  Accelerations  HarshTurns  \
# ...

# %%
hlSSL289=pd.read_csv('/home/jlhb1984/py-projects/data/pronavicola/hlSSL289.csv',sep=';',encoding='latin1')
hlSSL289['Events'].value_counts()
# Out:
# Events
# Drive             7430
# Travel Start       494
# Travel Stop        494
# End Speeding       419
# Alta velocidad     416
# Landmark IN        282
# Landmark OUT       280
# Idle - Stop        224
# Parked             158
# Ignition OFF       143
# Ignition ON        142
# Idle Alert         128
# Geofence OUT        73
# Geofence IN         72
# Name: count, dtype: int64

# %%
hlSSL289_ignition=hlSSL289[hlSSL289['Events'].str.contains('Ignition')]
hlSSL289_ignition
# Out:
#        Sequence    Unit        Events                  Date       Landmark  \
# 1         10754  SSL289  Ignition OFF  Aug 30 2025 11:12 AM            NaN
# 4         10751  SSL289   Ignition ON  Aug 30 2025 11:01 AM            NaN
# 5         10750  SSL289  Ignition OFF  Aug 30 2025 10:36 AM            NaN
# 69        10686  SSL289   Ignition ON  Aug 30 2025 08:45 AM            NaN
# 71        10684  SSL289  Ignition OFF  Aug 30 2025 07:52 AM            NaN
# ...         ...     ...           ...                   ...            ...
# 10250       505  SSL289  Ignition OFF  Aug 01 2025 11:16 AM  OFICINAS BUGA
# 10252       503  SSL289   Ignition ON  Aug 01 2025 11:09 AM  OFICINAS BUGA
# 10254       501  SSL289  Ignition OFF  Aug 01 2025 11:08 AM  OFICINAS BUGA
# 10644       111  SSL289   Ignition ON  Aug 01 2025 03:46 AM            NaN
# 10646       109  SSL289  Ignition OFF  Aug 01 2025 03:04 AM            NaN
#
# ...
