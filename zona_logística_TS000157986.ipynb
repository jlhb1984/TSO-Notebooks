# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Customer units.

# %%
cu_zl=pd.read_csv('/home/jlhb1984/py-projects/data/zona_logística_TS000157986/cu.csv',sep=';',encoding='latin1')
cu_zl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       53 non-null     int64
#  1   Owner                    53 non-null     object
#  2   Unit ID                  53 non-null     object
#  3   Unit                     53 non-null     object
#  4   Peripherals              41 non-null     object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          53 non-null     object
#  9   Monthly Fee              53 non-null     int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              53 non-null     object
#  12  Linked Mode              53 non-null     int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
cu_zl['Unit Type'].value_counts()
# Out:
# Unit Type
# CalAmp 2630 - HSPA -LMU26H3001-G1000                19
# Queclink GV55W                                      10
# CalAmp 2630 - GEMALTO HSPA -LMU26H3001-JAM01         8
# CalAmp 2630 - 3G - LMU2631H-H000-G1000               6
# CalAmp 0330H - 3G - LMU0330H-SKM6-G1000              4
# GenX 5P                                              2
# CalAmp 0330H - 3G -LMU0330H-SKM6-JAM01               1
# CalAmp 2631 - Gemalto HSPA - LMU2631H-0000-G1000     1
# CalAmp 2630 - CINTERION GSM - LMU30H30BT3-G1000      1
# GenX 656BV                                           1
# Name: count, dtype: int64

# %%
cu_zl['Unit Type 2']="Empty"
aux="aux"
for i in range(0,53):
    aux=cu_zl.iloc[i,17]
    #print(aux[0:3])
    if aux[0:3]=="Cal":
        cu_zl.iloc[i,47]="Calamp"
    if aux[0:3]=="Que":
        cu_zl.iloc[i,47]="Queclink"
    if aux[0:3]=="Gen":
        cu_zl.iloc[i,47]="GenX"

cu_zl['Unit Type 2'].value_counts()
# Out:
# Unit Type 2
# Calamp      40
# Queclink    10
# GenX         3
# Name: count, dtype: int64

# %%
cu_zl_gnx=cu_zl[cu_zl['Unit Type 2'].str.contains('Ge')]
cu_zl_gnx[['Last Event Date','Phone Number','IMEI','Unit']]
# Out:
#    Last Event Date  Phone Number             IMEI    Unit
# 8       28/07/2025    9103409918  357520075652962  SNU405
# 30      28/07/2025    9103418728  357520075735684  GDX532
# 38      28/07/2025    9103403708  358887091931624  ESR752

# %% [markdown]
# Comandos enviados por TSO.
#
# genx=SETPARAMS 123=0.0.0.0.0;ENDPARAMS
#
# calamp=RP,265,1,0
#
# queclink=Sin comando

# %%
cu_zl_calamp=cu_zl[cu_zl['Unit Type 2'].str.contains('Calamp')]
#cu_zl_calamp.info()
cu_zl_calamp['Unit']
cu_zl_calamp['Phone Number'].to_csv('/home/jlhb1984/py-projects/data/zona_logística_TS000157986/calamp_pn.csv')

# %%
cu_zl_calamp=cu_zl[cu_zl['Unit Type 2'].str.contains('Calamp')]
cu_zl_calamp.info()
cu_zl_calamp_sn=cu_zl_calamp['IMEI']
cu_zl_calamp_sn.to_csv('/home/jlhb1984/py-projects/data/zona_logística_TS000157986/zl_imeis.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 0 to 52
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       40 non-null     int64
#  1   Owner                    40 non-null     object
#  2   Unit ID                  40 non-null     object
#  3   Unit                     40 non-null     object
#  4   Peripherals              36 non-null     object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          40 non-null     object
#  9   Monthly Fee              40 non-null     int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              40 non-null     object
#  12  Linked Mode              40 non-null     int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
cu_zl_calamp_ctc=pd.read_csv('/home/jlhb1984/py-projects/data/zona_logística_TS000157986/devices28072025.csv')
cu_zl_calamp_ctc.info()
cu_zl_calamp_ctc['Script Identifier'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 64 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID                                    38 non-null     int64
#  1   Name                                  1 non-null      object
#  2   Identifier                            38 non-null     int64
#  3   Model                                 38 non-null     object
#  4   User ESN Mobile Id                    0 non-null      float64
#  5   EOL                                   38 non-null     object
#  6   Enabled Services                      0 non-null      float64
#  7   Asset                                 0 non-null      float64
#  8   Account                               38 non-null     object
#  9   Status                                38 non-null     object
#  10  Last Event Time                       0 non-null      float64
# ...

# %%
for i in range(0,38):
    if cu_zl_calamp_ctc.iloc[i,57]==55.161:
        print(cu_zl_calamp_ctc.iloc[i,45])
# Out:
# 354514101594176
# 351628098670741
# 359369091340717
# 358077091143517
# 352556101994338
# 351628093090242
# 359369091279477
# 352556102033664
# 358077092214630
# 359369091278750
# 358077091384582
# 351628093166265
# 354514101199323
# 358077092192984
# 351628098730354
# 351628093145533
# 351628093210048
# 351628093143611
# 359369091286118
# 358077090867546
# 358077091191532
# 357041069707100
# 359369091340485
# 358077092199005
# 359369091288585
# 354514101190397
# 359369091279113
# 359369091339990

# %%
for i in range(0,38):
    if cu_zl_calamp_ctc.iloc[i,57]==55.161:
        print(cu_zl_calamp_ctc.iloc[i,45])
# Out:
# 354514101594176
# 351628098670741
# 359369091340717
# 358077091143517
# 352556101994338
# 351628093090242
# 359369091279477
# 352556102033664
# 358077092214630
# 359369091278750
# 358077091384582
# 351628093166265
# 354514101199323
# 358077092192984
# 351628098730354
# 351628093145533
# 351628093210048
# 351628093143611
# 359369091286118
# 358077090867546
# 358077091191532
# 357041069707100
# 359369091340485
# 358077092199005
# 359369091288585
# 354514101190397
# 359369091279113
# 359369091339990

# %%
for i in range(0,38):
    if cu_zl_calamp_ctc.iloc[i,57]==55.610:
        print(cu_zl_calamp_ctc.iloc[i,45])
# Out:
# 358077091131942
# 351628093234303
# 351628098646964
# 351628098660809
# 351628098667325
# 351628098671962
# 359369091284915

# %%
for i in range(0,38):
    if cu_zl_calamp_ctc.iloc[i,57]==7.173:
        print(cu_zl_calamp_ctc.iloc[i,45])
# Out:
# 352556102797540

# %%
for i in range(0,38):
    if cu_zl_calamp_ctc.iloc[i,57]==7.170:
        print(cu_zl_calamp_ctc.iloc[i,45])
# Out:
# 351628093020447

# %%
for i in range(0,38):
    if cu_zl_calamp_ctc.iloc[i,57]==7.380:
        print(cu_zl_calamp_ctc.iloc[i,45])
# Out:
# 357041069871229

# %%
cu_zl_queclink=cu_zl[cu_zl['Unit Type 2'].str.contains('Queclink')]
cu_zl_queclink.info()
cu_zl_queclink_sn=cu_zl_queclink['Unit']
cu_zl_queclink_sn.to_csv('/home/jlhb1984/py-projects/data/zona_logística_TS000157986/queclink_unit.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 9 to 45
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       10 non-null     int64
#  1   Owner                    10 non-null     object
#  2   Unit ID                  10 non-null     object
#  3   Unit                     10 non-null     object
#  4   Peripherals              2 non-null      object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          10 non-null     object
#  9   Monthly Fee              10 non-null     int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              10 non-null     object
#  12  Linked Mode              10 non-null     int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
cu_zl_genx=cu_zl[cu_zl['Unit Type 2'].str.contains('Gen')]
cu_zl_genx.info()
cu_zl_genx=cu_zl_genx['Unit']
cu_zl_genx
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 8 to 38
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       3 non-null      int64
#  1   Owner                    3 non-null      object
#  2   Unit ID                  3 non-null      object
#  3   Unit                     3 non-null      object
#  4   Peripherals              3 non-null      object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          3 non-null      object
#  9   Monthly Fee              3 non-null      int64
#  10  Bill To                  0 non-null      float64
#  11  Assigned To              3 non-null      object
#  12  Linked Mode              3 non-null      int64
#  13  Paired GPS               0 non-null      float64
# ...

# %%
detailed_report=pd.read_csv('/home/jlhb1984/py-projects/data/zona_logística_TS000157986/DetailedSpeeding.csv')#,sep=';',encoding='latin1')
detailed_report.info()
#detailed_report['Vehicle'].value_counts().to_csv('/home/jlhb1984/py-projects/data/zona_logística_TS000157986/DetailedSpeeding_Units.csv')
detailed_report['Error']="Empty"

for i in range(0,177):
    if detailed_report.iloc[i,5]<80:
        detailed_report.iloc[i,11]="Error"
        #print(detailed_report.iloc[i,11])

detailed_report_error=detailed_report[detailed_report['Error'].str.contains('Error')]
detailed_report_error['Vehicle'].value_counts().to_csv('/home/jlhb1984/py-projects/data/zona_logística_TS000157986/DetailedSpeeding_Units.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Vehicle        177 non-null    object
#  1   StartDateTime  177 non-null    object
#  2   StartTime      177 non-null    object
#  3   EndTime        177 non-null    object
#  4   DurationSecs   177 non-null    object
#  5   MaxSpeed       177 non-null    int64
#  6   StartOdometer  177 non-null    int64
#  7   EndOdometer    177 non-null    int64
#  8   StartLat       177 non-null    object
#  9   StartLon       177 non-null    object
#  10  StartAddress   177 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 15.3+ KB

# %%
detailed_report_error.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145 entries, 0 to 176
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Vehicle        145 non-null    object
#  1   StartDateTime  145 non-null    object
#  2   StartTime      145 non-null    object
#  3   EndTime        145 non-null    object
#  4   DurationSecs   145 non-null    object
#  5   MaxSpeed       145 non-null    int64
#  6   StartOdometer  145 non-null    int64
#  7   EndOdometer    145 non-null    int64
#  8   StartLat       145 non-null    object
#  9   StartLon       145 non-null    object
#  10  StartAddress   145 non-null    object
#  11  Error          145 non-null    object
# dtypes: int64(3), object(9)
# memory usage: 14.7+ KB

# %%
df_book_table01=pd.read_csv('/home/jlhb1984/py-projects/data/zona_logística_TS000157986/DetailedSpeeding_Units.csv')
df_book_table02=cu_zl
df_book_table01.info()
df_book_table02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Vehicle  19 non-null     object
#  1   count    19 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 436.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       53 non-null     int64
#  1   Owner                    53 non-null     object
#  2   Unit ID                  53 non-null     object
#  3   Unit                     53 non-null     object
#  4   Peripherals              41 non-null     object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
# ...

# %%
num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])       
cont=0
df_aux=pd.DataFrame()        
list_field01=[]
list_field02=[]
list_field03=[]
list_field04=[]
list_field05=[]       
#print("df_book_table01[8,0]: ",df_book_table01.iloc[8,0]) #UnitsByDealer.csv_r.csv
#print("df_book_table02[8,5]: ",df_book_table02.iloc[8,5]) #6MB.        
print("\nInformación de las tablas: ")
print("\nTabla 1:")
print(df_book_table01.info())
print("\nTabla 2:")
print(df_book_table02.info())
attribute_name_table01='Vehicle'#Digitar el índice de la tabla 1.#input("\nDigita el atributo a comparar de la tabla 1: ")
attribute_name_table02='Unit'#Digitar el índice de la tabla 2.#input("Digita el atribito a comparar de la tabla 2: ")
position_table01=int(df_book_table01.columns.get_loc(attribute_name_table01))
position_table02=int(df_book_table02.columns.get_loc(attribute_name_table02))
print("\nAtributo de la tabla1: ",position_table01)
print("Atributo de la tabla2: ",position_table02,"\n")
print("Trabajando...")

print(df_book_table01.iloc[0,0])
print(df_book_table02.iloc[0,3])
                          
for i in range(0,num_filas_table01):
    for j in range(0,num_filas_table02):
        #if str(df_book_table01.iloc[i,5])==str(df_book_table02.iloc[j,3]): 
        if str(df_book_table01.iloc[i,position_table01])[0:6]==str(df_book_table02.iloc[j,position_table02]):                                                                             
            list_field01.append(df_book_table02.iloc[i,3])
            list_field02.append(df_book_table02.iloc[i,4])
            list_field03.append(df_book_table02.iloc[i,8])
            list_field04.append(df_book_table02.iloc[i,17])
            list_field05.append(df_book_table02.iloc[i,18])
            print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
            print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
            cont=cont+1
df_aux['Unit']=list_field01
#df_aux['Peripherals']=list_field02
#df_aux['Last Event Date']=list_field03
df_aux['Unit Type']=list_field04
df_aux['IMEI']=list_field05
print("Cont= ",cont)
print(df_aux)
option_exp=input("\n¿Desea generar un reporte de coincidencias en formato csv S/N?\n")
if option_exp=="S":
    df_aux.to_csv('./reports/tables_comparator_coincident.csv')
cont=0
option_exp=input("¿Desea generar un reporte de diferencias en formato csv S/N?\n")        
df_book_table02['ACTION']="Keep"
if option_exp=="S":
    print("Trabajando...")
    for i in range(0,num_filas_table01):
        for j in range(0,num_filas_table02):
            if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):
                df_book_table02.iloc[j,5]=np.nan
                print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
                print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
    df_book_table02.dropna(axis=0,inplace=True)
    #print(df_book_table02)
    df_book_table02.to_csv("./reports/tables_comparator_differences.csv")

#lista_combinada=[lista_simcard,lista_linea]
# Out:
# Información de las tablas:
#
# Tabla 1:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Vehicle  19 non-null     object
#  1   count    19 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 436.0+ bytes
# None
#
# Tabla 2:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       53 non-null     int64
#  1   Owner                    53 non-null     object
#  2   Unit ID                  53 non-null     object
#  3   Unit                     53 non-null     object
#  4   Peripherals              41 non-null     object
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
# ...

# %% [markdown]
# 28-07-2025:
# Se concluye que el problema afecta a todas las unidades. Verificar el 29-07-2025 si las unidades Quclink recibieron el comando GTSPD.
# Se envió comando general a todas las unidades pero las Queclink no lo tomaron.

# %% [markdown]
# 29-07-2025:
# LKO880, y LKO879 se envió el comando manualmente.
# El resto se hizo en forma masiva chequeando cada unidad.

# %%
short_name=input('Digita la placa a consultar')
cu_zl[cu_zl['Unit'].str.contains(short_name)]
# Out:
#         ID    Owner Unit ID    Unit   Peripherals  Reporting Status  \
# 0  1082543  Renting    0M56  WLZ294  Fuel Sensor,               NaN
#
#    Show Until  Billing Group Last Event Date  Monthly Fee  ...  \
# 0         NaN            NaN      28/07/2025        54800  ...
#
#    History Months Comments        Warranty Expires  \
# 0               3      NaN  11/20/2021 12:00:00 AM
#
#                               Script  JBOX Profile Contract Type Subscription  \
# 0  TSO_LMU26x0_FLS_ES2_BIN_AWS_10700           NaN           NaN          NaN
#
#   Firmware  Unit Type 2 ACTION
# 0      NaN       Calamp   Keep
#
# [1 rows x 49 columns]
