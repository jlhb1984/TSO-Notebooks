# %%
import pandas as pd

# %%
hlttv207=pd.read_csv('/home/jlhb1984/py-projects/data/hg/hlttv207.csv',sep=';',encoding='latin1')
hlttv207.info()
hlttv207['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     663 non-null    int64
#  1   Unit         663 non-null    object
#  2   Events       663 non-null    object
#  3   Date         663 non-null    object
#  4   Landmark     0 non-null      float64
#  5   Address      663 non-null    object
#  6   Speed        663 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     663 non-null    float64
#  10  Longitude    663 non-null    float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 57.1+ KB
# Events
# Idle - Stop         228
# Parked              160
# Drive               157
# Ignition OFF         35
# Ignition ON          35
# Towing/Drifting?     28
# Panic button         15
# Ping                  1
# POWER UP              1
# ...

# %%
hlttv207['Speed'].sort_values(ascending=False)
# Out:
# 523    59
# 524    57
# 527    57
# 533    57
# 540    56
#        ..
# 220     0
# 221     0
# 222     0
# 223     0
# 213     0
# Name: Speed, Length: 663, dtype: int64

# %%
raw_data_uds866=pd.read_csv('/home/jlhb1984/py-projects/data/hg/uds866.csv',sep=';',encoding='latin1')
raw_data_uds866.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1264 entries, 0 to 1263
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1264 non-null   object
#  1   Message  1264 non-null   object
#  2   Status   1264 non-null   object
# dtypes: object(3)
# memory usage: 29.8+ KB

# %%
raw_data_uds866_gtpspd=raw_data_uds866[raw_data_uds866['Message'].str.contains('GTSPD')]
raw_data_uds866_gtpspd
# Out:
#                       Created  \
# 47    2025-07-13 12:28:41.566
# 51    2025-07-13 12:30:23.231
# 61    2025-07-13 12:33:16.991
# 62    2025-07-13 12:33:49.844
# 251   2025-07-13 14:14:02.863
# ...                       ...
# 1194  2025-07-14 23:12:34.216
# 1199  2025-07-14 23:13:53.598
# 1201  2025-07-14 23:14:13.898
# 1202  2025-07-14 23:15:02.637
# 1204  2025-07-14 23:15:47.225
#
#                                                 Message  \
# 47    +RESP:GTSPD,500700,868574042846753,,,00,1,1,94...
# 51    +RESP:GTSPD,500700,868574042846753,,,01,1,1,41...
# 61    +RESP:GTSPD,500700,868574042846753,,,00,1,1,88...
# 62    +RESP:GTSPD,500700,868574042846753,,,01,1,1,34...
# 251   +RESP:GTSPD,500700,868574042846753,,,00,1,1,86...
# ...                                                 ...
# 1194  +RESP:GTSPD,500700,868574042846753,,,01,1,1,61...
# 1199  +RESP:GTSPD,500700,868574042846753,,,00,1,1,82...
# 1201  +RESP:GTSPD,500700,868574042846753,,,01,1,1,76...
# ...

# %% [markdown]
# El sistema está aproximando al entero menor siguiente si hay decimales en mph, razón por la cual, si se establece máxima velocidad a 80Km/h, 80.2Km/h que sería 49.84mph, quedaría como 49mph que sería igual a 78Km/h y esto es lo que aparecerá en el reporte. Según Carlos Morante, la columna que guarda esta información en la base de datos está configurada como entero y no se puede modificar.
