# %%
import pandas as pd
import numpy as np

# %%
act_report=pd.read_csv('/home/jlhb1984/py-projects/data/Triturados y Arenas Antioquia TS000158008/Activity Report_v3.csv')
act_report.rename(columns={'textbox43':'Event'},inplace=True)
act_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19841 entries, 0 to 19840
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GroupName         0 non-null      float64
#  1   UnitName          19841 non-null  object
#  2   StartTime         19841 non-null  object
#  3   MovingTimeSecs    19841 non-null  object
#  4   MilesDriven       19568 non-null  object
#  5   MaxSpeed          19841 non-null  int64
#  6   StopTime          19841 non-null  object
#  7   Event             19841 non-null  object
#  8   StopLengthSecs    19841 non-null  object
#  9   ContactName       19841 non-null  object
#  10  textbox45         19841 non-null  object
#  11  textbox54         19841 non-null  int64
#  12  textbox28         19841 non-null  object
#  13  textbox29         19841 non-null  object
#  14  textbox30         19841 non-null  int64
#  15  textbox32         19841 non-null  object
# ...

# %%
act_report['Event'].value_counts()
# Out:
# Event
# Idle            17012
# Parked/Idle      2009
# Ign Off           812
# Idle/Ign Off        8
# Name: count, dtype: int64

# %%
geofences_report=pd.read_csv('/home/jlhb1984/py-projects/data/Triturados y Arenas Antioquia TS000158008/Geofences InOut Report.csv')
geofences_report.info()
geofences_report['GeofenceName'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   textbox12       249 non-null    object
#  1   UnitName        249 non-null    object
#  2   textbox18       0 non-null      float64
#  3   EventTime       249 non-null    object
#  4   GeofenceName    249 non-null    object
#  5   GeofenceEvent1  249 non-null    object
#  6   Schedule        0 non-null      float64
# dtypes: float64(2), object(5)
# memory usage: 13.7+ KB
# GeofenceName
# Espera para cargue                                                                               187
# LIRIOS : 91-38 Carrera 50  Medellín Antioquia 050004                                              13
# HELICONIA                                                                                         11
# ...

# %%
cu=pd.read_csv('/home/jlhb1984/py-projects/data/Triturados y Arenas Antioquia TS000158008/cu.csv',sep=';',encoding='latin1')
cu.info()
cu['Unit Type'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       22 non-null     int64
#  1   Owner                    22 non-null     object
#  2   Unit ID                  22 non-null     object
#  3   Unit                     22 non-null     object
#  4   Peripherals              0 non-null      float64
#  5   BillingPeriod            22 non-null     object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            1 non-null      object
#  9   Last Event Date          22 non-null     object
#  10  Monthly Fee              22 non-null     int64
#  11  Bill To                  0 non-null      float64
#  12  Assigned To              22 non-null     object
#  13  Linked Mode              22 non-null     int64
# ...

# %%
calamp=cu[cu['Unit Type'].str.contains('CalAmp')]
calamp['IMEI'].to_csv('/home/jlhb1984/py-projects/data/Triturados y Arenas Antioquia TS000158008/calamp.csv')

# %%
calamp_06112025=pd.read_csv('/home/jlhb1984/py-projects/data/Triturados y Arenas Antioquia TS000158008/calamp_devices.csv')
calamp_06112025.info()
calamp_06112025_script_fir=calamp_06112025[['Model','IMEI','Script Identifier','Firmware Version','Last Event Time']]
calamp_06112025_script_fir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 64 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID                                    5 non-null      int64
#  1   Name                                  0 non-null      float64
#  2   Identifier                            5 non-null      int64
#  3   Model                                 5 non-null      object
#  4   User ESN Mobile Id                    0 non-null      float64
#  5   EOL                                   5 non-null      object
#  6   Enabled Services                      0 non-null      float64
#  7   Asset                                 0 non-null      float64
#  8   Account                               5 non-null      object
#  9   Status                                5 non-null      object
#  10  Last Event Time                       0 non-null      float64
# ...

# %% [markdown]
# Se cargó tarea a 359369091108460 y 351628093163098 para actualizar firmware.

# %%
queclink=cu[cu['Unit Type'].str.contains('Queclink')]
queclink['IMEI'].to_csv('/home/jlhb1984/py-projects/data/Triturados y Arenas Antioquia TS000158008/queclink.csv')

# %%
queclink_06112025=pd.read_csv('/home/jlhb1984/py-projects/data/Triturados y Arenas Antioquia TS000158008/queclink_devices.csv',sep=';')
queclink_06112025.info()
queclink_06112025_script_fir=queclink_06112025[['IMEI','Configuration Version','Firmware Version']]
queclink_06112025_script_fir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Device Name                     7 non-null      float64
#  1   Last Report Date                13 non-null     object
#  2   Create Time                     12 non-null     object
#  3   IMEI                            13 non-null     int64
#  4   Device Type                     13 non-null     object
#  5   Group                           13 non-null     object
#  6   Iccid                           13 non-null     object
#  7   MCU Firmware Version            0 non-null      float64
#  8   Modem Version                   0 non-null      float64
#  9   Firmware Version                13 non-null     object
#  10  Configuration Version           13 non-null     int64
#  11  Hardware Version                13 non-null     float64
# ...

# %% [markdown]
# Solo está disponible R00A12V03 en QMS.

# %%
genx=cu[cu['Unit Type'].str.contains('GenX')]
genx['IMEI'].to_csv('/home/jlhb1984/py-projects/data/Triturados y Arenas Antioquia TS000158008/genx.csv')

# %%
topfly=cu[cu['Unit Type'].str.contains('Topfly')]
topfly['IMEI'].to_csv('/home/jlhb1984/py-projects/data/Triturados y Arenas Antioquia TS000158008/topfly.csv')
#config=607, firmware=(V1.0.1.5)
