# %%
import pandas as pd
import numpy as np

# %%
cu_05122025=pd.read_csv('/home/jlhb1984/py-projects/data/lely/cu_lely_05122025.csv',sep=';',encoding='latin1')
cu_05122025.info()
placa=input('Digita la placa: ')
cu_register=cu_05122025[cu_05122025['Unit ID'].str.contains(placa)]
cu_register
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       51 non-null     int64
#  1   Owner                    51 non-null     object
#  2   Unit ID                  51 non-null     object
#  3   Unit                     51 non-null     object
#  4   Peripherals              1 non-null      object
#  5   BillingPeriod            47 non-null     object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            12 non-null     object
#  9   Last Event Date          51 non-null     object
#  10  Monthly Fee              51 non-null     int64
#  11  Bill To                  1 non-null      object
#  12  Assigned To              51 non-null     object
#  13  Linked Mode              51 non-null     int64
# ...
