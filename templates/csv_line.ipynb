# %%
import pandas as pd
import numpy as np

# %%
file=pd.read_csv('/home/jlhb1984/py-projects/data/sunrise/011001122025/imeis.csv')
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9 non-null      int64
#  1   IMEI        9 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 276.0+ bytes

# %%
total_points=file['IMEI'].count() #Serial para PM e IMEI para CRM

cad1=file.iloc[0,1]+","
for i in range(1,total_points):
    cad1=cad1+str(file.iloc[i,1])+","    
print(cad1)
# Out:
# 8B514208,8B5141PU,8B51426E,6B31117C,6B311142,6B31114Z,6B31111D,8B514256,8B5141SX,

# %%
total_points=file['Serial'].count() #Serial para PM e IMEI para CRM

cad1=file.iloc[0,1]+" "
for i in range(1,total_points):
    cad1=cad1+str(file.iloc[i,1])+" "    
print(cad1)
# Out:
# 6B3013YN 6B301433 6B30140U 6B3013X3 6B301400 6B3013ZA
