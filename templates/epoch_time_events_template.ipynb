# %%
import pandas as pd
import numpy as np

# %%
df_nsb=pd.DataFrame()
list_field01=[]
list_field02=[]
num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])
for i in range(0,num_filas_table01):
    aux=df_book_table01.iloc[i,1][5:18]
    #aux
    events=df_book_table02[df_book_table02['Message'].str.contains(aux)]
    list_field01.append(events['Created'])
    list_field02.append(aux)
df_nsb['No_Seat_Belt_event_date']=list_field01
df_nsb['Epoch_time_reported']=list_field02
df_nsb.to_csv('/home/jlhb1984/py-projects/data/riopaila/1bzu_no_seat_belt.csv')
