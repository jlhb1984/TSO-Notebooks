# %%
import pandas as pd
import numpy as np

# %%
path_1=input(str('Paste the path where Table 1 is located: '))
path_2=input(str('Paste the path where Table 2 is located: '))
df_book_table01=pd.read_csv(path_1,sep=';',encoding='latin1')
df_book_table02=pd.read_csv(path_2,sep=';',encoding='latin1')

# %%
#df_book_table01=df_book_table01[['TicketID','Subject','Company']]
#df_book_table02=df_book_table02[['TicketID','Subject','Company']]

# %%
df_book_table01.info()
df_book_table02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geofence       12 non-null     object
#  1   Geofence Type  12 non-null     object
#  2   Created On     12 non-null     object
# dtypes: object(3)
# memory usage: 420.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geofence       79 non-null     object
#  1   Geofence Type  79 non-null     object
#  2   Created On     79 non-null     object
# dtypes: object(3)
# memory usage: 2.0+ KB

# %%
num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])       
cont=0
df_aux=pd.DataFrame()        
list_field01=[]
list_field02=[]
list_field03=[]
list_field04=[]       
#print("df_book_table01[8,0]: ",df_book_table01.iloc[8,0]) #UnitsByDealer.csv_r.csv
#print("df_book_table02[8,5]: ",df_book_table02.iloc[8,5]) #6MB.        
print("\nInformación de las tablas: ")
print("\nTabla 1:")
print(df_book_table01.info())
print("\nTabla 2:")
print(df_book_table02.info())
attribute_name_table01='Geofence'#Digitar el índice de la tabla 1.#input("\nDigita el atributo a comparar de la tabla 1: ")
attribute_name_table02='Geofence'#Digitar el índice de la tabla 2.#input("Digita el atribito a comparar de la tabla 2: ")
position_table01=int(df_book_table01.columns.get_loc(attribute_name_table01))
position_table02=int(df_book_table02.columns.get_loc(attribute_name_table02))
print("\nAtributo de la tabla1: ",position_table01)
print("Atributo de la tabla2: ",position_table02,"\n")
print("Trabajando...")
                          
for i in range(0,num_filas_table01):
    for j in range(0,num_filas_table02):
        #if str(df_book_table01.iloc[i,5])==str(df_book_table02.iloc[j,3]): 
        if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):                                                                             
            list_field01.append(df_book_table02.iloc[j,0])
            list_field02.append(df_book_table02.iloc[j,1])
            list_field03.append(df_book_table02.iloc[j,2])
            #list_field04.append(df_book_table02.iloc[j,17])
            print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
            print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
            cont=cont+1
df_aux['Geofence']=list_field01
df_aux['Geofence Type']=list_field02
df_aux['Created']=list_field03
#df_aux['FIELD04']=list_field04
print("Cont= ",cont)
print(df_aux.info())
option_exp=input("\n¿Desea generar un reporte de coincidencias en formato csv S/N?\n")
if option_exp=="S":
    df_aux.to_csv(path_1+'coincidences'+'.csv')
cont=0
option_exp=input("¿Desea generar un reporte de diferencias en formato csv S/N?\n")        
df_book_table02['ACTION']="Keep"
if option_exp=="S":
    print("Trabajando...")
    for i in range(0,num_filas_table01):
        for j in range(0,num_filas_table02):
            if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):
                df_book_table02.iloc[j,3]=np.nan
                print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
                print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
    #print(df_book_table02)
    df_book_table02.dropna(axis=0,inplace=True)
    print(df_book_table02)
    df_book_table02.to_csv(path_2+'coincidences'+'.csv')

#lista_combinada=[lista_simcard,lista_linea]
# Out:
# Información de las tablas:
#
# Tabla 1:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geofence       12 non-null     object
#  1   Geofence Type  12 non-null     object
#  2   Created On     12 non-null     object
# dtypes: object(3)
# memory usage: 420.0+ bytes
# None
#
# Tabla 2:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geofence       79 non-null     object
#  1   Geofence Type  79 non-null     object
#  2   Created On     79 non-null     object
# dtypes: object(3)
# memory usage: 2.0+ KB
# None
#
# Atributo de la tabla1:  0
# Atributo de la tabla2:  0
#
# Trabajando...
# Cont=  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geofence       0 non-null      float64
#  1   Geofence Type  0 non-null      float64
#  2   Created        0 non-null      float64
# dtypes: float64(3)
# memory usage: 132.0 bytes
# None
# Trabajando...
#                    Geofence Geofence Type               Created On ACTION
# 0                     .....        Linear  2013-02-14 11:49:01.690   Keep
# 1                    ANDINO     Polygonal  2018-12-10 14:52:02.093   Keep
# 2                   ARKADIA     Polygonal  2021-07-16 17:45:58.630   Keep
# 3   AVENTURA PLAZA MEDELLIN     Polygonal  2019-01-03 07:56:12.820   Keep
# 4             BODEGA BOGOTA     Polygonal  2012-02-21 14:10:22.347   Keep
# ..                      ...           ...                      ...    ...
# 74            VILLAVICENCIO     Polygonal  2016-01-29 10:37:50.533   Keep
# 75         VIVA BARRNQUILLA     Polygonal  2019-01-02 10:36:52.563   Keep
# 76            VIVA ENVIGADO     Polygonal  2018-12-20 12:39:42.480   Keep
# 77                ZONA CALI     Polygonal  2016-01-28 09:51:51.603   Keep
# 78                 ZONA INN     Polygonal  2016-01-29 10:39:52.450   Keep
#
# [79 rows x 4 columns]
