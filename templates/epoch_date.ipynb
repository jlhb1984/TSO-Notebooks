# %%
import pandas as pd
import numpy as np

# %%
##Este método no es confiable, a veces cambia la ubicación del caracter 92 o 37, por lo que es mejor organizar el csv en columnas.
key_id_aux='0000000000000000'
ibutton_key=[]
unix_time=[]
date_time=[]

for i in range(0,4919):
    message=cep433_rd_01091911.iloc[i,2]
    status=cep433_rd_01091911.iloc[i,1]
    key_id=message[92:108]
    epoch_time=status[37:47]
    #print(epoch_time)
    if (key_id_aux)!=(key_id):
        ibutton_key.append(key_id)
        unix_time.append(epoch_time)
        date_time_aux=pd.to_datetime(int(epoch_time),unit='s')
        date_time.append(date_time_aux)
        #print(epoch_time)
#print(ibutton_key)
counts=Counter(ibutton_key)
unix_time.sort()
print("time: ",date_time)
