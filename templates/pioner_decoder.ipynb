# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
raw_data=pd.read_csv('/home/jlhb1984/py-projects/data/chilco/prz050.csv',sep=';',encoding='latin1')
raw_datam=pd.read_csv('/home/jlhb1984/py-projects/data/chilco/prz050m.csv',sep=';',encoding='latin1')
raw_datam.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam.info()
raw_datam.to_csv('/home/jlhb1984/py-projects/data/chilco/prz050decoded.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21052 entries, 0 to 21051
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           21052 non-null  object
#  1   Message Type      21052 non-null  object
#  2   Protocole         21052 non-null  object
#  3   IMEI              21052 non-null  object
#  4   Serial            21052 non-null  object
#  5   Mileage           21052 non-null  object
#  6   Date              21052 non-null  object
#  7   Ignition          21052 non-null  object
#  8   Latitude          21052 non-null  object
#  9   Longitude         21052 non-null  object
#  10  Altitude          21052 non-null  object
#  11  External Power    20803 non-null  object
#  12  RPM               20803 non-null  object
#  13  Speed             20512 non-null  object
#  14  Satellite Number  20512 non-null  object
#  15  Azimuth           20512 non-null  object
# ...

# %%
raw_data=pd.read_csv('/home/jlhb1984/py-projects/data/hagemsa/rawdata_12_25_tf.csv',sep=',',encoding='ISO 8859-1')
raw_data.info()
raw_data.rename(columns={'Unnamed: 1':'UnitID',
                                 'Unnamed: 2':'UnitType',
                                 'Unnamed: 3':'latitude',
                                 'Unnamed: 4':'longitude',
                                 'Unnamed: 5':'heading',
                                 'Unnamed: 6':'unitTime',
                                 'Unnamed: 7':'historyID',
                                 'Unnamed: 8':'eventCode',
                                 'Unnamed: 9':'ignitionStatus',
                                 'Unnamed: 10':'Speed',
                                 'Unnamed: 11':'satelliteCount',
                                 'Unnamed: 12':'engineOdomoter',
                                 'Unnamed: 13':'licenserPlate',
                                 'Unnamed: 14':'tempSensor',
                                 'Unnamed: 15':'busSensor',
                                 },inplace=True)
raw_data.info()

# %%
aux=raw_data_v4z_crm_845tf_ignition.iloc[0,2][64:68]
ignition_on_counter=0
ignition_off_counter=0

if aux=="6100":
    ignition=1
else:
    ignition=0

for i in range(1,raw_data_v4z_crm_845tf_ignition.shape[0]):
    if str(raw_data_v4z_crm_845tf_ignition.iloc[i,2][64:68])=="6100":
        ignition_aux=1       
    else:
        ignition_aux=0        
    if (ignition==1)and(ignition_aux==0):
        ignition_off_counter=ignition_off_counter+1
        print("Off","Bytes ",raw_data_v4z_crm_845tf_ignition.iloc[i,2][64:68],"Date ",raw_data_v4z_crm_845tf_ignition.iloc[i,0])
    if (ignition==0)and(ignition_aux==1):
        ignition_on_counter=ignition_on_counter+1
        print("On","Bytes ",raw_data_v4z_crm_845tf_ignition.iloc[i,2][64:68],"Date ",raw_data_v4z_crm_845tf_ignition.iloc[i,0])
    ignition=ignition_aux

print("ignition_on_counter: ",ignition_on_counter,'ignition_off_counter',ignition_off_counter)
