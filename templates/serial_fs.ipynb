# %%
import pandas as pd
import numpy as np

# %%
ubd=pd.read_csv('/home/jlhb1984/py-projects/data/cases/ubd.csv',sep=';',encoding='latin1')
ubd.info()
fs=ubd[ubd['Peripherals'].str.contains('Fuel Sensor')]
fs['Fuel Sensor Serials']='Empty'
fs.info()
fs_rows=fs.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10179 entries, 0 to 10178
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   10179 non-null  object
#  1   Company                  10179 non-null  object
#  2   VIP                      10179 non-null  object
#  3   FEIN                     10179 non-null  object
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      1035 non-null   object
#  6   Peripherals              10179 non-null  object
#  7   Service                  8373 non-null   object
#  8   Owner                    10179 non-null  object
#  9   Unit ID                  10179 non-null  object
#  10  Unit                     10179 non-null  object
#  11  Unit Type                10179 non-null  object
#  12  Carrier                  9328 non-null   object
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
serial_fs_value=[]
for i in range(0,fs_rows):
    serial_fs_value.append(fs.iloc[i,6][14:20])
    
fs['Fuel Sensor Serials']=serial_fs_value

fs[['Fuel Sensor Serials','Unit ID','Company']]
# Out:
# /tmp/ipykernel_54451/2976332491.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fs['Fuel Sensor Serials']=serial_fs_value
#       Fuel Sensor Serials Unit ID                    Company
# 7                  Fuel S    1BL4              A-JESUS-TEST2
# 26                 212690    17YD  AE INGENIEROS CIVILES SAS
# 27                 215129    19SL  AE INGENIEROS CIVILES SAS
# 28                 215130    19T1  AE INGENIEROS CIVILES SAS
# 29                 214906    19VQ  AE INGENIEROS CIVILES SAS
# ...                   ...     ...                        ...
# 10165              004035    0KJY         ZONA LOGISTICA SAS
# 10166              004036    0KJZ         ZONA LOGISTICA SAS
# ...
