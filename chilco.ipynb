# %%
import pandas as pd
import numpy as np

# %%
raw_data=pd.read_csv('/home/jlhb1984/py-projects/data/chilco/prz050.csv',sep=';',encoding='latin1')
raw_datam=pd.read_csv('/home/jlhb1984/py-projects/data/chilco/prz050m.csv',sep=';',encoding='latin1')
raw_datam.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam.info()
raw_datam.to_csv('/home/jlhb1984/py-projects/data/chilco/prz050decoded.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10161 entries, 0 to 10160
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           10161 non-null  object
#  1   Message Type      10161 non-null  object
#  2   Protocole         10161 non-null  object
#  3   IMEI              10161 non-null  object
#  4   Serial            10161 non-null  object
#  5   Mileage           10161 non-null  object
#  6   Date              10161 non-null  object
#  7   Ignition          10161 non-null  object
#  8   Latitude          10161 non-null  object
#  9   Longitude         10161 non-null  object
#  10  Altitude          10161 non-null  object
#  11  External Power    9986 non-null   object
#  12  RPM               9986 non-null   object
#  13  Speed             9784 non-null   object
#  14  Satellite Number  9784 non-null   object
#  15  Azimuth           9784 non-null   object
# ...

# %%
prz050d=pd.read_csv('/home/jlhb1984/py-projects/data/chilco/prz050decoded.csv')
prz050d_f=prz050d[['Date','Mileage','Speed']]
prz050d_f
# Out:
#                               Date                   Mileage      Speed
# 0      Date:"2025-11-01T00:02:05Z"          Mileage:15494501  Speed:0.0
# 1      Date:"2025-11-01T01:02:06Z"          Mileage:15494501  Speed:0.0
# 2      Date:"2025-11-01T02:02:06Z"          Mileage:15494501  Speed:0.0
# 3                          Model:0       Firmware:"V1.0.1.5"        NaN
# 4                   Band:"CAT-1 5"  AccessTechnology:"CAT-1"        NaN
# ...                            ...                       ...        ...
# 10156  Date:"2025-12-17T15:57:15Z"          Mileage:18430109  Speed:0.0
# 10157  Date:"2025-12-17T16:57:15Z"          Mileage:18430109  Speed:0.0
# 10158  Date:"2025-12-17T17:57:15Z"          Mileage:18430109  Speed:0.0
# 10159  Date:"2025-12-17T18:57:14Z"          Mileage:18430109  Speed:0.0
# 10160  Date:"2025-12-17T19:57:15Z"          Mileage:18430109  Speed:0.0
#
# [10161 rows x 3 columns]

# %%
#Looking for event:
value_to_look=input('Type the value to searh: ')
print("Working...")
prz050d_f_wanted=prz050d_f[prz050d_f['Date'].str.contains(value_to_look)]
prz050d_f_wanted
# Out:
# Working...
#                              Date           Mileage       Speed
# 169   Date:"2025-11-01T10:40:11Z"  Mileage:15557145  Speed:63.0
# 170   Date:"2025-11-01T10:41:11Z"  Mileage:15558248  Speed:66.0
# 171   Date:"2025-11-01T10:42:11Z"  Mileage:15559321  Speed:63.0
# 172   Date:"2025-11-01T10:42:58Z"  Mileage:15560207  Speed:68.0
# 173   Date:"2025-11-01T10:43:15Z"  Mileage:15560508  Speed:62.0
# ...                           ...               ...         ...
# 8266  Date:"2025-11-24T16:10:48Z"  Mileage:18054229  Speed:32.0
# 8558  Date:"2025-11-24T21:10:47Z"  Mileage:18187334   Speed:0.0
# 9552  Date:"2025-11-30T10:47:20Z"  Mileage:18390402   Speed:0.0
# 9576  Date:"2025-12-01T10:47:20Z"  Mileage:18390402   Speed:0.0
# 9697  Date:"2025-12-04T22:10:44Z"  Mileage:18390956   Speed:7.0
#
# [71 rows x 3 columns]

# %%
mileage_report_pm=pd.read_csv('/home/jlhb1984/py-projects/data/chilco/mileageReport_0111_3011.csv',sep=',')
mileage_report_pm
# Out:
#         Unit     Time/Date (COT)  \
# 0     PRZ050  11/01/2025 3:46 AM
# 1     PRZ050  11/01/2025 3:51 AM
# 2     PRZ050  11/01/2025 3:52 AM
# 3     PRZ050  11/01/2025 3:55 AM
# 4     PRZ050  11/01/2025 3:56 AM
# ...      ...                 ...
# 3814  PRZ050  11/27/2025 9:54 AM
# 3815  PRZ050  11/27/2025 9:55 AM
# 3816  PRZ050  11/27/2025 9:56 AM
# 3817  PRZ050  11/27/2025 9:57 AM
# 3818  PRZ050  11/27/2025 9:59 AM
#
#                                                 Address  Distance (km)  \
# 0        122-12250 Cra. 2, Soacha, Cundinamarca, 250055           0.75
# 1       36-35 Cra. 9 Este, Soacha, Cundinamarca, 250054           0.27
# 2     7 Este259-7 Este409 Cl. 33, Soacha, Cundinamar...           0.41
# 3                  Cl. 31, Soacha, Cundinamarca, 250054           0.55
# 4                 Dg. 30L, Soacha, Cundinamarca, 250051           0.21
# ...                                                 ...            ...
# ...

# %%
#Looking for event:
value_to_look=input('Type the value to searh: ')
print("Working...")
prz050d_f_wanted=mileage_report_pm[mileage_report_pm['Time/Date (COT)'].str.contains(value_to_look)]
prz050d_f_wanted
# Out:
# Working...
#         Unit     Time/Date (COT)  \
# 61    PRZ050  11/01/2025 5:40 AM
# 62    PRZ050  11/01/2025 5:41 AM
# 63    PRZ050  11/01/2025 5:42 AM
# 64    PRZ050  11/01/2025 5:43 AM
# 65    PRZ050  11/01/2025 5:43 AM
# 66    PRZ050  11/01/2025 5:44 AM
# 67    PRZ050  11/01/2025 5:45 AM
# 68    PRZ050  11/01/2025 5:45 AM
# 69    PRZ050  11/01/2025 5:46 AM
# 70    PRZ050  11/01/2025 5:46 AM
# 71    PRZ050  11/01/2025 5:47 AM
# 72    PRZ050  11/01/2025 5:48 AM
# 73    PRZ050  11/01/2025 5:48 AM
# 74    PRZ050  11/01/2025 5:49 AM
# 494   PRZ050  11/04/2025 5:48 AM
# 495   PRZ050  11/04/2025 5:48 AM
# 1723  PRZ050  11/11/2025 5:47 PM
# 1724  PRZ050  11/11/2025 5:47 PM
# 1725  PRZ050  11/11/2025 5:48 PM
# 1726  PRZ050  11/11/2025 5:49 PM
# 1727  PRZ050  11/11/2025 5:49 PM
# 1929  PRZ050  11/13/2025 5:44 AM
# 1930  PRZ050  11/13/2025 5:47 AM
# 2680  PRZ050  11/22/2025 5:40 PM
# 2681  PRZ050  11/22/2025 5:41 PM
# 2682  PRZ050  11/22/2025 5:41 PM
# 2683  PRZ050  11/22/2025 5:42 PM
# ...
