# %%
import pandas as pd
import numpy as np

# %%
bomba_foods_geofences=pd.read_csv('/home/jlhb1984/py-projects/data/bomba_foods/bomba_foods.csv',sep=';')
diaz_y_restrepo_geofences=pd.read_csv('/home/jlhb1984/py-projects/data/bomba_foods/diaz_y_restrepo.csv',sep=';')
bomba_foods_geofences.info()
diaz_y_restrepo_geofences.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geofence       12 non-null     object
#  1   Geofence Type  12 non-null     object
#  2   Created On     12 non-null     object
# dtypes: object(3)
# memory usage: 420.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geofence       79 non-null     object
#  1   Geofence Type  79 non-null     object
#  2   Created On     79 non-null     object
# dtypes: object(3)
# memory usage: 2.0+ KB
