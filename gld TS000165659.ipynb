# %%
import pandas as pd
import numpy as np

# %%
raw_data=pd.read_csv('/home/jlhb1984/py-projects/data/gld_transport/btr812_21_23.csv',sep=';',encoding='latin1')
raw_datam=pd.read_csv('/home/jlhb1984/py-projects/data/gld_transport/btr812m_21_23.csv',sep=';',encoding='latin1')
raw_datam.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam.info()
raw_datam.to_csv('/home/jlhb1984/py-projects/data/sakura/cfv839_decoded_after_speed.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2076 entries, 0 to 2075
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           2076 non-null   object
#  1   Message Type      2076 non-null   object
#  2   Protocole         2076 non-null   object
#  3   IMEI              2076 non-null   object
#  4   Serial            2076 non-null   object
#  5   Mileage           2076 non-null   object
#  6   Date              2076 non-null   object
#  7   Ignition          2076 non-null   object
#  8   Latitude          2076 non-null   object
#  9   Longitude         2076 non-null   object
#  10  Altitude          2076 non-null   object
#  11  External Power    2060 non-null   object
#  12  RPM               2060 non-null   object
#  13  Speed             2024 non-null   object
#  14  Satellite Number  2024 non-null   object
#  15  Azimuth           2024 non-null   object
# ...

# %%
raw_datam['Message Type'].value_counts()
# Out:
# Message Type
# MessageType:"LocationInfoMessage"     1951
# MessageType:"LocationAlarmMessage"      73
# MessageType:"SignInMessage"             36
# MessageType:"NetworkInfoMessage"        16
# Name: count, dtype: int64

# %%
raw_datam['Satellite Number'].value_counts()
# Out:
# Satellite Number
# SatelliteNumber:0     1701
# SatelliteNumber:5       54
# SatelliteNumber:7       43
# SatelliteNumber:8       36
# SatelliteNumber:4       34
# SatelliteNumber:6       33
# SatelliteNumber:10      31
# SatelliteNumber:9       30
# SatelliteNumber:11      15
# SatelliteNumber:12      11
# SatelliteNumber:13       9
# SatelliteNumber:15       8
# SatelliteNumber:14       7
# SatelliteNumber:16       7
# SatelliteNumber:17       5
# Name: count, dtype: int64

# %%
hlbtr812_21_23=pd.read_csv('/home/jlhb1984/py-projects/data/gld_transport/hlbtr812_21_23.csv',sep=';',encoding='latin1')
hlbtr812_21_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1747 entries, 0 to 1746
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     1747 non-null   int64
#  1   Unit         1747 non-null   object
#  2   Events       1747 non-null   object
#  3   Date         1747 non-null   object
#  4   Landmark     108 non-null    object
#  5   Address      1747 non-null   object
#  6   Speed        1747 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       1747 non-null   object
#  9   Latitude     1747 non-null   float64
#  10  Longitude    1747 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 150.3+ KB

# %%
hlbtr812_21_23['Events'].value_counts()
# Out:
# Events
# Idle - Stop                   1465
# Drive                          142
# Geofence OUT                    19
# Geofence IN                     18
# End Speeding                    17
# Speed alert                     17
# Ignition OFF                    16
# Ignition ON                     16
# Alerta de Vel. En Geocerca      15
# Parked                          10
# Landmark OUT                     3
# Landmark IN                      3
# End Idle Alert                   3
# Idle Alert                       3
# Name: count, dtype: int64
