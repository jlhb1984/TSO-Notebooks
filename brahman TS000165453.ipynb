# %%
import pandas as pd
import numpy as np

# %%
tdl798_tso=pd.read_csv('/home/jlhb1984/py-projects/data/brahman/tdl795_idle_report_tso.csv',sep=',')
tdl798_tso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   textbox12    0 non-null      float64
#  1   textbox16    71 non-null     object
#  2   EventTime    71 non-null     object
#  3   Address      71 non-null     object
#  4   EndLandmark  0 non-null      float64
#  5   textbox25    71 non-null     object
#  6   Driver       71 non-null     object
#  7   textbox20    71 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 4.6+ KB

# %%
tdl798_pm=pd.read_csv('/home/jlhb1984/py-projects/data/brahman/tdl795_idle_report_pm2.csv',sep=',')
tdl798_pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unit                 2 non-null      object
#  1   Time & Date (COT)    2 non-null      object
#  2   Driver               0 non-null      float64
#  3   Address              2 non-null      object
#  4   Event                2 non-null      object
#  5   Idle Time (minutes)  2 non-null      float64
# dtypes: float64(2), object(4)
# memory usage: 228.0+ bytes
