# %%
import pandas as pd
import numpy as np

# %%
lpl840=pd.read_csv('/home/jlhb1984/py-projects/data/fuel_troubles/Export.xlsx - Sheet1.csv')
lpl840.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8155 entries, 0 to 8154
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  8155 non-null   object
#  1   Message  8155 non-null   object
#  2   Status   8155 non-null   object
# dtypes: object(3)
# memory usage: 191.3+ KB

# %%
lpl840_fuel=lpl840[lpl840['Message'].str.contains('3E02')]
lpl840_fuel
# Out:
#                       Created  \
# 7569  2025-06-03 19:18:10.689
# 7570  2025-06-03 19:18:10.839
# 7571  2025-06-03 19:18:10.989
# 7757  2025-06-03 19:23:38.897
# 7758  2025-06-03 19:23:46.418
# ...                       ...
# 8136  2025-06-03 20:12:06.127
# 8137  2025-06-03 20:12:22.146
# 8138  2025-06-03 20:12:38.135
# 8139  2025-06-03 20:12:56.211
# 8151  2025-06-03 20:27:45.508
#
#                                                 Message  \
# 7569  11000001,5,4764434670,1,1,1,4,7561,1748977712,...
# 7570  11000001,5,4764434670,1,1,1,4,7562,1748977720,...
# 7571  11000001,5,4764434670,1,1,1,4,7563,1748977731,...
# 7757  11000001,5,4764434670,1,1,1,4,7749,1748978618,...
# 7758  11000001,5,4764434670,1,1,1,4,7750,1748978625,...
# ...                                                 ...
# 8136  11000001,5,4764434670,1,1,1,4,8127,1748981525,...
# 8137  11000001,5,4764434670,1,1,1,4,8128,1748981541,...
# 8138  11000001,5,4764434670,1,1,1,4,8129,1748981557,...
# ...

# %%
bbd992_fuel=pd.read_csv('/home/jlhb1984/py-projects/data/fuel_troubles/Export.xlsx - Sheet1.csv')
bbd992_fuel.info()
bbd992_fuel_e01=bbd992_fuel[bbd992_fuel['Status'].str.contains('3E01')]
bbd992_fuel_e01.info()
#bbd992_fuel_e01.to_csv('/home/jlhb1984/py-projects/data/fuel_troubles/Fuel_reportbbd992.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3401 entries, 0 to 3400
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  3401 non-null   object
#  1   Message  3401 non-null   object
#  2   Status   3401 non-null   object
# dtypes: object(3)
# memory usage: 79.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  0 non-null      object
#  1   Message  0 non-null      object
#  2   Status   0 non-null      object
# dtypes: object(3)
# memory usage: 0.0+ bytes

# %%
m2y859=pd.read_csv('/home/jlhb1984/py-projects/data/fuel_troubles/m2y859.csv')
m2y859.info()
m2y859_3e0x=m2y859[m2y859['Message'].str.contains('3E02')]
m2y859_3e0x.to_csv('/home/jlhb1984/py-projects/data/fuel_troubles/m2y859_3e02.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3953 entries, 0 to 3952
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  3953 non-null   object
#  1   Message  3953 non-null   object
#  2   Status   3953 non-null   object
# dtypes: object(3)
# memory usage: 92.8+ KB
