# %%
import pandas as pd
import numpy as np

# %%
lrv4c716=pd.read_csv('/home/jlhb1984/py-projects/data/ricopollo/lrv4c716.csv',encoding='latin1')
lrv4c716.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ï»¿Name      25 non-null     object
#  1   EventDate    25 non-null     object
#  2   EventDate_1  25 non-null     object
#  3   Status       25 non-null     object
#  4   MilesDriven  24 non-null     object
#  5   Address      24 non-null     object
# dtypes: object(6)
# memory usage: 1.3+ KB

# %%
lrv4c716.rename(columns={'ï»¿Name': 'Driver',
                   'EventDate': 'Unit',
                   'EventDate_1':'Log in',
                   'Status':'Address',
                   'MilesDriven':'Log out',
                   'Address ':'Address landmark',
                   },
          inplace=True)

lrv4c716.info()
lrv4c716.sort_values('Log in')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Driver   25 non-null     object
#  1   Unit     25 non-null     object
#  2   Log in   25 non-null     object
#  3   Address  25 non-null     object
#  4   Log out  24 non-null     object
#  5   Address  24 non-null     object
# dtypes: object(6)
# memory usage: 1.3+ KB
#                         Driver     Unit                 Log in  \
# 14         HUARI TTITO, SERGIO  V4C-716  10/09/2025 01:47 p.m.
# 6           DIAS CRUZ, ROLANDO  V4C-716  11/09/2025 02:21 a.m.
# 0         BARRIOS ESPEJO, JOSE  V4C-716  11/09/2025 11:26 a.m.
# 20  LACUAÃA ARIAS, JORGE LUIS  V4C-716  11/09/2025 11:30 a.m.
# 1         BARRIOS ESPEJO, JOSE  V4C-716  11/09/2025 11:31 a.m.
# 21  LACUAÃA ARIAS, JORGE LUIS  V4C-716  11/09/2025 11:39 a.m.
# 22  LACUAÃA ARIAS, JORGE LUIS  V4C-716  11/09/2025 11:47 a.m.
# ...

# %%
hlv4c716=pd.read_csv('/home/jlhb1984/py-projects/data/ricopollo/hlv4c716.csv',sep=';',encoding='latin1')
hlv4c716.info()
hlv4c716['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18668 entries, 0 to 18667
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     18668 non-null  int64
#  1   Unit         18668 non-null  object
#  2   Events       18668 non-null  object
#  3   Date         18668 non-null  object
#  4   Landmark     3836 non-null   object
#  5   Address      18668 non-null  object
#  6   Speed        18668 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       18592 non-null  object
#  9   Latitude     18668 non-null  float64
#  10  Longitude    18668 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.6+ MB
# Events
# Drive                 11817
# Geofence IN             896
# Geofence OUT            868
# Out of Coverage         621
# In Coverage             617
# Parked                  601
# Idle - Stop             551
# Ignition OFF            530
# ...
