# %%
import pandas as pd
import numpy as np

# %%
cu=pd.read_csv('/home/jlhb1984/py-projects/data/logistic/cu.csv',sep=';',encoding='latin1')
cu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       88 non-null     int64
#  1   Owner                    88 non-null     object
#  2   Unit ID                  88 non-null     object
#  3   Unit                     88 non-null     object
#  4   Peripherals              1 non-null      object
#  5   BillingPeriod            88 non-null     object
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            10 non-null     object
#  9   Last Event Date          88 non-null     object
#  10  Monthly Fee              88 non-null     int64
#  11  Bill To                  57 non-null     object
#  12  Assigned To              88 non-null     object
#  13  Linked Mode              88 non-null     int64
# ...

# %%
vf4K_units=cu[cu['Unit Type'].str.contains('4K')]
vf4K_units['IMEI'].to_csv('/home/jlhb1984/py-projects/data/logistic/cu_4K_201125.csv')
vfAIR2_units=cu[cu['Unit Type'].str.contains('AIR2')]
vfAIR2_units['IMEI'].to_csv('/home/jlhb1984/py-projects/data/logistic/cu_AIR2201125.csv')
