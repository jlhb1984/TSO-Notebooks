# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## PA

# %%
pa=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/pa_Engine Runtime Report.csv')
pa.rename(columns={'Textbox8':'Address','textbox32':'Time1'},inplace=True)
pa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GroupName         85 non-null     object
#  1   UnitName          85 non-null     object
#  2   StartTime         85 non-null     object
#  3   Address           85 non-null     object
#  4   StopTime          85 non-null     object
#  5   StopLengthSecs    85 non-null     object
#  6   ContactName       85 non-null     object
#  7   Time1             85 non-null     object
#  8   StopLengthSecs_1  85 non-null     object
# dtypes: object(9)
# memory usage: 6.1+ KB

# %%
pa.head(2)
# Out:
#   GroupName       UnitName               StartTime  \
# 0    AGHASO  Unit: BVG-901  1/08/2025 8:11:18 a.m.
# 1    AGHASO  Unit: BVG-901  1/08/2025 9:35:33 a.m.
#
#                                              Address                 StopTime  \
# 0  ALMACEN LURIN AGHASO\r\n2 12 Avenida San Pedro...   1/08/2025 8:11:24 a.m.
# 1  Av. San Pedro 2, Lurín 15823, Peru Provincia d...  1/08/2025 11:21:05 a.m.
#
#   StopLengthSecs                                        ContactName  \
# 0    00h:00m:06s  ALMACEN LURIN AGHASO\r\n2 12 Avenida San Pedro...
# 1    01h:45m:32s  Gaspar Hernandez-54, Lima (cercado), Lima, Lim...
#
#          Time1 StopLengthSecs_1
# 0  33h:02m:33s      33h:02m:33s
# 1  33h:02m:33s      33h:02m:33s

# %%
pa_negatives=pa[pa['StopLengthSecs'].str.contains('-')]
pa_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
pa_negatives=pa[pa['StopLengthSecs_1'].str.contains('-')]
pa_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
pa_negatives=pa[pa['Time1'].str.contains('-')]
pa_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
pa_unified=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/pa_Travels_Daily_Summary_Unified.csv')
#pa_unified

# %%
pa_06=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/pa_Travels_Daily_Summary_Unified_06.csv')
pa_06_Offtime_negative=pa_06[pa_06['OffTime'].str.contains('-')]
pa_06_Offtime_negative
# Out:
#             UnitName     DayDate  Decelerations  Accelerations  HarshTurns  \
# 1083         C9B-760   4/06/2025              0              0           0
# 1172         F3G-947   3/06/2025              0              0           0
# 1331  COMPRESOR-AF23  12/06/2025              0              0           0
# 1332  COMPRESOR-AF23  13/06/2025              0              0           1
# 1342  COMPRESOR-AF23  23/06/2025              0              0           0
# 1344  COMPRESOR-AF23  25/06/2025              0              0           0
# 1349  COMPRESOR-AF23  30/06/2025              0              0           0
# 1568         F3H-841   9/06/2025              0              0           0
#
#      DistanceDriven1 DriveTime     OffTime   IdleTime  Textbox17 MaxSpeed  \
# 1083           27,97   0:31:47   -24:28:22   46:59:51   47:31:38   47 kph
# 1172            0,00   0:00:00  -194:52:14  217:07:46  217:07:46    0 kph
# ...

# %% [markdown]
# Análisis después de la corrección 21-08-2025.

# %%
pa_06_corrected=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/pa_Travels_Daily_Summary_Unified_06_c.csv')
pa_06_corrected.info()
pa_06_Offtime_negative=pa_06_corrected[pa_06_corrected['OffTime'].str.contains('-')]
pa_06_Offtime_negative
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UnitName         918 non-null    object
#  1   DayDate          918 non-null    object
#  2   Decelerations    918 non-null    int64
#  3   Accelerations    918 non-null    int64
#  4   HarshTurns       918 non-null    int64
#  5   DistanceDriven1  918 non-null    object
#  6   DriveTime        918 non-null    object
#  7   OffTime          918 non-null    object
#  8   IdleTime         918 non-null    object
#  9   Textbox17        918 non-null    object
#  10  MaxSpeed         918 non-null    object
#  11  DriverName       123 non-null    object
#  12  GroupName        340 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 93.4+ KB
#            UnitName     DayDate  Decelerations  Accelerations  HarshTurns  \
# ...

# %%
hlcompresor_af23_0625c=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/COMPRESOR-AF23.csv',sep=';',encoding='latin1')
hlcompresor_af23_0625c.info()
hlcompresor_af23_0625c['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1487 entries, 0 to 1486
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     1487 non-null   int64
#  1   Unit         1487 non-null   object
#  2   Events       1487 non-null   object
#  3   Date         1487 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      1485 non-null   object
#  6   Speed        1487 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     1487 non-null   float64
#  10  Longitude    1487 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 127.9+ KB
# Events
# Drive           662
# Travel Stop     253
# Travel Start    253
# Idle - Stop     248
# Idle Alert       53
# End Speeding      7
# Speed alert       7
# Harsh Turn        2
# POWER UP          1
# Ignition ON       1
# Name: count, dtype: int64

# %%
hlf3h_841_0625c=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/F3H_841.csv',sep=';',encoding='latin1')
hlf3h_841_0625c.info()
hlf3h_841_0625c['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     149 non-null    int64
#  1   Unit         149 non-null    object
#  2   Events       149 non-null    object
#  3   Date         149 non-null    object
#  4   Landmark     3 non-null      object
#  5   Address      149 non-null    object
#  6   Speed        149 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     149 non-null    float64
#  10  Longitude    149 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 12.9+ KB
# Events
# Drive           42
# Idle - Stop     21
# Parked          17
# Travel Stop     17
# Travel Start    17
# Ignition ON      7
# End Speeding     6
# Ignition OFF     6
# Speed alert      6
# Idle Alert       5
# POWER UP         3
# Geofence OUT     1
# ...

# %% [markdown]
# Análisis de todas las unidades en agosto.

# %%
all_units_08=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/Travels_Daily_Summary_Unified_PA0825.csv')
all_units_08.info()
pa_08_Offtime_negative=all_units_08[all_units_08['OffTime'].str.contains('-')]
pa_08_Offtime_negative
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1134 entries, 0 to 1133
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UnitName         1134 non-null   object
#  1   DayDate          1134 non-null   object
#  2   Decelerations    1134 non-null   int64
#  3   Accelerations    1134 non-null   int64
#  4   HarshTurns       1134 non-null   int64
#  5   DistanceDriven1  1134 non-null   object
#  6   DriveTime        1134 non-null   object
#  7   OffTime          1134 non-null   object
#  8   IdleTime         1134 non-null   object
#  9   Textbox17        1134 non-null   object
#  10  MaxSpeed         1134 non-null   object
#  11  DriverName       111 non-null    object
#  12  GroupName        420 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 115.3+ KB
#            UnitName     DayDate  Decelerations  Accelerations  HarshTurns  \
# ...

# %%
hlcfj_087=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/hlcfj-087.csv',sep=';',encoding='latin1')
hlcfj_087.info()
hlcfj_087['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4125 entries, 0 to 4124
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     4125 non-null   int64
#  1   Unit         4125 non-null   object
#  2   Events       4125 non-null   object
#  3   Date         4125 non-null   object
#  4   Landmark     58 non-null     object
#  5   Address      4125 non-null   object
#  6   Speed        4125 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       4125 non-null   object
#  9   Latitude     4125 non-null   float64
#  10  Longitude    4125 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 354.6+ KB
# Events
# Parked          3860
# Idle - Stop      134
# Geofence IN       27
# Geofence OUT      27
# POWER UP          26
# Ignition ON       24
# Ignition OFF      16
# Idle Alert         9
# Landmark OUT       2
# Name: count, dtype: int64

# %%
hlcfj_087_ignitions=hlcfj_087[hlcfj_087['Events'].str.contains('Ignition')]
hlcfj_087_ignitions
# Out:
#       Sequence     Unit        Events                  Date Landmark  \
# 220       3905  CFJ-087  Ignition OFF  Aug 19 2025 05:00 PM      NaN
# 221       3904  CFJ-087   Ignition ON  Aug 19 2025 04:59 PM      NaN
# 269       3856  CFJ-087  Ignition OFF  Aug 19 2025 12:27 PM      NaN
# 270       3855  CFJ-087   Ignition ON  Aug 19 2025 12:26 PM      NaN
# 292       3833  CFJ-087  Ignition OFF  Aug 19 2025 10:26 AM      NaN
# 301       3824  CFJ-087   Ignition ON  Aug 19 2025 10:09 AM      NaN
# 303       3822  CFJ-087   Ignition ON  Aug 19 2025 10:08 AM      NaN
# 311       3814  CFJ-087   Ignition ON  Aug 16 2025 11:34 PM      NaN
# 379       3746  CFJ-087   Ignition ON  Aug 16 2025 12:33 PM      NaN
# 876       3249  CFJ-087  Ignition OFF  Aug 14 2025 12:47 PM      NaN
# 877       3248  CFJ-087   Ignition ON  Aug 14 2025 12:47 PM      NaN
# 1083      3042  CFJ-087  Ignition OFF  Aug 13 2025 04:45 PM      NaN
# 1084      3041  CFJ-087   Ignition ON  Aug 13 2025 04:44 PM      NaN
# ...

# %%
hlcfj_087['Date'].sort_values(ascending=True)
# Out:
# 4114    Aug 01 2025 01:03 AM
# 3987    Aug 01 2025 01:04 PM
# 4113    Aug 01 2025 01:05 AM
# 3986    Aug 01 2025 01:05 PM
# 4112    Aug 01 2025 01:09 AM
#                 ...
# 15      Aug 20 2025 12:43 PM
# 139     Aug 20 2025 12:49 AM
# 14      Aug 20 2025 12:49 PM
# 138     Aug 20 2025 12:55 AM
# 13      Aug 20 2025 12:55 PM
# Name: Date, Length: 4125, dtype: object

# %%
hlPE6068L243641=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/hlPE6068L243641.csv',sep=';',encoding='latin1')
hlPE6068L243641.info()
hlPE6068L243641['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     92 non-null     int64
#  1   Unit         92 non-null     object
#  2   Events       92 non-null     object
#  3   Date         92 non-null     object
#  4   Landmark     0 non-null      float64
#  5   Address      88 non-null     object
#  6   Speed        92 non-null     int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     92 non-null     float64
#  10  Longitude    92 non-null     float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 8.0+ KB
# Events
# Idle - Stop      52
# Drive            18
# POWER UP          5
# Ignition ON       5
# Travel Start      4
# Travel Stop       4
# Idle Alert        3
# Fuel Dropping     1
# Name: count, dtype: int64

# %%
hlPE6068L243641_ignitions=hlPE6068L243641[hlPE6068L243641['Events'].str.contains('Ignition')]
hlPE6068L243641_ignitions
# Out:
#     Sequence           Unit       Events                  Date  Landmark  \
# 0         92  PE6068L243641  Ignition ON  Aug 15 2025 02:39 PM       NaN
# 4         88  PE6068L243641  Ignition ON  Aug 13 2025 02:06 AM       NaN
# 86         6  PE6068L243641  Ignition ON  Aug 12 2025 07:40 AM       NaN
# 87         5  PE6068L243641  Ignition ON  Aug 12 2025 07:40 AM       NaN
# 90         2  PE6068L243641  Ignition ON  Aug 12 2025 07:39 AM       NaN
#
#                                               Address  Speed  Temperature  \
# 0   Av Malecon La Amistad-56, El Agustino, Lima, L...      0          NaN
# 4                                                 NaN      0          NaN
# 86  Cl. Los Duraznos-82, San Juan De Lurigancho, L...      0          NaN
# 87  Cl. Los Duraznos-82, San Juan De Lurigancho, L...      0          NaN
# 90  Cl. Los Duraznos-82, San Juan De Lurigancho, L...      0          NaN
#
#     Driver   Latitude  Longitude
# 0      NaN -12.027339 -76.989705
# ...

# %%
hlPE6068L243641['Date'].value_counts(ascending=True)
# Out:
# Date
# Aug 13 2025 02:11 AM    1
# Aug 13 2025 02:09 AM    1
# Aug 12 2025 04:14 PM    1
# Aug 12 2025 04:20 PM    1
# Aug 12 2025 04:08 PM    1
#                        ..
# Aug 12 2025 07:45 AM    2
# Aug 12 2025 07:39 AM    2
# Aug 12 2025 11:43 AM    3
# Aug 12 2025 11:52 AM    3
# Aug 12 2025 07:40 AM    4
# Name: count, Length: 77, dtype: int64

# %%
hlcompresor_af23_08=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/COMPRESOR-AF23.csv',sep=';',encoding='latin1')
hlcompresor_af23_08.info()
hlcompresor_af23_08['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1487 entries, 0 to 1486
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     1487 non-null   int64
#  1   Unit         1487 non-null   object
#  2   Events       1487 non-null   object
#  3   Date         1487 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      1485 non-null   object
#  6   Speed        1487 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     1487 non-null   float64
#  10  Longitude    1487 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 127.9+ KB
# Events
# Drive           662
# Travel Stop     253
# Travel Start    253
# Idle - Stop     248
# Idle Alert       53
# End Speeding      7
# Speed alert       7
# Harsh Turn        2
# POWER UP          1
# Ignition ON       1
# Name: count, dtype: int64

# %%
hlcompresor_ignitions=hlcompresor_af23_08[hlcompresor_af23_08['Events'].str.contains('Ignition')]
hlcompresor_ignitions
# Out:
#    Sequence            Unit       Events                  Date  Landmark  \
# 0      1487  COMPRESOR-AF23  Ignition ON  Aug 21 2025 04:33 PM       NaN
#
#   Address  Speed  Temperature  Driver  Latitude  Longitude
# 0     NaN      0          NaN     NaN -12.48659 -76.733343

# %%
hlcompresor_af23_08.head(2)
# Out:
#    Sequence            Unit       Events                  Date  Landmark  \
# 0      1487  COMPRESOR-AF23  Ignition ON  Aug 21 2025 04:33 PM       NaN
# 1      1486  COMPRESOR-AF23     POWER UP  Aug 21 2025 04:33 PM       NaN
#
#   Address  Speed  Temperature  Driver  Latitude  Longitude
# 0     NaN      0          NaN     NaN -12.48659 -76.733343
# 1     NaN      0          NaN     NaN -12.48659 -76.733343

# %% [markdown]
# hlcompresor_af23,0WXW,4764383400,358077093351829,949115107:
# 55.161, 74b(actualizar) -> SUCCESS 22-08-2025
#
# f3h_841,0YGA,4764383842,358077093175046,940557641
# 55.161, 74b(actualizar) -> SUCCESS 29-08-2025
#
# CFJ-087,S194,4764384498,358077093400527,943549014
# 55.161, 74b -> FAILED

# %% [markdown]
# Nuevo análisis después de actualización de firmware para COMPRESORAF23.

# %%
rdu_29082025=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/Travels_Daily_Summary_Unified.csv')
rdu_29082025.head(5)
# Out:
#   UnitName     DayDate  Decelerations  Accelerations  HarshTurns  \
# 0  CFJ-344  23/08/2025              0              0           0
# 1  CFJ-344  24/08/2025              0              0           0
# 2  CFJ-344  25/08/2025              0              0           0
# 3  CFJ-344  26/08/2025              0              0           0
# 4  CFJ-344  27/08/2025              0              0           0
#
#   DistanceDriven1 DriveTime   OffTime IdleTime Textbox17 MaxSpeed  \
# 0            0,58   0:01:19  23:53:12  0:05:29   0:06:48   35 kph
# 1            0,00   0:00:00  24:00:00  0:00:00   0:00:00    0 kph
# 2            1,14   0:01:35  23:30:11  0:28:14   0:29:49   29 kph
# 3            1,75   0:04:39  23:27:41  0:27:40   0:32:19   29 kph
# 4            3,52   0:05:49  23:41:33  0:12:38   0:18:27   24 kph
#
#     DriverName GroupName
# 0  JOSE MIGUEL  CATASTRO
# 1          NaN  CATASTRO
# 2  JOSE MIGUEL  CATASTRO
# 3  JOSE MIGUEL  CATASTRO
# 4  JOSE MIGUEL  CATASTRO

# %%
rdu_29082025_COMPRESORAF23=rdu_29082025[rdu_29082025['UnitName'].str.contains('COMPRESOR-AF23')]
rdu_29082025_COMPRESORAF23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 287 to 293
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UnitName         7 non-null      object
#  1   DayDate          7 non-null      object
#  2   Decelerations    7 non-null      int64
#  3   Accelerations    7 non-null      int64
#  4   HarshTurns       7 non-null      int64
#  5   DistanceDriven1  7 non-null      object
#  6   DriveTime        7 non-null      object
#  7   OffTime          7 non-null      object
#  8   IdleTime         7 non-null      object
#  9   Textbox17        7 non-null      object
#  10  MaxSpeed         7 non-null      object
#  11  DriverName       0 non-null      object
#  12  GroupName        0 non-null      object
# dtypes: int64(3), object(10)
# memory usage: 784.0+ bytes

# %%
rdu_29082025_COMPRESORAF23_off=rdu_29082025_COMPRESORAF23[rdu_29082025_COMPRESORAF23['OffTime'].str.contains('-')]
rdu_29082025_COMPRESORAF23_off
# Out:
# Empty DataFrame
# Columns: [UnitName, DayDate, Decelerations, Accelerations, HarshTurns, DistanceDriven1, DriveTime, OffTime, IdleTime, Textbox17, MaxSpeed, DriverName, GroupName]
# Index: []

# %%
hlcompresor_af23_29082025=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/historicallocationsCompresorAF232908.csv',sep=';',encoding='latin1')
hlcompresor_af23_29082025['Events'].value_counts()
# Out:
# Events
# Drive           216
# Travel Stop     116
# Travel Start    116
# Idle - Stop      85
# Idle Alert       21
# End Speeding     20
# Speed alert      20
# Geofence IN       1
# Name: count, dtype: int64

# %% [markdown]
# Nuevo análisis después de la actualización del firmware f3h_841, después de 29-08-2025.

# %%
rdu_f3h_841=rdu_29082025[rdu_29082025['UnitName'].str.contains('F3H-841')]
rdu_f3h_841.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 336 to 342
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UnitName         7 non-null      object
#  1   DayDate          7 non-null      object
#  2   Decelerations    7 non-null      int64
#  3   Accelerations    7 non-null      int64
#  4   HarshTurns       7 non-null      int64
#  5   DistanceDriven1  7 non-null      object
#  6   DriveTime        7 non-null      object
#  7   OffTime          7 non-null      object
#  8   IdleTime         7 non-null      object
#  9   Textbox17        7 non-null      object
#  10  MaxSpeed         7 non-null      object
#  11  DriverName       0 non-null      object
#  12  GroupName        0 non-null      object
# dtypes: int64(3), object(10)
# memory usage: 784.0+ bytes

# %%
rdu_f3h_841_off=rdu_f3h_841[rdu_f3h_841['OffTime'].str.contains('-')]
rdu_f3h_841_off
# Out:
# Empty DataFrame
# Columns: [UnitName, DayDate, Decelerations, Accelerations, HarshTurns, DistanceDriven1, DriveTime, OffTime, IdleTime, Textbox17, MaxSpeed, DriverName, GroupName]
# Index: []

# %%
hlf3h_841=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/hlf3h_841_29082025.csv',sep=';',encoding='latin1')
hlf3h_841['Events'].value_counts()
# Out:
# Events
# Drive           90
# Travel Start    36
# Travel Stop     34
# Idle - Stop     17
# Idle Alert       5
# Landmark OUT     3
# POWER UP         2
# Ignition ON      2
# End Speeding     1
# Speed alert      1
# Name: count, dtype: int64

# %%
hlf3h_841_ignitions=hlf3h_841[hlf3h_841['Events'].str.contains('Ignition')]
hlf3h_841_ignitions
# Out:
#      Sequence     Unit       Events                  Date Landmark  \
# 141        50  F3H-841  Ignition ON  Aug 29 2025 06:55 AM      NaN
# 189         2  F3H-841  Ignition ON  Aug 29 2025 05:55 AM      NaN
#
#             Address  Speed  Temperature  Driver  Latitude  Longitude
# 141  Gulf of Guinea      0          NaN     NaN       0.0        0.0
# 189  Gulf of Guinea      0          NaN     NaN       0.0        0.0

# %%
hlf3h_841_2908_5=hlf3h_841[hlf3h_841['Date'].str.contains('Aug 29 2025 05:5')]
hlf3h_841_2908_5
# Out:
#      Sequence     Unit        Events                  Date       Landmark  \
# 187         4  F3H-841  Landmark OUT  Aug 29 2025 05:58 AM  QUAVII AVANCE
# 188         3  F3H-841   Idle - Stop  Aug 29 2025 05:58 AM  QUAVII AVANCE
# 189         2  F3H-841   Ignition ON  Aug 29 2025 05:55 AM            NaN
# 190         1  F3H-841      POWER UP  Aug 29 2025 05:54 AM            NaN
#
#                                                Address  Speed  Temperature  \
# 187  La Union-85, Villa Maria Del Triunfo, Lima, Li...      0          NaN
# 188  La Union-85, Villa Maria Del Triunfo, Lima, Li...      0          NaN
# 189                                     Gulf of Guinea      0          NaN
# 190                                     Gulf of Guinea      0          NaN
#
#      Driver   Latitude  Longitude
# 187     NaN -12.172042   -76.9441
# 188     NaN -12.172042   -76.9441
# 189     NaN   0.000000     0.0000
# 190     NaN   0.000000     0.0000

# %%
hlf3h_841_2908_6=hlf3h_841[hlf3h_841['Date'].str.contains('Aug 29 2025 06:')]
hlf3h_841_2908_6
# Out:
#      Sequence     Unit        Events                  Date       Landmark  \
# 137        54  F3H-841         Drive  Aug 29 2025 06:59 AM            NaN
# 138        53  F3H-841         Drive  Aug 29 2025 06:57 AM            NaN
# 139        52  F3H-841  Landmark OUT  Aug 29 2025 06:55 AM  QUAVII AVANCE
# 140        51  F3H-841  Travel Start  Aug 29 2025 06:55 AM  QUAVII AVANCE
# 141        50  F3H-841   Ignition ON  Aug 29 2025 06:55 AM            NaN
# 142        49  F3H-841      POWER UP  Aug 29 2025 06:55 AM            NaN
# 143        48  F3H-841         Drive  Aug 29 2025 06:52 AM            NaN
# 144        47  F3H-841  Travel Start  Aug 29 2025 06:50 AM            NaN
# 145        46  F3H-841   Travel Stop  Aug 29 2025 06:50 AM            NaN
# 146        45  F3H-841         Drive  Aug 29 2025 06:48 AM            NaN
# 147        44  F3H-841         Drive  Aug 29 2025 06:47 AM            NaN
# 148        43  F3H-841         Drive  Aug 29 2025 06:45 AM            NaN
# ...

# %% [markdown]
# ## Hidrosant

# %%
hidrosant=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/hidrosant_Engine Runtime Report.csv')
hidrosant.rename(columns={'Textbox8':'Address','textbox32':'Time1'},inplace=True)
hidrosant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GroupName         0 non-null      float64
#  1   UnitName          273 non-null    object
#  2   StartTime         273 non-null    object
#  3   Address           273 non-null    object
#  4   StopTime          273 non-null    object
#  5   StopLengthSecs    273 non-null    object
#  6   ContactName       273 non-null    object
#  7   Time1             273 non-null    object
#  8   StopLengthSecs_1  273 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 19.3+ KB

# %%
hidrosant['Time1'].value_counts()
# Out:
# Time1
# 39h:21m:36s    273
# Name: count, dtype: int64

# %%
hidrosant_negatives=hidrosant[hidrosant['StopLengthSecs'].str.contains('-')]
hidrosant_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
hidrosant_negatives=hidrosant[hidrosant['StopLengthSecs_1'].str.contains('-')]
hidrosant_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
hidrosant_negatives=hidrosant[hidrosant['Time1'].str.contains('-')]
hidrosant_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
hidrosant_06=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/hidrosan_Travels_Daily_Summary_Unified_06.csv')
hidrosant_offtime_06=hidrosant_06[hidrosant_06['OffTime'].str.contains('-')]
hidrosant_offtime_06
# Out:
# Empty DataFrame
# Columns: [UnitName, DayDate, Decelerations, Accelerations, HarshTurns, DistanceDriven1, DriveTime, OffTime, IdleTime, Textbox17, MaxSpeed, DriverName, GroupName]
# Index: []

# %%
hidrosant_unified=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/hidrosant_Travels_Daily_Summary_Unified.csv')
hidrosant_unified
# Out:
#              UnitName     DayDate  Decelerations  Accelerations  HarshTurns  \
# 0   HBZN580NKLAH21750   1/08/2025              0              0           0
# 1   HBZN580NKLAH21750   2/08/2025              0              0           0
# 2   HBZN580NKLAH21750   3/08/2025              0              0           0
# 3   HBZN580NKLAH21750   4/08/2025              0              0           0
# 4   HBZN580NKLAH21750   5/08/2025              0              0           0
# 5   HBZN580NKLAH21750   6/08/2025              0              0           0
# 6   HBZN580NKLAH21750   7/08/2025              0              0           0
# 7   HBZN580NKLAH21750   8/08/2025              0              0           0
# 8   HBZN580NKLAH21750   9/08/2025              0              0           0
# 9   HBZN580NKLAH21750  10/08/2025              0              0           0
# 10  HBZN580NKLAH21750  11/08/2025              0              0           0
#
# ...

# %% [markdown]
# # Análisis después de la corrección

# %%
hlHBZN580NKLAH21750=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/HBZN580NKLAH21750.csv',sep=';',encoding='latin1')
hlHBZN580NKLAH21750.info()
hlHBZN580NKLAH21750['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     745 non-null    int64
#  1   Unit         745 non-null    object
#  2   Events       745 non-null    object
#  3   Date         745 non-null    object
#  4   Landmark     431 non-null    object
#  5   Address      745 non-null    object
#  6   Speed        745 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     745 non-null    float64
#  10  Longitude    745 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 64.2+ KB
# Events
# Parked          191
# Landmark IN      88
# Landmark OUT     84
# APAGADO          82
# ENCENDIDO        82
# Idle - Stop      80
# Idle Alert       63
# Drive            57
# Travel Stop       9
# Travel Start      9
# Name: count, dtype: int64

# %%
hlHBZN580NKLAH21750_ignitions=hlHBZN580NKLAH21750[hlHBZN580NKLAH21750['Events'].str.contains('ENCENDIDO')]
hlHBZN580NKLAH21750_ignitions

# %%
Engine_report_HBZN580NKLAH21750=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/Engine Runtime Report_HBZN580NKLAH21750.csv')
Engine_report_HBZN580NKLAH21750.rename(columns={'Textbox8':'Address','textbox32':'Time1'},inplace=True)
Engine_report_HBZN580NKLAH21750.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GroupName         0 non-null      float64
#  1   UnitName          82 non-null     object
#  2   StartTime         82 non-null     object
#  3   Address           82 non-null     object
#  4   StopTime          82 non-null     object
#  5   StopLengthSecs    82 non-null     object
#  6   ContactName       82 non-null     object
#  7   Time1             82 non-null     object
#  8   StopLengthSecs_1  82 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 5.9+ KB

# %%
Engine_report_HBZN580NKLAH21750_n=Engine_report_HBZN580NKLAH21750[Engine_report_HBZN580NKLAH21750['StartTime'].str.contains('-')]
Engine_report_HBZN580NKLAH21750_n
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
Engine_report_HBZN580NKLAH21750_n=Engine_report_HBZN580NKLAH21750[Engine_report_HBZN580NKLAH21750['StopLengthSecs'].str.contains('-')]
Engine_report_HBZN580NKLAH21750_n
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
Engine_report_HBZN580NKLAH21750_n=Engine_report_HBZN580NKLAH21750[Engine_report_HBZN580NKLAH21750['StopLengthSecs_1'].str.contains('-')]
Engine_report_HBZN580NKLAH21750_n
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
Engine_report_HBZN580NKLAH21750_n=Engine_report_HBZN580NKLAH21750[Engine_report_HBZN580NKLAH21750['Time1'].str.contains('-')]
Engine_report_HBZN580NKLAH21750_n
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
Engine_report_HBZN580NKLAH21750_n=Engine_report_HBZN580NKLAH21750[Engine_report_HBZN580NKLAH21750['StopTime'].str.contains('-')]
Engine_report_HBZN580NKLAH21750_n
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %% [markdown]
# ## Toyama

# %% [markdown]
# Este cliente no tiene el módulo de reportes actualizado.

# %%
toyama=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/toyama_Engine Runtime Report.csv')
toyama.rename(columns={'Textbox8':'Address','textbox32':'Time1'},inplace=True)
toyama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GroupName         0 non-null      float64
#  1   UnitName          34 non-null     object
#  2   StartTime         34 non-null     object
#  3   Address           34 non-null     object
#  4   StopTime          34 non-null     object
#  5   StopLengthSecs    34 non-null     object
#  6   ContactName       34 non-null     object
#  7   Time1             34 non-null     object
#  8   StopLengthSecs_1  34 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 2.5+ KB

# %%
toyama_negatives=toyama[toyama['StopLengthSecs'].str.contains('-')]
toyama_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
toyama_negatives=toyama[toyama['StopLengthSecs'].str.contains('-')]
toyama_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %% [markdown]
# # Análisis después de corrección

# %%
hlHITACHI=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/hlHITACHI 4848.csv',sep=';',encoding='latin1')
hlHITACHI.info()
hlHITACHI['Events'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7209 entries, 0 to 7208
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     7209 non-null   int64
#  1   Unit         7209 non-null   object
#  2   Events       7209 non-null   object
#  3   Date         7209 non-null   object
#  4   Landmark     0 non-null      float64
#  5   Address      7209 non-null   object
#  6   Speed        7209 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     7209 non-null   float64
#  10  Longitude    7209 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 619.7+ KB
# Events
# Idle - Stop                     5525
# Parked                           897
# Ping                             142
# POWER UP                         141
# Power OFF                        141
# Self Test/Reboot                 141
# ...

# %%
Engine_report_toyama=pd.read_csv('/home/jlhb1984/py-projects/data/motor_hours/Engine Runtime Report HITACHI 4848.csv')
Engine_report_toyama.rename(columns={'Textbox8':'Address','textbox32':'Time1'},inplace=True)
Engine_report_toyama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GroupName         0 non-null      float64
#  1   UnitName          57 non-null     object
#  2   StartTime         57 non-null     object
#  3   Address           57 non-null     object
#  4   StopTime          57 non-null     object
#  5   StopLengthSecs    57 non-null     object
#  6   ContactName       57 non-null     object
#  7   Time1             57 non-null     object
#  8   StopLengthSecs_1  57 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 4.1+ KB

# %%
Engine_report_toyama_negatives=Engine_report_toyama[Engine_report_toyama['StartTime'].str.contains('-')]
Engine_report_toyama_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
Engine_report_toyama_negatives=Engine_report_toyama[Engine_report_toyama['StopLengthSecs'].str.contains('-')]
Engine_report_toyama_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
Engine_report_toyama_negatives=Engine_report_toyama[Engine_report_toyama['StopLengthSecs_1'].str.contains('-')]
Engine_report_toyama_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
Engine_report_toyama_negatives=Engine_report_toyama[Engine_report_toyama['StopTime'].str.contains('-')]
Engine_report_toyama_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []

# %%
Engine_report_toyama_negatives=Engine_report_toyama[Engine_report_toyama['Time1'].str.contains('-')]
Engine_report_toyama_negatives
# Out:
# Empty DataFrame
# Columns: [GroupName, UnitName, StartTime, Address, StopTime, StopLengthSecs, ContactName, Time1, StopLengthSecs_1]
# Index: []
